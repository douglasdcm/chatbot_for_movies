# %% [markdown]
# ## A intenção do projeto é criar um chatbot baseado em reviews de filmes para que se possa fazer perguntas e manter uma conversa livre sobre este tema
#
# - link do banco de dados https://www.kaggle.com/Cornell-University/movie-dialog-corpus?select=movie_lines.tsv
# - referências
# >- https://shanebarker.com/blog/deep-learning-chatbot/
# > -https://towardsdatascience.com/how-to-create-a-chatbot-with-python-deep-learning-in-less-than-an-hour-56a063bdfc44

# %%
import string
import nltk
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import pandas as pd
import re
import gensim
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from scipy.spatial import distance
from sklearn.model_selection import train_test_split
import math
import random
# Out:
# [nltk_data] Downloading package wordnet to /home/douglas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Opening movie reviews

# %%
messages = pd.read_csv('./chatdata/movie_lines_normalized.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
messages.columns = ['msg_line', 'user_id', 'movie_id', 'msg']

# %%
messages.head(10)
# Out:
#   msg_line user_id movie_id                                                msg
# 0    L1045      u0       m0                                       They do not!
# 1    L1044      u2       m0                                        They do to!
# 2     L985      u0       m0                                         I hope so.
# 3     L984      u2       m0                                          She okay?
# 4     L925      u0       m0                                          Let's go.
# 5     L924      u2       m0                                                Wow
# 6     L872      u0       m0     Okay -- you're gonna need to learn how to lie.
# 7     L871      u2       m0                                                 No
# 8     L870      u0       m0  """I'm kidding. You know how sometimes you jus...
# 9     L869      u0       m0                   Like my fear of wearing pastels?

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304713 entries, 0 to 304712
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   msg_line  304713 non-null  object
#  1   user_id   304713 non-null  object
#  2   movie_id  304713 non-null  object
#  3   msg       304713 non-null  object
# dtypes: object(4)
# memory usage: 9.3+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id     msg
# count    304713  304713   304713  304713
# unique   304713    9035      659  265277
# top     L168013   u4525     m289   What?
# freq          1     537     1530    1679

# %% [markdown]
# ### Cleaning the msg_line of the conversations

# %%
#remove charactes
def remove_char(txt):
    return re.sub('[^0-9]','', txt)

# %%
#leaving just the number of the index, so L872 changes to 872
messages['msg_line_clean'] = [remove_char(msg) for msg in messages['msg_line']]

# %%
#change the column type to number
messages['msg_line_clean'] = pd.to_numeric(messages['msg_line_clean'])

# %%
messages = messages.sort_values(by=['msg_line_clean'])

# %%
#set the column as the index
messages = messages.set_index('msg_line_clean')

# %%
messages.head(10)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
#
#                                                               msg
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.

# %% [markdown]
# ### Opening conversation sequence

# %%
#read the file with the conversation sequence
conv_seq = pd.read_csv('./chatdata/movie_conversations.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
conv_seq.columns = ['user1_id', 'user2_id', 'movie_id', 'sequence']

# %%
conv_seq.head(10)
# Out:
#   user1_id user2_id movie_id                              sequence
# 0       u0       u2       m0         ['L194' 'L195' 'L196' 'L197']
# 1       u0       u2       m0                       ['L198' 'L199']
# 2       u0       u2       m0         ['L200' 'L201' 'L202' 'L203']
# 3       u0       u2       m0                ['L204' 'L205' 'L206']
# 4       u0       u2       m0                       ['L207' 'L208']
# 5       u0       u2       m0  ['L271' 'L272' 'L273' 'L274' 'L275']
# 6       u0       u2       m0                       ['L276' 'L277']
# 7       u0       u2       m0                       ['L280' 'L281']
# 8       u0       u2       m0                       ['L363' 'L364']
# 9       u0       u2       m0                       ['L365' 'L366']

# %%
conv_seq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83097 entries, 0 to 83096
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user1_id  83097 non-null  object
#  1   user2_id  83097 non-null  object
#  2   movie_id  83097 non-null  object
#  3   sequence  83097 non-null  object
# dtypes: object(4)
# memory usage: 2.5+ MB

# %%
conv_seq.describe()
# Out:
#        user1_id user2_id movie_id               sequence
# count     83097    83097    83097                  83097
# unique     5420     5608      617                  83097
# top       u4331    u1475     m289  ['L342896' 'L342897']
# freq        193      187      338                      1

# %% [markdown]
# ### Build conversation sequence

# %%
def split_conversation(txt):
    txt_alt = txt.split(' ')
    return txt_alt

# %%
def seq_to_list(seq):
    seq_list = [remove_char(s) for s in seq]
    return seq_list

# %%
#initializing the msg_2 column
messages['msg_2'] = '-'

# %%
def link_conversations(seq_list, df, filter1, filter2):
    i = 0
    while i in range(len(seq_list)):
        if i+1 < len(seq_list):
            next_msg = df.loc[int(seq_list[i+1]), filter1]
            df.at[int(seq_list[i]), filter2] = next_msg
        i+=1

# %%
#link each message with its answer
for conv in conv_seq['sequence']:
    #split each sequence by space
    seq = split_conversation(conv)

    #remove the char L from the sequences
    txt_alt = [remove_char(s) for s in seq]

    #use the conversation sequence to build the target answer for each message
    link_conversations(txt_alt, messages, 'msg', 'msg_2')

# %%
messages.head(30)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
# 78                  L78      u7       m0
# 87                  L87      u2       m0
# 88                  L88      u7       m0
# 89                  L89      u2       m0
# 90                  L90      u7       m0
# 91                  L91      u2       m0
# 92                  L92      u7       m0
# 103                L103      u8       m0
# 104                L104      u5       m0
# 105                L105      u8       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 89                                                    Who is she?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 91                                                       Why not?
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...
#
#                                                             msg_2
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                                              -
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                                              -
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                                              -
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                                              -
# 77              Yeah but these guys have never seen a horse. T...
# 78                                                              -
# 87                                  You burn you pine you perish?
# 88                                                    Who is she?
# 89              Bianca Stratford. Sophomore. Don't even think ...
# 90                                                       Why not?
# 91              I could start with your haircut but it doesn't...
# 92                                                              -
# 103              Expressing my opinion is not a terrorist action.
# 104             Well yes compared to your other choices of exp...
# 105             I still maintain that he kicked himself in the...

# %% [markdown]
# ## Pre processing the msg

# %%
data = messages['msg']

# %%
lemmatizer = WordNetLemmatizer()
def pre_processing_text(corpus):   
    #remove duplicated spaces
    corpus = re.sub(r' +', ' ', corpus)
    
    #capitalization
    corpus = corpus.lower()
    
    #tokenization
    corpus = re.findall(r"\w+(?:'\w+)?|[^\w\s]", corpus)
    
    #lammatization
    corpus = [lemmatizer.lemmatize(c) for c in corpus]
    
    #remove punctuation
    corpus = [t for t in corpus if t not in string.punctuation]
    
    #remove stopwords
    #it makes the model worst
    #stopwords_ = stopwords.words("english")
    #corpus = [t for t in corpus if t not in stopwords_]
    
    corpus = ' '.join(corpus)

    return corpus

# %%
# %%time
data_pre_processed = [pre_processing_text(m) for m in data]
data_pre_processed
# Out:
# CPU times: user 21.8 s, sys: 1.34 s, total: 23.2 s
# Wall time: 23.4 s
# ['did you change your hair',
#  'no',
#  'you might wanna think about it',
#  'i missed you',
#  'it say here you exposed yourself to a group of freshman girl',
#  'it wa a bratwurst i wa eating lunch',
#  'with the teeth of your zipper',
#  'you the new guy',
#  'so they tell me',
#  "c'mon i'm supposed to give you the tour",
#  'so which dakota you from',
#  "north actually how'd you",
#  'i wa kidding people actually live there',
#  "yeah a couple we're outnumbered by the cow though",
#  'how many people were in your old school',
#  'thirty two',
#  'get out',
#  'how many people go here',
#  'couple thousand most of them evil',
#  "that i'm used to",
#  'yeah but these guy have never seen a horse they just jack off to clint eastwood',
#  'that girl i',
#  'you burn you pine you perish',
#  'who is she',
#  "bianca stratford sophomore don't even think about it",
#  'why not',
#  "i could start with your haircut but it doesn't matter she's not allowed to date until her older sister doe and that's an impossibility",
#  "katarina stratford my my you've been terrorizing m blaise again",
#  'expressing my opinion is not a terrorist action',
#  "well yes compared to your other choice of expression this year today's event are quite mild by the way bobby rictor's gonad retrieval operation went quite well in case you're interested",
#  'i still maintain that he kicked himself in the ball i wa merely a spectator',
#  'the point is kat people perceive you a somewhat',
#  'tempestuous',
#  'no i believe heinous bitch is the term used most often',
#  "who's that",
#  'patrick verona random skid',
#  "that's pat verona the one who wa gone for a year i heard he wa doing porn movie",
#  "i'm sure he's completely incapable of doing anything that interesting",
#  'he always look so',
#  'block e',
#  'mandella eat starving yourself is a very slow way to die',
#  'just a little',
#  "what's this",
#  'an attempted slit',
#  "i realize that the men of this fine institution are severely lacking but killing yourself so you can be with william shakespeare is beyond the scope of normal teenage obsession you're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy",
#  "but imagine the thing he'd say during sex",
#  'why do girl like that always like guy like that',
#  "because they're bred to their mother liked guy like that and their grandmother before them their gene pool is rarely diluted",
#  'he always have that shit eating grin',
#  "joey dorsey perma shit grin i wish i could say he's a moron but he's number twelve in the class and a model mostly regional stuff but he's rumored to have a big tube sock ad coming out",
#  'you know french',
#  "sure do my mom's from canada",
#  'guess who just signed up for a tutor',
#  "you mean i'd get a chance to talk to her",
#  'you could consecrate with her my friend',
#  "the vintage look is over kat haven't you been reading your sassy",
#  'yeah and i noticed the only part of you featured in your big kmart spread wa your elbow tough break',
#  "they're running the rest of me next month",
#  'the people at this school are so incredibly foul',
#  "you could always go with me i'm sure william ha some friend",
#  'yeah just a minor encounter with the shrew',
#  "that's her bianca's sister",
#  'the mewling rampalian wretch herself',
#  'in the microwave',
#  'make anyone cry today',
#  "where've you been",
#  'nowhere hi daddy',
#  "what's a synonym for throbbing",
#  'sarah lawrence is on the other side of the country',
#  'i know',
#  'i thought we decided you were going to school here at u of 0',
#  'you decided',
#  "now don't get upset daddy but there's this boy and i think he might ask",
#  "no you're not dating until your sister start dating end of discussion",
#  'what if she never start dating',
#  "then neither will you and i'll get to sleep at night",
#  "but it's not fair she's a mutant daddy",
#  'this from someone whose diary is devoted to favorite grooming tip',
#  'enough',
#  "but she doesn't want to date",
#  'exactly my point',
#  'jesus can a man even grab a sandwich before you woman start dilating',
#  'tumescent',
#  "you're not helping",
#  'can we make this quick roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad again',
#  "well i thought we'd start with pronunciation if that's okay with you",
#  'not the hacking and gagging and spitting part please',
#  'okay then how bout we try out some french cuisine saturday night',
#  "you're asking me out that's so cute what's your name again",
#  'forget it',
#  "no no it's my fault we didn't have a proper introduction",
#  'cameron',
#  "the thing is cameron i'm at the mercy of a particularly hideous breed of loser my sister i can't date until she doe",
#  'seems like she could get a date easy enough',
#  'why',
#  'unsolved mystery she used to be really popular when she started high school then it wa just like she got sick of it or something',
#  "that's a shame",
#  'gosh if only we could find kat a boyfriend',
#  'let me see what i can do',
#  'i teach her french get to know her dazzle her with charm and she fall in love with me',
#  "unlikely but even so she still can't go out with you so what's the point",
#  'what about him',
#  'you wanna go out with him',
#  "what make you think he'll do it",
#  'he seems like he thrives on danger',
#  "no kidding he's a criminal i heard he lit a state trooper on fire he just got out of alcatraz",
#  'they always let felon sit in on honor biology',
#  "i'm serious man he's whacked he sold his own liver on the black market so he could buy new speaker",
#  "forget his reputation do you think we've got a plan or not",
#  "did she actually say she'd go out with you",
#  "that's what i just said",
#  "you know if you do go out with bianca you'd be set you'd outrank everyone strictly a list with me by your side",
#  'i thought you hated those people',
#  "hey i've gotta have a few client when i get to wall street",
#  'hey',
#  'are you lost',
#  'nope just came by to chat',
#  "we don't chat",
#  "well actually i thought i'd run an idea by you you know just to see if you're interested",
#  "we're not",
#  "but she can't go out with you because her sister is this insane head case and no one will go out with her right",
#  'doe this conversation have a purpose',
#  "so what you need to do is recruit a guy who'll go out with her someone who's up for the job",
#  'you got him involved',
#  "like we had a choice besides when you let the enemy think he's orchestrating the battle you're in a position of power we let him pretend he's calling the shot and while he's busy setting up the plan you have time to woo bianca",
#  'so he ha this huge raging fit about sarah lawrence and insists that i go to his male dominated puking frat boy number one golf team school i have no say at all',
#  'william would never have gone to a state school',
#  "william didn't even go to high school",
#  "that's never been proven",
#  'neither ha his heterosexuality',
#  "i appreciate your effort toward a speedy death but i'm consuming do you mind",
#  'doe it matter',
#  "if i wa bianca it would be any school you want precious don't forget your tiara",
#  "i don't understand patrick you haven't done anything asinine this week are you not feeling well",
#  'touch of the flu',
#  "i'm at a loss then what should we talk about your year of absence",
#  "why don't we discus your driving need to be a hemorrhoid",
#  "what's to discus",
#  "you weren't abused you aren't stupid and a far a i can tell you're only slightly psychotic so why is it that you're such a fuck up",
#  "well you know there's the prestige of the job title and the benefit package is pretty good",
#  "c'esc ma tete this is my head",
#  "right see you're ready for the quiz",
#  "i don't want to know how to say that though i want to know useful thing like where the good store are how much doe champagne cost stuff like chat i have never in my life had to point out my head to someone",
#  "that's because it's such a nice one",
#  'forget french',
#  'how is our little find the wench a date plan progressing',
#  "well there's someone i think might be",
#  'there',
#  'where',
#  'yeah',
#  'what do you think',
#  'two leg nice rack',
#  'yeah whatever i want you to go out with her',
#  "sure sparky i'll get right on it",
#  'you just said',
#  'you need money to take a girl out',
#  "but you'd go out with her if you had the cake",
#  'you got it verona i pick up the tab you do the honor',
#  "you're gonna pay me to take out some girl",
#  "i can't date her sister until that one get a boyfriend and that's the catch she doesn't want a boyfriend",
#  'how much',
#  "i can't take a girl like that out on twenty buck",
#  'fine thirty',
#  "take it or leave it this isn't a negotiation",
#  "fifty and you've got your man",
#  'i mean wo man how ya doin',
#  'sweating like a pig actually and yourself',
#  "there's a way to get a guy's attention",
#  'my mission in life',
#  'pick you up friday then',
#  'oh right friday',
#  "the night i take you to place you've never been before and back",
#  'like where the 7 eleven on burnside do you even know my name screwboy',
#  'i know a lot more than that',
#  "i have the potential to smack the crap out of you if you don't get out of my way",
#  'can you at least start wearing a bra',
#  "you hate me don't you",
#  "i don't really think you warrant that strong an emotion",
#  "then say you'll spend dollar night at the track with me",
#  'and why would i do that',
#  'come on the pony the flat beer you with money in your eye me with my hand on your as',
#  'you covered in my vomit',
#  'seven thirty',
#  'are you following me',
#  "i wa in the laundromat i saw your car thought i'd say hi",
#  'hi',
#  "you're not a big talker are you",
#  "depends on the topic my fender don't really whip me into a verbal frenzy",
#  'hey do you mind',
#  'not at all',
#  'my insurance doe not cover pm',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  "why can't we agree on this",
#  "because you're making decision for me",
#  "a a parent that's my right",
#  "so what i want doesn't matter",
#  "you're eighteen you don't know what you want you won't know until you're forty five and you don't have it",
#  'i want to go to an east coast school i want you to trust me to make my own choice i want',
#  'when i shell out fifty i expect result',
#  "i'm on it",
#  "watching the bitch trash my car doesn't count a a date",
#  'i got her under control she just act crazed in public to keep up the image',
#  'i just upped my price',
#  'what',
#  'a hundred buck a date',
#  'forget it',
#  'forget her sister then',
#  'you got something on your mind',
#  "i counted on you to help my cause you and that thug are obviously failing aren't we ever going on our date",
#  'you have my word a a gentleman',
#  "you're sweet",
#  'how do you get your hair to look like that',
#  "eber's deep conditioner every two day and i never ever use a blowdryer without the diffuser attachment",
#  'say it',
#  'what',
#  "whatever the hell it is you're standin there waitin to say",
#  'what plan',
#  'the situation is my man cameron here ha a major jones for bianca stratford',
#  'what is it with this chick she have three tit',
#  "i think i speak correctly when i say that cameron's love is pure purer than say joey dorsey's",
#  "dorsey can plow whoever he want i'm just in this for the cash",
#  "that's where we can help you with kat",
#  'so dorsey can get the girl',
#  "patrick pat you're not looking at the big picture joey's just a pawn we set this whole thing up so cameron can get the girl",
#  'you two are gonna help me tame the wild beast',
#  "we're your guy",
#  'and he mean that strictly in a non prison movie type of way',
#  "yeah we'll see",
#  'this is it a golden opportunity patrick can ask katarina to the party',
#  "in that case we'll need to make it a school wide blow out",
#  'will bogey get bent',
#  "are you kidding he'll piss himself with joy he's the ultimate kiss as",
#  "it's more",
#  'expensive',
#  "exactly so you going to bogey lowenbrau's thing on saturday",
#  'hopefully',
#  'sure have',
#  "i really really really wanna go but i can't not unless my sister go",
#  "i'm workin on it but she doesn't seem to be goin for him",
#  "she's not a",
#  "lesbian no i found a picture of jared leto in one of her drawer so i'm pretty sure she's not harboring same sex tendency",
#  "so that's the kind of guy she like pretty one",
#  "who know all i've ever heard her say is that she'd dip before dating a guy that smoke",
#  "what've you got for me",
#  "i've retrieved certain piece of information on miss katarina stratford i think you'll find helpful",
#  'what',
#  'good enough',
#  'number one she hate smoker',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'dead at forty one',
#  "are you telling me i'm a non smoker",
#  'just for now',
#  "he's pretty",
#  "okay i wasn't sure",
#  'okay like thai food feminist prose and angry stinky girl music of the indie rock persuasion',
#  "so what doe that give me i'm supposed to buy her some noodle and a book and sit around listening to chick who can't play their instrument",
#  'ever been to club skunk',
#  'yeah',
#  'gigglepuss is playing there tomorrow night',
#  "don't make me do it man",
#  'assail your ear for one night',
#  "it's her favorite band",
#  'i prefer to think of it simply a an alternative to what the law allows',
#  "i'm likin you guy better",
#  "oh my god doe this mean you're becoming normal",
#  "it mean that gigglepuss is playing at club skunk and we're going",
#  "oh i thought you might have a date i don't know why i'm bothering to ask but are you going to bogey lowenstein's party saturday night",
#  'what do you think',
#  "i think you're a freak i think you do this to torture me and i think you suck",
#  "you think this'll work",
#  'no fear',
#  'always a pleasure brucie',
#  "didn't have you pegged for a gigglepuss fan aren't they a little too pre teen belly button ring for you",
#  'fan of a fan you see a couple of minor come in',
#  'never',
#  'padua girl one tall decent body the other one kinda short and undersexed',
#  'just sent em through',
#  'hey great show huh',
#  'unknown',
#  'excuse me',
#  "that's what you want isn't it",
#  "do you mind you're sort of ruining it for me",
#  "you know these guy are no bikini kill or the raincoat but they're right up there",
#  'you know who the raincoat are',
#  "why don't you",
#  "what'd he say",
#  'who care',
#  'you told me that part already',
#  "hell i've just been going over the whole thing in my head and",
#  "i hear you're helpin verona",
#  "uh yeah we're old friend",
#  'you and verona',
#  'what we took bathe together when we were kid',
#  "you better not fuck this up i'm heavily invested",
#  "hey it's all for the higher good right",
#  "you're completely demented",
#  'see you next week',
#  'daddy i',
#  "and where're you going",
#  'if you must know we were attempting to go to a small study group of friend',
#  'otherwise known a an orgy',
#  "it's just a party daddy but i knew you'd forbid me to go since gloria steinem over there isn't going",
#  'daddy people expect me to be there',
#  "if kat's not going you're not going",
#  "you're ruining my life because you won't be normal i can't be normal",
#  "what's normal",
#  "bogey lowenstein's party is normal but you're too busy listening to bitch who need prozac to know that",
#  "can't you forget for just one night that you're completely wretched",
#  "at least i'm not a clouted fen sucked hedge pig",
#  "like i'm supposed to know what that even mean",
#  "it's shakespeare maybe you've heard of him",
#  "yeah he's your freak friend mandella's boyfriend i guess since i'm not allowed to go out i should ob over a dead guy too",
#  "oh god it's starting",
#  "it's just a party daddy",
#  'wear the belly before you go',
#  'daddy no',
#  'just for a minute',
#  'you are so completely unbalanced',
#  'can we go now',
#  "promise me you won't talk to any boy unless your sister is present",
#  'why',
#  "because she'll scare them away",
#  'where ya goin',
#  'away',
#  'your sister here',
#  'leave my sister alone',
#  'and why would i do that',
#  "what's this",
#  "i'm getting trashed man isn't that what you're supposed to do at a party",
#  'i say do what you wanna do',
#  "funny you're the only one",
#  'where did he go he wa just here',
#  'who',
#  'joey',
#  'hi',
#  'look like thing worked out tonight huh',
#  'you know chastity',
#  'i believe we share an art instructor',
#  'great',
#  'would you mind getting me a drink cameron',
#  'extremely unfortunate maneuver',
#  "the hell is that what kind of guy just pick up a girl and carry her away while you're talking to her",
#  "buttholus extremus but hey you're making progress",
#  'no i m not',
#  "so yeah i've got the sears catalog thing going and the tube sock gig that's gonna be huge and then i'm up for an ad for queen harry next week",
#  'queen harry',
#  "it's a gay cruise line but i'll be like wearing a uniform and stuff",
#  'neat',
#  "my agent say i've got a good shot at being the prada guy next year",
#  "he practically proposed when he found out we had the same dermatologist i mean dr bonchowski is great an all but he's not exactly relevant party conversation",
#  'is he oily or dry',
#  "combination i don't know i thought he'd be different more of a gentleman",
#  "bianca i don't think the highlight of dating joey dorsey are going to include door opening and coat holding",
#  "sometimes i wonder if the guy we're supposed to want to go out with are the one we actually want to go out with you know",
#  "all i know is i'd give up my private line to go out with a guy like joey",
#  'bianca i need to talk to you i need to tell you',
#  "i really don't think i need any social advice from you right now",
#  "it's about time",
#  "a deal's a deal",
#  "how'd you do it",
#  'do what',
#  'get her to act like a human',
#  'okay',
#  "i'm fine i'm",
#  "you're not okay",
#  'i just need to lie down for awhile',
#  "uh uh you lie down and you'll go to sleep",
#  'i know just let me sleep',
#  'what if you have a concussion my dog went to sleep with a concussion and woke up a vegetable not that i could tell the difference',
#  "cameron i'm a little busy",
#  "it's off the whole thing",
#  'what re you talking about',
#  "she's partial to joey not me",
#  'cameron do you like the girl',
#  'sure',
#  'then go get her',
#  'this is so patronizing',
#  "leave it to you to use big word when you're shitfaced",
#  'why re you doing this',
#  'i told you',
#  "you don't care if i die",
#  'sure i do',
#  'why',
#  "because then i'd have to start taking out girl who like me",
#  'like you could find one',
#  "see that who need affection when i've got blind hatred",
#  'just let me sit down',
#  "why'd you let him get to you",
#  'who',
#  'dorsey',
#  'i hate him',
#  "i know it'd have to be a pretty big deal to get you to mainline tequila you don't seem like the type",
#  "hey man you don t think i can be cool you don't think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'you know what they say',
#  'kat wake up',
#  'what',
#  "i don't get you you act like you're too good for any of this and then you go totally apeshit when you get here",
#  "you're welcome",
#  'i have to be home in twenty minute',
#  "i don't have to be home til two",
#  'have fun tonight',
#  'ton',
#  "and i'm in control of it",
#  "but it's gigglepuss i know you like them i saw you there",
#  'when you were gone last year where were you',
#  'busy',
#  'were you in jail',
#  'maybe',
#  "no you weren't",
#  "then why'd you ask",
#  "why'd you lie",
#  'i should do this',
#  'do what',
#  'this',
#  'start a band',
#  "my father wouldn't approve of that that",
#  "you don't strike me a the type that would ask permission",
#  'oh so now you think you know me',
#  "i'm gettin there",
#  'so what s up with your dad he a pain in the as',
#  "he just want me to be someone i'm not",
#  'who',
#  'bianca',
#  "no offense but you're sister is without i know everyone like her and all but",
#  'i looked for you back at the party but you always seemed to be occupied',
#  'i wa',
#  'you never wanted to go out with me did you',
#  'well no',
#  "then that's all you had to say",
#  'but',
#  'you always been this selfish',
#  'you went to the party i thought we were officially opposed to suburban social activity',
#  "i didn't have a choice",
#  "you didn't have a choice where's kat and what have you done with her",
#  'i did bianca a favor and it backfired',
#  "you didn't",
#  'i got drunk i puked i got rejected it wa big fun',
#  'so you got cozy with she who sting',
#  "no i've got a sweet payin job that i'm about to lose",
#  "what'd you do to her",
#  'i don t know i decided not to nail her when she wa too drunk to remember it',
#  'hey there tired of breathing',
#  'hi',
#  'cool picture you a fan',
#  'yeah i guess',
#  'you think',
#  'oh yeah',
#  'macbeth right',
#  'right',
#  'kat a fan too',
#  'yeah',
#  "she hate you with the fire of a thousand sun that's a direct quote",
#  "she just need time to cool off i'll give it a day",
#  'you makin any headway',
#  'she kissed me',
#  'where',
#  "i don't know dorsey the limo the flower another hundred for the tux",
#  'enough with the barbie n ken shit i know',
#  'can you even imagine who the hell would go to this a bastion of commercial excess',
#  "well i guess we're not since we don't have date",
#  'listen to you you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we won't go it's not like i have a dress anyway",
#  "you re looking at this from the wrong perspective we're making a statement",
#  'oh good something new and different for u',
#  'hey sweet cheek',
#  'hi joey',
#  "you're concentrating awfully hard considering it's gym class",
#  'listen i want to talk to you about the prom',
#  "you know the deal i can t go if kat doesn't go",
#  'excuse me have you seen the feminine mystique i lost my copy',
#  'what are you doing here',
#  'i heard there wa a poetry reading',
#  'you re so',
#  'pleasant',
#  'wholesome',
#  'unwelcome',
#  'unwelcome i guess someone still ha her panty in a twist',
#  "don't for one minute think that you had any effect whatsoever on my panty",
#  'so what did i have an effect on',
#  'other than my upchuck reflex nothing',
#  "you were right she's still pissed",
#  'sweet love renew thy force',
#  "man don't say shit like that to me people can hear you",
#  'you humiliated the woman sacrifice yourself on the altar of dignity and even the score',
#  "best case scenario you're back on the payroll for awhile",
#  "what's the worst",
#  'you get the girl',
#  'he left i sprung the dickhead and he cruised on me',
#  'look up sunshine',
#  "i guess i never told you i'm afraid of height",
#  "c'mon it's not that bad",
#  'try lookin at it from this angle',
#  'put your right foot there',
#  "forget it i'm stayin",
#  'you want me to climb up and show you how to get down',
#  'maybe',
#  'the partridge family',
#  'i figured it had to be something ridiculous to win your respect and piss you off',
#  'good call',
#  "so how'd you get chapin to look the other way",
#  'i dazzled him with my wit',
#  'a soft side who knew',
#  "yeah well don't let it get out",
#  "so what's your excuse",
#  'acting the way we do',
#  'yes',
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change",
#  "so if you disappoint them from the start you're covered",
#  'something like that',
#  'then you screwed up',
#  'how',
#  'you never disappointed me',
#  'you up for it',
#  'for',
#  'state trooper',
#  'fallacy',
#  'the duck',
#  'hearsay',
#  "i know the porn career's a lie",
#  'tell me something true',
#  'i hate pea',
#  'no something real something no one else know',
#  "you're sweet and sexy and completely hot for me",
#  'what',
#  'no one else know',
#  "you're amazingly self assured ha anyone ever told you that",
#  'go to the prom with me',
#  'is that a request or a command',
#  'you know what i mean',
#  'no',
#  'no what',
#  "no i won't go with you",
#  'why not',
#  "because i don't want to it's a stupid tradition",
#  'create a little drama start a new rumor what',
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy ha anyone ever told you that',
#  'answer the question patrick',
#  "nothing there's nothing in it for me just the pleasure of your company",
#  "then guillermo say if you go any lighter you're gonna look like an extra on 90210",
#  'no',
#  'do you listen to this crap',
#  'what crap',
#  "me this endless blonde babble i'm like boring myself",
#  'thank god if i had to hear one more story about your coiffure',
#  "i figured you'd get to the good stuff eventually",
#  'what good stuff',
#  'the real you',
#  'like my fear of wearing pastel',
#  "i'm kidding you know how sometimes you just become this persona and you don't know how to quit",
#  'no',
#  "okay you're gonna need to learn how to lie",
#  'would you rather be ravished by a pirate or a british rear admiral',
#  'pirate no question',
#  "daddy i want to discus the prom with you it's tomorrow night",
#  'the prom kat ha a date',
#  'no but',
#  "it's that hot rod joey right that s who you want me to bend my rule for",
#  "he's not a hot rod whatever that is",
#  "you're not going unless your sister go end of story",
#  "fine i see that i'm a prisoner in my own house i'm not a daughter i'm a possession",
#  "they'll dance they'll kiss they'll come home let her go",
#  "kissing is that what you think happens kissing isn't what keep me up to my elbow in placenta all day",
#  "listen i know you hate having to sit home because i'm not susie high school",
#  'like you care',
#  "i do care but i'm a firm believer in doing something for your own reason not someone else s",
#  "i wish i had that luxury i'm the only sophomore that got asked to the prom and i can't go because you won t",
#  'joey never told you we went out did he',
#  'what',
#  'in 9th for a month',
#  'why',
#  'he wa like a total babe',
#  'but you hate joey',
#  'now i do back then wa a different story',
#  'a in',
#  'he said everyone wa doing it so i did it',
#  'you did what',
#  "just once afterwards i told him i didn't want to anymore i wasn't ready he got pissed then he broke up with me",
#  'but',
#  "after that i swore i'd never do anything just because everyone else wa doing it and i haven't since except for bogey's party and my stunning gastro intestinal display",
#  "why didn't you tell me",
#  'i wanted to let you make up your own mind about him',
#  "no you didn't if you really thought i could make my own decision you would've let me go out with him instead of helping daddy hold me hostage",
#  "that's not",
#  "i'm not stupid enough to repeat your mistake",
#  'i guess i thought i wa protecting you',
#  "god you're just like him just keep me locked away in the dark so i can't experience anything for myself",
#  "not all experience are good bianca you can't always trust the people you want to",
#  "i guess i'll never know will i",
#  "what do you wanna watch we've got crap crap crap or crap",
#  'dr ruth',
#  "i'm missing something",
#  'i have a date daddy and he s not a captain of oppression like some men we know',
#  'wow',
#  "let's go",
#  'have a great time honey',
#  'but who what',
#  'what just happened',
#  'your daughter went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  'that s what i thought',
#  "how'd you get a tux at the last minute",
#  "it's scurvy's his date got convicted where'd you get the dress",
#  "it's just something i had you know",
#  'oh huh',
#  "look i'm sorry that i questioned your motif i wa wrong",
#  'have you seen him',
#  'who',
#  'william he asked me to meet him here',
#  "oh honey tell me we haven't progressed to full on hallucination",
#  'you think you re the only sophomore at the prom',
#  'i did',
#  "my grandmother's",
#  'what',
#  "that's where i wa last year she'd never lived alone my grandfather died i stayed with her i wasn't in jail i don't know marilyn manson and i've never slept with a spice girl i spent a year sitting next to my grandma on the couch watching wheel of fortune end of story",
#  'that s completely adorable',
#  'it get worse you still have your freshman yearbook',
#  'wait i',
#  'you were paid to take me out by the one person i truly hate i knew it wa a set up',
#  "it wasn't like that",
#  'really what wa it like a down payment now then a bonus for sleeping with me',
#  "i didn't care about the money",
#  'you looked beautiful last night you know',
#  'so did you',
#  'she okay',
#  'i hope so',
#  'wa that your sister',
#  'yeah she left with some bikers big one full of sperm',
#  'funny',
#  "i don't understand the allure of dehydrated food is this something i should be hip to",
#  'no daddy',
#  'so tell me about this dance wa it fun',
#  'part of it',
#  'which part',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  "what's the matter upset that i rubbed off on her",
#  'no impressed',
#  "you know father don't like to admit that their daughter are capable of running their own life it mean we've become spectator bianca still let me play a few inning you've had me on the bleacher for year when you go to sarah lawrence i won't even be able to watch the game",
#  'when i go',
#  "oh christ don't tell me you've changed your mind i already sent em a check",
#  'let go',
#  'you set me up',
#  'i just wanted',
#  'what to completely damage me to send me to therapy forever what',
#  'no i just wanted',
#  'am i supposed to feel better like right now or do i have some time to think about it',
#  'just smack her now',
#  'is that woman a complete fruit loop or is it just me',
#  "it's just you",
#  'a fender strat you bought this',
#  'i thought you could use it when you start your band',
#  'besides i had some extra cash some asshole paid me to take out a really great girl',
#  'is that right',
#  'yeah but then i fucked up i fell for her',
#  'why is my veggie burger the only burnt object on this grill',
#  'because i like to torture you',
#  'oh bianca can you get me my freshman yearbook',
#  'don t you even dare',
#  'they do to',
#  'they do not',
#  'patrick is that a',
#  'perm',
#  'is that the man i knew treasurer sanchez',
#  'yes your majesty',
#  'diego is a bright boy a pleasure to teach but so serious brother should be raised together colon even brother from different mother',
#  'father i am doing what i think is the best for him and he ha the teacher i would have chosen for myself',
#  "god that's in a week",
#  "that's what it say",
#  'how did you manage it',
#  'with some difficulty i had to promise them you were not a total fool',
#  'why do you wish to sail west',
#  'to open a new route to asia at the moment there are only two way of reaching it',
#  'how can you be so certain the ocean is said to be infinite',
#  'ignorance i believe the indie are no more than 750 league west of the canary island',
#  'how can you be so certain',
#  'the calculation of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  'so wa christ',
#  "two minute and already you're a dead man don't let passion overwhelm you colon",
#  "i'll try to remember that marchena",
#  'father marchena',
#  'passion is something one cannot control',
#  'you get so carried away when you are being contradicted',
#  "i've been contradicted all my life eternity",
#  'only god know the meaning of such word my son',
#  'i could be gone for year',
#  'i know',
#  "i haven't given you much of a life",
#  "well that's true i have a child by a man who won't marry me who's always leaving",
#  'are we going to argue',
#  "i'd love to argue with you sometimes but you're never here",
#  'perhaps i wa never meant to live with a woman',
#  'i find that hard to believe',
#  'you say asia can be found by sailing west',
#  'yes your eminence the voyage should not take more than six or seven week',
#  'unfortunately don colon that is precisely where our opinion differ are you familiar with the work of aristotle erathostene ptolemeus',
#  'i am your eminence',
#  'then you cannot ignore that according to their calculation the circumference of the earth is approximately 22000 league or more which make the ocean uncrossable',
#  'senor colon an experienced captain such a yourself will understand our concern with the crew i am not willing to have on my conscience the loss of men who would have relied upon our judgment',
#  'excellency you are right',
#  'your eminence there is only one way to settle the matter and that is to make the journey i am ready to risk my life to prove it possible',
#  'your life and that of others',
#  'if they agree to follow me yes',
#  'trade your excellency according to marco polo the kingdom of china is one of the richest of the world even the meanest building are roofed with gold',
#  'is that all that interest you gold',
#  'no the portuguese have already discovered black skinned people i too will find other population and bring them to the word of god',
#  'if god intended our proximity to asia do you believe he would have waited for you to show it to the world',
#  "did he not choose a carpenter's son to reveal himself to the world",
#  "don't you realize your word could be considered heretical",
#  'blind faith is what i consider heresy',
#  'asia can be found to the west and i will prove it',
#  'if god will it',
#  "the state ha some reason to be interested in this man's proposition your eminence",
#  'the judgment is ours',
#  'naturally but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography',
#  'he is a mercenary did he not already try to convince the king of portugal of his absurd notion',
#  'indeed the world is full of mercenary and state often make use of them when it benefit them my only concern is the welfare and prosperity of spain',
#  "you mustn't give way to despair you must wait",
#  "wait i've waited seven year already how much longer do you want me to wait",
#  'if god intends you to go then you will go',
#  'damn god',
#  'colon',
#  'damn all of you you all set up theory based on what you never leave the safety of your study go out find out what the world is about and then tell me something i can listen to',
#  'all of them just lie',
#  "colon don't",
#  'where can i meet this man',
#  'immediately',
#  'i should not even be listening to you since my council said no but santangel tell me you are a man of honor and sincerity and sanchez that you are not a fool',
#  'no more than the woman who said she would take granada from the moor',
#  'the ocean is uncrossable',
#  'what did they say about granada before today',
#  'that she wa impregnable',
#  'i cannot ignore the verdict of my council',
#  'surely you can do anything you want',
#  'may i speak freely',
#  'you show no inclination to speak otherwise',
#  "i know what i see i see someone who doesn't accept the world a it is who's not afraid i see a woman who think what if",
#  'a woman',
#  'how old are you senor colon',
#  'thirty seven your majesty and you',
#  'no',
#  'no',
#  'no i have waited too long fought too hard now you expect me to take all the risk while you take the profit no i will not be your servant',
#  'i remind you senor colon that you are in no position to bargain with me',
#  "i'm not bargaining",
#  'then you are too ambitious',
#  'and were you never ambitious excellency or is ambition only a virtue among the noble a fault for the rest of u',
#  "if you won't accept our proposal we'll simply find someone who will",
#  'you were right don sanchez his demand could never be granted',
#  'never your majesty although',
#  'into a monk',
#  "yes it would be a pity wouldn't it call him back",
#  'she said yes',
#  'thank god',
#  "i'm not asking you to swear to anything",
#  "i don't want you to wait for me",
#  "that's something you can't decide",
#  'i want to go with you',
#  "there'll be a time",
#  'you promise do you swear on st christopher',
#  'do you swear on all the holy saint in heaven',
#  'yes yes i do on all of them',
#  'in nomine patris et filius et spiritus sancti',
#  'forgive me father for i have sinned',
#  'i am listening my son',
#  'father i have betrayed my family i betrayed my men and i betrayed you',
#  'what are you saying',
#  'i lied the journey will be longer than i said',
#  'how long',
#  'i am not sure it could be twice the distance',
#  'may god forgive you you must tell them you must tell your men',
#  "if i tell them they won't follow me you know that i am right father you trust me",
#  "my son my son your certitude are sometimes frightening christopher you must speak to them and if you don't i will",
#  'you are bound by an oath father',
#  'i believed in you',
#  'give me absolution',
#  'due west captain mendez and may god be with u',
#  'god be with u admiral',
#  "well it's the men sir they wonder how you know our position we've lost sight from land day ago",
#  'and what do you think mendez',
#  "well i surely know what a quadrant is but i've never seen it used at night before",
#  'come over here',
#  'what do you read',
#  'twenty eight',
#  'i never seen heat like this not even in la mina',
#  "the water's going putrid in the barrel",
#  "you'll be drinking your own piss for the glory of spain and admiral colon bastard",
#  'what are you listening to chicken as',
#  "ah leave him alone he's doing no harm",
#  "with a face like that i don't want you looking at me you hear",
#  "he's the devil's child",
#  "we'll all go crazy",
#  'we should have seen land',
#  "we left three week ago alonso can't be that near",
#  "can't be that far i say also i don't like the smell of the sea around here smell like a cunt bad sign",
#  "you lied you cheated we're way past 750 league",
#  'six day ago yes',
#  'you must be mad',
#  'we have to keep the hope of these men alive',
#  "we're on the verge of a mutiny colon",
#  "you think i don't know that",
#  "we're lost",
#  'the land is there i know it',
#  "you don't know anything listen colon these are my ship right so i'm telling you we're turning back",
#  'and then what half of the water ha gone the rest is nearly putrid you know that',
#  'jesus maria i should have never listened to you',
#  'you never did you did all the talking for both of u remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward think about that',
#  'you tell that to them',
#  "you're right let the men decide",
#  'say not here cuba',
#  'what is it a tribe an island',
#  'island far',
#  'you come you speak first',
#  'tell the chief we thank him',
#  'chief know',
#  'tell him his country is very beautiful tell him we are leaving men here to build a fort',
#  'chief say how many',
#  'thousand',
#  'why',
#  'to bring the word of god',
#  'chief say he ha a god',
#  'and also to bring medicine',
#  'chief say',
#  'he ha medicine tell him we admire his people',
#  "it won't be easy to get rid of your prophet now don sanchez",
#  'on the contrary your eminence it seems to me the man is preparing his own cross',
#  "and you say this is an indian vice by god i don't see any kind of pleasure that would make this a sin",
#  'the indian have no such word don moxica',
#  'do they have such thought',
#  'they come and go a naked a the day god created them',
#  "they don't see sin in their nakedness they live according to nature in a never ending summer the island are covered with tree filled with blossom and fruit and",
#  'forgive me don colon but what about gold',
#  'you defend yourself admirably',
#  'for a commoner',
#  'i understand that you will soon be appointing governor for the island is it not so',
#  'forgive me don bobadilla those position have already been taken',
#  'may i ask by whom',
#  'bartolome and giacomo colon',
#  'but we do have a lack of notary you should contact my administration',
#  'don bobadilla is already a judge my dear don cristobal',
#  'good we are also in need of judge except there are no thief',
#  'you seem to have a special talent for making friend',
#  'what do i have so many already',
#  'to rise so high in so short a time is a dangerous occupation a little hypocrisy go a long way',
#  'beatrix i want to ask you something',
#  "you don't usually ask",
#  'i can arrange for the queen to take fernando and diego into her service',
#  'we lost cousin friend we will wash this in blood',
#  "if you want to keep your head on your shoulder you'll do a i say",
#  'you want a war fine we are a thousand they outnumber u by ten who will you kill which tribe',
#  "we don't need to know",
#  'we came here to stay to build not to start a crusade in this forest there is enough danger to sweep u away in day so we will be brave and swallow our grief and in the name of those who died we will accomplish what we came for',
#  'we will work with his people we want peace ask the chief if he understands',
#  'he understands',
#  'ask him if he will help',
#  "we can't raise the wheel without it",
#  "my horse doesn't work",
#  'don moxica we all have to work',
#  'you did not hear me don colon not my horse',
#  'every ship return with a cargo of sick and dying but with no gold the new world prof expensive your majesty',
#  "we weren't expecting immediate profit were we we must have faith we must give time for time",
#  'in one act of brutality you have created chaos tribe who were fighting each other are now joining force against u all that because of your criminal savagery',
#  'savagery is what monkey understand',
#  "you'll be held in detention deprived of your privilege and possession until you are returned to spain where you will be judged have you anything to say",
#  'you will regret this',
#  'you have to find them utapan look what they did',
#  'you did the same to your god',
#  "utapan won't you speak to me you used to know how to speak to me",
#  'you never learned how to speak my language',
#  'but there is worse he ordered the execution of five member of the nobility',
#  'is this true brother buyl',
#  'then what do you suggest don sanchez',
#  'he must be replaced',
#  'and who would you think of for such a task',
#  'don alonso de bobadilla',
#  'yes i remember',
#  'my letter of appointment',
#  'appointment to what',
#  'viceroy of the west indie',
#  'congratulation then i am free to search for the mainland',
#  'how far from here',
#  'i am not a seaman but i heard it is no more than a week at sea i hope you are not too disappointed',
#  'how could i be the mainland ha been found exactly a i said it would',
#  'i am afraid this is not the worst news',
#  'i have to explore the mainland',
#  'this time with me',
#  'but without your brother nor are you to return to santo domingo or any of the other colony you may explore the continent',
#  'thank you',
#  "there is one thing i'd like to understand why do you want to go back after all this",
#  'your majesty some men are content to read about thing i must see them with my own eye i cannot be other than i am',
#  'i know i should not tolerate his impertinence',
#  'then why',
#  'because he is not afraid of me',
#  'all i have to do is call the guard',
#  'call them',
#  'i am not afraid of you you are nothing but a dreamer',
#  'look out of that window',
#  'what do you see',
#  'roof tower palace spire',
#  'all of them created by people like me',
#  "god you're so beautiful i can't believe no other man ha ever taken you away from me",
#  "they tried but i didn't let them",
#  'they took everything',
#  "not everything do you think i care i'm a free man again rich don't make a man rich they only make him busier",
#  'how are you feeling fernando',
#  'not bad',
#  "what's he doing",
#  "he's drawing an isthmus he's saying we're on an isthmus",
#  "we can't be",
#  'father',
#  'there must be a passage to that other ocean',
#  'you can see for yourself',
#  'what a tragedy what a waste of a life',
#  'a waste let me tell you something arojaz if your name or mine is ever remembered it will only be because of his',
#  "i suppose we're both old men now",
#  "you'll always be older than me father",
#  'i have to disagree',
#  'i knew you would',
#  'new world create new people',
#  'oh so you are a new man',
#  "i don't know i have the impression that i didn't change that much i still can't accept the world a it is",
#  "can't you stay with u a little",
#  'i am busy inside',
#  'what is it now tell me',
#  "i can't keep my eye off you i would like to catch up with all the moment i didn't spend with you",
#  'what are you listening to',
#  "i am not listening father but i can't help hearing",
#  'what doe he say',
#  'he asks when he can come to visit you he left his address',
#  'he never had one except aboard my ship',
#  'i want you to tell me everything you remember father from the beginning everything',
#  "really god i wouldn't know where to start and yet",
#  'tell me the first thing that come to your mind',
#  "just do what i do say the same thing i say don't open your mouth",
#  'okay',
#  "don't fool around",
#  'okay',
#  'did you hear what i said',
#  'i want to document my trip to america',
#  'next could i see your document please',
#  'yes sir',
#  'what is your intended purpose of your visit to the united state',
#  'two week holiday',
#  'how much money are you carrying with you',
#  'i have five hundred dollar',
#  'can you show me sir no camera in the fis area',
#  'is he with you are you travelling together',
#  'yes',
#  'please join u come on forward',
#  'is there a problem',
#  "no you're travelling together i want to talk to you together hi how are you can i take a look at your document are you related",
#  "yes he's my friend",
#  "okay you're a czech national and you're a russian national how do you know one another",
#  'we are both from prague',
#  'how long are you planning to stay',
#  'two week',
#  "i'd like to speak for himself okay",
#  "he doesn't speak english",
#  'i speak english',
#  "then answer my question where were you planning to stay during the two week that you're here",
#  'new york',
#  "yes we're in new york now but where are you planning to stay in new york",
#  'a cheap hotel',
#  'what are you coming here to do',
#  "i'm here for movie",
#  'movie to be in the movie or to see movie',
#  "yes no both when i wa a boy i see movie at school called it's a wonderful life directed by frank capra ever since i want to come to america land of the free home of the brave a land where anyone can be anything a long a they are white",
#  'excuse me',
#  "so we're waitin to hit this warrant we got emergency service with the heavy weapon standin by ready to go i say lemme get a cigar outta the car i go to get the cigar and boom all the sudden i turn around and a kid with a shotgun let one go right where i wa standin that coulda been it i coulda had my head blown off and for what some stupid kid got panicky take the safety off and it's over if i hadn't gone back for that cigar for a bad habit i would've had my head blown off",
#  'jesus christ',
#  'coffee for me i gotta slow down',
#  'vodka tonic',
#  'maybe you could just put in a shot of martell',
#  "it wa freaky i'll tell you stupid kid",
#  "what's the kid gonna say sorry meanwhile i'm not here anymore like last week we were at the morgue and this guy wa all chopped up spleen here liver there his heart in a pan six hour ago this guy wa walkin his dog or buyin a quart of milk who know but some kid's robbed him for 3 or some shit and shot him and now you can't tell if he's a piece of beef or a human being and i'm thinkin that's me sooner or later that's me",
#  "sooner or later that's everybody",
#  'not chopped up not chopped up like that i mean what do i got left coupla article a medal or two plaque here and there and in a coupla year no one remembers me anymore',
#  "i think you're getting a little moody there eddie",
#  "i'm not moody",
#  "isn't he a little moody",
#  "of course he's moody he think he's in love",
#  'in love with who',
#  'how old are your kid',
#  "my kid let's see susan's 15 aundrea's 9 don't tell me you're thinking about having a kid how old are you never mind let me just tell you this every stupid cliche you hear about kid they change your life they make you a better person they make you whole it's all true before i had kid when friend talked about their kid i wanted to vomit now i get it am i right leon",
#  'yeah',
#  "paulie you've got kid right",
#  'okay you work in a vodka factory i understand that and what kind of work do you do',
#  'i am butcher',
#  "you're a butcher what do you use pig intestine for",
#  'you stuff sausage in it',
#  'and what do you do with the bone',
#  ...]

# %%
messages['msg_pre_processed'] = data_pre_processed

# %% [markdown]
# ### Checking for duplicated messages in msg

# %%
data = messages['msg_pre_processed']

# %%
dict = {}
for n in data:
    if n in dict:
        dict[n] = dict[n] + 1
    else:
        dict[n] = 1

# %%
dict
# Out:
# {'did you change your hair': 2,
#  'no': 1692,
#  'you might wanna think about it': 1,
#  'i missed you': 4,
#  'it say here you exposed yourself to a group of freshman girl': 1,
#  'it wa a bratwurst i wa eating lunch': 1,
#  'with the teeth of your zipper': 1,
#  'you the new guy': 1,
#  'so they tell me': 1,
#  "c'mon i'm supposed to give you the tour": 1,
#  'so which dakota you from': 1,
#  "north actually how'd you": 1,
#  'i wa kidding people actually live there': 1,
#  "yeah a couple we're outnumbered by the cow though": 1,
#  'how many people were in your old school': 1,
#  'thirty two': 2,
#  'get out': 38,
#  'how many people go here': 1,
#  'couple thousand most of them evil': 1,
#  "that i'm used to": 1,
#  'yeah but these guy have never seen a horse they just jack off to clint eastwood': 1,
#  'that girl i': 1,
#  'you burn you pine you perish': 1,
#  'who is she': 11,
#  "bianca stratford sophomore don't even think about it": 1,
#  'why not': 265,
#  "i could start with your haircut but it doesn't matter she's not allowed to date until her older sister doe and that's an impossibility": 1,
#  "katarina stratford my my you've been terrorizing m blaise again": 1,
#  'expressing my opinion is not a terrorist action': 1,
#  "well yes compared to your other choice of expression this year today's event are quite mild by the way bobby rictor's gonad retrieval operation went quite well in case you're interested": 1,
#  'i still maintain that he kicked himself in the ball i wa merely a spectator': 1,
#  'the point is kat people perceive you a somewhat': 1,
#  'tempestuous': 1,
#  'no i believe heinous bitch is the term used most often': 1,
#  "who's that": 36,
#  'patrick verona random skid': 1,
#  "that's pat verona the one who wa gone for a year i heard he wa doing porn movie": 1,
#  "i'm sure he's completely incapable of doing anything that interesting": 1,
#  'he always look so': 1,
#  'block e': 1,
#  'mandella eat starving yourself is a very slow way to die': 1,
#  'just a little': 2,
#  "what's this": 75,
#  'an attempted slit': 1,
#  "i realize that the men of this fine institution are severely lacking but killing yourself so you can be with william shakespeare is beyond the scope of normal teenage obsession you're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy": 1,
#  "but imagine the thing he'd say during sex": 1,
#  'why do girl like that always like guy like that': 1,
#  "because they're bred to their mother liked guy like that and their grandmother before them their gene pool is rarely diluted": 1,
#  'he always have that shit eating grin': 1,
#  "joey dorsey perma shit grin i wish i could say he's a moron but he's number twelve in the class and a model mostly regional stuff but he's rumored to have a big tube sock ad coming out": 1,
#  'you know french': 1,
#  "sure do my mom's from canada": 1,
#  'guess who just signed up for a tutor': 1,
#  "you mean i'd get a chance to talk to her": 1,
#  'you could consecrate with her my friend': 1,
#  "the vintage look is over kat haven't you been reading your sassy": 1,
#  'yeah and i noticed the only part of you featured in your big kmart spread wa your elbow tough break': 1,
#  "they're running the rest of me next month": 1,
#  'the people at this school are so incredibly foul': 1,
#  "you could always go with me i'm sure william ha some friend": 1,
#  'yeah just a minor encounter with the shrew': 1,
#  "that's her bianca's sister": 1,
#  'the mewling rampalian wretch herself': 1,
#  'in the microwave': 1,
#  'make anyone cry today': 1,
#  "where've you been": 7,
#  'nowhere hi daddy': 1,
#  "what's a synonym for throbbing": 1,
#  'sarah lawrence is on the other side of the country': 1,
#  'i know': 249,
#  'i thought we decided you were going to school here at u of 0': 1,
#  'you decided': 1,
#  "now don't get upset daddy but there's this boy and i think he might ask": 1,
#  "no you're not dating until your sister start dating end of discussion": 1,
#  'what if she never start dating': 1,
#  "then neither will you and i'll get to sleep at night": 1,
#  "but it's not fair she's a mutant daddy": 1,
#  'this from someone whose diary is devoted to favorite grooming tip': 1,
#  'enough': 11,
#  "but she doesn't want to date": 1,
#  'exactly my point': 1,
#  'jesus can a man even grab a sandwich before you woman start dilating': 1,
#  'tumescent': 1,
#  "you're not helping": 2,
#  'can we make this quick roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad again': 1,
#  "well i thought we'd start with pronunciation if that's okay with you": 1,
#  'not the hacking and gagging and spitting part please': 1,
#  'okay then how bout we try out some french cuisine saturday night': 1,
#  "you're asking me out that's so cute what's your name again": 1,
#  'forget it': 54,
#  "no no it's my fault we didn't have a proper introduction": 1,
#  'cameron': 3,
#  "the thing is cameron i'm at the mercy of a particularly hideous breed of loser my sister i can't date until she doe": 1,
#  'seems like she could get a date easy enough': 1,
#  'why': 588,
#  'unsolved mystery she used to be really popular when she started high school then it wa just like she got sick of it or something': 1,
#  "that's a shame": 2,
#  'gosh if only we could find kat a boyfriend': 1,
#  'let me see what i can do': 1,
#  'i teach her french get to know her dazzle her with charm and she fall in love with me': 1,
#  "unlikely but even so she still can't go out with you so what's the point": 1,
#  'what about him': 17,
#  'you wanna go out with him': 1,
#  "what make you think he'll do it": 1,
#  'he seems like he thrives on danger': 1,
#  "no kidding he's a criminal i heard he lit a state trooper on fire he just got out of alcatraz": 1,
#  'they always let felon sit in on honor biology': 1,
#  "i'm serious man he's whacked he sold his own liver on the black market so he could buy new speaker": 1,
#  "forget his reputation do you think we've got a plan or not": 1,
#  "did she actually say she'd go out with you": 1,
#  "that's what i just said": 1,
#  "you know if you do go out with bianca you'd be set you'd outrank everyone strictly a list with me by your side": 1,
#  'i thought you hated those people': 1,
#  "hey i've gotta have a few client when i get to wall street": 1,
#  'hey': 151,
#  'are you lost': 1,
#  'nope just came by to chat': 1,
#  "we don't chat": 1,
#  "well actually i thought i'd run an idea by you you know just to see if you're interested": 1,
#  "we're not": 4,
#  "but she can't go out with you because her sister is this insane head case and no one will go out with her right": 1,
#  'doe this conversation have a purpose': 1,
#  "so what you need to do is recruit a guy who'll go out with her someone who's up for the job": 1,
#  'you got him involved': 1,
#  "like we had a choice besides when you let the enemy think he's orchestrating the battle you're in a position of power we let him pretend he's calling the shot and while he's busy setting up the plan you have time to woo bianca": 1,
#  'so he ha this huge raging fit about sarah lawrence and insists that i go to his male dominated puking frat boy number one golf team school i have no say at all': 1,
#  'william would never have gone to a state school': 1,
#  "william didn't even go to high school": 1,
#  "that's never been proven": 1,
#  'neither ha his heterosexuality': 1,
#  "i appreciate your effort toward a speedy death but i'm consuming do you mind": 1,
#  'doe it matter': 4,
#  "if i wa bianca it would be any school you want precious don't forget your tiara": 1,
#  "i don't understand patrick you haven't done anything asinine this week are you not feeling well": 1,
#  'touch of the flu': 1,
#  "i'm at a loss then what should we talk about your year of absence": 1,
#  "why don't we discus your driving need to be a hemorrhoid": 1,
#  "what's to discus": 1,
#  "you weren't abused you aren't stupid and a far a i can tell you're only slightly psychotic so why is it that you're such a fuck up": 1,
#  "well you know there's the prestige of the job title and the benefit package is pretty good": 1,
#  "c'esc ma tete this is my head": 1,
#  "right see you're ready for the quiz": 1,
#  "i don't want to know how to say that though i want to know useful thing like where the good store are how much doe champagne cost stuff like chat i have never in my life had to point out my head to someone": 1,
#  "that's because it's such a nice one": 1,
#  'forget french': 1,
#  'how is our little find the wench a date plan progressing': 1,
#  "well there's someone i think might be": 1,
#  'there': 23,
#  'where': 167,
#  'yeah': 1346,
#  'what do you think': 89,
#  'two leg nice rack': 1,
#  'yeah whatever i want you to go out with her': 1,
#  "sure sparky i'll get right on it": 1,
#  'you just said': 2,
#  'you need money to take a girl out': 1,
#  "but you'd go out with her if you had the cake": 1,
#  'you got it verona i pick up the tab you do the honor': 1,
#  "you're gonna pay me to take out some girl": 1,
#  "i can't date her sister until that one get a boyfriend and that's the catch she doesn't want a boyfriend": 1,
#  'how much': 57,
#  "i can't take a girl like that out on twenty buck": 1,
#  'fine thirty': 1,
#  "take it or leave it this isn't a negotiation": 1,
#  "fifty and you've got your man": 1,
#  'i mean wo man how ya doin': 1,
#  'sweating like a pig actually and yourself': 1,
#  "there's a way to get a guy's attention": 1,
#  'my mission in life': 1,
#  'pick you up friday then': 1,
#  'oh right friday': 1,
#  "the night i take you to place you've never been before and back": 1,
#  'like where the 7 eleven on burnside do you even know my name screwboy': 1,
#  'i know a lot more than that': 1,
#  "i have the potential to smack the crap out of you if you don't get out of my way": 1,
#  'can you at least start wearing a bra': 1,
#  "you hate me don't you": 1,
#  "i don't really think you warrant that strong an emotion": 1,
#  "then say you'll spend dollar night at the track with me": 1,
#  'and why would i do that': 2,
#  'come on the pony the flat beer you with money in your eye me with my hand on your as': 1,
#  'you covered in my vomit': 1,
#  'seven thirty': 2,
#  'are you following me': 3,
#  "i wa in the laundromat i saw your car thought i'd say hi": 1,
#  'hi': 234,
#  "you're not a big talker are you": 1,
#  "depends on the topic my fender don't really whip me into a verbal frenzy": 1,
#  'hey do you mind': 1,
#  'not at all': 43,
#  'my insurance doe not cover pm': 1,
#  'then tell them i had a seizure': 1,
#  'is this about sarah lawrence you punishing me': 1,
#  'i thought you were punishing me': 1,
#  "why can't we agree on this": 1,
#  "because you're making decision for me": 1,
#  "a a parent that's my right": 1,
#  "so what i want doesn't matter": 1,
#  "you're eighteen you don't know what you want you won't know until you're forty five and you don't have it": 1,
#  'i want to go to an east coast school i want you to trust me to make my own choice i want': 1,
#  'when i shell out fifty i expect result': 1,
#  "i'm on it": 6,
#  "watching the bitch trash my car doesn't count a a date": 1,
#  'i got her under control she just act crazed in public to keep up the image': 1,
#  'i just upped my price': 1,
#  'what': 1985,
#  'a hundred buck a date': 1,
#  'forget her sister then': 1,
#  'you got something on your mind': 1,
#  "i counted on you to help my cause you and that thug are obviously failing aren't we ever going on our date": 1,
#  'you have my word a a gentleman': 1,
#  "you're sweet": 2,
#  'how do you get your hair to look like that': 1,
#  "eber's deep conditioner every two day and i never ever use a blowdryer without the diffuser attachment": 1,
#  'say it': 8,
#  "whatever the hell it is you're standin there waitin to say": 1,
#  'what plan': 4,
#  'the situation is my man cameron here ha a major jones for bianca stratford': 1,
#  'what is it with this chick she have three tit': 1,
#  "i think i speak correctly when i say that cameron's love is pure purer than say joey dorsey's": 1,
#  "dorsey can plow whoever he want i'm just in this for the cash": 1,
#  "that's where we can help you with kat": 1,
#  'so dorsey can get the girl': 1,
#  "patrick pat you're not looking at the big picture joey's just a pawn we set this whole thing up so cameron can get the girl": 1,
#  'you two are gonna help me tame the wild beast': 1,
#  "we're your guy": 1,
#  'and he mean that strictly in a non prison movie type of way': 1,
#  "yeah we'll see": 2,
#  'this is it a golden opportunity patrick can ask katarina to the party': 1,
#  "in that case we'll need to make it a school wide blow out": 1,
#  'will bogey get bent': 1,
#  "are you kidding he'll piss himself with joy he's the ultimate kiss as": 1,
#  "it's more": 1,
#  'expensive': 1,
#  "exactly so you going to bogey lowenbrau's thing on saturday": 1,
#  'hopefully': 1,
#  'sure have': 2,
#  "i really really really wanna go but i can't not unless my sister go": 1,
#  "i'm workin on it but she doesn't seem to be goin for him": 1,
#  "she's not a": 1,
#  "lesbian no i found a picture of jared leto in one of her drawer so i'm pretty sure she's not harboring same sex tendency": 1,
#  "so that's the kind of guy she like pretty one": 1,
#  "who know all i've ever heard her say is that she'd dip before dating a guy that smoke": 1,
#  "what've you got for me": 1,
#  "i've retrieved certain piece of information on miss katarina stratford i think you'll find helpful": 1,
#  'good enough': 2,
#  'number one she hate smoker': 1,
#  "it's a lung cancer issue": 1,
#  'her favorite uncle': 1,
#  'dead at forty one': 1,
#  "are you telling me i'm a non smoker": 1,
#  'just for now': 1,
#  "he's pretty": 1,
#  "okay i wasn't sure": 1,
#  'okay like thai food feminist prose and angry stinky girl music of the indie rock persuasion': 1,
#  "so what doe that give me i'm supposed to buy her some noodle and a book and sit around listening to chick who can't play their instrument": 1,
#  'ever been to club skunk': 1,
#  'gigglepuss is playing there tomorrow night': 1,
#  "don't make me do it man": 1,
#  'assail your ear for one night': 1,
#  "it's her favorite band": 1,
#  'i prefer to think of it simply a an alternative to what the law allows': 1,
#  "i'm likin you guy better": 1,
#  "oh my god doe this mean you're becoming normal": 1,
#  "it mean that gigglepuss is playing at club skunk and we're going": 1,
#  "oh i thought you might have a date i don't know why i'm bothering to ask but are you going to bogey lowenstein's party saturday night": 1,
#  "i think you're a freak i think you do this to torture me and i think you suck": 1,
#  "you think this'll work": 1,
#  'no fear': 1,
#  'always a pleasure brucie': 1,
#  "didn't have you pegged for a gigglepuss fan aren't they a little too pre teen belly button ring for you": 1,
#  'fan of a fan you see a couple of minor come in': 1,
#  'never': 35,
#  'padua girl one tall decent body the other one kinda short and undersexed': 1,
#  'just sent em through': 1,
#  'hey great show huh': 1,
#  'unknown': 310,
#  'excuse me': 135,
#  "that's what you want isn't it": 1,
#  "do you mind you're sort of ruining it for me": 1,
#  "you know these guy are no bikini kill or the raincoat but they're right up there": 1,
#  'you know who the raincoat are': 1,
#  "why don't you": 4,
#  "what'd he say": 20,
#  'who care': 11,
#  'you told me that part already': 1,
#  "hell i've just been going over the whole thing in my head and": 1,
#  "i hear you're helpin verona": 1,
#  "uh yeah we're old friend": 1,
#  'you and verona': 1,
#  'what we took bathe together when we were kid': 1,
#  "you better not fuck this up i'm heavily invested": 1,
#  "hey it's all for the higher good right": 1,
#  "you're completely demented": 1,
#  'see you next week': 2,
#  'daddy i': 1,
#  "and where're you going": 1,
#  'if you must know we were attempting to go to a small study group of friend': 1,
#  'otherwise known a an orgy': 1,
#  "it's just a party daddy but i knew you'd forbid me to go since gloria steinem over there isn't going": 1,
#  'daddy people expect me to be there': 1,
#  "if kat's not going you're not going": 1,
#  "you're ruining my life because you won't be normal i can't be normal": 1,
#  "what's normal": 2,
#  "bogey lowenstein's party is normal but you're too busy listening to bitch who need prozac to know that": 1,
#  "can't you forget for just one night that you're completely wretched": 1,
#  "at least i'm not a clouted fen sucked hedge pig": 1,
#  "like i'm supposed to know what that even mean": 1,
#  "it's shakespeare maybe you've heard of him": 1,
#  "yeah he's your freak friend mandella's boyfriend i guess since i'm not allowed to go out i should ob over a dead guy too": 1,
#  "oh god it's starting": 1,
#  "it's just a party daddy": 1,
#  'wear the belly before you go': 1,
#  'daddy no': 1,
#  'just for a minute': 1,
#  'you are so completely unbalanced': 1,
#  'can we go now': 3,
#  "promise me you won't talk to any boy unless your sister is present": 1,
#  "because she'll scare them away": 1,
#  'where ya goin': 2,
#  'away': 1,
#  'your sister here': 1,
#  'leave my sister alone': 1,
#  "i'm getting trashed man isn't that what you're supposed to do at a party": 1,
#  'i say do what you wanna do': 1,
#  "funny you're the only one": 1,
#  'where did he go he wa just here': 1,
#  'who': 286,
#  'joey': 8,
#  'look like thing worked out tonight huh': 1,
#  'you know chastity': 1,
#  'i believe we share an art instructor': 1,
#  'great': 73,
#  'would you mind getting me a drink cameron': 1,
#  'extremely unfortunate maneuver': 1,
#  "the hell is that what kind of guy just pick up a girl and carry her away while you're talking to her": 1,
#  "buttholus extremus but hey you're making progress": 1,
#  'no i m not': 1,
#  "so yeah i've got the sears catalog thing going and the tube sock gig that's gonna be huge and then i'm up for an ad for queen harry next week": 1,
#  'queen harry': 1,
#  "it's a gay cruise line but i'll be like wearing a uniform and stuff": 1,
#  'neat': 3,
#  "my agent say i've got a good shot at being the prada guy next year": 1,
#  "he practically proposed when he found out we had the same dermatologist i mean dr bonchowski is great an all but he's not exactly relevant party conversation": 1,
#  'is he oily or dry': 1,
#  "combination i don't know i thought he'd be different more of a gentleman": 1,
#  "bianca i don't think the highlight of dating joey dorsey are going to include door opening and coat holding": 1,
#  "sometimes i wonder if the guy we're supposed to want to go out with are the one we actually want to go out with you know": 1,
#  "all i know is i'd give up my private line to go out with a guy like joey": 1,
#  'bianca i need to talk to you i need to tell you': 1,
#  "i really don't think i need any social advice from you right now": 1,
#  "it's about time": 4,
#  "a deal's a deal": 2,
#  "how'd you do it": 1,
#  'do what': 27,
#  'get her to act like a human': 1,
#  'okay': 421,
#  "i'm fine i'm": 1,
#  "you're not okay": 1,
#  'i just need to lie down for awhile': 1,
#  "uh uh you lie down and you'll go to sleep": 1,
#  'i know just let me sleep': 1,
#  'what if you have a concussion my dog went to sleep with a concussion and woke up a vegetable not that i could tell the difference': 1,
#  "cameron i'm a little busy": 1,
#  "it's off the whole thing": 1,
#  'what re you talking about': 1,
#  "she's partial to joey not me": 1,
#  'cameron do you like the girl': 1,
#  'sure': 307,
#  'then go get her': 1,
#  'this is so patronizing': 1,
#  "leave it to you to use big word when you're shitfaced": 1,
#  'why re you doing this': 1,
#  'i told you': 15,
#  "you don't care if i die": 1,
#  'sure i do': 6,
#  "because then i'd have to start taking out girl who like me": 1,
#  'like you could find one': 1,
#  "see that who need affection when i've got blind hatred": 1,
#  'just let me sit down': 1,
#  "why'd you let him get to you": 1,
#  'dorsey': 1,
#  'i hate him': 3,
#  "i know it'd have to be a pretty big deal to get you to mainline tequila you don't seem like the type": 1,
#  "hey man you don t think i can be cool you don't think i can be laid back like everyone else": 1,
#  'i thought you were above all that': 1,
#  'you know what they say': 1,
#  'kat wake up': 1,
#  "i don't get you you act like you're too good for any of this and then you go totally apeshit when you get here": 1,
#  "you're welcome": 19,
#  'i have to be home in twenty minute': 1,
#  "i don't have to be home til two": 1,
#  'have fun tonight': 1,
#  'ton': 1,
#  "and i'm in control of it": 1,
#  "but it's gigglepuss i know you like them i saw you there": 1,
#  'when you were gone last year where were you': 1,
#  'busy': 2,
#  'were you in jail': 1,
#  'maybe': 78,
#  "no you weren't": 3,
#  "then why'd you ask": 1,
#  "why'd you lie": 1,
#  'i should do this': 1,
#  'this': 17,
#  'start a band': 1,
#  "my father wouldn't approve of that that": 1,
#  "you don't strike me a the type that would ask permission": 1,
#  'oh so now you think you know me': 1,
#  "i'm gettin there": 1,
#  'so what s up with your dad he a pain in the as': 1,
#  "he just want me to be someone i'm not": 1,
#  'bianca': 1,
#  "no offense but you're sister is without i know everyone like her and all but": 1,
#  'i looked for you back at the party but you always seemed to be occupied': 1,
#  'i wa': 11,
#  'you never wanted to go out with me did you': 1,
#  'well no': 5,
#  "then that's all you had to say": 1,
#  'but': 71,
#  'you always been this selfish': 1,
#  'you went to the party i thought we were officially opposed to suburban social activity': 1,
#  "i didn't have a choice": 1,
#  "you didn't have a choice where's kat and what have you done with her": 1,
#  'i did bianca a favor and it backfired': 1,
#  "you didn't": 15,
#  'i got drunk i puked i got rejected it wa big fun': 1,
#  'so you got cozy with she who sting': 1,
#  "no i've got a sweet payin job that i'm about to lose": 1,
#  "what'd you do to her": 1,
#  'i don t know i decided not to nail her when she wa too drunk to remember it': 1,
#  'hey there tired of breathing': 1,
#  'cool picture you a fan': 1,
#  'yeah i guess': 12,
#  'you think': 14,
#  'oh yeah': 113,
#  'macbeth right': 1,
#  'right': 231,
#  'kat a fan too': 1,
#  "she hate you with the fire of a thousand sun that's a direct quote": 1,
#  "she just need time to cool off i'll give it a day": 1,
#  'you makin any headway': 1,
#  'she kissed me': 1,
#  "i don't know dorsey the limo the flower another hundred for the tux": 1,
#  'enough with the barbie n ken shit i know': 1,
#  'can you even imagine who the hell would go to this a bastion of commercial excess': 1,
#  "well i guess we're not since we don't have date": 1,
#  'listen to you you sound like betty all pissed off because archie is taking veronica': 1,
#  "okay okay we won't go it's not like i have a dress anyway": 1,
#  "you re looking at this from the wrong perspective we're making a statement": 1,
#  'oh good something new and different for u': 1,
#  'hey sweet cheek': 1,
#  'hi joey': 1,
#  "you're concentrating awfully hard considering it's gym class": 1,
#  'listen i want to talk to you about the prom': 1,
#  "you know the deal i can t go if kat doesn't go": 1,
#  'excuse me have you seen the feminine mystique i lost my copy': 1,
#  'what are you doing here': 84,
#  'i heard there wa a poetry reading': 1,
#  'you re so': 1,
#  'pleasant': 1,
#  'wholesome': 1,
#  'unwelcome': 1,
#  'unwelcome i guess someone still ha her panty in a twist': 1,
#  "don't for one minute think that you had any effect whatsoever on my panty": 1,
#  'so what did i have an effect on': 1,
#  'other than my upchuck reflex nothing': 1,
#  "you were right she's still pissed": 1,
#  'sweet love renew thy force': 1,
#  "man don't say shit like that to me people can hear you": 1,
#  'you humiliated the woman sacrifice yourself on the altar of dignity and even the score': 1,
#  "best case scenario you're back on the payroll for awhile": 1,
#  "what's the worst": 1,
#  'you get the girl': 1,
#  'he left i sprung the dickhead and he cruised on me': 1,
#  'look up sunshine': 1,
#  "i guess i never told you i'm afraid of height": 1,
#  "c'mon it's not that bad": 1,
#  'try lookin at it from this angle': 1,
#  'put your right foot there': 1,
#  "forget it i'm stayin": 1,
#  'you want me to climb up and show you how to get down': 1,
#  'the partridge family': 1,
#  'i figured it had to be something ridiculous to win your respect and piss you off': 1,
#  'good call': 3,
#  "so how'd you get chapin to look the other way": 1,
#  'i dazzled him with my wit': 1,
#  'a soft side who knew': 1,
#  "yeah well don't let it get out": 1,
#  "so what's your excuse": 1,
#  'acting the way we do': 1,
#  'yes': 1762,
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change": 1,
#  "so if you disappoint them from the start you're covered": 1,
#  'something like that': 32,
#  'then you screwed up': 1,
#  'how': 139,
#  'you never disappointed me': 1,
#  'you up for it': 1,
#  'for': 3,
#  'state trooper': 1,
#  'fallacy': 1,
#  'the duck': 1,
#  'hearsay': 1,
#  "i know the porn career's a lie": 1,
#  'tell me something true': 1,
#  'i hate pea': 1,
#  'no something real something no one else know': 1,
#  "you're sweet and sexy and completely hot for me": 1,
#  'no one else know': 1,
#  "you're amazingly self assured ha anyone ever told you that": 1,
#  'go to the prom with me': 1,
#  'is that a request or a command': 1,
#  'you know what i mean': 15,
#  'no what': 13,
#  "no i won't go with you": 1,
#  "because i don't want to it's a stupid tradition": 1,
#  'create a little drama start a new rumor what': 1,
#  'so i have to have a motive to be with you': 1,
#  'you tell me': 12,
#  'you need therapy ha anyone ever told you that': 1,
#  'answer the question patrick': 1,
#  "nothing there's nothing in it for me just the pleasure of your company": 1,
#  "then guillermo say if you go any lighter you're gonna look like an extra on 90210": 1,
#  'do you listen to this crap': 1,
#  'what crap': 1,
#  "me this endless blonde babble i'm like boring myself": 1,
#  'thank god if i had to hear one more story about your coiffure': 1,
#  "i figured you'd get to the good stuff eventually": 1,
#  'what good stuff': 1,
#  'the real you': 1,
#  'like my fear of wearing pastel': 1,
#  "i'm kidding you know how sometimes you just become this persona and you don't know how to quit": 1,
#  "okay you're gonna need to learn how to lie": 1,
#  'would you rather be ravished by a pirate or a british rear admiral': 1,
#  'pirate no question': 1,
#  "daddy i want to discus the prom with you it's tomorrow night": 1,
#  'the prom kat ha a date': 1,
#  'no but': 10,
#  "it's that hot rod joey right that s who you want me to bend my rule for": 1,
#  "he's not a hot rod whatever that is": 1,
#  "you're not going unless your sister go end of story": 1,
#  "fine i see that i'm a prisoner in my own house i'm not a daughter i'm a possession": 1,
#  "they'll dance they'll kiss they'll come home let her go": 1,
#  "kissing is that what you think happens kissing isn't what keep me up to my elbow in placenta all day": 1,
#  "listen i know you hate having to sit home because i'm not susie high school": 1,
#  'like you care': 1,
#  "i do care but i'm a firm believer in doing something for your own reason not someone else s": 1,
#  "i wish i had that luxury i'm the only sophomore that got asked to the prom and i can't go because you won t": 1,
#  'joey never told you we went out did he': 1,
#  'in 9th for a month': 1,
#  'he wa like a total babe': 1,
#  'but you hate joey': 1,
#  'now i do back then wa a different story': 1,
#  'a in': 3,
#  'he said everyone wa doing it so i did it': 1,
#  'you did what': 4,
#  "just once afterwards i told him i didn't want to anymore i wasn't ready he got pissed then he broke up with me": 1,
#  "after that i swore i'd never do anything just because everyone else wa doing it and i haven't since except for bogey's party and my stunning gastro intestinal display": 1,
#  "why didn't you tell me": 14,
#  'i wanted to let you make up your own mind about him': 1,
#  "no you didn't if you really thought i could make my own decision you would've let me go out with him instead of helping daddy hold me hostage": 1,
#  "that's not": 2,
#  "i'm not stupid enough to repeat your mistake": 1,
#  'i guess i thought i wa protecting you': 1,
#  "god you're just like him just keep me locked away in the dark so i can't experience anything for myself": 1,
#  "not all experience are good bianca you can't always trust the people you want to": 1,
#  "i guess i'll never know will i": 1,
#  "what do you wanna watch we've got crap crap crap or crap": 1,
#  'dr ruth': 1,
#  "i'm missing something": 1,
#  'i have a date daddy and he s not a captain of oppression like some men we know': 1,
#  'wow': 44,
#  "let's go": 51,
#  'have a great time honey': 1,
#  'but who what': 1,
#  'what just happened': 4,
#  'your daughter went to the prom': 1,
#  'did i have anything to say about it': 1,
#  'absolutely not': 17,
#  'that s what i thought': 1,
#  "how'd you get a tux at the last minute": 1,
#  "it's scurvy's his date got convicted where'd you get the dress": 1,
#  "it's just something i had you know": 1,
#  'oh huh': 4,
#  "look i'm sorry that i questioned your motif i wa wrong": 1,
#  'have you seen him': 4,
#  'william he asked me to meet him here': 1,
#  "oh honey tell me we haven't progressed to full on hallucination": 1,
#  'you think you re the only sophomore at the prom': 1,
#  'i did': 46,
#  "my grandmother's": 1,
#  "that's where i wa last year she'd never lived alone my grandfather died i stayed with her i wasn't in jail i don't know marilyn manson and i've never slept with a spice girl i spent a year sitting next to my grandma on the couch watching wheel of fortune end of story": 1,
#  'that s completely adorable': 1,
#  'it get worse you still have your freshman yearbook': 1,
#  'wait i': 1,
#  'you were paid to take me out by the one person i truly hate i knew it wa a set up': 1,
#  "it wasn't like that": 5,
#  'really what wa it like a down payment now then a bonus for sleeping with me': 1,
#  "i didn't care about the money": 1,
#  'you looked beautiful last night you know': 1,
#  'so did you': 1,
#  'she okay': 2,
#  'i hope so': 15,
#  'wa that your sister': 1,
#  'yeah she left with some bikers big one full of sperm': 1,
#  'funny': 8,
#  "i don't understand the allure of dehydrated food is this something i should be hip to": 1,
#  'no daddy': 1,
#  'so tell me about this dance wa it fun': 1,
#  'part of it': 1,
#  'which part': 2,
#  'the part where bianca beat the hell out of some guy': 1,
#  'bianca did what': 1,
#  "what's the matter upset that i rubbed off on her": 1,
#  'no impressed': 1,
#  "you know father don't like to admit that their daughter are capable of running their own life it mean we've become spectator bianca still let me play a few inning you've had me on the bleacher for year when you go to sarah lawrence i won't even be able to watch the game": 1,
#  'when i go': 1,
#  "oh christ don't tell me you've changed your mind i already sent em a check": 1,
#  'let go': 7,
#  'you set me up': 3,
#  'i just wanted': 1,
#  'what to completely damage me to send me to therapy forever what': 1,
#  'no i just wanted': 1,
#  'am i supposed to feel better like right now or do i have some time to think about it': 1,
#  'just smack her now': 1,
#  'is that woman a complete fruit loop or is it just me': 1,
#  "it's just you": 1,
#  'a fender strat you bought this': 1,
#  'i thought you could use it when you start your band': 1,
#  'besides i had some extra cash some asshole paid me to take out a really great girl': 1,
#  'is that right': 18,
#  'yeah but then i fucked up i fell for her': 1,
#  'why is my veggie burger the only burnt object on this grill': 1,
#  'because i like to torture you': 1,
#  'oh bianca can you get me my freshman yearbook': 1,
#  'don t you even dare': 1,
#  'they do to': 1,
#  'they do not': 1,
#  'patrick is that a': 1,
#  'perm': 1,
#  'is that the man i knew treasurer sanchez': 1,
#  'yes your majesty': 2,
#  'diego is a bright boy a pleasure to teach but so serious brother should be raised together colon even brother from different mother': 1,
#  'father i am doing what i think is the best for him and he ha the teacher i would have chosen for myself': 1,
#  "god that's in a week": 1,
#  "that's what it say": 2,
#  'how did you manage it': 1,
#  'with some difficulty i had to promise them you were not a total fool': 1,
#  'why do you wish to sail west': 1,
#  'to open a new route to asia at the moment there are only two way of reaching it': 1,
#  'how can you be so certain the ocean is said to be infinite': 1,
#  'ignorance i believe the indie are no more than 750 league west of the canary island': 1,
#  'how can you be so certain': 1,
#  'the calculation of toscanelli marin de tyr esdras': 1,
#  'esdras is a jew': 1,
#  'so wa christ': 1,
#  "two minute and already you're a dead man don't let passion overwhelm you colon": 1,
#  "i'll try to remember that marchena": 1,
#  'father marchena': 1,
#  'passion is something one cannot control': 1,
#  'you get so carried away when you are being contradicted': 1,
#  "i've been contradicted all my life eternity": 1,
#  'only god know the meaning of such word my son': 1,
#  'i could be gone for year': 1,
#  "i haven't given you much of a life": 1,
#  "well that's true i have a child by a man who won't marry me who's always leaving": 1,
#  'are we going to argue': 1,
#  "i'd love to argue with you sometimes but you're never here": 1,
#  'perhaps i wa never meant to live with a woman': 1,
#  'i find that hard to believe': 1,
#  'you say asia can be found by sailing west': 1,
#  'yes your eminence the voyage should not take more than six or seven week': 1,
#  'unfortunately don colon that is precisely where our opinion differ are you familiar with the work of aristotle erathostene ptolemeus': 1,
#  'i am your eminence': 1,
#  'then you cannot ignore that according to their calculation the circumference of the earth is approximately 22000 league or more which make the ocean uncrossable': 1,
#  'senor colon an experienced captain such a yourself will understand our concern with the crew i am not willing to have on my conscience the loss of men who would have relied upon our judgment': 1,
#  'excellency you are right': 1,
#  'your eminence there is only one way to settle the matter and that is to make the journey i am ready to risk my life to prove it possible': 1,
#  'your life and that of others': 1,
#  'if they agree to follow me yes': 1,
#  'trade your excellency according to marco polo the kingdom of china is one of the richest of the world even the meanest building are roofed with gold': 1,
#  'is that all that interest you gold': 1,
#  'no the portuguese have already discovered black skinned people i too will find other population and bring them to the word of god': 1,
#  'if god intended our proximity to asia do you believe he would have waited for you to show it to the world': 1,
#  "did he not choose a carpenter's son to reveal himself to the world": 1,
#  "don't you realize your word could be considered heretical": 1,
#  'blind faith is what i consider heresy': 1,
#  'asia can be found to the west and i will prove it': 1,
#  'if god will it': 1,
#  "the state ha some reason to be interested in this man's proposition your eminence": 1,
#  'the judgment is ours': 1,
#  'naturally but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography': 1,
#  'he is a mercenary did he not already try to convince the king of portugal of his absurd notion': 1,
#  'indeed the world is full of mercenary and state often make use of them when it benefit them my only concern is the welfare and prosperity of spain': 1,
#  "you mustn't give way to despair you must wait": 1,
#  "wait i've waited seven year already how much longer do you want me to wait": 1,
#  'if god intends you to go then you will go': 1,
#  'damn god': 1,
#  'colon': 1,
#  'damn all of you you all set up theory based on what you never leave the safety of your study go out find out what the world is about and then tell me something i can listen to': 1,
#  'all of them just lie': 1,
#  "colon don't": 1,
#  'where can i meet this man': 1,
#  'immediately': 1,
#  'i should not even be listening to you since my council said no but santangel tell me you are a man of honor and sincerity and sanchez that you are not a fool': 1,
#  'no more than the woman who said she would take granada from the moor': 1,
#  'the ocean is uncrossable': 1,
#  'what did they say about granada before today': 1,
#  'that she wa impregnable': 1,
#  'i cannot ignore the verdict of my council': 1,
#  'surely you can do anything you want': 1,
#  'may i speak freely': 1,
#  'you show no inclination to speak otherwise': 1,
#  "i know what i see i see someone who doesn't accept the world a it is who's not afraid i see a woman who think what if": 1,
#  'a woman': 5,
#  'how old are you senor colon': 1,
#  'thirty seven your majesty and you': 1,
#  'no i have waited too long fought too hard now you expect me to take all the risk while you take the profit no i will not be your servant': 1,
#  'i remind you senor colon that you are in no position to bargain with me': 1,
#  "i'm not bargaining": 1,
#  'then you are too ambitious': 1,
#  'and were you never ambitious excellency or is ambition only a virtue among the noble a fault for the rest of u': 1,
#  "if you won't accept our proposal we'll simply find someone who will": 1,
#  'you were right don sanchez his demand could never be granted': 1,
#  'never your majesty although': 1,
#  'into a monk': 1,
#  "yes it would be a pity wouldn't it call him back": 1,
#  'she said yes': 1,
#  'thank god': 16,
#  "i'm not asking you to swear to anything": 1,
#  "i don't want you to wait for me": 1,
#  "that's something you can't decide": 1,
#  'i want to go with you': 2,
#  "there'll be a time": 1,
#  'you promise do you swear on st christopher': 1,
#  'do you swear on all the holy saint in heaven': 1,
#  'yes yes i do on all of them': 1,
#  'in nomine patris et filius et spiritus sancti': 1,
#  'forgive me father for i have sinned': 1,
#  'i am listening my son': 1,
#  'father i have betrayed my family i betrayed my men and i betrayed you': 1,
#  'what are you saying': 22,
#  'i lied the journey will be longer than i said': 1,
#  'how long': 19,
#  'i am not sure it could be twice the distance': 1,
#  'may god forgive you you must tell them you must tell your men': 1,
#  "if i tell them they won't follow me you know that i am right father you trust me": 1,
#  "my son my son your certitude are sometimes frightening christopher you must speak to them and if you don't i will": 1,
#  'you are bound by an oath father': 1,
#  'i believed in you': 1,
#  'give me absolution': 1,
#  'due west captain mendez and may god be with u': 1,
#  'god be with u admiral': 1,
#  "well it's the men sir they wonder how you know our position we've lost sight from land day ago": 1,
#  'and what do you think mendez': 1,
#  "well i surely know what a quadrant is but i've never seen it used at night before": 1,
#  'come over here': 3,
#  'what do you read': 1,
#  'twenty eight': 3,
#  'i never seen heat like this not even in la mina': 1,
#  "the water's going putrid in the barrel": 1,
#  "you'll be drinking your own piss for the glory of spain and admiral colon bastard": 1,
#  'what are you listening to chicken as': 1,
#  "ah leave him alone he's doing no harm": 1,
#  "with a face like that i don't want you looking at me you hear": 1,
#  "he's the devil's child": 1,
#  "we'll all go crazy": 1,
#  'we should have seen land': 1,
#  "we left three week ago alonso can't be that near": 1,
#  "can't be that far i say also i don't like the smell of the sea around here smell like a cunt bad sign": 1,
#  "you lied you cheated we're way past 750 league": 1,
#  'six day ago yes': 1,
#  'you must be mad': 2,
#  'we have to keep the hope of these men alive': 1,
#  "we're on the verge of a mutiny colon": 1,
#  "you think i don't know that": 2,
#  "we're lost": 1,
#  'the land is there i know it': 1,
#  "you don't know anything listen colon these are my ship right so i'm telling you we're turning back": 1,
#  'and then what half of the water ha gone the rest is nearly putrid you know that': 1,
#  'jesus maria i should have never listened to you': 1,
#  'you never did you did all the talking for both of u remember': 1,
#  'you bloody': 1,
#  'pinzon pinzon all we can do now is go forward think about that': 1,
#  'you tell that to them': 1,
#  "you're right let the men decide": 1,
#  'say not here cuba': 1,
#  'what is it a tribe an island': 1,
#  'island far': 1,
#  'you come you speak first': 1,
#  'tell the chief we thank him': 1,
#  'chief know': 1,
#  'tell him his country is very beautiful tell him we are leaving men here to build a fort': 1,
#  'chief say how many': 1,
#  'thousand': 2,
#  'to bring the word of god': 1,
#  'chief say he ha a god': 1,
#  'and also to bring medicine': 1,
#  'chief say': 1,
#  'he ha medicine tell him we admire his people': 1,
#  "it won't be easy to get rid of your prophet now don sanchez": 1,
#  'on the contrary your eminence it seems to me the man is preparing his own cross': 1,
#  "and you say this is an indian vice by god i don't see any kind of pleasure that would make this a sin": 1,
#  'the indian have no such word don moxica': 1,
#  'do they have such thought': 1,
#  'they come and go a naked a the day god created them': 1,
#  "they don't see sin in their nakedness they live according to nature in a never ending summer the island are covered with tree filled with blossom and fruit and": 1,
#  'forgive me don colon but what about gold': 1,
#  'you defend yourself admirably': 1,
#  'for a commoner': 1,
#  'i understand that you will soon be appointing governor for the island is it not so': 1,
#  'forgive me don bobadilla those position have already been taken': 1,
#  'may i ask by whom': 1,
#  'bartolome and giacomo colon': 1,
#  'but we do have a lack of notary you should contact my administration': 1,
#  'don bobadilla is already a judge my dear don cristobal': 1,
#  'good we are also in need of judge except there are no thief': 1,
#  'you seem to have a special talent for making friend': 1,
#  'what do i have so many already': 1,
#  'to rise so high in so short a time is a dangerous occupation a little hypocrisy go a long way': 1,
#  'beatrix i want to ask you something': 1,
#  "you don't usually ask": 1,
#  'i can arrange for the queen to take fernando and diego into her service': 1,
#  'we lost cousin friend we will wash this in blood': 1,
#  "if you want to keep your head on your shoulder you'll do a i say": 1,
#  'you want a war fine we are a thousand they outnumber u by ten who will you kill which tribe': 1,
#  "we don't need to know": 1,
#  'we came here to stay to build not to start a crusade in this forest there is enough danger to sweep u away in day so we will be brave and swallow our grief and in the name of those who died we will accomplish what we came for': 1,
#  'we will work with his people we want peace ask the chief if he understands': 1,
#  'he understands': 1,
#  'ask him if he will help': 1,
#  "we can't raise the wheel without it": 1,
#  "my horse doesn't work": 1,
#  'don moxica we all have to work': 1,
#  'you did not hear me don colon not my horse': 1,
#  'every ship return with a cargo of sick and dying but with no gold the new world prof expensive your majesty': 1,
#  "we weren't expecting immediate profit were we we must have faith we must give time for time": 1,
#  'in one act of brutality you have created chaos tribe who were fighting each other are now joining force against u all that because of your criminal savagery': 1,
#  'savagery is what monkey understand': 1,
#  "you'll be held in detention deprived of your privilege and possession until you are returned to spain where you will be judged have you anything to say": 1,
#  'you will regret this': 1,
#  'you have to find them utapan look what they did': 1,
#  'you did the same to your god': 1,
#  "utapan won't you speak to me you used to know how to speak to me": 1,
#  'you never learned how to speak my language': 1,
#  'but there is worse he ordered the execution of five member of the nobility': 1,
#  'is this true brother buyl': 1,
#  'then what do you suggest don sanchez': 1,
#  'he must be replaced': 1,
#  'and who would you think of for such a task': 1,
#  'don alonso de bobadilla': 1,
#  'yes i remember': 3,
#  'my letter of appointment': 1,
#  'appointment to what': 1,
#  'viceroy of the west indie': 1,
#  'congratulation then i am free to search for the mainland': 1,
#  'how far from here': 1,
#  'i am not a seaman but i heard it is no more than a week at sea i hope you are not too disappointed': 1,
#  'how could i be the mainland ha been found exactly a i said it would': 1,
#  'i am afraid this is not the worst news': 1,
#  'i have to explore the mainland': 1,
#  'this time with me': 1,
#  'but without your brother nor are you to return to santo domingo or any of the other colony you may explore the continent': 1,
#  'thank you': 322,
#  "there is one thing i'd like to understand why do you want to go back after all this": 1,
#  'your majesty some men are content to read about thing i must see them with my own eye i cannot be other than i am': 1,
#  'i know i should not tolerate his impertinence': 1,
#  'then why': 3,
#  'because he is not afraid of me': 1,
#  'all i have to do is call the guard': 1,
#  'call them': 1,
#  'i am not afraid of you you are nothing but a dreamer': 1,
#  'look out of that window': 1,
#  'what do you see': 7,
#  'roof tower palace spire': 1,
#  'all of them created by people like me': 1,
#  "god you're so beautiful i can't believe no other man ha ever taken you away from me": 1,
#  "they tried but i didn't let them": 1,
#  'they took everything': 1,
#  "not everything do you think i care i'm a free man again rich don't make a man rich they only make him busier": 1,
#  'how are you feeling fernando': 1,
#  'not bad': 10,
#  "what's he doing": 6,
#  "he's drawing an isthmus he's saying we're on an isthmus": 1,
#  "we can't be": 1,
#  'father': 14,
#  'there must be a passage to that other ocean': 1,
#  'you can see for yourself': 1,
#  'what a tragedy what a waste of a life': 1,
#  'a waste let me tell you something arojaz if your name or mine is ever remembered it will only be because of his': 1,
#  "i suppose we're both old men now": 1,
#  "you'll always be older than me father": 1,
#  'i have to disagree': 1,
#  'i knew you would': 3,
#  'new world create new people': 1,
#  'oh so you are a new man': 1,
#  "i don't know i have the impression that i didn't change that much i still can't accept the world a it is": 1,
#  "can't you stay with u a little": 1,
#  'i am busy inside': 1,
#  'what is it now tell me': 1,
#  "i can't keep my eye off you i would like to catch up with all the moment i didn't spend with you": 1,
#  'what are you listening to': 2,
#  "i am not listening father but i can't help hearing": 1,
#  'what doe he say': 4,
#  'he asks when he can come to visit you he left his address': 1,
#  'he never had one except aboard my ship': 1,
#  'i want you to tell me everything you remember father from the beginning everything': 1,
#  "really god i wouldn't know where to start and yet": 1,
#  'tell me the first thing that come to your mind': 1,
#  "just do what i do say the same thing i say don't open your mouth": 1,
#  "don't fool around": 1,
#  'did you hear what i said': 6,
#  'i want to document my trip to america': 1,
#  'next could i see your document please': 1,
#  'yes sir': 277,
#  'what is your intended purpose of your visit to the united state': 1,
#  'two week holiday': 1,
#  'how much money are you carrying with you': 1,
#  'i have five hundred dollar': 1,
#  'can you show me sir no camera in the fis area': 1,
#  'is he with you are you travelling together': 1,
#  'please join u come on forward': 1,
#  'is there a problem': 6,
#  "no you're travelling together i want to talk to you together hi how are you can i take a look at your document are you related": 1,
#  "yes he's my friend": 1,
#  "okay you're a czech national and you're a russian national how do you know one another": 1,
#  'we are both from prague': 1,
#  'how long are you planning to stay': 1,
#  'two week': 4,
#  "i'd like to speak for himself okay": 1,
#  "he doesn't speak english": 1,
#  'i speak english': 2,
#  "then answer my question where were you planning to stay during the two week that you're here": 1,
#  'new york': 5,
#  "yes we're in new york now but where are you planning to stay in new york": 1,
#  'a cheap hotel': 1,
#  'what are you coming here to do': 1,
#  "i'm here for movie": 1,
#  'movie to be in the movie or to see movie': 1,
#  "yes no both when i wa a boy i see movie at school called it's a wonderful life directed by frank capra ever since i want to come to america land of the free home of the brave a land where anyone can be anything a long a they are white": 1,
#  "so we're waitin to hit this warrant we got emergency service with the heavy weapon standin by ready to go i say lemme get a cigar outta the car i go to get the cigar and boom all the sudden i turn around and a kid with a shotgun let one go right where i wa standin that coulda been it i coulda had my head blown off and for what some stupid kid got panicky take the safety off and it's over if i hadn't gone back for that cigar for a bad habit i would've had my head blown off": 1,
#  'jesus christ': 29,
#  'coffee for me i gotta slow down': 1,
#  'vodka tonic': 1,
#  'maybe you could just put in a shot of martell': 1,
#  "it wa freaky i'll tell you stupid kid": 1,
#  "what's the kid gonna say sorry meanwhile i'm not here anymore like last week we were at the morgue and this guy wa all chopped up spleen here liver there his heart in a pan six hour ago this guy wa walkin his dog or buyin a quart of milk who know but some kid's robbed him for 3 or some shit and shot him and now you can't tell if he's a piece of beef or a human being and i'm thinkin that's me sooner or later that's me": 1,
#  "sooner or later that's everybody": 1,
#  'not chopped up not chopped up like that i mean what do i got left coupla article a medal or two plaque here and there and in a coupla year no one remembers me anymore': 1,
#  "i think you're getting a little moody there eddie": 1,
#  "i'm not moody": 1,
#  "isn't he a little moody": 1,
#  "of course he's moody he think he's in love": 1,
#  'in love with who': 1,
#  'how old are your kid': 1,
#  "my kid let's see susan's 15 aundrea's 9 don't tell me you're thinking about having a kid how old are you never mind let me just tell you this every stupid cliche you hear about kid they change your life they make you a better person they make you whole it's all true before i had kid when friend talked about their kid i wanted to vomit now i get it am i right leon": 1,
#  "paulie you've got kid right": 1,
#  'okay you work in a vodka factory i understand that and what kind of work do you do': 1,
#  'i am butcher': 1,
#  "you're a butcher what do you use pig intestine for": 1,
#  'you stuff sausage in it': 1,
#  'and what do you do with the bone': 1,
#  'dog food': 1,
#  'are you married': 8,
#  'no are you proposing': 1,
#  "i'm gonna propose": 1,
#  'when': 91,
#  'tomorrow at lunch': 1,
#  'you ready': 10,
#  'look time square just like in the movie': 1,
#  "don't speak russian": 1,
#  'why why do i always have to speak to you in czech': 1,
#  "because i don't like your ugly language i heard enough of it in school now speak czech or english and don't fool around anymore you almost got u thrown out": 1,
#  'look new videocameras color viewfinder image stabilization solarization night vision': 1,
#  'we have no money come on': 1,
#  "so what's unique": 1,
#  'not what who': 1,
#  "he's from antigua his girlfriend wa taking too long to put her make up on they were late for a party stabbed her with a beer bottle": 1,
#  "that's unique": 1,
#  'yeah and he still went to the party': 1,
#  "i hope this prick doesn't run my knee are killing me stay behind me": 1,
#  "you're worried for my safety i'm touched": 1,
#  'ready': 30,
#  'keep them out of my way': 1,
#  'okay you ready': 1,
#  'yeah yeah jesus': 1,
#  'any chance we can do that again': 1,
#  "again i didn't wanna do it the first time": 1,
#  'turn that off get the bag': 1,
#  'why should i carry your bag i am not a dog': 1,
#  "for five year i paid for your stupidness you'll carry my bag for the rest of my life if i say so unless you refuse oleg": 1,
#  'smell like chemical for smoking drug': 1,
#  'emil': 1,
#  'surprise surprise': 2,
#  "your sister said she didn't know where you were so you shouldn't write to her with return address if you're hiding": 1,
#  'did you hurt her': 1,
#  "you know me i never hurt anybody where's the money": 1,
#  "take your eye off her oleg look it wasn't my fault you two were caught it's his fault trying to get the bank clerk's phone number i wasn't going to wait": 1,
#  'milo get my money': 1,
#  ...}

# %%
#example of duplcated msg
messages[messages['msg_pre_processed'] == 'did you change your hair']
# Out:
#                msg_line user_id movie_id                        msg  \
# msg_line_clean
# 49                  L49      u0       m0  Did you change your hair?
# 151439          L151439   u4736     m314  Did you change your hair?
#
#                     msg_2         msg_pre_processed
# msg_line_clean
# 49                    No.  did you change your hair
# 151439          A little.  did you change your hair

# %%
d_list = list()
for k in dict:
    if dict[k] > 1:
        d_list.append(k)

# %%
d_list
# Out:
# ['did you change your hair',
#  'no',
#  'i missed you',
#  'thirty two',
#  'get out',
#  'who is she',
#  'why not',
#  "who's that",
#  'just a little',
#  "what's this",
#  "where've you been",
#  'i know',
#  'enough',
#  "you're not helping",
#  'forget it',
#  'cameron',
#  'why',
#  "that's a shame",
#  'what about him',
#  'hey',
#  "we're not",
#  'doe it matter',
#  'there',
#  'where',
#  'yeah',
#  'what do you think',
#  'you just said',
#  'how much',
#  'and why would i do that',
#  'seven thirty',
#  'are you following me',
#  'hi',
#  'not at all',
#  "i'm on it",
#  'what',
#  "you're sweet",
#  'say it',
#  'what plan',
#  "yeah we'll see",
#  'sure have',
#  'good enough',
#  'never',
#  'unknown',
#  'excuse me',
#  "why don't you",
#  "what'd he say",
#  'who care',
#  'see you next week',
#  "what's normal",
#  'can we go now',
#  'where ya goin',
#  'who',
#  'joey',
#  'great',
#  'neat',
#  "it's about time",
#  "a deal's a deal",
#  'do what',
#  'okay',
#  'sure',
#  'i told you',
#  'sure i do',
#  'i hate him',
#  "you're welcome",
#  'busy',
#  'maybe',
#  "no you weren't",
#  'this',
#  'i wa',
#  'well no',
#  'but',
#  "you didn't",
#  'yeah i guess',
#  'you think',
#  'oh yeah',
#  'right',
#  'what are you doing here',
#  'good call',
#  'yes',
#  'something like that',
#  'how',
#  'for',
#  'you know what i mean',
#  'no what',
#  'you tell me',
#  'no but',
#  'a in',
#  'you did what',
#  "why didn't you tell me",
#  "that's not",
#  'wow',
#  "let's go",
#  'what just happened',
#  'absolutely not',
#  'oh huh',
#  'have you seen him',
#  'i did',
#  "it wasn't like that",
#  'she okay',
#  'i hope so',
#  'funny',
#  'which part',
#  'let go',
#  'you set me up',
#  'is that right',
#  'yes your majesty',
#  "that's what it say",
#  'a woman',
#  'thank god',
#  'i want to go with you',
#  'what are you saying',
#  'how long',
#  'come over here',
#  'twenty eight',
#  'you must be mad',
#  "you think i don't know that",
#  'thousand',
#  'yes i remember',
#  'thank you',
#  'then why',
#  'what do you see',
#  'not bad',
#  "what's he doing",
#  'father',
#  'i knew you would',
#  'what are you listening to',
#  'what doe he say',
#  'did you hear what i said',
#  'yes sir',
#  'is there a problem',
#  'two week',
#  'i speak english',
#  'new york',
#  'jesus christ',
#  'are you married',
#  'when',
#  'you ready',
#  'ready',
#  'surprise surprise',
#  'ha ha',
#  'a job',
#  'clean',
#  'what wa that',
#  'no what is it',
#  "what's he looking for",
#  'you okay',
#  'speak english',
#  'yeah right',
#  'give me the address',
#  'pretty',
#  'hmmmm',
#  "i'll come with you",
#  'stay here',
#  'who is he',
#  'where is she',
#  "it's okay",
#  "who's there",
#  "what's wrong",
#  'describe him',
#  'you thirsty',
#  "i'm on duty",
#  'of course',
#  "no i'm okay",
#  'alright',
#  'go on',
#  'a cop',
#  "i don't have a girlfriend",
#  'my point exactly',
#  'so am i',
#  'shut up',
#  'doe it hurt',
#  'divorced',
#  'stop it',
#  "i'm not",
#  "that's good",
#  'promise',
#  'i love you',
#  'tonight',
#  'you promise',
#  "don't be late",
#  'what is it',
#  'what is that',
#  'sit down',
#  'oh',
#  'what do you want',
#  'good idea',
#  'cut',
#  'robert',
#  'wait a minute wait a minute',
#  'how wa it',
#  'not good',
#  'are you alright',
#  "i'm sorry",
#  'is he your boyfriend',
#  'in the kitchen',
#  'what are you doing',
#  'get outta here',
#  'what the hell happened',
#  "i'm serious",
#  'you got that',
#  'where are we going',
#  "i'm coming with you",
#  "i'll take him",
#  'what are you gonna do',
#  'oh sure',
#  'no no way',
#  "but it's",
#  'fine',
#  'are you coming to my party',
#  'when are you coming home',
#  'thank you daddy',
#  'yes daddy',
#  'continued',
#  'really',
#  "that's right",
#  'i see',
#  'certainly',
#  'oh thank you very much',
#  'what do you mean',
#  'sure what is it',
#  "what's up",
#  "it's possible",
#  'well what is it',
#  'yes i thought so',
#  "that's true",
#  'true',
#  'roger',
#  'i understand',
#  "well that's something",
#  "you're kidding",
#  'yes i know',
#  'i guess not',
#  'yes it is',
#  "that's the way i see it too",
#  "what's wrong with that",
#  "what'd you do",
#  'how ya doin',
#  "can't complain",
#  'yeah old time',
#  'call me later',
#  "i don't know what you're talkin about",
#  'shit',
#  'jack',
#  'jack are you okay',
#  "you're crazy",
#  'bullshit',
#  "i'll think about it",
#  "i don't know",
#  'when how',
#  'last night',
#  'well',
#  'what are you talkin about',
#  'vodka',
#  'come on',
#  'how about it',
#  'half a million',
#  'jesus',
#  "where's the money",
#  'name',
#  'great just great',
#  'no class',
#  'you stay with me',
#  'no way',
#  'how you doing man',
#  'not bad not bad',
#  'you sure',
#  'give it back',
#  'you look awful',
#  'nothing',
#  'goodbye',
#  'hello again',
#  'hello',
#  "hi it's me",
#  'fuck you',
#  'that wa quick',
#  'let her go',
#  "don't worry about it",
#  'who the hell are you',
#  'how would you know',
#  'how do you know',
#  'so what',
#  'where is he',
#  'tell me',
#  "you're impossible",
#  'thanks',
#  'amen',
#  'drink',
#  'is that better',
#  'option',
#  'recommendation',
#  'gentleman',
#  'how do i look',
#  "i don't need one",
#  'and then',
#  'been here long',
#  'uh',
#  "it's not",
#  'thanks for reminding me',
#  'what are we going to do',
#  'wonderful',
#  'scuse me',
#  'who are you',
#  'the girl',
#  'you noticed',
#  "it's a miracle",
#  'what is',
#  "what's your name",
#  'leeloo',
#  "that's what i thought",
#  "what's she doing",
#  'yes of course',
#  'perfect',
#  "we're saved",
#  'would you like a drink',
#  'no thank you',
#  'hi ma',
#  'yes ma',
#  'what mission',
#  "i'm not going",
#  "it's my wife",
#  'apipoulai',
#  'good luck',
#  'you hear that',
#  'oh god',
#  'not yet',
#  'love',
#  'which one',
#  'apipoussan',
#  'am i disturbing you',
#  'got it',
#  'ma',
#  'here we go again',
#  'where you going',
#  'do you love her',
#  'they are with me',
#  "i'll be right back",
#  'found it',
#  "i don't even know what i'm looking for",
#  "that's what i'm saying",
#  'is that all',
#  'like love',
#  'exactly',
#  'because',
#  'welcome home',
#  'i try to be',
#  "i'm listening",
#  'my condolence',
#  'pittsburgh',
#  'we do',
#  'any good',
#  'yes but',
#  "i didn't mean to",
#  'you should be',
#  'pardon me',
#  "i'll risk it",
#  'good for you',
#  'max',
#  'not quite',
#  'what are these',
#  'how old are you',
#  'twenty five',
#  'what about me',
#  'good question',
#  "you're joking",
#  "i'm here",
#  'what is this',
#  "i'll do what i can",
#  'cash',
#  'no you may not',
#  'okay fine',
#  'certainly sir',
#  'eddie',
#  'i know what you did',
#  'who is this',
#  'what the fuck are you',
#  'what are you talking about',
#  "i'm telling you",
#  'see ya',
#  "i hope it's nothing serious",
#  'wha',
#  'hmm',
#  'is it',
#  'machine',
#  'we can do that',
#  "i'd rather you didn't",
#  "what's the problem",
#  "where's that",
#  "what's next",
#  'nope',
#  'right here',
#  'excellent',
#  'what are you',
#  'is that him',
#  'friend of yours',
#  'give me the film',
#  'leave him alone',
#  'fuck off',
#  'what the fuck',
#  'sorry',
#  "what's he talking about",
#  "he's lying",
#  "what's going on",
#  'what happened to you',
#  'tom',
#  "i don't know i'm sorry",
#  "you couldn't",
#  "you don't understand",
#  "i don't know what to say",
#  "don't",
#  'amy',
#  'who are you calling',
#  "i told you i don't know",
#  'tell me what happened',
#  'show me',
#  'keep moving',
#  'stop talking',
#  'do it',
#  "don't think i won't",
#  'no no no',
#  "i don't want to",
#  'you what',
#  'you in a hurry',
#  "i'll tell you later",
#  "i don't get it",
#  'so',
#  "what's wrong with me",
#  'you alright',
#  'in her dream',
#  'that obvious huh',
#  'it wa bad',
#  "i can't find him",
#  'three day',
#  'not really',
#  "he's going after debbie i gotta stop him",
#  'here we are',
#  'what the hell wa that',
#  'you look great',
#  'about him',
#  "you're right",
#  'me too',
#  'dad',
#  'huh',
#  'my name is',
#  'how did you know that',
#  "what's that got to do with it",
#  'very funny',
#  'alice',
#  'mark',
#  'my baby',
#  'where are you going',
#  'you too',
#  "that's their problem",
#  'meaning',
#  'no shit',
#  "i don't understand",
#  "i've got to go",
#  'now',
#  'mommy',
#  'but how',
#  'virgil',
#  'not for long',
#  'who else',
#  'that must be it',
#  'what happened',
#  'check this out',
#  'copy that',
#  'how you guy doing',
#  'where are we',
#  'hey you okay',
#  "i don't know i don't know",
#  "what's the matter with you",
#  'need some help',
#  'you watch yourself',
#  'fish',
#  'now what',
#  'give me that',
#  'try again',
#  'son of a bitch',
#  "i don't know how",
#  "what's the plan",
#  'tell me later',
#  'who then',
#  'uh oh',
#  'used to what',
#  'but where are you going',
#  "i'm thirsty",
#  'did you sleep well',
#  'why have we stopped',
#  'ask her',
#  'how are you',
#  'wait for what',
#  'who are you talking to',
#  'at what',
#  'well what',
#  'nothing nothing at all',
#  'are you feeling better',
#  'unfortunately no',
#  'a you wish',
#  "we'll try again",
#  'to do what',
#  'and what about you',
#  'and who is this',
#  'here i am',
#  "why don't you try",
#  'any news',
#  'are you joking',
#  'why are you looking at me like that',
#  'your mother',
#  'yes yes of course',
#  'you know',
#  "it's not that",
#  'what then',
#  "it's stupid",
#  "it's fun",
#  "don't mind if i do",
#  'jesus why',
#  'not here',
#  'for a while',
#  "how's she doing",
#  'damn straight',
#  'you think so',
#  'mmm',
#  "i'm okay",
#  'this way',
#  'rolfe',
#  'just do it',
#  "it don't look right",
#  'said what',
#  'call me',
#  'the other guy',
#  "what's the hurry",
#  'like hell',
#  'you see it',
#  'sure you did',
#  'wade',
#  'how wa she',
#  'get some sleep',
#  "how's that",
#  'what the hell are you talking about',
#  'hold on',
#  'money',
#  'but not now',
#  'what way',
#  "it's nice",
#  'good',
#  'strange',
#  'sleeping',
#  "where's ma",
#  'when did she die',
#  'in the living room',
#  'it make me sad',
#  'can',
#  'yeah i forgot',
#  "i'm fine fine",
#  'this is nut',
#  'what about her',
#  'which is',
#  "i don't know you tell me",
#  'not particularly',
#  "that's what you think",
#  'how soon',
#  'could be',
#  "you don't believe me",
#  'for what',
#  'hi honey',
#  'pop',
#  'i want to go home',
#  "you can't",
#  'you and me',
#  'yes i',
#  'no one',
#  'is that normal',
#  "what's his name",
#  "no i don't",
#  "that wasn't me",
#  "no i'm not",
#  "let's talk about something else",
#  'right now',
#  'uh huh',
#  'oh yes',
#  'often',
#  'would you like to talk about it',
#  'why should they',
#  'did it hurt',
#  'down there',
#  'and what did you do',
#  'and what happened',
#  'and then what',
#  'i fell asleep',
#  'what baby',
#  "i i don't understand",
#  "don't you know",
#  'agnes',
#  'anything',
#  "what's your real name",
#  'would you like some',
#  'doe it bother you',
#  'no question',
#  'one',
#  'no do you',
#  'why should i',
#  "what's your opinion",
#  "that's ridiculous",
#  "that's absurd",
#  "i can't say",
#  'who told you this',
#  "i'm not hungry",
#  "i'm being punished",
#  '',
#  'like what',
#  'what thing',
#  'somebody told her',
#  "you'll laugh",
#  'do you',
#  "because i don't want one",
#  'like you',
#  'a mistake',
#  'i am',
#  'answer',
#  'oh dear god',
#  'yes mother',
#  'when wa that',
#  'what doe this have to do with',
#  "i'm not sick",
#  'what did you do',
#  "i can't",
#  'she',
#  "i'm afraid",
#  'yes i am',
#  'you lied to me',
#  'about what',
#  'larry',
#  "we'll see about that",
#  "i haven't decided yet",
#  'all right',
#  'fine thanks',
#  'yes i do',
#  'who am i',
#  'of what',
#  "i can't tell you that",
#  'and then what happened',
#  "someone's following me",
#  'my bed',
#  'what else',
#  'are you ill',
#  'what do you do',
#  "go away i don't want you here",
#  "you're what",
#  "don't be ridiculous",
#  'this is insane',
#  'next week',
#  'wa it you',
#  'too late for what',
#  "that's a lie",
#  'and the baby',
#  'him',
#  'are you frightened',
#  'stay away from me',
#  "that's enough",
#  "i don't remember",
#  'oh i see',
#  'he started it',
#  'well what happened',
#  'and',
#  "y'what",
#  'yeah so what',
#  'me why',
#  'ah',
#  'lay them down',
#  'eh',
#  'they are',
#  'wake up',
#  'you are',
#  'is it is it really',
#  'nerve',
#  'what are you doing there',
#  'hiding',
#  'shurrup',
#  'behave',
#  "you wouldn't",
#  "what's he know",
#  "so's mine",
#  'out where',
#  "what's that mean",
#  "yeah that's right",
#  'a book',
#  'get knotted',
#  "he hasn't",
#  'nine',
#  'just you',
#  "why aren't you at work",
#  'oh there you are',
#  'is he',
#  'well come on',
#  "i'm afraid i don't understand",
#  'ta',
#  "i don't care",
#  'i beg your pardon',
#  'get him out of here',
#  "how'd you guess",
#  'gear',
#  'is she',
#  'pity',
#  'see you',
#  "you don't think",
#  "they'll be here",
#  'what is he',
#  'me',
#  'what are they saying',
#  'come here',
#  "no we're not",
#  "that's my job",
#  "i'm sorry honey",
#  "can't it wait",
#  'you know what',
#  'daddy',
#  'dead',
#  'twenty minute',
#  "we don't know that",
#  'who did this',
#  "i don't drink coffee",
#  'mom',
#  'yes dear',
#  'where are we now',
#  'gravity',
#  'the fax machine',
#  "that's affirmative",
#  'yes mr president',
#  'over my dead body',
#  'alice i',
#  'four',
#  'jim',
#  'three',
#  'stop',
#  "you'll do it",
#  'good good',
#  'sir',
#  "this doesn't make sense",
#  'there they are',
#  'stand by',
#  'elaine',
#  "if that's the way you want it",
#  "you can't go in there",
#  'all right here',
#  'dunn',
#  'ted',
#  'not now elaine',
#  'negative',
#  'i think so',
#  "that's my girl",
#  'go ahead',
#  'do you want to talk about it',
#  'did you feel that',
#  'yes i did',
#  'what is it mary',
#  "what's the story",
#  "you're sure",
#  "i'm sure",
#  'you mean',
#  'are you afraid',
#  'set',
#  'you expect me to believe that',
#  'every day',
#  'good bye darling',
#  "what's the matter",
#  "what's his problem",
#  'no no thank you',
#  "i can't tell",
#  'rain',
#  'and a little ice',
#  'sluggish like a wet sponge',
#  'here',
#  'yes captain',
#  'where the hell are we',
#  "let's hear it",
#  'oh my god',
#  'look',
#  "i'll see what i can do",
#  'locked',
#  'how long to fix',
#  'hard to say',
#  'yeah okay',
#  'close',
#  'anything else',
#  'receiving',
#  'that way',
#  'how far',
#  'found what',
#  'who know',
#  "i'll go first",
#  'martin',
#  "i'm on my way",
#  'take a look',
#  "i'm trying",
#  'yeah okay go ahead',
#  'yes what is it',
#  "why what's wrong",
#  'take care',
#  'what do you mean no',
#  "we're not going anywhere",
#  'how many',
#  'oh no',
#  "what the hell's going on",
#  'here let me try',
#  'ask him',
#  'where did it come from',
#  'look at that',
#  "it's stopped",
#  'this is horrible',
#  'engaged',
#  "don't you remember",
#  'it grows on you',
#  'oh no oh no',
#  'i hope not',
#  "where's it coming from",
#  'where are you',
#  "we're coming",
#  "don't be an idiot",
#  'you win',
#  'poison gas',
#  "what's that supposed to mean",
#  "don't count on it",
#  'u how u',
#  "good that's good",
#  'kill me',
#  "no don't",
#  'what can i do',
#  'it is',
#  'you',
#  'what is wrong',
#  'did you talk to him',
#  'why did you do it',
#  'who said that',
#  'but i',
#  "i'll handle it",
#  "what's that",
#  'screw you',
#  "i'm going home",
#  "where'd you get this",
#  'stop the car',
#  'what wa that about',
#  'what kind of test',
#  'we all did',
#  'in there',
#  'tell me about it',
#  'i get the picture',
#  'sweet jesus',
#  'yeah what',
#  'save it',
#  'poor bastard',
#  'what did you say',
#  "they're dead",
#  'alive',
#  "she's right",
#  'so so',
#  'position',
#  'you son of a bitch',
#  'gone',
#  'sorry to disappoint you',
#  "i'll go",
#  'see you soon',
#  'on my way',
#  "they'll get u",
#  'maybe maybe not',
#  'how do you feel',
#  "let's go let's go",
#  'fuckin a',
#  'stand back',
#  'how much time',
#  'ellen',
#  "i knew you'd come",
#  'mommy mommy',
#  'what do you need',
#  'is that a fact',
#  'what is this twenty question',
#  'want some',
#  'is it dead',
#  'wait a minute',
#  'oh man',
#  'yep',
#  'agreed',
#  'do you believe him',
#  'better',
#  'so what do you think',
#  'listen to what',
#  'i dunno',
#  'take a look at this',
#  "that's a fact",
#  "how's it going",
#  'what the hell are you doing',
#  'yeah i got it',
#  'hold it hold it',
#  'what where',
#  "what's happening",
#  "it's too late",
#  'nooooo',
#  'deal',
#  'sound great',
#  'what why',
#  'i found it',
#  'keep trying',
#  "i i can't",
#  'you have to',
#  'eve eve harrington',
#  'loud',
#  'easy now',
#  "ain't it the truth",
#  'oh brother',
#  'hello miss channing',
#  'my husband',
#  'of course it is',
#  'try',
#  'thank you so much',
#  'bill',
#  "that's nice",
#  "you're not going are you",
#  "no don't go",
#  "i'd like that",
#  'why what',
#  'of course not',
#  "i'll try",
#  'what again',
#  'oh oh',
#  'happy birthday darling',
#  'she did',
#  'the show must go on',
#  "i won't forget",
#  'yes yes it doe',
#  "i'm sorry i didn't mean to",
#  'cut it out',
#  'hear hear',
#  'need any help',
#  'coming',
#  'in a minute',
#  "i'd like to hear it",
#  "i don't think that's funny",
#  'guilty',
#  'please',
#  'liebestraum',
#  'a couple of week',
#  'would you',
#  'i promise',
#  'i will',
#  'how do you mean',
#  'of course i knew',
#  'how nice',
#  "it's all over",
#  'addison',
#  "i didn't hear you",
#  'here we go',
#  'well i am',
#  "i'll say",
#  'what time is it',
#  'incredible',
#  "it doesn't matter",
#  'what about bill',
#  'everything',
#  'and for you',
#  'find out',
#  'may i come in',
#  'please do',
#  'margo',
#  "i just can't believe it",
#  'eve',
#  'now just a minute',
#  'such a',
#  'you were great',
#  'too bad',
#  'well all right',
#  "i'm not cry",
#  'hungry',
#  'just like that',
#  'with tear',
#  'check',
#  'not much',
#  'i remember',
#  'that depends',
#  "what's so funny",
#  "aren't you",
#  'frankly yes',
#  'star',
#  'what time',
#  "we're",
#  'what do you take me for',
#  'what do you mean by that',
#  'what of it',
#  "that's not true",
#  'yes addison',
#  'how did you get in here',
#  "that's all",
#  'what for',
#  'probably not',
#  'i might',
#  "don't bother",
#  'phoebe',
#  "i'm not here",
#  'ok',
#  'i have nothing more to say',
#  'your name please',
#  'the c i a',
#  ...]

# %%
messages = messages.drop_duplicates(subset=['msg_pre_processed'])

# %%
#messages = messages.reset_index()

# %%
#example of duplcated msg
messages[messages['msg_pre_processed'] == 'did you change your hair']
# Out:
#                msg_line user_id movie_id                        msg msg_2  \
# msg_line_clean
# 49                  L49      u0       m0  Did you change your hair?   No.
#
#                        msg_pre_processed
# msg_line_clean
# 49              did you change your hair

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257095 entries, 49 to 666576
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   msg_line           257095 non-null  object
#  1   user_id            257095 non-null  object
#  2   movie_id           257095 non-null  object
#  3   msg                257095 non-null  object
#  4   msg_2              257095 non-null  object
#  5   msg_pre_processed  257095 non-null  object
# dtypes: object(6)
# memory usage: 13.7+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id  \
# count    257095  257095   257095
# unique   257095    8985      617
# top     L168013   u3681     m289
# freq          1     440     1268
#
#                                                       msg   msg_2  \
# count                                              257095  257095
# unique                                             257095  163760
# top     It's sticky. What you do slobber on 'em? I wou...       -
# freq                                                    1   70915
#
#                   msg_pre_processed
# count                        257095
# unique                       257095
# top     she read it in cosmopolitan
# freq                              1

# %% [markdown]
# ### Removing nan msg origined by '' messages

# %%
#filling the nan messages with a string
#messages = messages.fillna('UNKNOWN')

# %% [markdown]
# ### Removing apostrophes (need for embedding)

# %%
#The quality of the model became worst
#messages['msg_pre_processed'] = [ word.replace("\'","") for word in messages['msg_pre_processed']]

# %% [markdown]
# ### Filling '-' messages with a generic one

# %%
#return generic answer
def generic_answer(txt):
  asw_list = ['talk more about it',
              'can you explain it better?',
              'I need to think more about it',
              'maybe...'
              ]
  if txt == '-':
    return random.choice(asw_list)
  return txt

# %%
#seting a generic answer to the messages without answer
messages['msg_2'] = [generic_answer(msg) for msg in messages['msg_2']]

# %%
messages.head(30)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
# 78                  L78      u7       m0
# 87                  L87      u2       m0
# 88                  L88      u7       m0
# 89                  L89      u2       m0
# 90                  L90      u7       m0
# 91                  L91      u2       m0
# 92                  L92      u7       m0
# 103                L103      u8       m0
# 104                L104      u5       m0
# 105                L105      u8       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 89                                                    Who is she?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 91                                                       Why not?
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                                       maybe...
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                             talk more about it
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                  I need to think more about it
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                  I need to think more about it
# 77              Yeah but these guys have never seen a horse. T...
# 78                                                       maybe...
# 87                                  You burn you pine you perish?
# 88                                                    Who is she?
# 89              Bianca Stratford. Sophomore. Don't even think ...
# 90                                                       Why not?
# 91              I could start with your haircut but it doesn't...
# 92                                             talk more about it
# 103              Expressing my opinion is not a terrorist action.
# 104             Well yes compared to your other choices of exp...
# 105             I still maintain that he kicked himself in the...
#
#                                                 msg_pre_processed
# msg_line_clean
# 49                                       did you change your hair
# 50                                                             no
# 51                                 you might wanna think about it
# 59                                                   i missed you
# 60              it say here you exposed yourself to a group of...
# 61                            it wa a bratwurst i wa eating lunch
# 62                                  with the teeth of your zipper
# 63                                                you the new guy
# 64                                                so they tell me
# 65                        c'mon i'm supposed to give you the tour
# 66                                       so which dakota you from
# 67                                       north actually how'd you
# 68                        i wa kidding people actually live there
# 69              yeah a couple we're outnumbered by the cow though
# 70                        how many people were in your old school
# 71                                                     thirty two
# 72                                                        get out
# 73                                        how many people go here
# 74                              couple thousand most of them evil
# 77                                               that i'm used to
# 78              yeah but these guy have never seen a horse the...
# 87                                                    that girl i
# 88                                   you burn you pine you perish
# 89                                                     who is she
# 90              bianca stratford sophomore don't even think ab...
# 91                                                        why not
# 92              i could start with your haircut but it doesn't...
# 103             katarina stratford my my you've been terrorizi...
# 104               expressing my opinion is not a terrorist action
# 105             well yes compared to your other choice of expr...

# %% [markdown]
# ### Tagging the msg with classes

# %%
def define_target(corpus):
    
    if '?' in corpus:
        return 1
    else:
        return 0

# %%
data = messages['msg']

# %%
messages['target'] = [define_target(m) for m in data]

# %%
messages['target'] = messages['target'].astype(int)

# %%
messages.head(20)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                                       maybe...
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                             talk more about it
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                  I need to think more about it
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                  I need to think more about it
# 77              Yeah but these guys have never seen a horse. T...
#
#                                                 msg_pre_processed  target
# msg_line_clean
# 49                                       did you change your hair       1
# 50                                                             no       0
# 51                                 you might wanna think about it       0
# 59                                                   i missed you       0
# 60              it say here you exposed yourself to a group of...       0
# 61                            it wa a bratwurst i wa eating lunch       0
# 62                                  with the teeth of your zipper       1
# 63                                                you the new guy       1
# 64                                                so they tell me       0
# 65                        c'mon i'm supposed to give you the tour       0
# 66                                       so which dakota you from       1
# 67                                       north actually how'd you       1
# 68                        i wa kidding people actually live there       1
# 69              yeah a couple we're outnumbered by the cow though       0
# 70                        how many people were in your old school       1
# 71                                                     thirty two       0
# 72                                                        get out       0
# 73                                        how many people go here       1
# 74                              couple thousand most of them evil       0
# 77                                               that i'm used to       0

# %% [markdown]
# ### Analysing the target

# %% [markdown]
# ### Save data

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257095 entries, 49 to 666576
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   msg_line           257095 non-null  object
#  1   user_id            257095 non-null  object
#  2   movie_id           257095 non-null  object
#  3   msg                257095 non-null  object
#  4   msg_2              257095 non-null  object
#  5   msg_pre_processed  257095 non-null  object
#  6   target             257095 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 15.7+ MB

# %%
messages.describe()
# Out:
#               target
# count  257095.000000
# mean        0.304074
# std         0.460015
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
messages.to_csv('./chatdata/movie_lines_pre_processed.tsv', index=False, sep='\t', header=True)
