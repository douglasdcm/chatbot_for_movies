# %% [markdown]
# ## A intenção do projeto é criar um chatbot baseado em reviews de filmes para que se possa fazer perguntas e manter uma conversa livre sobre este tema
#
# - link do banco de dados https://www.kaggle.com/Cornell-University/movie-dialog-corpus?select=movie_lines.tsv
# - referências
# >- https://shanebarker.com/blog/deep-learning-chatbot/
# > -https://towardsdatascience.com/how-to-create-a-chatbot-with-python-deep-learning-in-less-than-an-hour-56a063bdfc44

# %%
import string
import nltk
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import pandas as pd
import re
import numpy as np
import math
import random
# Out:
# [nltk_data] Downloading package wordnet to /home/douglas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Opening movie reviews

# %%
messages = pd.read_csv('./chatdata/movie_lines_normalized.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
messages.columns = ['msg_line', 'user_id', 'movie_id', 'msg']

# %%
messages.head(10)
# Out:
#   msg_line user_id movie_id                                                msg
# 0    L1045      u0       m0                                       They do not!
# 1    L1044      u2       m0                                        They do to!
# 2     L985      u0       m0                                         I hope so.
# 3     L984      u2       m0                                          She okay?
# 4     L925      u0       m0                                          Let's go.
# 5     L924      u2       m0                                                Wow
# 6     L872      u0       m0     Okay -- you're gonna need to learn how to lie.
# 7     L871      u2       m0                                                 No
# 8     L870      u0       m0  """I'm kidding. You know how sometimes you jus...
# 9     L869      u0       m0                   Like my fear of wearing pastels?

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304713 entries, 0 to 304712
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   msg_line  304713 non-null  object
#  1   user_id   304713 non-null  object
#  2   movie_id  304713 non-null  object
#  3   msg       304713 non-null  object
# dtypes: object(4)
# memory usage: 9.3+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id     msg
# count    304713  304713   304713  304713
# unique   304713    9035      659  265277
# top     L171298   u4525     m289   What?
# freq          1     537     1530    1679

# %% [markdown]
# ### Cleaning the msg_line of the conversations

# %%
#remove charactes
def remove_char(txt):
    return re.sub('[^0-9]','', txt)

# %%
#leaving just the number of the index, so L872 changes to 872
messages['msg_line_clean'] = [remove_char(msg) for msg in messages['msg_line']]

# %%
#change the column type to number
messages['msg_line_clean'] = pd.to_numeric(messages['msg_line_clean'])

# %%
messages = messages.sort_values(by=['msg_line_clean'])

# %%
#set the column as the index
messages = messages.set_index('msg_line_clean')

# %%
messages.head(10)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
#
#                                                               msg
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.

# %% [markdown]
# ### Removing entities

# %%
entities = pd.read_csv('./chatdata/entity_list.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
entities.columns = ['ent', 'type']

# %%
entities.head()
# Out:
#                        ent    type
# 0                    Kinda     ORG
# 1  The Dallas Times Herald     ORG
# 2             Queen Louisa  PERSON
# 3                      A.M     GPE
# 4               Cousin Hop  PERSON

# %%
entities['ent_len'] = [len(e) for e in entities['ent']]

# %%
s = entities['ent_len'].sort_values(ascending=False).index

# %%
entities = entities.reindex(s)

# %%
entities = entities.reset_index(drop=True)

# %%
entities.head()
# Out:
#                                                  ent         type  ent_len
# 0  """How can the Bolshevik cause gain respect am...  WORK_OF_ART      237
# 1  """The Premier wishes to inform the Government...  WORK_OF_ART      192
# 2  """ Come Tuesday twelve a.m. bingo these like-...  WORK_OF_ART      182
# 3  """The suggestion of the President regarding t...  WORK_OF_ART      155
# 4  """The Management of Boyd's takes pleasure in ...  WORK_OF_ART      146

# %%
data = messages['msg']

# %%
#ent_list =  ['PERSON', 'ORG', 'NORP', 'FAC', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW', 'LANGUAGE']
ent_list =  ['LANGUAGE']

ent = list()
for i in range(len(entities.index)):
    if entities['type'][i] in ent_list:
        ent.append(entities['ent'][i])

# %%
ent = list(set(ent))
print(len(ent))
print(ent)
# Out:
# 22
# ['Hebrew', 'Fifteen', 'German', 'Czech', 'Fran', 'Arabic', 'Lillian', 'Russian', 'MiGs', 'Superfreak', 'Latin', 'Chinese', 'Fabian', 'Spanish', 'French', 'English', 'Mandarin', 'Barzini', 'Saffrin', 'Barnes', 'Cantonese', 'Jewish']

# %%
def remove_entity(corpus):
    corpus = corpus.split(' ')
    corpus = [c for c in corpus if c not in ent]
    return ' '.join(corpus)

# %%
# %%time
messages['msg_pre_processed'] = [remove_entity(m) for m in list(data)]
# Out:
# CPU times: user 1.39 s, sys: 109 ms, total: 1.5 s
# Wall time: 1.47 s

# %%
#chepoint
messages.to_csv('./chatdata/movie_lines_pre_processed.tsv', index=False, sep='\t', header=True)

# %% [markdown]
# ### Opening conversation sequence

# %%
#read the file with the conversation sequence
conv_seq = pd.read_csv('./chatdata/movie_conversations.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
conv_seq.columns = ['user1_id', 'user2_id', 'movie_id', 'sequence']

# %%
conv_seq.head(10)
# Out:
#   user1_id user2_id movie_id                              sequence
# 0       u0       u2       m0         ['L194' 'L195' 'L196' 'L197']
# 1       u0       u2       m0                       ['L198' 'L199']
# 2       u0       u2       m0         ['L200' 'L201' 'L202' 'L203']
# 3       u0       u2       m0                ['L204' 'L205' 'L206']
# 4       u0       u2       m0                       ['L207' 'L208']
# 5       u0       u2       m0  ['L271' 'L272' 'L273' 'L274' 'L275']
# 6       u0       u2       m0                       ['L276' 'L277']
# 7       u0       u2       m0                       ['L280' 'L281']
# 8       u0       u2       m0                       ['L363' 'L364']
# 9       u0       u2       m0                       ['L365' 'L366']

# %%
conv_seq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83097 entries, 0 to 83096
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user1_id  83097 non-null  object
#  1   user2_id  83097 non-null  object
#  2   movie_id  83097 non-null  object
#  3   sequence  83097 non-null  object
# dtypes: object(4)
# memory usage: 2.5+ MB

# %%
conv_seq.describe()
# Out:
#        user1_id user2_id movie_id  \
# count     83097    83097    83097
# unique     5420     5608      617
# top       u4331    u1475     m289
# freq        193      187      338
#
#                                                  sequence
# count                                               83097
# unique                                              83097
# top     ['L114180' 'L114181' 'L114182' 'L114183' 'L114...
# freq                                                    1

# %% [markdown]
# ### Build conversation sequence

# %%
def split_conversation(txt):
    txt_alt = txt.split(' ')
    return txt_alt

# %%
def seq_to_list(seq):
    seq_list = [remove_char(s) for s in seq]
    return seq_list

# %%
#initializing the msg_2 column
messages['msg_2'] = '-'

# %%
def link_conversations(seq_list, df, filter1, filter2):
    i = 0
    while i in range(len(seq_list)):
        if i+1 < len(seq_list):
            next_msg = df.loc[int(seq_list[i+1]), filter1]
            df.at[int(seq_list[i]), filter2] = next_msg
        i+=1

# %%
#link each message with its answer
for conv in conv_seq['sequence']:
    #split each sequence by space
    seq = split_conversation(conv)

    #remove the char L from the sequences
    txt_alt = [remove_char(s) for s in seq]

    #use the conversation sequence to build the target answer for each message
    link_conversations(txt_alt, messages, 'msg_pre_processed', 'msg_2')

# %%
messages.head(30)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
# 78                  L78      u7       m0
# 87                  L87      u2       m0
# 88                  L88      u7       m0
# 89                  L89      u2       m0
# 90                  L90      u7       m0
# 91                  L91      u2       m0
# 92                  L92      u7       m0
# 103                L103      u8       m0
# 104                L104      u5       m0
# 105                L105      u8       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 89                                                    Who is she?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 91                                                       Why not?
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                                              -
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                                              -
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                                              -
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                                              -
# 77              Yeah but these guys have never seen a horse. T...
# 78                                                              -
# 87                                  You burn you pine you perish?
# 88                                                    Who is she?
# 89              Bianca Stratford. Sophomore. Don't even think ...
# 90                                                       Why not?
# 91              I could start with your haircut but it doesn't...
# 92                                                              -
# 103              Expressing my opinion is not a terrorist action.
# 104             Well yes compared to your other choices of exp...
# 105             I still maintain that he kicked himself in the...
#
#                                                 msg_pre_processed
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 89                                                    Who is she?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 91                                                       Why not?
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...

# %% [markdown]
# ## Pre processing the msg

# %%
data = messages['msg_pre_processed']

# %%
lemmatizer = WordNetLemmatizer()
def pre_processing_text(corpus):
    #remove html tags
    corpus = re.sub(r'<.*?>', '', str(corpus))
    
    #remove non-alphanumeric characters
    corpus = re.sub(r'[^a-z A-Z 0-9 \s]', '', str(corpus))
    
    #remove duplicated spaces
    corpus = re.sub(r' +', ' ', str(corpus))
    
    #capitalization
    corpus = corpus.lower()
    
    #tokenization
    corpus = re.findall(r"\w+(?:'\w+)?|[^\w\s]", corpus)
    
    #lammatization
    corpus = [lemmatizer.lemmatize(c) for c in corpus]
    
    #remove punctuation
    corpus = [t for t in corpus if t not in string.punctuation]
    
    #remove stopwords
    #it makes the model worst
    #stopwords_ = stopwords.words("english")
    #corpus = [t for t in corpus if t not in stopwords_]
    
    corpus = ' '.join(corpus)

    return corpus

# %%
# %%time
data_pre_processed = [pre_processing_text(str(m)) for m in data]
data_pre_processed
# Out:
# CPU times: user 19.7 s, sys: 250 ms, total: 20 s
# Wall time: 20.4 s
# ['did you change your hair',
#  'no',
#  'you might wanna think about it',
#  'i missed you',
#  'it say here you exposed yourself to a group of freshman girl',
#  'it wa a bratwurst i wa eating lunch',
#  'with the teeth of your zipper',
#  'you the new guy',
#  'so they tell me',
#  'cmon im supposed to give you the tour',
#  'so which dakota you from',
#  'north actually howd you',
#  'i wa kidding people actually live there',
#  'yeah a couple were outnumbered by the cow though',
#  'how many people were in your old school',
#  'thirtytwo',
#  'get out',
#  'how many people go here',
#  'couple thousand most of them evil',
#  'that im used to',
#  'yeah but these guy have never seen a horse they just jack off to clint eastwood',
#  'that girl i',
#  'you burn you pine you perish',
#  'who is she',
#  'bianca stratford sophomore dont even think about it',
#  'why not',
#  'i could start with your haircut but it doesnt matter shes not allowed to date until her older sister doe and thats an impossibility',
#  'katarina stratford my my youve been terrorizing m blaise again',
#  'expressing my opinion is not a terrorist action',
#  'well yes compared to your other choice of expression this year today event are quite mild by the way bobby rictors gonad retrieval operation went quite well in case youre interested',
#  'i still maintain that he kicked himself in the ball i wa merely a spectator',
#  'the point is kat people perceive you a somewhat',
#  'tempestuous',
#  'no i believe heinous bitch is the term used most often',
#  'who that',
#  'patrick verona random skid',
#  'thats pat verona the one who wa gone for a year i heard he wa doing porn movie',
#  'im sure he completely incapable of doing anything that interesting',
#  'he always look so',
#  'block e',
#  'mandella eat starving yourself is a very slow way to die',
#  'just a little',
#  'whats this',
#  'an attempted slit',
#  'i realize that the men of this fine institution are severely lacking but killing yourself so you can be with william shakespeare is beyond the scope of normal teenage obsession youre venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy',
#  'but imagine the thing hed say during sex',
#  'why do girl like that always like guy like that',
#  'because theyre bred to their mother liked guy like that and their grandmother before them their gene pool is rarely diluted',
#  'he always have that shiteating grin',
#  'joey dorsey permashitgrin i wish i could say he a moron but he number twelve in the class and a model mostly regional stuff but he rumored to have a big tube sock ad coming out',
#  'you know french',
#  'sure do my mom from canada',
#  'guess who just signed up for a tutor',
#  'you mean id get a chance to talk to her',
#  'you could consecrate with her my friend',
#  'the vintage look is over kat havent you been reading your sassy',
#  'yeah and i noticed the only part of you featured in your big kmart spread wa your elbow tough break',
#  'theyre running the rest of me next month',
#  'the people at this school are so incredibly foul',
#  'you could always go with me im sure william ha some friend',
#  'yeah just a minor encounter with the shrew',
#  'thats her biancas sister',
#  'the mewling rampalian wretch herself',
#  'in the microwave',
#  'make anyone cry today',
#  'whereve you been',
#  'nowhere hi daddy',
#  'whats a synonym for throbbing',
#  'sarah lawrence is on the other side of the country',
#  'i know',
#  'i thought we decided you were going to school here at u of 0',
#  'you decided',
#  'now dont get upset daddy but there this boy and i think he might ask',
#  'no youre not dating until your sister start dating end of discussion',
#  'what if she never start dating',
#  'then neither will you and ill get to sleep at night',
#  'but it not fair shes a mutant daddy',
#  'this from someone whose diary is devoted to favorite grooming tip',
#  'enough',
#  'but she doesnt want to date',
#  'exactly my point',
#  'jesus can a man even grab a sandwich before you woman start dilating',
#  'tumescent',
#  'youre not helping',
#  'can we make this quick roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad again',
#  'well i thought wed start with pronunciation if thats okay with you',
#  'not the hacking and gagging and spitting part please',
#  'okay then how bout we try out some cuisine saturday night',
#  'youre asking me out thats so cute whats your name again',
#  'forget it',
#  'no no it my fault we didnt have a proper introduction',
#  'cameron',
#  'the thing is cameron im at the mercy of a particularly hideous breed of loser my sister i cant date until she doe',
#  'seems like she could get a date easy enough',
#  'why',
#  'unsolved mystery she used to be really popular when she started high school then it wa just like she got sick of it or something',
#  'thats a shame',
#  'gosh if only we could find kat a boyfriend',
#  'let me see what i can do',
#  'i teach her get to know her dazzle her with charm and she fall in love with me',
#  'unlikely but even so she still cant go out with you so whats the point',
#  'what about him',
#  'you wanna go out with him',
#  'what make you think hell do it',
#  'he seems like he thrives on danger',
#  'no kidding he a criminal i heard he lit a state trooper on fire he just got out of alcatraz',
#  'they always let felon sit in on honor biology',
#  'im serious man he whacked he sold his own liver on the black market so he could buy new speaker',
#  'forget his reputation do you think weve got a plan or not',
#  'did she actually say shed go out with you',
#  'thats what i just said',
#  'you know if you do go out with bianca youd be set youd outrank everyone strictly alist with me by your side',
#  'i thought you hated those people',
#  'hey ive gotta have a few client when i get to wall street',
#  'hey',
#  'are you lost',
#  'nope just came by to chat',
#  'we dont chat',
#  'well actually i thought id run an idea by you you know just to see if youre interested',
#  'were not',
#  'but she cant go out with you because her sister is this insane head case and no one will go out with her right',
#  'doe this conversation have a purpose',
#  'so what you need to do is recruit a guy wholl go out with her someone who up for the job',
#  'you got him involved',
#  'like we had a choice besides when you let the enemy think he orchestrating the battle youre in a position of power we let him pretend he calling the shot and while he busy setting up the plan you have time to woo bianca',
#  'so he ha this huge raging fit about sarah lawrence and insists that i go to his maledominated puking frat boy number one golf team school i have no say at all',
#  'william would never have gone to a state school',
#  'william didnt even go to high school',
#  'thats never been proven',
#  'neither ha his heterosexuality',
#  'i appreciate your effort toward a speedy death but im consuming do you mind',
#  'doe it matter',
#  'if i wa bianca it would be any school you want precious dont forget your tiara',
#  'i dont understand patrick you havent done anything asinine this week are you not feeling well',
#  'touch of the flu',
#  'im at a loss then what should we talk about your year of absence',
#  'why dont we discus your driving need to be a hemorrhoid',
#  'whats to discus',
#  'you werent abused you arent stupid and a far a i can tell youre only slightly psychotic so why is it that youre such a fuckup',
#  'well you know there the prestige of the job title and the benefit package is pretty good',
#  'cesc ma tete this is my head',
#  'right see youre ready for the quiz',
#  'i dont want to know how to say that though i want to know useful thing like where the good store are how much doe champagne cost stuff like chat i have never in my life had to point out my head to someone',
#  'thats because it such a nice one',
#  'forget french',
#  'how is our little find the wench a date plan progressing',
#  'well there someone i think might be',
#  'there',
#  'where',
#  'yeah',
#  'what do you think',
#  'two leg nice rack',
#  'yeah whatever i want you to go out with her',
#  'sure sparky ill get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'but youd go out with her if you had the cake',
#  'you got it verona i pick up the tab you do the honor',
#  'youre gonna pay me to take out some girl',
#  'i cant date her sister until that one get a boyfriend and thats the catch she doesnt want a boyfriend',
#  'how much',
#  'i cant take a girl like that out on twenty buck',
#  'fine thirty',
#  'take it or leave it this isnt a negotiation',
#  'fifty and youve got your man',
#  'i mean woman how ya doin',
#  'sweating like a pig actually and yourself',
#  'there a way to get a guy attention',
#  'my mission in life',
#  'pick you up friday then',
#  'oh right friday',
#  'the night i take you to place youve never been before and back',
#  'like where the 7eleven on burnside do you even know my name screwboy',
#  'i know a lot more than that',
#  'i have the potential to smack the crap out of you if you dont get out of my way',
#  'can you at least start wearing a bra',
#  'you hate me dont you',
#  'i dont really think you warrant that strong an emotion',
#  'then say youll spend dollar night at the track with me',
#  'and why would i do that',
#  'come on the pony the flat beer you with money in your eye me with my hand on your as',
#  'you covered in my vomit',
#  'seventhirty',
#  'are you following me',
#  'i wa in the laundromat i saw your car thought id say hi',
#  'hi',
#  'youre not a big talker are you',
#  'depends on the topic my fender dont really whip me into a verbal frenzy',
#  'hey do you mind',
#  'not at all',
#  'my insurance doe not cover pm',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why cant we agree on this',
#  'because youre making decision for me',
#  'a a parent thats my right',
#  'so what i want doesnt matter',
#  'youre eighteen you dont know what you want you wont know until youre fortyfive and you dont have it',
#  'i want to go to an east coast school i want you to trust me to make my own choice i want',
#  'when i shell out fifty i expect result',
#  'im on it',
#  'watching the bitch trash my car doesnt count a a date',
#  'i got her under control she just act crazed in public to keep up the image',
#  'i just upped my price',
#  'what',
#  'a hundred buck a date',
#  'forget it',
#  'forget her sister then',
#  'you got something on your mind',
#  'i counted on you to help my cause you and that thug are obviously failing arent we ever going on our date',
#  'you have my word a a gentleman',
#  'youre sweet',
#  'how do you get your hair to look like that',
#  'ebers deep conditioner every two day and i never ever use a blowdryer without the diffuser attachment',
#  'say it',
#  'what',
#  'whatever the hell it is youre standin there waitin to say',
#  'what plan',
#  'the situation is my man cameron here ha a major jones for bianca stratford',
#  'what is it with this chick she have three tit',
#  'i think i speak correctly when i say that camerons love is pure purer than say joey dorseys',
#  'dorsey can plow whoever he want im just in this for the cash',
#  'thats where we can help you with kat',
#  'so dorsey can get the girl',
#  'patrick pat youre not looking at the big picture joeys just a pawn we set this whole thing up so cameron can get the girl',
#  'you two are gonna help me tame the wild beast',
#  'were your guy',
#  'and he mean that strictly in a non prisonmovie type of way',
#  'yeah well see',
#  'this is it a golden opportunity patrick can ask katarina to the party',
#  'in that case well need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'are you kidding hell piss himself with joy he the ultimate kiss as',
#  'it more',
#  'expensive',
#  'exactly so you going to bogey lowenbraus thing on saturday',
#  'hopefully',
#  'sure have',
#  'i really really really wanna go but i cant not unless my sister go',
#  'im workin on it but she doesnt seem to be goin for him',
#  'shes not a',
#  'lesbian no i found a picture of jared leto in one of her drawer so im pretty sure shes not harboring samesex tendency',
#  'so thats the kind of guy she like pretty one',
#  'who know all ive ever heard her say is that shed dip before dating a guy that smoke',
#  'whatve you got for me',
#  'ive retrieved certain piece of information on miss katarina stratford i think youll find helpful',
#  'what',
#  'good enough',
#  'number one she hate smoker',
#  'it a lung cancer issue',
#  'her favorite uncle',
#  'dead at fortyone',
#  'are you telling me im a nonsmoker',
#  'just for now',
#  'he pretty',
#  'okay i wasnt sure',
#  'okay like thai food feminist prose and angry stinky girl music of the indierock persuasion',
#  'so what doe that give me im supposed to buy her some noodle and a book and sit around listening to chick who cant play their instrument',
#  'ever been to club skunk',
#  'yeah',
#  'gigglepuss is playing there tomorrow night',
#  'dont make me do it man',
#  'assail your ear for one night',
#  'it her favorite band',
#  'i prefer to think of it simply a an alternative to what the law allows',
#  'im likin you guy better',
#  'oh my god doe this mean youre becoming normal',
#  'it mean that gigglepuss is playing at club skunk and were going',
#  'oh i thought you might have a date i dont know why im bothering to ask but are you going to bogey lowensteins party saturday night',
#  'what do you think',
#  'i think youre a freak i think you do this to torture me and i think you suck',
#  'you think thisll work',
#  'no fear',
#  'always a pleasure brucie',
#  'didnt have you pegged for a gigglepuss fan arent they a little too preteen bellybutton ring for you',
#  'fan of a fan you see a couple of minor come in',
#  'never',
#  'padua girl one tall decent body the other one kinda short and undersexed',
#  'just sent em through',
#  'hey great show huh',
#  'unknown',
#  'excuse me',
#  'thats what you want isnt it',
#  'do you mind youre sort of ruining it for me',
#  'you know these guy are no bikini kill or the raincoat but theyre right up there',
#  'you know who the raincoat are',
#  'why dont you',
#  'whatd he say',
#  'who care',
#  'you told me that part already',
#  'hell ive just been going over the whole thing in my head and',
#  'i hear youre helpin verona',
#  'uh yeah were old friend',
#  'you and verona',
#  'what we took bathe together when we were kid',
#  'you better not fuck this up im heavily invested',
#  'hey it all for the higher good right',
#  'youre completely demented',
#  'see you next week',
#  'daddy i',
#  'and wherere you going',
#  'if you must know we were attempting to go to a small study group of friend',
#  'otherwise known a an orgy',
#  'it just a party daddy but i knew youd forbid me to go since gloria steinem over there isnt going',
#  'daddy people expect me to be there',
#  'if kat not going youre not going',
#  'youre ruining my life because you wont be normal i cant be normal',
#  'whats normal',
#  'bogey lowensteins party is normal but youre too busy listening to bitch who need prozac to know that',
#  'cant you forget for just one night that youre completely wretched',
#  'at least im not a clouted fen sucked hedgepig',
#  'like im supposed to know what that even mean',
#  'it shakespeare maybe youve heard of him',
#  'yeah he your freak friend mandellas boyfriend i guess since im not allowed to go out i should ob over a dead guy too',
#  'oh god it starting',
#  'it just a party daddy',
#  'wear the belly before you go',
#  'daddy no',
#  'just for a minute',
#  'you are so completely unbalanced',
#  'can we go now',
#  'promise me you wont talk to any boy unless your sister is present',
#  'why',
#  'because shell scare them away',
#  'where ya goin',
#  'away',
#  'your sister here',
#  'leave my sister alone',
#  'and why would i do that',
#  'whats this',
#  'im getting trashed man isnt that what youre supposed to do at a party',
#  'i say do what you wanna do',
#  'funny youre the only one',
#  'where did he go he wa just here',
#  'who',
#  'joey',
#  'hi',
#  'look like thing worked out tonight huh',
#  'you know chastity',
#  'i believe we share an art instructor',
#  'great',
#  'would you mind getting me a drink cameron',
#  'extremely unfortunate maneuver',
#  'the hell is that what kind of guy just pick up a girl and carry her away while youre talking to her',
#  'buttholus extremus but hey youre making progress',
#  'no i m not',
#  'so yeah ive got the sears catalog thing going and the tube sock gig thats gonna be huge and then im up for an ad for queen harry next week',
#  'queen harry',
#  'it a gay cruise line but ill be like wearing a uniform and stuff',
#  'neat',
#  'my agent say ive got a good shot at being the prada guy next year',
#  'he practically proposed when he found out we had the same dermatologist i mean dr bonchowski is great an all but he not exactly relevant party conversation',
#  'is he oily or dry',
#  'combination i dont know i thought hed be different more of a gentleman',
#  'bianca i dont think the highlight of dating joey dorsey are going to include dooropening and coatholding',
#  'sometimes i wonder if the guy were supposed to want to go out with are the one we actually want to go out with you know',
#  'all i know is id give up my private line to go out with a guy like joey',
#  'bianca i need to talk to you i need to tell you',
#  'i really dont think i need any social advice from you right now',
#  'it about time',
#  'a deal a deal',
#  'howd you do it',
#  'do what',
#  'get her to act like a human',
#  'okay',
#  'im fine im',
#  'youre not okay',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and youll go to sleep',
#  'i know just let me sleep',
#  'what if you have a concussion my dog went to sleep with a concussion and woke up a vegetable not that i could tell the difference',
#  'cameron im a little busy',
#  'it off the whole thing',
#  'what re you talking about',
#  'shes partial to joey not me',
#  'cameron do you like the girl',
#  'sure',
#  'then go get her',
#  'this is so patronizing',
#  'leave it to you to use big word when youre shitfaced',
#  'why re you doing this',
#  'i told you',
#  'you dont care if i die',
#  'sure i do',
#  'why',
#  'because then id have to start taking out girl who like me',
#  'like you could find one',
#  'see that who need affection when ive got blind hatred',
#  'just let me sit down',
#  'whyd you let him get to you',
#  'who',
#  'dorsey',
#  'i hate him',
#  'i know itd have to be a pretty big deal to get you to mainline tequila you dont seem like the type',
#  'hey man you don t think i can be cool you dont think i can be laid back like everyone else',
#  'i thought you were above all that',
#  'you know what they say',
#  'kat wake up',
#  'what',
#  'i dont get you you act like youre too good for any of this and then you go totally apeshit when you get here',
#  'youre welcome',
#  'i have to be home in twenty minute',
#  'i dont have to be home til two',
#  'have fun tonight',
#  'ton',
#  'and im in control of it',
#  'but it gigglepuss i know you like them i saw you there',
#  'when you were gone last year where were you',
#  'busy',
#  'were you in jail',
#  'maybe',
#  'no you werent',
#  'then whyd you ask',
#  'whyd you lie',
#  'i should do this',
#  'do what',
#  'this',
#  'start a band',
#  'my father wouldnt approve of that that',
#  'you dont strike me a the type that would ask permission',
#  'oh so now you think you know me',
#  'im gettin there',
#  'so what s up with your dad he a pain in the as',
#  'he just want me to be someone im not',
#  'who',
#  'bianca',
#  'no offense but youre sister is without i know everyone like her and all but',
#  'i looked for you back at the party but you always seemed to be occupied',
#  'i wa',
#  'you never wanted to go out with me did you',
#  'well no',
#  'then thats all you had to say',
#  'but',
#  'you always been this selfish',
#  'you went to the party i thought we were officially opposed to suburban social activity',
#  'i didnt have a choice',
#  'you didnt have a choice wheres kat and what have you done with her',
#  'i did bianca a favor and it backfired',
#  'you didnt',
#  'i got drunk i puked i got rejected it wa big fun',
#  'so you got cozy with she who sting',
#  'no ive got a sweetpayin job that im about to lose',
#  'whatd you do to her',
#  'i don t know i decided not to nail her when she wa too drunk to remember it',
#  'hey there tired of breathing',
#  'hi',
#  'cool picture you a fan',
#  'yeah i guess',
#  'you think',
#  'oh yeah',
#  'macbeth right',
#  'right',
#  'kat a fan too',
#  'yeah',
#  'she hate you with the fire of a thousand sun thats a direct quote',
#  'she just need time to cool off ill give it a day',
#  'you makin any headway',
#  'she kissed me',
#  'where',
#  'i dont know dorsey the limothe flower another hundred for the tux',
#  'enough with the barbie n ken shit i know',
#  'can you even imagine who the hell would go to this a bastion of commercial excess',
#  'well i guess were not since we dont have date',
#  'listen to you you sound like betty all pissed off because archie is taking veronica',
#  'okay okay we wont go it not like i have a dress anyway',
#  'you re looking at this from the wrong perspective were making a statement',
#  'oh good something new and different for u',
#  'hey sweet cheek',
#  'hi joey',
#  'youre concentrating awfully hard considering it gym class',
#  'listen i want to talk to you about the prom',
#  'you know the deal i can t go if kat doesnt go',
#  'excuse me have you seen the feminine mystique i lost my copy',
#  'what are you doing here',
#  'i heard there wa a poetry reading',
#  'you re so',
#  'pleasant',
#  'wholesome',
#  'unwelcome',
#  'unwelcome i guess someone still ha her panty in a twist',
#  'dont for one minute think that you had any effect whatsoever on my panty',
#  'so what did i have an effect on',
#  'other than my upchuck reflex nothing',
#  'you were right shes still pissed',
#  'sweet love renew thy force',
#  'man dont say shit like that to me people can hear you',
#  'you humiliated the woman sacrifice yourself on the altar of dignity and even the score',
#  'best case scenario youre back on the payroll for awhile',
#  'whats the worst',
#  'you get the girl',
#  'he left i sprung the dickhead and he cruised on me',
#  'look up sunshine',
#  'i guess i never told you im afraid of height',
#  'cmon it not that bad',
#  'try lookin at it from this angle',
#  'put your right foot there',
#  'forget it im stayin',
#  'you want me to climb up and show you how to get down',
#  'maybe',
#  'the partridge family',
#  'i figured it had to be something ridiculous to win your respect and piss you off',
#  'good call',
#  'so howd you get chapin to look the other way',
#  'i dazzled him with my wit',
#  'a soft side who knew',
#  'yeah well dont let it get out',
#  'so whats your excuse',
#  'acting the way we do',
#  'yes',
#  'i dont like to do what people expect then they expect it all the time and they get disappointed when you change',
#  'so if you disappoint them from the start youre covered',
#  'something like that',
#  'then you screwed up',
#  'how',
#  'you never disappointed me',
#  'you up for it',
#  'for',
#  'state trooper',
#  'fallacy',
#  'the duck',
#  'hearsay',
#  'i know the porn career a lie',
#  'tell me something true',
#  'i hate pea',
#  'no something real something no one else know',
#  'youre sweet and sexy and completely hot for me',
#  'what',
#  'no one else know',
#  'youre amazingly selfassured ha anyone ever told you that',
#  'go to the prom with me',
#  'is that a request or a command',
#  'you know what i mean',
#  'no',
#  'no what',
#  'no i wont go with you',
#  'why not',
#  'because i dont want to it a stupid tradition',
#  'create a little drama start a new rumor what',
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy ha anyone ever told you that',
#  'answer the question patrick',
#  'nothing there nothing in it for me just the pleasure of your company',
#  'then guillermo say if you go any lighter youre gonna look like an extra on 90210',
#  'no',
#  'do you listen to this crap',
#  'what crap',
#  'me this endless blonde babble im like boring myself',
#  'thank god if i had to hear one more story about your coiffure',
#  'i figured youd get to the good stuff eventually',
#  'what good stuff',
#  'the real you',
#  'like my fear of wearing pastel',
#  'im kidding you know how sometimes you just become this persona and you dont know how to quit',
#  'no',
#  'okay youre gonna need to learn how to lie',
#  'would you rather be ravished by a pirate or a british rear admiral',
#  'pirate no question',
#  'daddy i want to discus the prom with you it tomorrow night',
#  'the prom kat ha a date',
#  'no but',
#  'it that hot rod joey right that s who you want me to bend my rule for',
#  'he not a hot rod whatever that is',
#  'youre not going unless your sister go end of story',
#  'fine i see that im a prisoner in my own house im not a daughter im a possession',
#  'theyll dance theyll kiss theyll come home let her go',
#  'kissing is that what you think happens kissing isnt what keep me up to my elbow in placenta all day',
#  'listen i know you hate having to sit home because im not susie high school',
#  'like you care',
#  'i do care but im a firm believer in doing something for your own reason not someone else s',
#  'i wish i had that luxury im the only sophomore that got asked to the prom and i cant go because you won t',
#  'joey never told you we went out did he',
#  'what',
#  'in 9th for a month',
#  'why',
#  'he wa like a total babe',
#  'but you hate joey',
#  'now i do back then wa a different story',
#  'a in',
#  'he said everyone wa doing it so i did it',
#  'you did what',
#  'just once afterwards i told him i didnt want to anymore i wasnt ready he got pissed then he broke up with me',
#  'but',
#  'after that i swore id never do anything just because everyone else wa doing it and i havent since except for bogey party and my stunning gastrointestinal display',
#  'why didnt you tell me',
#  'i wanted to let you make up your own mind about him',
#  'no you didnt if you really thought i could make my own decision you wouldve let me go out with him instead of helping daddy hold me hostage',
#  'thats not',
#  'im not stupid enough to repeat your mistake',
#  'i guess i thought i wa protecting you',
#  'god youre just like him just keep me locked away in the dark so i cant experience anything for myself',
#  'not all experience are good bianca you cant always trust the people you want to',
#  'i guess ill never know will i',
#  'what do you wanna watch weve got crap crap crap or crap',
#  'dr ruth',
#  'im missing something',
#  'i have a date daddy and he s not a captain of oppression like some men we know',
#  'wow',
#  'let go',
#  'have a great time honey',
#  'but who what',
#  'what just happened',
#  'your daughter went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  'that s what i thought',
#  'howd you get a tux at the last minute',
#  'it scurvy his date got convicted whered you get the dress',
#  'it just something i had you know',
#  'oh huh',
#  'look im sorry that i questioned your motif i wa wrong',
#  'have you seen him',
#  'who',
#  'william he asked me to meet him here',
#  'oh honey tell me we havent progressed to fullon hallucination',
#  'you think you re the only sophomore at the prom',
#  'i did',
#  'my grandmother',
#  'what',
#  'thats where i wa last year shed never lived alone my grandfather died i stayed with her i wasnt in jail i dont know marilyn manson and ive never slept with a spice girl i spent a year sitting next to my grandma on the couch watching wheel of fortune end of story',
#  'that s completely adorable',
#  'it get worse you still have your freshman yearbook',
#  'wait i',
#  'you were paid to take me out by the one person i truly hate i knew it wa a setup',
#  'it wasnt like that',
#  'really what wa it like a down payment now then a bonus for sleeping with me',
#  'i didnt care about the money',
#  'you looked beautiful last night you know',
#  'so did you',
#  'she okay',
#  'i hope so',
#  'wa that your sister',
#  'yeah she left with some bikers big one full of sperm',
#  'funny',
#  'i dont understand the allure of dehydrated food is this something i should be hip to',
#  'no daddy',
#  'so tell me about this dance wa it fun',
#  'part of it',
#  'which part',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'whats the matter upset that i rubbed off on her',
#  'no impressed',
#  'you know father dont like to admit that their daughter are capable of running their own life it mean weve become spectator bianca still let me play a few inning youve had me on the bleacher for year when you go to sarah lawrence i wont even be able to watch the game',
#  'when i go',
#  'oh christ dont tell me youve changed your mind i already sent em a check',
#  'let go',
#  'you set me up',
#  'i just wanted',
#  'what to completely damage me to send me to therapy forever what',
#  'no i just wanted',
#  'am i supposed to feel better like right now or do i have some time to think about it',
#  'just smack her now',
#  'is that woman a complete fruitloop or is it just me',
#  'it just you',
#  'a fender strat you bought this',
#  'i thought you could use it when you start your band',
#  'besides i had some extra cash some asshole paid me to take out a really great girl',
#  'is that right',
#  'yeah but then i fucked up i fell for her',
#  'why is my veggie burger the only burnt object on this grill',
#  'because i like to torture you',
#  'oh bianca can you get me my freshman yearbook',
#  'don t you even dare',
#  'they do to',
#  'they do not',
#  'patrick is that a',
#  'perm',
#  'is that the man i knew treasurer sanchez',
#  'yes your majesty',
#  'diego is a bright boy a pleasure to teach but so serious brother should be raised together colon even brother from different mother',
#  'father i am doing what i think is the best for him and he ha the teacher i would have chosen for myself',
#  'god thats in a week',
#  'thats what it say',
#  'how did you manage it',
#  'with some difficulty i had to promise them you were not a total fool',
#  'why do you wish to sail west',
#  'to open a new route to asia at the moment there are only two way of reaching it',
#  'how can you be so certain the ocean is said to be infinite',
#  'ignorance i believe the indie are no more than 750 league west of the canary island',
#  'how can you be so certain',
#  'the calculation of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  'so wa christ',
#  'two minute and already youre a dead man dont let passion overwhelm you colon',
#  'ill try to remember that marchena',
#  'father marchena',
#  'passion is something one cannot control',
#  'you get so carried away when you are being contradicted',
#  'ive been contradicted all my life eternity',
#  'only god know the meaning of such word my son',
#  'i could be gone for year',
#  'i know',
#  'i havent given you much of a life',
#  'well thats true i have a child by a man who wont marry me who always leaving',
#  'are we going to argue',
#  'id love to argue with you sometimes but youre never here',
#  'perhaps i wa never meant to live with a woman',
#  'i find that hard to believe',
#  'you say asia can be found by sailing west',
#  'yes your eminence the voyage should not take more than six or seven week',
#  'unfortunately don colon that is precisely where our opinion differ are you familiar with the work of aristotle erathostene ptolemeus',
#  'i am your eminence',
#  'then you cannot ignore that according to their calculation the circumference of the earth is approximately 22000 league or more which make the ocean uncrossable',
#  'senor colon an experienced captain such a yourself will understand our concern with the crew i am not willing to have on my conscience the loss of men who would have relied upon our judgment',
#  'excellency you are right',
#  'your eminence there is only one way to settle the matter and that is to make the journey i am ready to risk my life to prove it possible',
#  'your life and that of others',
#  'if they agree to follow me yes',
#  'trade your excellency according to marco polo the kingdom of china is one of the richest of the world even the meanest building are roofed with gold',
#  'is that all that interest you gold',
#  'no the portuguese have already discovered blackskinned people i too will find other population and bring them to the word of god',
#  'if god intended our proximity to asia do you believe he would have waited for you to show it to the world',
#  'did he not choose a carpenter son to reveal himself to the world',
#  'dont you realize your word could be considered heretical',
#  'blind faith is what i consider heresy',
#  'asia can be found to the west and i will prove it',
#  'ifgodwillsit',
#  'the state ha some reason to be interested in this man proposition your eminence',
#  'the judgment is ours',
#  'naturally but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography',
#  'he is a mercenary did he not already try to convince the king of portugal of his absurd notion',
#  'indeed the world is full of mercenary and state often make use of them when it benefit them my only concern is the welfare and prosperity of spain',
#  'you mustnt give way to despair you must wait',
#  'wait ive waited seven year already how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'damn god',
#  'colon',
#  'damn all of you you all set up theory based on what you never leave the safety of your study go out find out what the world is about and then tell me something i can listen to',
#  'all of them just lie',
#  'colon dont',
#  'where can i meet this man',
#  'immediately',
#  'i should not even be listening to you since my council said no but santangel tell me you are a man of honor and sincerity and sanchez that you are not a fool',
#  'no more than the woman who said she would take granada from the moor',
#  'the ocean is uncrossable',
#  'what did they say about granada before today',
#  'that she wa impregnable',
#  'i cannot ignore the verdict of my council',
#  'surely you can do anything you want',
#  'may i speak freely',
#  'you show no inclination to speak otherwise',
#  'i know what i see i see someone who doesnt accept the world a it is who not afraid i see a woman who think what if',
#  'a woman',
#  'how old are you senor colon',
#  'thirty seven your majesty and you',
#  'no',
#  'no',
#  'no i have waited too long fought too hard now you expect me to take all the risk while you take the profit no i will not be your servant',
#  'i remind you senor colon that you are in no position to bargain with me',
#  'im not bargaining',
#  'then you are too ambitious',
#  'and were you never ambitious excellency or is ambition only a virtue among the noble a fault for the rest of u',
#  'if you wont accept our proposal well simply find someone who will',
#  'you were right don sanchez his demand could never be granted',
#  'never your majesty although',
#  'into a monk',
#  'yes it would be a pity wouldnt it call him back',
#  'she said yes',
#  'thank god',
#  'im not asking you to swear to anything',
#  'i dont want you to wait for me',
#  'thats something you cant decide',
#  'i want to go with you',
#  'therell be a time',
#  'you promise do you swear on st christopher',
#  'do you swear on all the holy saint in heaven',
#  'yes yes i do on all of them',
#  'in nomine patris et filius et spiritus sancti',
#  'forgive me father for i have sinned',
#  'i am listening my son',
#  'father i have betrayed my family i betrayed my men and i betrayed you',
#  'what are you saying',
#  'i lied the journey will be longer than i said',
#  'how long',
#  'i am not sure it could be twice the distance',
#  'may god forgive you you must tell them you must tell your men',
#  'if i tell them they wont follow me you know that i am right father you trust me',
#  'my son my son your certitude are sometimes frightening christopher you must speak to them and if you dont i will',
#  'you are bound by an oath father',
#  'i believed in you',
#  'give me absolution',
#  'due west captain mendez and may god be with u',
#  'god be with u admiral',
#  'well it the men sir they wonder how you know our position weve lost sight from land day ago',
#  'and what do you think mendez',
#  'well i surely know what a quadrant is but ive never seen it used at night before',
#  'come over here',
#  'what do you read',
#  'twenty eight',
#  'i never seen heat like this not even in la mina',
#  'the water going putrid in the barrel',
#  'youll be drinking your own piss for the glory of spain and admiral colon bastard',
#  'what are you listening to chicken as',
#  'ah leave him alone he doing no harm',
#  'with a face like that i dont want you looking at me you hear',
#  'he the devil child',
#  'well all go crazy',
#  'we should have seen land',
#  'we left three week ago alonso cant be that near',
#  'cant be that far i say also i dont like the smell of the sea around here smell like a cunt bad sign',
#  'you lied you cheated were way past 750 league',
#  'six day ago yes',
#  'you must be mad',
#  'we have to keep the hope of these men alive',
#  'were on the verge of a mutiny colon',
#  'you think i dont know that',
#  'were lost',
#  'the land is there i know it',
#  'you dont know anything listen colon these are my ship right so im telling you were turning back',
#  'and then what half of the water ha gone the rest is nearly putrid you know that',
#  'jesus maria i should have never listened to you',
#  'you never did you did all the talking for both of u remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward think about that',
#  'you tell that to them',
#  'youre right let the men decide',
#  'say not here cuba',
#  'what is it a tribe an island',
#  'island far',
#  'you come you speak first',
#  'tell the chief we thank him',
#  'chief know',
#  'tell him his country is very beautiful tell him we are leaving men here to build a fort',
#  'chief say how many',
#  'thousand',
#  'why',
#  'to bring the word of god',
#  'chief say he ha a god',
#  'and also to bring medicine',
#  'chief say',
#  'he ha medicine tell him we admire his people',
#  'it wont be easy to get rid of your prophet now don sanchez',
#  'on the contrary your eminence it seems to me the man is preparing his own cross',
#  'and you say this is an indian vice by god i dont see any kind of pleasure that would make this a sin',
#  'the indian have no such word don moxica',
#  'do they have such thought',
#  'they come and go a naked a the day god created them',
#  'they dont see sin in their nakedness they live according to nature in a never ending summer the island are covered with tree filled with blossom and fruit and',
#  'forgive me don colon but what about gold',
#  'you defend yourself admirably',
#  'for a commoner',
#  'i understand that you will soon be appointing governor for the island is it not so',
#  'forgive me don bobadilla those position have already been taken',
#  'may i ask by whom',
#  'bartolome and giacomo colon',
#  'but we do have a lack of notary you should contact my administration',
#  'don bobadilla is already a judge my dear don cristobal',
#  'good we are also in need of judge except there are no thief',
#  'you seem to have a special talent for making friend',
#  'what do i have so many already',
#  'to rise so high in so short a time is a dangerous occupation a little hypocrisy go a long way',
#  'beatrix i want to ask you something',
#  'you dont usually ask',
#  'i can arrange for the queen to take fernando and diego into her service',
#  'we lost cousin friend we will wash this in blood',
#  'if you want to keep your head on your shoulder youll do a i say',
#  'you want a war fine we are a thousand they outnumber u by ten who will you kill which tribe',
#  'we dont need to know',
#  'we came here to stay to build not to start a crusade in this forest there is enough danger to sweep u away in day so we will be brave and swallow our grief and in the name of those who died we will accomplish what we came for',
#  'we will work with his people we want peace ask the chief if he understands',
#  'he understands',
#  'ask him if he will help',
#  'we cant raise the wheel without it',
#  'my horse doesnt work',
#  'don moxica we all have to work',
#  'you did not hear me don colon not my horse',
#  'every ship return with a cargo of sick and dying but with no gold the new world prof expensive your majesty',
#  'we werent expecting immediate profit were we we must have faith we must give time for time',
#  'in one act of brutality you have created chaos tribe who were fighting each other are now joining force against u all that because of your criminal savagery',
#  'savagery is what monkey understand',
#  'youll be held in detention deprived of your privilege and possession until you are returned to spain where you will be judged have you anything to say',
#  'you will regret this',
#  'you have to find them utapan look what they did',
#  'you did the same to your god',
#  'utapan wont you speak to me you used to know how to speak to me',
#  'you never learned how to speak my language',
#  'but there is worse he ordered the execution of five member of the nobility',
#  'is this true brother buyl',
#  'then what do you suggest don sanchez',
#  'he must be replaced',
#  'and who would you think of for such a task',
#  'don alonso de bobadilla',
#  'yes i remember',
#  'my letter of appointment',
#  'appointment to what',
#  'viceroy of the west indie',
#  'congratulation then i am free to search for the mainland',
#  'how far from here',
#  'i am not a seaman but i heard it is no more than a week at sea i hope you are not too disappointed',
#  'how could i be the mainland ha been found exactly a i said it would',
#  'i am afraid this is not the worst news',
#  'i have to explore the mainland',
#  'this time with me',
#  'but without your brother nor are you to return to santo domingo or any of the other colony you may explore the continent',
#  'thank you',
#  'there is one thing id like to understand why do you want to go back after all this',
#  'your majesty some men are content to read about thing i must see them with my own eye i cannot be other than i am',
#  'i know i should not tolerate his impertinence',
#  'then why',
#  'because he is not afraid of me',
#  'all i have to do is call the guard',
#  'call them',
#  'i am not afraid of you you are nothing but a dreamer',
#  'look out of that window',
#  'what do you see',
#  'roof tower palace spire',
#  'all of them created by people like me',
#  'god youre so beautiful i cant believe no other man ha ever taken you away from me',
#  'they tried but i didnt let them',
#  'they took everything',
#  'not everything do you think i care im a free man again rich dont make a man rich they only make him busier',
#  'how are you feeling fernando',
#  'not bad',
#  'whats he doing',
#  'he drawing an isthmus he saying were on an isthmus',
#  'we cant be',
#  'father',
#  'there must be a passage to that other ocean',
#  'you can see for yourself',
#  'what a tragedy what a waste of a life',
#  'a waste let me tell you something arojaz if your name or mine is ever remembered it will only be because of his',
#  'i suppose were both old men now',
#  'youll always be older than me father',
#  'i have to disagree',
#  'i knew you would',
#  'new world create new people',
#  'oh so you are a new man',
#  'i dont know i have the impression that i didnt change that much i still cant accept the world a it is',
#  'cant you stay with u a little',
#  'i am busy inside',
#  'what is it now tell me',
#  'i cant keep my eye off you i would like to catch up with all the moment i didnt spend with you',
#  'what are you listening to',
#  'i am not listening father but i cant help hearing',
#  'what doe he say',
#  'he asks when he can come to visit you he left his address',
#  'he never had one except aboard my ship',
#  'i want you to tell me everything you remember father from the beginning everything',
#  'really god i wouldnt know where to start and yet',
#  'tell me the first thing that come to your mind',
#  'just do what i do say the same thing i say dont open your mouth',
#  'okay',
#  'dont fool around',
#  'okay',
#  'did you hear what i said',
#  'i want to document my trip to america',
#  'next could i see your document please',
#  'yes sir',
#  'what is your intended purpose of your visit to the united state',
#  'two week holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollar',
#  'can you show me sir no camera in the fis area',
#  'is he with you are you travelling together',
#  'yes',
#  'please join u come on forward',
#  'is there a problem',
#  'no youre travelling together i want to talk to you together hi how are you can i take a look at your document are you related',
#  'yeshes my friend',
#  'okay youre a national and youre a national how do you know one another',
#  'we are both from prague',
#  'how long are you planning to stay',
#  'two week',
#  'id like to speak for himself okay',
#  'he doesnt speak english',
#  'i speak english',
#  'then answer my question where were you planning to stay during the two week that youre here',
#  'new york',
#  'yes were in new york now but where are you planning to stay in new york',
#  'a cheap hotel',
#  'what are you coming here to do',
#  'im here for movie',
#  'moviesto be in the movie or to see movie',
#  'yes no both when i wa a boy i see movie at school called it a wonderful life directed by frank capra ever since i want to come to america land of the free home of the brave a land where anyone can be anything a long a they are white',
#  'excuse me',
#  'so were waitin to hit this warrant we got emergency service with the heavy weapon standin by ready to go i say lemme get a cigar outta the car i go to get the cigar and boom all the sudden i turn around and a kid with a shotgun let one go right where i wa standin that coulda been it i coulda had my head blown off and for what some stupid kid got panicky take the safety off and it over if i hadnt gone back for that cigar for a bad habit i wouldve had my head blown off',
#  'jesus christ',
#  'coffee for me i gotta slow down',
#  'vodka tonic',
#  'maybe you could just put in a shot of martell',
#  'it wa freaky ill tell you stupid kid',
#  'whats the kid gonna say sorry meanwhile im not here anymore like last week we were at the morgue and this guy wa all chopped up spleen here liver there his heart in a pan six hour ago this guy wa walkin his dog or buyin a quart of milk who know but some kid robbed him for 3 or some shit and shot him and now you cant tell if he a piece of beef or a human being and im thinkin thats me sooner or later thats me',
#  'sooner or later thats everybody',
#  'not chopped up not chopped up like that i mean what do i got left coupla article a medal or two plaque here and there and in a coupla year no one remembers me anymore',
#  'i think youre getting a little moody there eddie',
#  'im not moody',
#  'isnt he a little moody',
#  'of course he moody he think he in love',
#  'in love with who',
#  'how old are your kid',
#  'my kid let seesusans 15 aundreas 9 dont tell me youre thinking about having a kid how old are you never mind let me just tell you this every stupid cliche you hear about kid they change your life they make you a better person they make you whole it all true before i had kid when friend talked about their kid i wanted to vomit now i get it am i right leon',
#  'yeah',
#  'paulie youve got kid right',
#  'okay you work in a vodka factory i understand that and what kind of work do you do',
#  'i am butcher',
#  'youre a butcher what do you use pig intestine for',
#  'you stuff sausage in it',
#  'and what do you do with the bone',
#  ...]

# %%
messages['msg_pre_processed'] = data_pre_processed

# %% [markdown]
# ### Checking for duplicated messages in msg

# %%
data = messages['msg_pre_processed']

# %%
dict = {}
for n in data:
    if n in dict:
        dict[n] = dict[n] + 1
    else:
        dict[n] = 1

# %%
#sort dict by biggest values
dict = {k: v for k, v in sorted(dict.items(), key=lambda item: item[1], reverse=True)}

# %%
dict
# Out:
# {'what': 1998,
#  'yes': 1765,
#  'no': 1695,
#  'yeah': 1349,
#  'why': 595,
#  'i dont know': 456,
#  'okay': 421,
#  'oh': 347,
#  'thank you': 320,
#  'unknown': 310,
#  'sure': 307,
#  'hello': 291,
#  'who': 289,
#  'yes sir': 277,
#  'why not': 265,
#  'i know': 249,
#  'really': 243,
#  'what is it': 240,
#  'what do you mean': 237,
#  'huh': 237,
#  'hi': 234,
#  'right': 231,
#  'thanks': 215,
#  'whats that': 198,
#  'well': 195,
#  'im sorry': 193,
#  'uhhuh': 188,
#  'what are you doing': 186,
#  'nothing': 186,
#  'thats right': 181,
#  'where': 167,
#  'what happened': 166,
#  'what are you talking about': 163,
#  'of course': 161,
#  'hey': 151,
#  'how': 141,
#  'excuse me': 139,
#  'good': 135,
#  'so': 131,
#  'sorry': 129,
#  'shut up': 113,
#  'oh yeah': 112,
#  'what do you want': 112,
#  'fine': 112,
#  'shit': 105,
#  'whats wrong': 99,
#  'jesus': 99,
#  'where are you going': 99,
#  'please': 99,
#  'come on': 98,
#  'all right': 92,
#  'when': 91,
#  'what do you think': 89,
#  'who are you': 88,
#  'no sir': 87,
#  'what are you doing here': 86,
#  'i see': 84,
#  'sir': 83,
#  'what for': 83,
#  'and': 81,
#  'i dont think so': 81,
#  'maybe': 80,
#  'ok': 80,
#  'you okay': 77,
#  'me': 77,
#  'like what': 76,
#  'i cant': 76,
#  'whats this': 75,
#  'whats the matter': 75,
#  'i dont understand': 74,
#  'great': 73,
#  'you': 73,
#  'but': 72,
#  'oh my god': 72,
#  'whats going on': 70,
#  'oh no': 69,
#  'dad': 66,
#  'about what': 65,
#  'me too': 63,
#  'are you sure': 63,
#  'no thanks': 63,
#  'for what': 62,
#  'here': 61,
#  'i do': 61,
#  'fuck you': 60,
#  'not yet': 60,
#  'uh huh': 60,
#  'who is it': 60,
#  'let go': 59,
#  'how do you know': 59,
#  'thats it': 59,
#  'what wa that': 58,
#  'nope': 58,
#  'how much': 57,
#  'i understand': 57,
#  'you do': 57,
#  'forget it': 55,
#  'what doe that mean': 55,
#  'i': 54,
#  'i love you': 52,
#  'what did you say': 52,
#  'yep': 52,
#  'no way': 51,
#  'you sure': 50,
#  'goodbye': 50,
#  'oh god': 50,
#  'are you okay': 50,
#  'no no': 50,
#  'go ahead': 49,
#  'good night': 49,
#  'bullshit': 48,
#  'now': 47,
#  'yes maam': 47,
#  'are you all right': 47,
#  'i did': 46,
#  'i dont': 46,
#  'what are you going to do': 46,
#  'exactly': 45,
#  'absolutely': 45,
#  'im fine': 45,
#  'wow': 44,
#  'stop it': 44,
#  'i beg your pardon': 44,
#  'i think so': 44,
#  'wait': 44,
#  'not at all': 43,
#  'got it': 43,
#  'i am': 43,
#  'i guess': 43,
#  'oh shit': 43,
#  'alright': 42,
#  'jack': 42,
#  'good morning': 42,
#  'bye': 40,
#  'yah': 40,
#  'whats up': 39,
#  'whats your name': 39,
#  'oh yes': 39,
#  'do you': 39,
#  'look': 39,
#  'mm': 39,
#  'you did': 39,
#  'get out': 38,
#  'where is she': 38,
#  'tell me': 38,
#  'what is this': 38,
#  'mom': 38,
#  'go on': 37,
#  'what is that': 37,
#  'who that': 36,
#  'youre kidding': 36,
#  'where is he': 36,
#  'now what': 36,
#  'yes i do': 36,
#  'oh jesus': 36,
#  'go': 36,
#  'yup': 36,
#  'never': 35,
#  'no thank you': 35,
#  'ah': 35,
#  'it okay': 34,
#  'who is this': 34,
#  'dont': 34,
#  'anything': 34,
#  'of course not': 34,
#  'hmm': 33,
#  'goodnight': 33,
#  'something like that': 32,
#  'mmm': 32,
#  'i will': 32,
#  'what time is it': 32,
#  'what did he say': 32,
#  'you got it': 32,
#  'okay okay': 32,
#  'im not': 31,
#  'not really': 31,
#  'no i dont': 31,
#  'holy shit': 31,
#  'jesus christ': 30,
#  'ready': 30,
#  'stop': 30,
#  'where are you': 30,
#  'where is it': 30,
#  'aye sir': 30,
#  'are you alright': 29,
#  'where are we going': 29,
#  'hows that': 29,
#  'two': 29,
#  'the what': 29,
#  'cool': 29,
#  'a what': 29,
#  'thank you sir': 29,
#  'i dont believe it': 29,
#  'yes it is': 28,
#  'im here': 28,
#  'do it': 28,
#  'no im not': 28,
#  'i know that': 28,
#  'yeah right': 27,
#  'uh': 27,
#  'how old are you': 27,
#  'no shit': 27,
#  'it is': 27,
#  'i know i know': 27,
#  'what about it': 27,
#  'yeah sure': 27,
#  'damn': 27,
#  'im not sure': 27,
#  'shhh': 27,
#  'do what': 26,
#  'who is he': 26,
#  'so what': 26,
#  'which one': 26,
#  'you think so': 26,
#  'you are': 26,
#  'come here': 26,
#  'wait a minute': 26,
#  'what about you': 26,
#  'no problem': 26,
#  'hm': 26,
#  'i dont know what youre talking about': 26,
#  'mother': 26,
#  'get out of here': 26,
#  'how are you': 25,
#  'how many': 25,
#  'whats that supposed to mean': 25,
#  'whats happening': 25,
#  'whatever': 25,
#  'i guess so': 25,
#  'yeah i know': 25,
#  'you all right': 25,
#  'no youre not': 25,
#  'did you': 25,
#  'again': 25,
#  'thats good': 24,
#  'what is': 24,
#  'good luck': 24,
#  'hold on': 24,
#  'i dont care': 24,
#  'hmmm': 24,
#  'i dont believe you': 24,
#  'my god': 24,
#  'how do you do': 24,
#  'there': 23,
#  'you what': 23,
#  'yes i am': 23,
#  'what else': 23,
#  'daddy': 23,
#  'what the hell are you doing': 23,
#  'tomorrow': 23,
#  'john': 23,
#  'what are you saying': 22,
#  'tonight': 22,
#  'where you going': 22,
#  'what about me': 22,
#  'i dont get it': 22,
#  'you know': 22,
#  'dead': 22,
#  'yes i did': 22,
#  'i dunno': 22,
#  'listen': 22,
#  'george': 22,
#  'out': 22,
#  'aye': 22,
#  'harry': 22,
#  'promise': 21,
#  'no no no': 21,
#  'youre sure': 21,
#  'michael': 21,
#  'be careful': 21,
#  'how come': 21,
#  'nah': 21,
#  'then what': 21,
#  'where to': 21,
#  'objection': 21,
#  'it me': 21,
#  'claire': 21,
#  'whatd he say': 20,
#  'sit down': 20,
#  'roger': 20,
#  'right here': 20,
#  'youre right': 20,
#  'whats the matter with you': 20,
#  'tell me about it': 20,
#  'how did you know': 20,
#  'can i help you': 20,
#  'sort of': 20,
#  'honey': 20,
#  'probably': 20,
#  'what do we do': 20,
#  'what now': 20,
#  'frank': 20,
#  'so do i': 20,
#  'you dont know': 20,
#  'youre welcome': 19,
#  'how long': 19,
#  'youre crazy': 19,
#  'is it': 19,
#  'you cant': 19,
#  'right now': 19,
#  'i didnt': 19,
#  'what about': 19,
#  'nice': 19,
#  'no i didnt': 19,
#  'later': 19,
#  'where are they': 19,
#  'fuck': 19,
#  'home': 19,
#  'nick': 19,
#  'you bet': 19,
#  'no you dont': 19,
#  'is that right': 18,
#  'yes i know': 18,
#  'what happened to you': 18,
#  'you too': 18,
#  'meaning': 18,
#  'of what': 18,
#  'im sure': 18,
#  'everything': 18,
#  'leave me alone': 18,
#  'i have no idea': 18,
#  'david': 18,
#  'what wa it': 18,
#  'no kidding': 18,
#  'oh right': 18,
#  'what what': 18,
#  'why that': 18,
#  'but why': 18,
#  'go away': 18,
#  'you bastard': 18,
#  'what do you want me to do': 18,
#  'who this': 18,
#  'youre late': 18,
#  'you dont': 18,
#  'are you serious': 18,
#  'i wont': 18,
#  'he dead': 18,
#  'xxxxxx': 18,
#  'mmhm': 18,
#  'a little': 18,
#  'but what': 18,
#  'always': 18,
#  'i have to go': 18,
#  'what about him': 17,
#  'this': 17,
#  'absolutely not': 17,
#  'wha': 17,
#  'whats the problem': 17,
#  'excellent': 17,
#  'three': 17,
#  'are you crazy': 17,
#  'such a': 17,
#  'no why': 17,
#  'well i': 17,
#  'youre lying': 17,
#  'that': 17,
#  'beautiful': 17,
#  'are you': 17,
#  'what are they': 17,
#  'very well': 17,
#  'cmon': 17,
#  'how is he': 17,
#  'he did': 17,
#  'congratulation': 17,
#  'youre not': 17,
#  'bob': 17,
#  'where were you': 17,
#  'yes yes': 17,
#  'i told you': 16,
#  'thank god': 16,
#  'so am i': 16,
#  'certainly': 16,
#  'true': 16,
#  'whats his name': 16,
#  'what do you do': 16,
#  'hows it going': 16,
#  'deal': 16,
#  'i promise': 16,
#  'check': 16,
#  'thats not true': 16,
#  'who wa that': 16,
#  'mmmm': 16,
#  'me neither': 16,
#  'oh hi': 16,
#  'why do you say that': 16,
#  'dont worry': 16,
#  'what the hell is that': 16,
#  'oh really': 16,
#  'how so': 16,
#  'thats great': 16,
#  'morning': 16,
#  'whatd you say': 16,
#  'thats too bad': 16,
#  'do i know you': 16,
#  'not exactly': 16,
#  'all right then': 16,
#  'you didnt': 15,
#  'you know what i mean': 15,
#  'i hope so': 15,
#  'dont worry about it': 15,
#  'because': 15,
#  'yes but': 15,
#  'pardon me': 15,
#  'what are you': 15,
#  'what the fuck': 15,
#  'where are we': 15,
#  'just do it': 15,
#  'what the hell are you talking about': 15,
#  'how do you mean': 15,
#  'just like that': 15,
#  'my pleasure': 15,
#  'never mind': 15,
#  'no i': 15,
#  'uhuh': 15,
#  'sometimes': 15,
#  'no not yet': 15,
#  'ouch': 15,
#  'very good': 15,
#  'pardon': 15,
#  'yessir': 15,
#  'we': 15,
#  'thank you very much': 15,
#  'i have': 15,
#  'ow': 15,
#  'what the hell': 15,
#  'oh okay': 15,
#  'you think': 14,
#  'why didnt you tell me': 14,
#  'father': 14,
#  'good idea': 14,
#  'im serious': 14,
#  'what are we going to do': 14,
#  'yes of course': 14,
#  'is that all': 14,
#  'show me': 14,
#  'money': 14,
#  'thats ridiculous': 14,
#  'what did you do': 14,
#  'thats enough': 14,
#  'eh': 14,
#  'anything else': 14,
#  'thats nice': 14,
#  'it doesnt matter': 14,
#  'where am i': 14,
#  'why are you doing this': 14,
#  'how do you know that': 14,
#  'charlie': 14,
#  'what the': 14,
#  'i dont want to talk about it': 14,
#  'shoot': 14,
#  'come on in': 14,
#  'yeah yeah': 14,
#  'thats me': 14,
#  'oh please': 14,
#  'whatre you doing': 14,
#  'yeah me too': 14,
#  'is that so': 14,
#  'why me': 14,
#  'i agree': 14,
#  'walter': 14,
#  'no i dont think so': 14,
#  'whats wrong with you': 14,
#  'what do you want from me': 14,
#  'come again': 14,
#  'get up': 14,
#  'it all right': 14,
#  'i cant do that': 14,
#  'who are they': 14,
#  'and you': 14,
#  'this could be it': 14,
#  'no what': 13,
#  'i guess not': 13,
#  'and then': 13,
#  'perfect': 13,
#  'ill be right back': 13,
#  'im listening': 13,
#  'good for you': 13,
#  'this way': 13,
#  'could be': 13,
#  'im not hungry': 13,
#  'four': 13,
#  'im trying': 13,
#  'what the hell going on': 13,
#  'better': 13,
#  'what doe it say': 13,
#  'perhaps': 13,
#  'with what': 13,
#  'mhm': 13,
#  'what do i do': 13,
#  'open it': 13,
#  'captain': 13,
#  'know what': 13,
#  'come in': 13,
#  'if you say so': 13,
#  'im working on it': 13,
#  'oh my': 13,
#  'thats okay': 13,
#  'no it not': 13,
#  'dont say that': 13,
#  'it beautiful': 13,
#  'where have you been': 13,
#  'i love you too': 13,
#  'whatre you talking about': 13,
#  'ha': 13,
#  'he is': 13,
#  'jake': 13,
#  'hurry': 13,
#  'whats the difference': 13,
#  'i wa': 12,
#  'you tell me': 12,
#  'oh sure': 12,
#  'thats true': 12,
#  'love': 12,
#  'fuck off': 12,
#  'mommy': 12,
#  'well what': 12,
#  'im okay': 12,
#  'what about her': 12,
#  'what thing': 12,
#  'him': 12,
#  'i dont remember': 12,
#  'yeah okay': 12,
#  'she did': 12,
#  'should i': 12,
#  'no really': 12,
#  'mine': 12,
#  'see you later': 12,
#  'doing what': 12,
#  'can i come in': 12,
#  'ill do it': 12,
#  'coffee': 12,
#  'andy': 12,
#  'what did she say': 12,
#  'oh great': 12,
#  'i forgive you': 12,
#  'shes dead': 12,
#  'more or le': 12,
#  'something wrong': 12,
#  'not me': 12,
#  'peter': 12,
#  'thats fine': 12,
#  'uhoh': 12,
#  'im scared': 12,
#  'you like it': 12,
#  'ray': 12,
#  'hi dad': 12,
#  'who told you that': 12,
#  'give it to me': 12,
#  'how is she': 12,
#  'i know but': 12,
#  'hi mom': 12,
#  'you dont say': 12,
#  'im all right': 12,
#  'well see': 12,
#  'id love to': 12,
#  'it fine': 12,
#  'bobby': 12,
#  'on screen': 12,
#  'who is she': 11,
#  'enough': 11,
#  'who care': 11,
#  'yeah i guess': 11,
#  'how wa it': 11,
#  'continued': 11,
#  'it not': 11,
#  'you hear that': 11,
#  'wheres that': 11,
#  'tom': 11,
#  'a you wish': 11,
#  'dont be ridiculous': 11,
#  'yeah thats right': 11,
#  'what why': 11,
#  'yeah what': 11,
#  'oh man': 11,
#  'it too late': 11,
#  'id like that': 11,
#  'too bad': 11,
#  'alex': 11,
#  'no not really': 11,
#  'yes thank you': 11,
#  'fair enough': 11,
#  'im hungry': 11,
#  'we need to talk': 11,
#  'whoa': 11,
#  'nervous': 11,
#  'god': 11,
#  'christ': 11,
#  'nice to meet you': 11,
#  'time': 11,
#  'dont do this': 11,
#  'do i': 11,
#  'definitely': 11,
#  'where do you live': 11,
#  'whats her name': 11,
#  'do you love me': 11,
#  'can i ask you something': 11,
#  'go to hell': 11,
#  'dave': 11,
#  'obviously': 11,
#  'and now': 11,
#  'oh come on': 11,
#  'what make you say that': 11,
#  'mama': 11,
#  'what is this place': 11,
#  'like this': 11,
#  'jeffrey': 11,
#  'get away from me': 11,
#  'nobody': 11,
#  'what do you want to do': 11,
#  'no not at all': 11,
#  'just a minute': 11,
#  'what is your name': 11,
#  'i heard': 11,
#  'shhhh': 11,
#  'what about them': 11,
#  'hang on': 11,
#  'sam': 11,
#  'help me': 11,
#  'mary': 11,
#  'yes you are': 11,
#  'jimmy': 11,
#  'whats happened': 11,
#  'you will': 11,
#  'terrific': 11,
#  'bingo': 11,
#  'your father': 11,
#  'you believe that': 11,
#  'quiet': 11,
#  'why is that': 11,
#  'oh christ': 11,
#  'sound good': 11,
#  'benjamin': 11,
#  'joe': 11,
#  'beth': 11,
#  'spock': 11,
#  'no but': 10,
#  'not bad': 10,
#  'you ready': 10,
#  'who there': 10,
#  'amen': 10,
#  'how do i look': 10,
#  'you dont understand': 10,
#  'you alright': 10,
#  'i dont know i dont know': 10,
#  'son of a bitch': 10,
#  'one': 10,
#  '': 10,
#  'oh i see': 10,
#  'whats that mean': 10,
#  'im going home': 10,
#  'fuckin a': 10,
#  'agreed': 10,
#  'ill try': 10,
#  'coming': 10,
#  'would you': 10,
#  'here we go': 10,
#  'dont bother': 10,
#  'see': 10,
#  'what do you want to know': 10,
#  'your majesty': 10,
#  'oh thank you': 10,
#  'for me': 10,
#  'not now': 10,
#  'al': 10,
#  'interesting': 10,
#  'where we going': 10,
#  'yeah thanks': 10,
#  'i can handle it': 10,
#  'wait a second': 10,
#  'let get out of here': 10,
#  'yeah well': 10,
#  'thats what i said': 10,
#  'let me see': 10,
#  'seriously': 10,
#  'you first': 10,
#  'it true': 10,
#  'marty': 10,
#  'mmmmm': 10,
#  'yeah but': 10,
#  'yes you do': 10,
#  'keep it': 10,
#  'ben': 10,
#  'oh good': 10,
#  'i wouldnt know': 10,
#  'kay': 10,
#  'darling': 10,
#  'am i': 10,
#  'what the hell is this': 10,
#  'it alright': 10,
#  'nothin': 10,
#  'how are you doing': 10,
#  'like': 10,
#  'youre wrong': 10,
#  'yeah so': 10,
#  'what what is it': 10,
#  'who wa it': 10,
#  'what wa that all about': 10,
#  'what did i say': 10,
#  'it locked': 10,
#  'trust me': 10,
#  'bastard': 10,
#  'follow me': 10,
#  'whats wrong with it': 10,
#  'my wife': 10,
#  'listen to me': 10,
#  'i have to': 10,
#  'not a chance': 10,
#  'are you ok': 10,
#  'up': 10,
#  'no answer': 10,
#  'come on come on': 10,
#  'certainly not': 10,
#  'never heard of him': 10,
#  'ellie': 10,
#  'guess': 10,
#  'yes it doe': 10,
#  'mr president': 10,
#  'so what do we do': 10,
#  'yo': 10,
#  'which way': 10,
#  'on what': 10,
#  'why did you do that': 10,
#  'let do it': 10,
#  'i have to talk to you': 10,
#  'where you goin': 10,
#  'i got it': 10,
#  'it ok': 10,
#  'it possible': 9,
#  'we do': 9,
#  'max': 9,
#  'not quite': 9,
#  'youre joking': 9,
#  'eddie': 9,
#  'i dont know what to say': 9,
#  'who else': 9,
#  'whats the plan': 9,
#  'pop': 9,
#  'why should i': 9,
#  'like you': 9,
#  'thats a lie': 9,
#  'you wouldnt': 9,
#  'see you': 9,
#  'jim': 9,
#  'that way': 9,
#  'ill go': 9,
#  'how do you feel': 9,
#  'so what do you think': 9,
#  'whats so funny': 9,
#  'arent you': 9,
#  'what do you mean by that': 9,
#  'thats all': 9,
#  'probably not': 9,
#  'why are you here': 9,
#  'no please': 9,
#  'no you didnt': 9,
#  'thanks a lot': 9,
#  'gotta go': 9,
#  'shut the fuck up': 9,
#  'then dont': 9,
#  'mmhmm': 9,
#  'you know him': 9,
#  'i know im sorry': 9,
#  'ill be there': 9,
#  'oh im sorry': 9,
#  'oh sorry': 9,
#  'no never': 9,
#  'im ready': 9,
#  'it important': 9,
#  'look at this': 9,
#  'come with me': 9,
#  'oh oh': 9,
#  'naturally': 9,
#  'none': 9,
#  'so what happened': 9,
#  'so whats the problem': 9,
#  'good evening': 9,
#  'all the time': 9,
#  'both': 9,
#  'yeah maybe': 9,
#  'i am not': 9,
#  'tired': 9,
#  'howd it go': 9,
#  'what the hell are you doing here': 9,
#  'fire': 9,
#  'positive': 9,
#  'whats wrong with him': 9,
#  'soon': 9,
#  'it okay it okay': 9,
#  'what the fuck is going on': 9,
#  'say what': 9,
#  'try me': 9,
#  'son': 9,
#  'oh dear': 9,
#  'correct': 9,
#  'youre insane': 9,
#  'say who': 9,
#  'will': 9,
#  'naw': 9,
#  'it doe': 9,
#  'whats it to you': 9,
#  'i suppose': 9,
#  'and whats that': 9,
#  'what can we do': 9,
#  'five': 9,
#  'yeah why': 9,
#  'run': 9,
#  'thats all right': 9,
#  'yes you did': 9,
#  'you could say that': 9,
#  'i believe you': 9,
#  'you know her': 9,
#  'thats impossible': 9,
#  'mile': 9,
#  'it': 9,
#  'ed': 9,
#  'neither do i': 9,
#  'get it': 9,
#  'good point': 9,
#  'it not your fault': 9,
#  'what can i do for you': 9,
#  'very much': 9,
#  'hear what': 9,
#  'were leaving': 9,
#  'what kind': 9,
#  'who did': 9,
#  'dont do that': 9,
#  'howd you know': 9,
#  'we are': 9,
#  'ahh': 9,
#  'say it': 8,
#  'joey': 8,
#  'funny': 8,
#  'are you married': 8,
#  'doe it hurt': 8,
#  'not good': 8,
#  'ill think about it': 8,
#  'who the hell are you': 8,
#  'thats what i thought': 8,
#  'im not going': 8,
#  'i dont want to': 8,
#  'you look great': 8,
#  'alice': 8,
#  'to do what': 8,
#  'your mother': 8,
#  'which is': 8,
#  'not particularly': 8,
#  'i want to go home': 8,
#  'im afraid': 8,
#  'youre what': 8,
#  'stay away from me': 8,
#  'nine': 8,
#  'no were not': 8,
#  'you mean': 8,
#  'look at that': 8,
#  'what can i do': 8,
#  'but i': 8,
#  'whered you get this': 8,
#  'alive': 8,
#  'gone': 8,
#  'why what': 8,
#  'in a minute': 8,
#  'what time': 8,
#  'night': 8,
#  'is it true': 8,
#  'indeed': 8,
#  'yes what': 8,
#  'wrong': 8,
#  'did you hear that': 8,
#  'what happened to them': 8,
#  'where is he now': 8,
#  'boy': 8,
#  'yes darling': 8,
#  'what do we do now': 8,
#  'noooo': 8,
#  'watch me': 8,
#  'whatever you say': 8,
#  'you have': 8,
#  'im so sorry': 8,
#  'you dont have to': 8,
#  'i dont mind': 8,
#  'right right': 8,
#  'you really think so': 8,
#  'who he': 8,
#  'sure thing': 8,
#  'what did he want': 8,
#  'impossible': 8,
#  'death': 8,
#  'what are you thinking': 8,
#  'i know you': 8,
#  'and what': 8,
#  'sir yes sir': 8,
#  'i didnt do anything': 8,
#  'liar': 8,
#  'im going with you': 8,
#  'is he all right': 8,
#  'oh thats nice': 8,
#  'hey man': 8,
#  'what the fuck are you talking about': 8,
#  'whats that for': 8,
#  'you dont know that': 8,
#  'what are you looking at': 8,
#  'pas': 8,
#  'i dont know yet': 8,
#  'i cant do it': 8,
#  'im really sorry': 8,
#  'for how long': 8,
#  'this is it': 8,
#  'okay thanks': 8,
#  'ill call you': 8,
#  'are you kidding': 8,
#  'from what': 8,
#  'you killed him': 8,
#  'well i dont know': 8,
#  'go home': 8,
#  'not anymore': 8,
#  'suit yourself': 8,
#  'of course i do': 8,
#  'ohh': 8,
#  'he gone': 8,
#  'no no no no': 8,
#  'take your time': 8,
#  'no nothing': 8,
#  'where do you think youre going': 8,
#  'why would i do that': 8,
#  'just relax': 8,
#  'i dont know what you mean': 8,
#  'whats your point': 8,
#  'doc': 8,
#  'not tonight': 8,
#  'i need your help': 8,
#  'are you finished': 8,
#  'susan': 8,
#  'six': 8,
#  'none of your business': 8,
#  'yeah i think so': 8,
#  'understood': 8,
#  'im in': 8,
#  'im glad': 8,
#  'youre serious': 8,
#  'are you out of your mind': 8,
#  'alan': 8,
#  'what do you think youre doing': 8,
#  'come on let go': 8,
#  'damn right': 8,
#  'sure why not': 8,
#  'yes my lord': 8,
#  'possibly': 8,
#  'keep your voice down': 8,
#  'ill bet': 8,
#  'johnny': 8,
#  'what the hell is going on': 8,
#  'you got that right': 8,
#  'yes he is': 8,
#  'done': 8,
#  'what happened to your hand': 8,
#  'steve': 8,
#  'oh boy': 8,
#  'mike': 8,
#  'report': 8,
#  'whereve you been': 7,
#  'what do you see': 7,
#  'no im okay': 7,
#  'what are you gonna do': 7,
#  'whatd you do': 7,
#  'last night': 7,
#  'drink': 7,
#  'cash': 7,
#  'see ya': 7,
#  'whats wrong with me': 7,
#  'how did you know that': 7,
#  'but how': 7,
#  'hi honey': 7,
#  'yes mother': 7,
#  'when wa that': 7,
#  'you lied to me': 7,
#  'well see about that': 7,
#  'who am i': 7,
#  'next week': 7,
#  'ted': 7,
#  'thats my girl': 7,
#  'goodbye darling': 7,
#  'who know': 7,
#  'is that a fact': 7,
#  'bill': 7,
#  'how nice': 7,
#  'not much': 7,
#  'i remember': 7,
#  'that depends': 7,
#  'i might': 7,
#  'hardly': 7,
#  'i heard that': 7,
#  'feeling better': 7,
#  'do you like it': 7,
#  'very nice': 7,
#  'lovely': 7,
#  'i thought so': 7,
#  'mine too': 7,
#  'twenty': 7,
#  'i swear': 7,
#  'good day': 7,
#  ...}

# %%
#example of duplcated msg
messages[messages['msg_pre_processed'] == 'did you change your hair']
# Out:
#                msg_line user_id movie_id                        msg  \
# msg_line_clean
# 49                  L49      u0       m0  Did you change your hair?
# 151439          L151439   u4736     m314  Did you change your hair?
#
#                     msg_2         msg_pre_processed
# msg_line_clean
# 49                    No.  did you change your hair
# 151439          A little.  did you change your hair

# %%
#get the repeated messages
d_list = list()
for k in dict:
    if dict[k] > 1:
        d_list.append(k)

# %%
d_list
# Out:
# ['what',
#  'yes',
#  'no',
#  'yeah',
#  'why',
#  'i dont know',
#  'okay',
#  'oh',
#  'thank you',
#  'unknown',
#  'sure',
#  'hello',
#  'who',
#  'yes sir',
#  'why not',
#  'i know',
#  'really',
#  'what is it',
#  'what do you mean',
#  'huh',
#  'hi',
#  'right',
#  'thanks',
#  'whats that',
#  'well',
#  'im sorry',
#  'uhhuh',
#  'what are you doing',
#  'nothing',
#  'thats right',
#  'where',
#  'what happened',
#  'what are you talking about',
#  'of course',
#  'hey',
#  'how',
#  'excuse me',
#  'good',
#  'so',
#  'sorry',
#  'shut up',
#  'oh yeah',
#  'what do you want',
#  'fine',
#  'shit',
#  'whats wrong',
#  'jesus',
#  'where are you going',
#  'please',
#  'come on',
#  'all right',
#  'when',
#  'what do you think',
#  'who are you',
#  'no sir',
#  'what are you doing here',
#  'i see',
#  'sir',
#  'what for',
#  'and',
#  'i dont think so',
#  'maybe',
#  'ok',
#  'you okay',
#  'me',
#  'like what',
#  'i cant',
#  'whats this',
#  'whats the matter',
#  'i dont understand',
#  'great',
#  'you',
#  'but',
#  'oh my god',
#  'whats going on',
#  'oh no',
#  'dad',
#  'about what',
#  'me too',
#  'are you sure',
#  'no thanks',
#  'for what',
#  'here',
#  'i do',
#  'fuck you',
#  'not yet',
#  'uh huh',
#  'who is it',
#  'let go',
#  'how do you know',
#  'thats it',
#  'what wa that',
#  'nope',
#  'how much',
#  'i understand',
#  'you do',
#  'forget it',
#  'what doe that mean',
#  'i',
#  'i love you',
#  'what did you say',
#  'yep',
#  'no way',
#  'you sure',
#  'goodbye',
#  'oh god',
#  'are you okay',
#  'no no',
#  'go ahead',
#  'good night',
#  'bullshit',
#  'now',
#  'yes maam',
#  'are you all right',
#  'i did',
#  'i dont',
#  'what are you going to do',
#  'exactly',
#  'absolutely',
#  'im fine',
#  'wow',
#  'stop it',
#  'i beg your pardon',
#  'i think so',
#  'wait',
#  'not at all',
#  'got it',
#  'i am',
#  'i guess',
#  'oh shit',
#  'alright',
#  'jack',
#  'good morning',
#  'bye',
#  'yah',
#  'whats up',
#  'whats your name',
#  'oh yes',
#  'do you',
#  'look',
#  'mm',
#  'you did',
#  'get out',
#  'where is she',
#  'tell me',
#  'what is this',
#  'mom',
#  'go on',
#  'what is that',
#  'who that',
#  'youre kidding',
#  'where is he',
#  'now what',
#  'yes i do',
#  'oh jesus',
#  'go',
#  'yup',
#  'never',
#  'no thank you',
#  'ah',
#  'it okay',
#  'who is this',
#  'dont',
#  'anything',
#  'of course not',
#  'hmm',
#  'goodnight',
#  'something like that',
#  'mmm',
#  'i will',
#  'what time is it',
#  'what did he say',
#  'you got it',
#  'okay okay',
#  'im not',
#  'not really',
#  'no i dont',
#  'holy shit',
#  'jesus christ',
#  'ready',
#  'stop',
#  'where are you',
#  'where is it',
#  'aye sir',
#  'are you alright',
#  'where are we going',
#  'hows that',
#  'two',
#  'the what',
#  'cool',
#  'a what',
#  'thank you sir',
#  'i dont believe it',
#  'yes it is',
#  'im here',
#  'do it',
#  'no im not',
#  'i know that',
#  'yeah right',
#  'uh',
#  'how old are you',
#  'no shit',
#  'it is',
#  'i know i know',
#  'what about it',
#  'yeah sure',
#  'damn',
#  'im not sure',
#  'shhh',
#  'do what',
#  'who is he',
#  'so what',
#  'which one',
#  'you think so',
#  'you are',
#  'come here',
#  'wait a minute',
#  'what about you',
#  'no problem',
#  'hm',
#  'i dont know what youre talking about',
#  'mother',
#  'get out of here',
#  'how are you',
#  'how many',
#  'whats that supposed to mean',
#  'whats happening',
#  'whatever',
#  'i guess so',
#  'yeah i know',
#  'you all right',
#  'no youre not',
#  'did you',
#  'again',
#  'thats good',
#  'what is',
#  'good luck',
#  'hold on',
#  'i dont care',
#  'hmmm',
#  'i dont believe you',
#  'my god',
#  'how do you do',
#  'there',
#  'you what',
#  'yes i am',
#  'what else',
#  'daddy',
#  'what the hell are you doing',
#  'tomorrow',
#  'john',
#  'what are you saying',
#  'tonight',
#  'where you going',
#  'what about me',
#  'i dont get it',
#  'you know',
#  'dead',
#  'yes i did',
#  'i dunno',
#  'listen',
#  'george',
#  'out',
#  'aye',
#  'harry',
#  'promise',
#  'no no no',
#  'youre sure',
#  'michael',
#  'be careful',
#  'how come',
#  'nah',
#  'then what',
#  'where to',
#  'objection',
#  'it me',
#  'claire',
#  'whatd he say',
#  'sit down',
#  'roger',
#  'right here',
#  'youre right',
#  'whats the matter with you',
#  'tell me about it',
#  'how did you know',
#  'can i help you',
#  'sort of',
#  'honey',
#  'probably',
#  'what do we do',
#  'what now',
#  'frank',
#  'so do i',
#  'you dont know',
#  'youre welcome',
#  'how long',
#  'youre crazy',
#  'is it',
#  'you cant',
#  'right now',
#  'i didnt',
#  'what about',
#  'nice',
#  'no i didnt',
#  'later',
#  'where are they',
#  'fuck',
#  'home',
#  'nick',
#  'you bet',
#  'no you dont',
#  'is that right',
#  'yes i know',
#  'what happened to you',
#  'you too',
#  'meaning',
#  'of what',
#  'im sure',
#  'everything',
#  'leave me alone',
#  'i have no idea',
#  'david',
#  'what wa it',
#  'no kidding',
#  'oh right',
#  'what what',
#  'why that',
#  'but why',
#  'go away',
#  'you bastard',
#  'what do you want me to do',
#  'who this',
#  'youre late',
#  'you dont',
#  'are you serious',
#  'i wont',
#  'he dead',
#  'xxxxxx',
#  'mmhm',
#  'a little',
#  'but what',
#  'always',
#  'i have to go',
#  'what about him',
#  'this',
#  'absolutely not',
#  'wha',
#  'whats the problem',
#  'excellent',
#  'three',
#  'are you crazy',
#  'such a',
#  'no why',
#  'well i',
#  'youre lying',
#  'that',
#  'beautiful',
#  'are you',
#  'what are they',
#  'very well',
#  'cmon',
#  'how is he',
#  'he did',
#  'congratulation',
#  'youre not',
#  'bob',
#  'where were you',
#  'yes yes',
#  'i told you',
#  'thank god',
#  'so am i',
#  'certainly',
#  'true',
#  'whats his name',
#  'what do you do',
#  'hows it going',
#  'deal',
#  'i promise',
#  'check',
#  'thats not true',
#  'who wa that',
#  'mmmm',
#  'me neither',
#  'oh hi',
#  'why do you say that',
#  'dont worry',
#  'what the hell is that',
#  'oh really',
#  'how so',
#  'thats great',
#  'morning',
#  'whatd you say',
#  'thats too bad',
#  'do i know you',
#  'not exactly',
#  'all right then',
#  'you didnt',
#  'you know what i mean',
#  'i hope so',
#  'dont worry about it',
#  'because',
#  'yes but',
#  'pardon me',
#  'what are you',
#  'what the fuck',
#  'where are we',
#  'just do it',
#  'what the hell are you talking about',
#  'how do you mean',
#  'just like that',
#  'my pleasure',
#  'never mind',
#  'no i',
#  'uhuh',
#  'sometimes',
#  'no not yet',
#  'ouch',
#  'very good',
#  'pardon',
#  'yessir',
#  'we',
#  'thank you very much',
#  'i have',
#  'ow',
#  'what the hell',
#  'oh okay',
#  'you think',
#  'why didnt you tell me',
#  'father',
#  'good idea',
#  'im serious',
#  'what are we going to do',
#  'yes of course',
#  'is that all',
#  'show me',
#  'money',
#  'thats ridiculous',
#  'what did you do',
#  'thats enough',
#  'eh',
#  'anything else',
#  'thats nice',
#  'it doesnt matter',
#  'where am i',
#  'why are you doing this',
#  'how do you know that',
#  'charlie',
#  'what the',
#  'i dont want to talk about it',
#  'shoot',
#  'come on in',
#  'yeah yeah',
#  'thats me',
#  'oh please',
#  'whatre you doing',
#  'yeah me too',
#  'is that so',
#  'why me',
#  'i agree',
#  'walter',
#  'no i dont think so',
#  'whats wrong with you',
#  'what do you want from me',
#  'come again',
#  'get up',
#  'it all right',
#  'i cant do that',
#  'who are they',
#  'and you',
#  'this could be it',
#  'no what',
#  'i guess not',
#  'and then',
#  'perfect',
#  'ill be right back',
#  'im listening',
#  'good for you',
#  'this way',
#  'could be',
#  'im not hungry',
#  'four',
#  'im trying',
#  'what the hell going on',
#  'better',
#  'what doe it say',
#  'perhaps',
#  'with what',
#  'mhm',
#  'what do i do',
#  'open it',
#  'captain',
#  'know what',
#  'come in',
#  'if you say so',
#  'im working on it',
#  'oh my',
#  'thats okay',
#  'no it not',
#  'dont say that',
#  'it beautiful',
#  'where have you been',
#  'i love you too',
#  'whatre you talking about',
#  'ha',
#  'he is',
#  'jake',
#  'hurry',
#  'whats the difference',
#  'i wa',
#  'you tell me',
#  'oh sure',
#  'thats true',
#  'love',
#  'fuck off',
#  'mommy',
#  'well what',
#  'im okay',
#  'what about her',
#  'what thing',
#  'him',
#  'i dont remember',
#  'yeah okay',
#  'she did',
#  'should i',
#  'no really',
#  'mine',
#  'see you later',
#  'doing what',
#  'can i come in',
#  'ill do it',
#  'coffee',
#  'andy',
#  'what did she say',
#  'oh great',
#  'i forgive you',
#  'shes dead',
#  'more or le',
#  'something wrong',
#  'not me',
#  'peter',
#  'thats fine',
#  'uhoh',
#  'im scared',
#  'you like it',
#  'ray',
#  'hi dad',
#  'who told you that',
#  'give it to me',
#  'how is she',
#  'i know but',
#  'hi mom',
#  'you dont say',
#  'im all right',
#  'well see',
#  'id love to',
#  'it fine',
#  'bobby',
#  'on screen',
#  'who is she',
#  'enough',
#  'who care',
#  'yeah i guess',
#  'how wa it',
#  'continued',
#  'it not',
#  'you hear that',
#  'wheres that',
#  'tom',
#  'a you wish',
#  'dont be ridiculous',
#  'yeah thats right',
#  'what why',
#  'yeah what',
#  'oh man',
#  'it too late',
#  'id like that',
#  'too bad',
#  'alex',
#  'no not really',
#  'yes thank you',
#  'fair enough',
#  'im hungry',
#  'we need to talk',
#  'whoa',
#  'nervous',
#  'god',
#  'christ',
#  'nice to meet you',
#  'time',
#  'dont do this',
#  'do i',
#  'definitely',
#  'where do you live',
#  'whats her name',
#  'do you love me',
#  'can i ask you something',
#  'go to hell',
#  'dave',
#  'obviously',
#  'and now',
#  'oh come on',
#  'what make you say that',
#  'mama',
#  'what is this place',
#  'like this',
#  'jeffrey',
#  'get away from me',
#  'nobody',
#  'what do you want to do',
#  'no not at all',
#  'just a minute',
#  'what is your name',
#  'i heard',
#  'shhhh',
#  'what about them',
#  'hang on',
#  'sam',
#  'help me',
#  'mary',
#  'yes you are',
#  'jimmy',
#  'whats happened',
#  'you will',
#  'terrific',
#  'bingo',
#  'your father',
#  'you believe that',
#  'quiet',
#  'why is that',
#  'oh christ',
#  'sound good',
#  'benjamin',
#  'joe',
#  'beth',
#  'spock',
#  'no but',
#  'not bad',
#  'you ready',
#  'who there',
#  'amen',
#  'how do i look',
#  'you dont understand',
#  'you alright',
#  'i dont know i dont know',
#  'son of a bitch',
#  'one',
#  '',
#  'oh i see',
#  'whats that mean',
#  'im going home',
#  'fuckin a',
#  'agreed',
#  'ill try',
#  'coming',
#  'would you',
#  'here we go',
#  'dont bother',
#  'see',
#  'what do you want to know',
#  'your majesty',
#  'oh thank you',
#  'for me',
#  'not now',
#  'al',
#  'interesting',
#  'where we going',
#  'yeah thanks',
#  'i can handle it',
#  'wait a second',
#  'let get out of here',
#  'yeah well',
#  'thats what i said',
#  'let me see',
#  'seriously',
#  'you first',
#  'it true',
#  'marty',
#  'mmmmm',
#  'yeah but',
#  'yes you do',
#  'keep it',
#  'ben',
#  'oh good',
#  'i wouldnt know',
#  'kay',
#  'darling',
#  'am i',
#  'what the hell is this',
#  'it alright',
#  'nothin',
#  'how are you doing',
#  'like',
#  'youre wrong',
#  'yeah so',
#  'what what is it',
#  'who wa it',
#  'what wa that all about',
#  'what did i say',
#  'it locked',
#  'trust me',
#  'bastard',
#  'follow me',
#  'whats wrong with it',
#  'my wife',
#  'listen to me',
#  'i have to',
#  'not a chance',
#  'are you ok',
#  'up',
#  'no answer',
#  'come on come on',
#  'certainly not',
#  'never heard of him',
#  'ellie',
#  'guess',
#  'yes it doe',
#  'mr president',
#  'so what do we do',
#  'yo',
#  'which way',
#  'on what',
#  'why did you do that',
#  'let do it',
#  'i have to talk to you',
#  'where you goin',
#  'i got it',
#  'it ok',
#  'it possible',
#  'we do',
#  'max',
#  'not quite',
#  'youre joking',
#  'eddie',
#  'i dont know what to say',
#  'who else',
#  'whats the plan',
#  'pop',
#  'why should i',
#  'like you',
#  'thats a lie',
#  'you wouldnt',
#  'see you',
#  'jim',
#  'that way',
#  'ill go',
#  'how do you feel',
#  'so what do you think',
#  'whats so funny',
#  'arent you',
#  'what do you mean by that',
#  'thats all',
#  'probably not',
#  'why are you here',
#  'no please',
#  'no you didnt',
#  'thanks a lot',
#  'gotta go',
#  'shut the fuck up',
#  'then dont',
#  'mmhmm',
#  'you know him',
#  'i know im sorry',
#  'ill be there',
#  'oh im sorry',
#  'oh sorry',
#  'no never',
#  'im ready',
#  'it important',
#  'look at this',
#  'come with me',
#  'oh oh',
#  'naturally',
#  'none',
#  'so what happened',
#  'so whats the problem',
#  'good evening',
#  'all the time',
#  'both',
#  'yeah maybe',
#  'i am not',
#  'tired',
#  'howd it go',
#  'what the hell are you doing here',
#  'fire',
#  'positive',
#  'whats wrong with him',
#  'soon',
#  'it okay it okay',
#  'what the fuck is going on',
#  'say what',
#  'try me',
#  'son',
#  'oh dear',
#  'correct',
#  'youre insane',
#  'say who',
#  'will',
#  'naw',
#  'it doe',
#  'whats it to you',
#  'i suppose',
#  'and whats that',
#  'what can we do',
#  'five',
#  'yeah why',
#  'run',
#  'thats all right',
#  'yes you did',
#  'you could say that',
#  'i believe you',
#  'you know her',
#  'thats impossible',
#  'mile',
#  'it',
#  'ed',
#  'neither do i',
#  'get it',
#  'good point',
#  'it not your fault',
#  'what can i do for you',
#  'very much',
#  'hear what',
#  'were leaving',
#  'what kind',
#  'who did',
#  'dont do that',
#  'howd you know',
#  'we are',
#  'ahh',
#  'say it',
#  'joey',
#  'funny',
#  'are you married',
#  'doe it hurt',
#  'not good',
#  'ill think about it',
#  'who the hell are you',
#  'thats what i thought',
#  'im not going',
#  'i dont want to',
#  'you look great',
#  'alice',
#  'to do what',
#  'your mother',
#  'which is',
#  'not particularly',
#  'i want to go home',
#  'im afraid',
#  'youre what',
#  'stay away from me',
#  'nine',
#  'no were not',
#  'you mean',
#  'look at that',
#  'what can i do',
#  'but i',
#  'whered you get this',
#  'alive',
#  'gone',
#  'why what',
#  'in a minute',
#  'what time',
#  'night',
#  'is it true',
#  'indeed',
#  'yes what',
#  'wrong',
#  'did you hear that',
#  'what happened to them',
#  'where is he now',
#  'boy',
#  'yes darling',
#  'what do we do now',
#  'noooo',
#  'watch me',
#  'whatever you say',
#  'you have',
#  'im so sorry',
#  'you dont have to',
#  'i dont mind',
#  'right right',
#  'you really think so',
#  'who he',
#  'sure thing',
#  'what did he want',
#  'impossible',
#  'death',
#  'what are you thinking',
#  'i know you',
#  'and what',
#  'sir yes sir',
#  'i didnt do anything',
#  'liar',
#  'im going with you',
#  'is he all right',
#  'oh thats nice',
#  'hey man',
#  'what the fuck are you talking about',
#  'whats that for',
#  'you dont know that',
#  'what are you looking at',
#  'pas',
#  'i dont know yet',
#  'i cant do it',
#  'im really sorry',
#  'for how long',
#  'this is it',
#  'okay thanks',
#  'ill call you',
#  'are you kidding',
#  'from what',
#  'you killed him',
#  'well i dont know',
#  'go home',
#  'not anymore',
#  'suit yourself',
#  'of course i do',
#  'ohh',
#  'he gone',
#  'no no no no',
#  'take your time',
#  'no nothing',
#  'where do you think youre going',
#  'why would i do that',
#  'just relax',
#  'i dont know what you mean',
#  'whats your point',
#  'doc',
#  'not tonight',
#  'i need your help',
#  'are you finished',
#  'susan',
#  'six',
#  'none of your business',
#  'yeah i think so',
#  'understood',
#  'im in',
#  'im glad',
#  'youre serious',
#  'are you out of your mind',
#  'alan',
#  'what do you think youre doing',
#  'come on let go',
#  'damn right',
#  'sure why not',
#  'yes my lord',
#  'possibly',
#  'keep your voice down',
#  'ill bet',
#  'johnny',
#  'what the hell is going on',
#  'you got that right',
#  'yes he is',
#  'done',
#  'what happened to your hand',
#  'steve',
#  'oh boy',
#  'mike',
#  'report',
#  'whereve you been',
#  'what do you see',
#  'no im okay',
#  'what are you gonna do',
#  'whatd you do',
#  'last night',
#  'drink',
#  'cash',
#  'see ya',
#  'whats wrong with me',
#  'how did you know that',
#  'but how',
#  'hi honey',
#  'yes mother',
#  'when wa that',
#  'you lied to me',
#  'well see about that',
#  'who am i',
#  'next week',
#  'ted',
#  'thats my girl',
#  'goodbye darling',
#  'who know',
#  'is that a fact',
#  'bill',
#  'how nice',
#  'not much',
#  'i remember',
#  'that depends',
#  'i might',
#  'hardly',
#  'i heard that',
#  'feeling better',
#  'do you like it',
#  'very nice',
#  'lovely',
#  'i thought so',
#  'mine too',
#  'twenty',
#  'i swear',
#  'good day',
#  ...]

# %%
messages = messages.drop_duplicates(subset=['msg_pre_processed'])

# %%
#example of duplcated msg
messages[messages['msg_pre_processed'] == 'did you change your hair']
# Out:
#                msg_line user_id movie_id                        msg msg_2  \
# msg_line_clean
# 49                  L49      u0       m0  Did you change your hair?   No.
#
#                        msg_pre_processed
# msg_line_clean
# 49              did you change your hair

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256901 entries, 49 to 666576
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   msg_line           256901 non-null  object
#  1   user_id            256901 non-null  object
#  2   movie_id           256901 non-null  object
#  3   msg                256901 non-null  object
#  4   msg_2              256901 non-null  object
#  5   msg_pre_processed  256901 non-null  object
# dtypes: object(6)
# memory usage: 13.7+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id                  msg   msg_2  \
# count    256901  256901   256901               256901  256901
# unique   256901    8998      617               256901  163643
# top     L171298   u3681     m289  Remember the Alamo?       -
# freq          1     440     1268                    1   70838
#
#                            msg_pre_processed
# count                                 256901
# unique                                256901
# top     a forlorn hope but there is a chance
# freq                                       1

# %% [markdown]
# ### Removing nan msg origined by '' messages

# %%
#filling the nan messages with a string- not necessary
#messages = messages.fillna('UNKNOWN')

# %% [markdown]
# ### Removing apostrophes (need for embedding)

# %%
#The quality of the model became worst
#messages['msg_pre_processed'] = [ word.replace("\'","") for word in messages['msg_pre_processed']]

# %% [markdown]
# ### Filling '-' messages with a generic one

# %%
#return generic answer
def generic_answer(txt):
  asw_list = ['talk more about it',
              'can you explain it better?',
              'I need to think more about it',
              'maybe...'
              ]
  if txt == '-':
    return random.choice(asw_list)
  return txt

# %%
#seting a generic answer to the messages without answer
messages['msg_2'] = [generic_answer(msg) for msg in messages['msg_2']]
# Out:
# <ipython-input-464-416b64f870a1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messages['msg_2'] = [generic_answer(msg) for msg in messages['msg_2']]

# %%
messages.head(30)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
# 78                  L78      u7       m0
# 87                  L87      u2       m0
# 88                  L88      u7       m0
# 89                  L89      u2       m0
# 90                  L90      u7       m0
# 91                  L91      u2       m0
# 92                  L92      u7       m0
# 103                L103      u8       m0
# 104                L104      u5       m0
# 105                L105      u8       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 89                                                    Who is she?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 91                                                       Why not?
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                  I need to think more about it
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                  I need to think more about it
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                  I need to think more about it
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                             talk more about it
# 77              Yeah but these guys have never seen a horse. T...
# 78                                     can you explain it better?
# 87                                  You burn you pine you perish?
# 88                                                    Who is she?
# 89              Bianca Stratford. Sophomore. Don't even think ...
# 90                                                       Why not?
# 91              I could start with your haircut but it doesn't...
# 92                                                       maybe...
# 103              Expressing my opinion is not a terrorist action.
# 104             Well yes compared to your other choices of exp...
# 105             I still maintain that he kicked himself in the...
#
#                                                 msg_pre_processed
# msg_line_clean
# 49                                       did you change your hair
# 50                                                             no
# 51                                 you might wanna think about it
# 59                                                   i missed you
# 60              it say here you exposed yourself to a group of...
# 61                            it wa a bratwurst i wa eating lunch
# 62                                  with the teeth of your zipper
# 63                                                you the new guy
# 64                                                so they tell me
# 65                          cmon im supposed to give you the tour
# 66                                       so which dakota you from
# 67                                        north actually howd you
# 68                        i wa kidding people actually live there
# 69               yeah a couple were outnumbered by the cow though
# 70                        how many people were in your old school
# 71                                                      thirtytwo
# 72                                                        get out
# 73                                        how many people go here
# 74                              couple thousand most of them evil
# 77                                                that im used to
# 78              yeah but these guy have never seen a horse the...
# 87                                                    that girl i
# 88                                   you burn you pine you perish
# 89                                                     who is she
# 90              bianca stratford sophomore dont even think abo...
# 91                                                        why not
# 92              i could start with your haircut but it doesnt ...
# 103             katarina stratford my my youve been terrorizin...
# 104               expressing my opinion is not a terrorist action
# 105             well yes compared to your other choice of expr...

# %% [markdown]
# ### Tagging the msg with classes

# %%
def define_target(corpus):
    
    if '?' in corpus:
        return 1
    else:
        return 0

# %%
data = messages['msg']

# %%
messages['target'] = [define_target(m) for m in data]
# Out:
# <ipython-input-468-8c498f5d1460>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messages['target'] = [define_target(m) for m in data]

# %%
messages['target'] = messages['target'].astype(int)
# Out:
# <ipython-input-469-359a35de7aa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messages['target'] = messages['target'].astype(int)

# %%
messages.head(20)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                  I need to think more about it
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                  I need to think more about it
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                  I need to think more about it
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                             talk more about it
# 77              Yeah but these guys have never seen a horse. T...
#
#                                                 msg_pre_processed  target
# msg_line_clean
# 49                                       did you change your hair       1
# 50                                                             no       0
# 51                                 you might wanna think about it       0
# 59                                                   i missed you       0
# 60              it say here you exposed yourself to a group of...       0
# 61                            it wa a bratwurst i wa eating lunch       0
# 62                                  with the teeth of your zipper       1
# 63                                                you the new guy       1
# 64                                                so they tell me       0
# 65                          cmon im supposed to give you the tour       0
# 66                                       so which dakota you from       1
# 67                                        north actually howd you       1
# 68                        i wa kidding people actually live there       1
# 69               yeah a couple were outnumbered by the cow though       0
# 70                        how many people were in your old school       1
# 71                                                      thirtytwo       0
# 72                                                        get out       0
# 73                                        how many people go here       1
# 74                              couple thousand most of them evil       0
# 77                                                that im used to       0

# %% [markdown]
# ### Save data

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 304713 entries, 49 to 666576
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   msg_line           304713 non-null  object
#  1   user_id            304713 non-null  object
#  2   movie_id           304713 non-null  object
#  3   msg                304713 non-null  object
#  4   msg_2              304713 non-null  object
#  5   msg_pre_processed  304713 non-null  object
#  6   target             304713 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 28.6+ MB

# %%
messages
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# ...                 ...     ...      ...
# 666522          L666522   u9034     m616
# 666546          L666546   u9027     m616
# 666547          L666547   u9029     m616
# 666575          L666575   u9028     m616
# 666576          L666576   u9031     m616
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# ...                                                           ...
# 666522          So far only their scouts. But we have had repo...
# 666546          Splendid site Crealock splendil I want to esta...
# 666547                                              Certainly Sin
# 666575          Choose your targets men. That's right Watch th...
# 666576          Keep steady. You're the best shots of the Twen...
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                  I need to think more about it
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# ...                                                           ...
# 666522                              I need to think more about it
# 666546                                              Certainly Sin
# 666547                                 can you explain it better?
# 666575          Keep steady. You're the best shots of the Twen...
# 666576                                                   maybe...
#
#                                                 msg_pre_processed  target
# msg_line_clean
# 49                                           you change your hair       1
# 50                                                             no       0
# 51                                       you might think about it       0
# 59                                                   i missed you       0
# 60              it say here you exposed yourself to a group of...       0
# ...                                                           ...     ...
# 666522          so far only their scout but we have had report...       0
# 666546          splendid site splendil i want to establish cam...       0
# 666547                                              certainly sin       0
# 666575          choose your target men thats right watch those...       0
# 666576          keep steady the best shot of the twentyfourth ...       0
#
# [304713 rows x 7 columns]

# %%
messages.to_csv('./chatdata/movie_lines_pre_processed.tsv', index=False, sep='\t', header=True)
