# %% [markdown]
# ## A intenção do projeto é criar um chatbot baseado em reviews de filmes para que se possa fazer perguntas e manter uma conversa livre sobre este tema
#
# - link do banco de dados https://www.kaggle.com/Cornell-University/movie-dialog-corpus?select=movie_lines.tsv
# - referências
# >- https://shanebarker.com/blog/deep-learning-chatbot/
# > -https://towardsdatascience.com/how-to-create-a-chatbot-with-python-deep-learning-in-less-than-an-hour-56a063bdfc44

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd
import re
import gensim
import numpy as np
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import load_model
from scipy.spatial import distance
import math
import random
import bz2
import itertools
import pickle
from sklearn.feature_extraction.text import CountVectorizer

# %%
#expand jupyter cells
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Opening movie reviews

# %%
messages = pd.read_csv('./chatdata/movie_lines_pre_processed.tsv', delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
messages.head()
# Out:
#   msg_line user_id movie_id  \
# 0      L49      u0       m0
# 1      L50      u3       m0
# 2      L51      u0       m0
# 3      L59      u9       m0
# 4      L60      u8       m0
#
#                                                  msg  \
# 0                          Did you change your hair?
# 1                                                No.
# 2                     You might wanna think about it
# 3                                      I missed you.
# 4  It says here you exposed yourself to a group o...
#
#                                    msg_pre_processed  \
# 0                               you change your hair
# 1                                                 no
# 2                           you might think about it
# 3                                       i missed you
# 4  it say here you exposed yourself to a group of...
#
#                                                msg_2  target
# 0                                                No.       1
# 1                           You might think about it       0
# 2                                           maybe...       0
# 3  It says here you exposed yourself to a group o...       0
# 4            It was a bratwurst. I was eating lunch.       0

# %% [markdown]
# ### Defining the list of questions and answers

# %%
questions = set(messages[messages['target'] == 1]['msg_pre_processed'])

# %%
answers = set(messages[messages['target'] == 0]['msg_pre_processed'])

# %%
len(answers)
# Out:
# 175694

# %%
len(questions)
# Out:
# 76902

# %%
lemmatizer = WordNetLemmatizer()
def pre_processing_text(corpus):
    #remove html tags
    corpus = re.sub(r'<.*?>', '', str(corpus))
    
    #remove non-alphanumeric characters
    corpus = re.sub(r'[^a-z A-Z 0-9 \s]', '', str(corpus))
    
    #remove duplicated spaces
    corpus = re.sub(r' +', ' ', str(corpus))
    
    #capitalization
    corpus = corpus.lower()
    
    #tokenization
    corpus = re.findall(r"\w+(?:'\w+)?|[^\w\s]", corpus)
    
    #lammatization
    corpus = [lemmatizer.lemmatize(c) for c in corpus]
    
    #remove punctuation
    corpus = [t for t in corpus if t not in string.punctuation]
    
    #remove stopwords
    #it makes the model worst
    #stopwords_ = stopwords.words("english")
    #corpus = [t for t in corpus if t not in stopwords_]
    
    corpus = ' '.join(corpus)

    return corpus

# %%
msg_raw = 'I heard you are a good guy. Is it right?'
#msg_raw = 'yes i heard you all right 20000000 thats quite a lot isnt it'
msg = pre_processing_text(msg_raw)
print(msg)

with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
p = tokenizer.texts_to_matrix([msg])

model = load_model('chatbot_model.h5')
res = model.predict(p)

print(res)
# Out:
# i heard you are a good guy is it right
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f61cbda6550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0.79494965]]

# %% [markdown]
# ## Returning the conversation for the message using Jaccard Similarity

# %%
def jaccard_similarity(f1, f2):    
    f1 = set(str(f1).split(' '))
    f2 = set(str(f2).split(' '))
    
    intersecao = f1.intersection(f2)
    uniao = f1.union(f2)
    
    return len(intersecao) / len(uniao)

# %%
def return_conversation_by_jaccard(msg, res, questions, answers, threshold=None):
    """
    Return a dictionary of message and similarity sorted by highter similarity
    """
    if res >= 0.5:
        msg_list = questions
        similarity = [jaccard_similarity(msg, str(m)) for m in questions]        
    else:
        similarity = [jaccard_similarity(msg, str(m)) for m in answers]
        msg_list = answers
    
    result = {} 
    for key in msg_list: 
        for value in similarity:
            result[key] = value
            similarity.remove(value) 
            break 
    
    return {k: v for k, v in sorted(result.items(), key=lambda item: item[1], reverse=True)}

# %%
# %%time
conversations = return_conversation_by_jaccard(msg, res, questions, answers)
conversations
# Out:
# CPU times: user 1.55 s, sys: 0 ns, total: 1.55 s
# Wall time: 1.56 s
# {'is it a good a i hope it is': 0.45454545454545453,
#  'you guy hear a joke i heard': 0.4166666666666667,
#  'are you sure this is a good idea': 0.38461538461538464,
#  'are you kidding because i think it good': 0.38461538461538464,
#  'is it a good morning': 0.36363636363636365,
#  'you are a therapist right': 0.36363636363636365,
#  'what is it what are you': 0.36363636363636365,
#  'are you a good lawyer': 0.36363636363636365,
#  'is it a good room': 0.36363636363636365,
#  'are you guy all right': 0.36363636363636365,
#  'you heard me is it': 0.36363636363636365,
#  'barton what time is it are you all right': 0.35714285714285715,
#  'are you surprised that i know what it is': 0.35714285714285715,
#  'i just heard you poor sausage are you all right': 0.35714285714285715,
#  'just a moment are you saying it is he': 0.35714285714285715,
#  'how is it youre good you on a list': 0.35714285714285715,
#  'is it such a chore i dont understand you': 0.35714285714285715,
#  'i heard you screaming wa it a bad one': 0.35714285714285715,
#  'yes i heard you all right 20000000 thats quite a lot isnt it': 0.35294117647058826,
#  'are you sure it all right': 0.3333333333333333,
#  'i figured it wa are you': 0.3333333333333333,
#  'precisely are you a good shot': 0.3333333333333333,
#  'are you having a good time': 0.3333333333333333,
#  'what is it are you ok': 0.3333333333333333,
#  'are you alright what is it': 0.3333333333333333,
#  'no i mean what is it for what are you selling': 0.3333333333333333,
#  'how are you is it joe': 0.3333333333333333,
#  'thats so good to hear sweetheart it really is you know i are you alone': 0.3333333333333333,
#  'is it true carter are you in hong right now': 0.3333333333333333,
#  'are you a good cop john': 0.3333333333333333,
#  'i guess have you ever made it with a guy': 0.3333333333333333,
#  'you relax i know it is a big deal day': 0.3333333333333333,
#  'i am are you a climber': 0.3333333333333333,
#  'are you sure it is dead': 0.3333333333333333,
#  'a i said then it right': 0.3333333333333333,
#  'you have a good week mama are they treating you all right': 0.3125,
#  'so i heard you had a good bunch of killer here': 0.3125,
#  'how are you you werent in class i called a soon a i heard': 0.3125,
#  'thats right thats what i said you have a good memory then what': 0.3125,
#  'i guess shes not good enough for you is that it': 0.3125,
#  'so how is it that you guy are fluent in russian': 0.3125,
#  'what is it what are you talking about': 0.3076923076923077,
#  'i just have a feeling are you': 0.3076923076923077,
#  'you guy are from the museum right': 0.3076923076923077,
#  'are you kidding i think it stealing': 0.3076923076923077,
#  'are you okay i thought i heard screaming': 0.3076923076923077,
#  'i suppose you is a doctor homer': 0.3076923076923077,
#  'you send this is it a joke': 0.3076923076923077,
#  'not having a good time are you': 0.3076923076923077,
#  'are you sure i really appreciate it': 0.3076923076923077,
#  'is it real you people are sick': 0.3076923076923077,
#  'yeah a billion right how are you': 0.3076923076923077,
#  'what is that to you a you are': 0.3076923076923077,
#  'right not a classic anecdote is it': 0.3076923076923077,
#  'what is it barton are you okay': 0.3076923076923077,
#  'this is a good level isnt it': 0.3076923076923077,
#  'what is it what are you doin here': 0.3076923076923077,
#  'i thought it wa you how are you': 0.3076923076923077,
#  'i know it late i are you there': 0.3076923076923077,
#  'are you a good witch or a bad witch': 0.3076923076923077,
#  'what is it patrick are you alright': 0.3076923076923077,
#  'andy what is it andy are you okay': 0.3076923076923077,
#  'is it good': 0.3,
#  'you heard it': 0.3,
#  'it good right': 0.3,
#  'is it you': 0.3,
#  'is a guy': 0.3,
#  'you too i justi cant get it on for good guy yknow': 0.29411764705882354,
#  'is it a gift for your wife are you getting a set together': 0.29411764705882354,
#  'you keep it nice can i ask you is thisis this a sandwich': 0.29411764705882354,
#  'who are you the good i have heard of merida thats who i hear you are': 0.29411764705882354,
#  'all you been through i ever tell you what a good friend you are': 0.29411764705882354,
#  'you want a new car you want a new house is that it the money right': 0.29411764705882354,
#  'i want to know why you see him is it a payoff': 0.29411764705882354,
#  'i see that is a body but where did you get it': 0.29411764705882354,
#  'can i give you a kiss good night': 0.2857142857142857,
#  'elizabeth is everything all right are you decent': 0.2857142857142857,
#  'i see are you a socialist mr penfield': 0.2857142857142857,
#  'i said are you deaf a well a stupid': 0.2857142857142857,
#  'might a well i suppose are you busy': 0.2857142857142857,
#  'are you gitting these if it a boy': 0.2857142857142857,
#  'you boosted a vette then where is it': 0.2857142857142857,
#  'i thought you said it wa a nightmare': 0.2857142857142857,
#  'you a scorpion thats it a scorpion i can tell': 0.2857142857142857,
#  'are you certain this is the right way': 0.2857142857142857,
#  'wood ward wood hey what do you know it is wood secretary you can never get a good one right': 0.2857142857142857,
#  'just what is it that you are saying': 0.2857142857142857,
#  'is it five year i quit right now': 0.2857142857142857,
#  'are you sure this is a real dance': 0.2857142857142857,
#  'is it all right if i get personal': 0.2857142857142857,
#  'of course it is are you doubting me': 0.2857142857142857,
#  'that is one hell of a shirt i bet you paid a pretty price for it am i right': 0.2857142857142857,
#  'were you right spock is a living machine': 0.2857142857142857,
#  'only if you are a good man a friend are you a friend': 0.2857142857142857,
#  'what kind of man are you are you a good man': 0.2857142857142857,
#  'who is he who is she who are you who am i who are you': 0.2857142857142857,
#  'what is this is this a present are you kidding': 0.2857142857142857,
#  'well and are you not a good student': 0.2857142857142857,
#  'i wa just asking are you all right': 0.2857142857142857,
#  'whats done is done i need you cool are you cool': 0.2857142857142857,
#  'okay what is it you want a ride': 0.2857142857142857,
#  'are you a psychiatrist said it take time': 0.2857142857142857,
#  'is it a problem for you to ask': 0.2857142857142857,
#  'is it all right if i stand up': 0.2857142857142857,
#  'i have eightfifteen thats not right is it': 0.2857142857142857,
#  'you suggested it dont you think it a good idea': 0.2857142857142857,
#  'that a fact now is it a good play': 0.2857142857142857,
#  'am i dreaming this are you a dream': 0.2857142857142857,
#  'are you all right marty you seem a littlenervous': 0.2857142857142857,
#  'you know it is isnt it i cant keep all of this a secret': 0.2777777777777778,
#  'i wish you a very good evening mr preysing you are staying here too mr preysing': 0.2777777777777778,
#  'i know but if it is a trap then why are we going': 0.2777777777777778,
#  'okay i give you my word is everthing gonna be okay are you all right': 0.2777777777777778,
#  'is it the shakedown hon you picked a loser i just dont have it': 0.2777777777777778,
#  'i mean realistically what are the odds that this is a terrific guy': 0.2777777777777778,
#  'i dont know give me a minute are you all right with this': 0.2777777777777778,
#  'hey cut it out that tickle im serious you guy are related right': 0.2777777777777778,
#  'is that what a good doctor would do how old are you please': 0.2777777777777778,
#  'to hey i heard you were out of it for a while too': 0.2777777777777778,
#  'are you going to him is that it to be a whore to that gutter rat': 0.2777777777777778,
#  'are you a fremen': 0.2727272727272727,
#  'are you a ray': 0.2727272727272727,
#  'is this it this is it right': 0.2727272727272727,
#  'you jump i jump right': 0.2727272727272727,
#  'is it a girl': 0.2727272727272727,
#  'is it a star': 0.2727272727272727,
#  'is it a kappa': 0.2727272727272727,
#  'are you are you all right': 0.2727272727272727,
#  'are you right now': 0.2727272727272727,
#  'is it i want it': 0.2727272727272727,
#  'are you a reporter': 0.2727272727272727,
#  'are you a lawyer': 0.2727272727272727,
#  'i what are you': 0.2727272727272727,
#  'is it a rex': 0.2727272727272727,
#  'i mean is it is it': 0.2727272727272727,
#  'are you recording it': 0.2727272727272727,
#  'are you a relative': 0.2727272727272727,
#  'are you a fruit': 0.2727272727272727,
#  'i did are you': 0.2727272727272727,
#  'are you a hairdresser': 0.2727272727272727,
#  'are you guy friend': 0.2727272727272727,
#  'are you a virgin': 0.2727272727272727,
#  'are you a warrior': 0.2727272727272727,
#  'are you a man': 0.2727272727272727,
#  'are you a physician': 0.2727272727272727,
#  'is it a what': 0.2727272727272727,
#  'is it a crime': 0.2727272727272727,
#  'who are you guy': 0.2727272727272727,
#  'are you a doctor': 0.2727272727272727,
#  'is it touching you': 0.2727272727272727,
#  'are you guy bruddas': 0.2727272727272727,
#  'are you a traveller': 0.2727272727272727,
#  'pure adrenalin right the ultimate rush other guy snort for it a vein for it all you do is jump': 0.2727272727272727,
#  'is it all right': 0.2727272727272727,
#  'you guy are new': 0.2727272727272727,
#  'are you all right': 0.2727272727272727,
#  'you are a catholic': 0.2727272727272727,
#  'are you guy hurt': 0.2727272727272727,
#  'you know it is': 0.2727272727272727,
#  'it is that you': 0.2727272727272727,
#  'is it a planet': 0.2727272727272727,
#  'are you a cop': 0.2727272727272727,
#  'are you a fag': 0.2727272727272727,
#  'are you a preacher': 0.2727272727272727,
#  'is it a poem': 0.2727272727272727,
#  'it is a deal': 0.2727272727272727,
#  'i get it this is your old plan right': 0.26666666666666666,
#  'last i heard you were offered a posi tion in the somewhere wa it': 0.2631578947368421,
#  'what is it with you why is it so important a buzz right like getting high': 0.2631578947368421,
#  'i dont need a gun is it if it isnt on you it around here someplace': 0.2631578947368421,
#  'how someone strong like you scared from a message is good news i sure': 0.2631578947368421,
#  'i think youre right is there anything i can do to make it up to you': 0.2631578947368421,
#  'are you two all right you see that they left we made it i think we made it': 0.2631578947368421,
#  'what are you talking about this is it this is the stuff right here well maybe just a pinch more sugar': 0.2608695652173913,
#  'are you a spirit too': 0.25,
#  'but you are taking it': 0.25,
#  'i dont know is it': 0.25,
#  'what are you guy doing': 0.25,
#  'you like a good saloon': 0.25,
#  'keeping a record are you': 0.25,
#  'are you a believer then': 0.25,
#  'are you all right shelly': 0.25,
#  'barton are you all right': 0.25,
#  'i take it you dont know where he is then': 0.25,
#  'i mean right isnt it': 0.25,
#  'are you a doctor too': 0.25,
#  'the question is are you': 0.25,
#  'are you crazy stop it': 0.25,
#  'i know are you adam': 0.25,
#  'stop it are you saying my husband is defrauding me': 0.25,
#  'all right what is it': 0.25,
#  'then what good are you': 0.25,
#  'jen are you all right': 0.25,
#  'are you all right barney': 0.25,
#  'bobby are you all right': 0.25,
#  'are you a deist is that it a free thinker who doe not believe in divinity': 0.25,
#  'no it is not something ive heard about you it is someth why is there something i should have heard about you': 0.25,
#  'a hospital what is it': 0.25,
#  'are you all right honey': 0.25,
#  'a good script isnt it': 0.25,
#  'you think it a conspiracy': 0.25,
#  'so are you having a good time on the island': 0.25,
#  'i have a headache you have a headache': 0.25,
#  'am i a good a they': 0.25,
#  'i think it a pig hair how much is offering': 0.25,
#  'are you wearing a uniform': 0.25,
#  'is you all good nazi': 0.25,
#  'are you a gambling man': 0.25,
#  'what are you a cop': 0.25,
#  'is she a pretty a you': 0.25,
#  'are you a service man': 0.25,
#  'are you sure it isnt time for a colorful metaphor': 0.25,
#  'surgery are you a doctor': 0.25,
#  'i have a tattoo would you like to see it': 0.25,
#  'are you awake is he awake': 0.25,
#  'is this a needlepoint club is it about you and me': 0.25,
#  'is it a charge sir': 0.25,
#  'you have a good day': 0.25,
#  'what are you talkin a': 0.25,
#  'why sure i got it do you have a match': 0.25,
#  'i told i would take a look is it that sink': 0.25,
#  'are you sure you like it': 0.25,
#  'well it quite a place your ashram is that right': 0.25,
#  'is is who i think it is': 0.25,
#  'a very good little girl what are you doing here': 0.25,
#  'you said a neighbor heard a ruckus wa it outside inside': 0.25,
#  'is she a good fuck': 0.25,
#  'are you a man who like to treat himself right': 0.25,
#  'are you all right now': 0.25,
#  'you guy are crazy you know that i mean you guy are really nut': 0.25,
#  'andy this is a nice surprise how are you hon': 0.25,
#  'yes it is a girlfriend maybe but a wife i mean': 0.25,
#  'oh oh oh oh oh oh are you all right': 0.25,
#  'i dont get it whyd you make him a pirate': 0.25,
#  'you son of a bitch you know what time it is': 0.25,
#  'all right what are you': 0.25,
#  'princess are you all right': 0.25,
#  'are you all right marty': 0.25,
#  'how is it a farce': 0.25,
#  'this is a joke right': 0.25,
#  'is it the good room': 0.25,
#  'you got a good lawyer': 0.25,
#  'a good thing i didnt have that baby isnt it': 0.25,
#  'so if i needed a doctor you could be it': 0.25,
#  'what are you a scout': 0.25,
#  'are you all right are you still you': 0.25,
#  'so i know this is a bad time but you will have a medical program right': 0.25,
#  'dollar is a lot of money are you sure you can trust me with it i mean arent you afraid i might steal it': 0.25,
#  'it didnt work out a planned are you off to': 0.25,
#  'it do you any good': 0.25,
#  'you have a good time': 0.25,
#  'are you really a virgin': 0.25,
#  'what is that a threat are you threatening me marcel': 0.25,
#  'are you all right dad': 0.25,
#  'could you handle it if it wa in a good cause': 0.25,
#  'i think you want a drink how about it judge': 0.25,
#  'is it a jamming device': 0.25,
#  'it is a favor isnt it': 0.25,
#  'well where is it i': 0.25,
#  'thats right who are you': 0.25,
#  'are you a bad boy': 0.25,
#  'i suppose i wa i poured a drink would you like it': 0.25,
#  'a bouncer are you serious': 0.25,
#  'i dont know him is he a nice guy you think hell help me out': 0.25,
#  'a are you the guy whore hiding out in the attic': 0.25,
#  'all i am to you is a sex fantasy then': 0.25,
#  'are you a writer too': 0.25,
#  'a delicious amalgamation is it': 0.25,
#  'hi sweetie were you a good girl are and katie': 0.25,
#  'what are you guy doin': 0.25,
#  'are you writing a poem': 0.25,
#  'right right you think it the wrong moment enough do you mind if i have a go': 0.25,
#  'why are you saying it': 0.25,
#  'you think i could make it to the a a manager': 0.25,
#  'ray are you are you all right': 0.25,
#  'were you a disco guy': 0.25,
#  'all right who are you': 0.25,
#  'is it all right if i go to the bathroom': 0.25,
#  'you think it that good': 0.25,
#  'i give it to you': 0.25,
#  'what is it you seek': 0.25,
#  'you think i got it': 0.25,
#  'are you a regular there': 0.25,
#  'are you carrying a surgeon': 0.25,
#  'are you feeling all right': 0.25,
#  'wow we give it a moment but this is tasty really good how about you': 0.25,
#  'you know where it is': 0.25,
#  'is it news to you': 0.25,
#  'you are a private investigator': 0.25,
#  'are you gonna do it': 0.25,
#  'a bit of a climb you guy think you can make it': 0.25,
#  'penny are you all right': 0.25,
#  'what is it you want': 0.25,
#  'is that what you heard': 0.25,
#  'so are you a cheerleader': 0.25,
#  'no it good you have a family good if it make you happy nice to have nice thing are you happy son': 0.25,
#  'what is it a surprise': 0.25,
#  'is it ok if i leave my car you think': 0.25,
#  'are you a private detective': 0.25,
#  'you look so sad is it something i have done': 0.25,
#  'is there anything i can get you water a blanket': 0.25,
#  'what is it a tranquilizer': 0.25,
#  'pendergast are you all right': 0.25,
#  'is this a good spot': 0.25,
#  'so this is it right': 0.25,
#  'no i just ran it why are you running it again': 0.25,
#  'it wont are you ready': 0.25,
#  'you guy are playing music': 0.25,
#  'hmmm i suppose this is a step above that profession ten second are you leaving': 0.25,
#  'who is it raped you': 0.25,
#  'ah good new acquisition you are a protocol droid are you not': 0.25,
#  'are you tired of it': 0.25,
#  'i heard a lot anything you want to deny mike': 0.25,
#  'are you giving a party': 0.25,
#  'are you sure it all right for to be here': 0.25,
#  'no a sample you guy ever heard of the superbill': 0.25,
#  'i got you on this flight biederman is that right': 0.25,
#  'i got a message for you the guy from aint you': 0.25,
#  'just what is it you think i can do for you': 0.25,
#  'i wanted to ask you because youre a doctor right': 0.25,
#  'i do who is it the doctor what do you them': 0.25,
#  'what are you a policeman': 0.25,
#  'is that right thats what you do for a living': 0.25,
#  'you think i know it': 0.25,
#  'are you all right dorothy': 0.25,
#  'you are saying in effect that this is a forgery': 0.25,
#  'what is it a sapphire': 0.25,
#  'is that it is this right': 0.25,
#  'i do im are you': 0.25,
#  'what is it a thing': 0.25,
#  'what is this a whorehouse or are you my wife': 0.25,
#  'is it for a child': 0.25,
#  'are you still a virgin': 0.25,
#  'i believe on your last job you executed a tax collector in is that right': 0.25,
#  'whats this a signal you come whenever i ring it': 0.25,
#  'well thats all there is to it are you alright': 0.25,
#  'you want death is it death you want': 0.25,
#  'isnt it isnt it you know i wa a professor for twenty year and a very good one': 0.25,
#  'i see that reality is a real no isnt it': 0.25,
#  'you think it a good idea taking it back to yours': 0.25,
#  'do you want a shock i think youre a great guy': 0.25,
#  'uh are you a giraffe': 0.25,
#  'what what is it a monster': 0.25,
#  'you guy are real arent you': 0.25,
#  'what is it you look like youve seen a ghost': 0.25,
#  'are you all right doctor': 0.25,
#  'how can you just take a life i mean it a life life is so precious how doe it feel': 0.25,
#  'it is you isnt it harold': 0.25,
#  'are you all right dil': 0.25,
#  'i have a better plan you want to hear it': 0.25,
#  'fighting a part of it annie you know that right': 0.25,
#  'are you a dream too': 0.25,
#  'are you sure it real': 0.25,
#  'this a good one a pro came up and asked what is this compulsion with you guy and i said well we think it important and he said if it so goddamn important who the hell are and bernstein': 0.24242424242424243,
#  'im the one who found his perforating proboscis are you wearing a gun right now ooh cool can i see it can i': 0.24,
#  'let say i do want her dead what is it you want this morning you werent a killer': 0.23809523809523808,
#  'is good so what is it maggie you here on business i saw your lamp theyre terrific': 0.23809523809523808,
#  'i know is cranking out a pretty good double sawbuck but you knew that too didnt you': 0.23809523809523808,
#  'well i think it charming rose but dont you think ah the skirt is a little tight': 0.23809523809523808,
#  'thats always a good idea would you like some money i have a great deal of it': 0.23809523809523808,
#  'you mean because it been a while since there wa a sunny day what a good detective you are': 0.23809523809523808,
#  'i dont have a minute are you saying it wa soze you told the you didnt know who it wa': 0.23809523809523808,
#  'i saw a picture of it is very clean it appeared to look very white to me you think': 0.23809523809523808,
#  'my deal is with rosanna i knew you guy were up to something are you two fucking': 0.23809523809523808,
#  'you are uso right what a nerve on that guy bring my dress to church huh': 0.23809523809523808,
#  'and now im paying for it right that what this is about i told you so': 0.23809523809523808,
#  'it out great huh i tell you those guy know what time it is im with that': 0.23809523809523808,
#  'wait im sorry right eight year is a long time can i offer you a of tea': 0.23809523809523808,
#  'i like it to be what it is sarah thats a biblical name you want to know it meaning': 0.23809523809523808,
#  'are you saying i should be frightened is this a message passed on from clergyman steenwyck': 0.23809523809523808,
#  'no you idiot i said is it a receptacle tip not is a despicable twit is it a receptacle tip get off me': 0.23809523809523808,
#  'all right then come on and let see this paragon is he a good a you say': 0.23809523809523808,
#  'i understand i saw the dress iim sorry are you all right': 0.23529411764705882,
#  'this is a joke right you just want to rattle me right': 0.23529411764705882,
#  'this is not a time for frivolity is it am i mistaken': 0.23529411764705882,
#  'thats right so if you know it why are you in trouble': 0.23529411764705882,
#  'wait a minute why is this about you now why is it always about you': 0.23529411764705882,
#  'my people are good to go you know who i mean': 0.23529411764705882,
#  'such a doll i hate money dont you it been fun': 0.23529411764705882,
#  'either you are incredibly brave or incredibly stupid which one is it': 0.23529411764705882,
#  'i suppose i can sir are you planning to take a swim': 0.23529411764705882,
#  'well thats not what i pay you for now is it': 0.23529411764705882,
#  'i dont know of a bitch who the hell are you': 0.23529411764705882,
#  'are you allowed to do it more than once a night': 0.23529411764705882,
#  'hello yes he is just a moment mr it for you': 0.23529411764705882,
#  'but you dont have any idea a to what it is': 0.23529411764705882,
#  'a lesbian are you i must inform you that i find that highly arousing': 0.23529411764705882,
#  'i told you i cant i just it doesnt feel right anymore you know': 0.23529411764705882,
#  'i wa driving by i saw all the car are you all right': 0.23529411764705882,
#  'everybodys a big shot well leo are you having a good time': 0.23529411764705882,
#  'i mean lakeview high just closed it door for good right': 0.23529411764705882,
#  'what is it i thought i told you never to call me': 0.23529411764705882,
#  'you know what this is a dinosaur egg the dinosaur are breeding': 0.23529411764705882,
#  'a beautiful child is that what you still think i am': 0.23529411764705882,
#  'is it being deliberately cruel you mean i dont think so': 0.23529411764705882,
#  'so good a to tell me with whom you think you are': 0.23529411764705882,
#  'thats what make it so good you hear what i saw today': 0.23529411764705882,
#  'you think this is a good idea we never did this before': 0.23529411764705882,
#  'you break into her apartment to deliver a gift is it': 0.23529411764705882,
#  'is that right are you going to be staying here long': 0.23529411764705882,
#  'so this other guy he a terminator too right like you': 0.23529411764705882,
#  'are you sure it them maybe i should see the body': 0.23529411764705882,
#  'see i told you it wa him your name something right': 0.23529411764705882,
#  'uhuhprobably a good idea why dont you do it this time': 0.23529411764705882,
#  'is it me or are you this nervous around all woman': 0.23529411764705882,
#  'is this really important because i dont think it a problem': 0.23529411764705882,
#  'there is a great future in plastic think about it you think about it': 0.23529411764705882,
#  'yah course i remember how are ya what time is it': 0.23529411764705882,
#  'be a good sport rose you like me dont you i like you a lot': 0.23529411764705882,
#  'this is a college im sorry i thought it wa a carnival': 0.23529411764705882,
#  'he listens to you do you think it a good idea seriously': 0.23529411764705882,
#  'you have a nice flight are they taking good care of you': 0.23529411764705882,
#  'i got a new car only it red you know died': 0.23529411764705882,
#  'ive never been a rich man i hear it nice is it nice': 0.23529411764705882,
#  'you tell it straight or i pull the trigger who are you': 0.23529411764705882,
#  'are you kidding might a well say can i date rape you': 0.23529411764705882,
#  'i like it when you say my name is that stupid': 0.23529411764705882,
#  'you know what i wished daddy i wished i could be a good girl': 0.23529411764705882,
#  'do you know what a penis is stay away from it': 0.23529411764705882,
#  'it lois this is the fourth message ive left are you': 0.23529411764705882,
#  'is everything all right is it bad for you that im here': 0.23529411764705882,
#  'are you sure it safe to let him around that guy': 0.23529411764705882,
#  'karen are you i been trying to get a hold of you': 0.23529411764705882,
#  'i know just be quick about it will you do it right': 0.23529411764705882,
#  'you look all right you want to pick it up a little': 0.23529411764705882,
#  'you heard me a gun i left mine in the car': 0.23529411764705882,
#  'i think antisemitism today is largely a phenomenon wouldnt you agree': 0.23529411764705882,
#  'yeah thats good sorry is good you know i finished that model': 0.23529411764705882,
#  'yes it did mr can i ask you a personal question': 0.23529411764705882,
#  'how about you and now you guy are a couple or something': 0.23529411764705882,
#  'i take it the odds are against and the situation is grim': 0.23529411764705882,
#  'jack thank god i cant believe it you i heard youd been': 0.23529411764705882,
#  'why are you like this because is dead it what you wanted': 0.23529411764705882,
#  'i didnt think i could sleep im surprised you could are you all right': 0.23529411764705882,
#  'is that right well good for you sull im proud of you': 0.23529411764705882,
#  'i so agree how did you acquire a taste for it': 0.23529411764705882,
#  'um kimberly this is a neighborhood you may slow it down': 0.23529411764705882,
#  'i get it you want to make me beg is that it': 0.23529411764705882,
#  'i can see that you know this is a big deal': 0.23529411764705882,
#  'are you crazy what if you miss i hate it up here': 0.23529411764705882,
#  'what is this are you holding a microphone behind my head': 0.23529411764705882,
#  'this is a new town for you do you like it here': 0.23529411764705882,
#  'charles i didnt know you were back have a good holiday': 0.23529411764705882,
#  'no he absolutely right absolutely right ryan talk must be banned canine conversation are completely discouraged it really good of you to join u can i get you a drink': 0.23333333333333334,
#  'can i give you a lift': 0.23076923076923078,
#  'are you on drug right now': 0.23076923076923078,
#  'harlem what is it a restaurant': 0.23076923076923078,
#  'do you think it a possibility': 0.23076923076923078,
#  'so is now a good time': 0.23076923076923078,
#  'of course i do are you': 0.23076923076923078,
#  'is it because shes a nun': 0.23076923076923078,
#  'no i mean are you sure': 0.23076923076923078,
#  'are you a fan of james': 0.23076923076923078,
#  'stop it what are you doing': 0.23076923076923078,
#  'you think i have a problem': 0.23076923076923078,
#  'you are a friend of his': 0.23076923076923078,
#  'good you up for a drive': 0.23076923076923078,
#  'you mean it a girl band': 0.23076923076923078,
#  'do you have a good answer': 0.23076923076923078,
#  'i give up who are you': 0.23076923076923078,
#  'why are you a sex fiend': 0.23076923076923078,
#  'have i been a good partner': 0.23076923076923078,
#  'i think you have a call': 0.23076923076923078,
#  'can i get you a drink': 0.23076923076923078,
#  'are you sure you dont need it': 0.23076923076923078,
#  'is it about a pirate daughter': 0.23076923076923078,
#  'cant i take it for you': 0.23076923076923078,
#  'i mean it not true is it': 0.23076923076923078,
#  'sure i do but the bet defense is a good offense right not going to let your opponent throw you off your game': 0.23076923076923078,
#  'a real booger you know it': 0.23076923076923078,
#  'is that a good sign doctor': 0.23076923076923078,
#  'is a genetics corporation isnt it': 0.23076923076923078,
#  'can i lend you a hand': 0.23076923076923078,
#  'do i know you who are you': 0.23076923076923078,
#  'let go over it are you': 0.23076923076923078,
#  'are you deaf a well a stupid': 0.23076923076923078,
#  'do you remember where it is': 0.23076923076923078,
#  'and what are you a cop': 0.23076923076923078,
#  'i wa what are you reading': 0.23076923076923078,
#  'this is not very good is it': 0.23076923076923078,
#  'are you wearing a coconut bra': 0.23076923076923078,
#  'can i ask you a question': 0.23076923076923078,
#  'i dont know is that right': 0.23076923076923078,
#  'could i see you a minute': 0.23076923076923078,
#  'yeah what is it about you': 0.23076923076923078,
#  'may i offer you a drink': 0.23076923076923078,
#  'are you looking for a problem': 0.23076923076923078,
#  'no no i dont are you sure': 0.23076923076923078,
#  'is anything wrong are you ill': 0.23076923076923078,
#  'this is good who did it': 0.23076923076923078,
#  'what is it you do again': 0.23076923076923078,
#  'it a pleasure how you doing': 0.23076923076923078,
#  'are you a 5 or a 6': 0.23076923076923078,
#  'well are you selfconscious about it': 0.23076923076923078,
#  'are you saying she liked it': 0.23076923076923078,
#  'i suppose you want a tip': 0.23076923076923078,
#  'you sure i just made it': 0.23076923076923078,
#  'a married man am i right': 0.23076923076923078,
#  'you heard me smith are you with me': 0.23076923076923078,
#  'are you in a bad mood': 0.23076923076923078,
#  'may i see you a minute': 0.23076923076923078,
#  'you heard what i said dil': 0.23076923076923078,
#  'are you asking me a question': 0.23076923076923078,
#  'are you going to deny it': 0.23076923076923078,
#  'what are you talking about is what': 0.23076923076923078,
#  'then you really are a gardener': 0.23076923076923078,
#  'what is it you got between you': 0.23076923076923078,
#  'julie hey you are a looker': 0.23076923076923078,
#  'are you sure it an opera': 0.23076923076923078,
#  'thats not a question is it': 0.23076923076923078,
#  'you do know where it is': 0.23076923076923078,
#  'no good this is a disaster': 0.23076923076923078,
#  'what is it you do sami': 0.23076923076923078,
#  'are you a homosexual interesting nonsequitur': 0.23076923076923078,
#  'you know what a disparity is': 0.23076923076923078,
#  'what is it what do you see': 0.23076923076923078,
#  'calm down calm down are you all right are you all right': 0.23076923076923078,
#  'all right it plank is there': 0.23076923076923078,
#  'not a film producer are you': 0.23076923076923078,
#  'you wonder why i do it': 0.23076923076923078,
#  'then why are you doing it': 0.23076923076923078,
#  'you are shes glad i called': 0.23076923076923078,
#  'i got a half a tank you': 0.23076923076923078,
#  'what is it like being you': 0.23076923076923078,
#  'are you a tranz or a rez': 0.23076923076923078,
#  'hey i got a mother you got a mother': 0.23076923076923078,
#  'you think thats a good idea': 0.23076923076923078,
#  'yeah i said is that it': 0.23076923076923078,
#  'are you offering me a bribe': 0.23076923076923078,
#  'you sure you heard what i said': 0.23076923076923078,
#  'sound good where are you now': 0.23076923076923078,
#  'what is it with this guy': 0.23076923076923078,
#  'you just hear what i just heard': 0.23076923076923078,
#  'is that how you remember it': 0.23076923076923078,
#  'are you saying this is illegal': 0.23076923076923078,
#  'are you going to keep it': 0.23076923076923078,
#  'what is it can i help': 0.23076923076923078,
#  'yes i do i love it you': 0.23076923076923078,
#  'yes i believe you are huh': 0.23076923076923078,
#  'is it worth taking a chance': 0.23076923076923078,
#  'who do you think it is': 0.23076923076923078,
#  'are you a fucking colossal idiot': 0.23076923076923078,
#  'are you sure this is cool': 0.23076923076923078,
#  'are you all right anything broken': 0.23076923076923078,
#  'i couldnt hear you how are you': 0.23076923076923078,
#  'it wa a man though right': 0.23076923076923078,
#  'what is it with you anyway': 0.23076923076923078,
#  'are you having a bad dream': 0.23076923076923078,
#  'are you a friend of mitchs': 0.23076923076923078,
#  'but it stupid right you admit it stupid': 0.23076923076923078,
#  'they guy treatin you all right': 0.23076923076923078,
#  'is it the one you wanted': 0.23076923076923078,
#  'are you considering a comeback tour': 0.23076923076923078,
#  'do you feel good about it': 0.23076923076923078,
#  'do you think it a dog': 0.23076923076923078,
#  'yeah i heard you hear jimmy': 0.23076923076923078,
#  'are you trying damn it just': 0.23076923076923078,
#  'i cant talk you into it': 0.23076923076923078,
#  'what is it you find incredible': 0.23076923076923078,
#  'are you really a bail bondsman': 0.23076923076923078,
#  'a good honest business isnt it': 0.23076923076923078,
#  'could i ask you a question': 0.23076923076923078,
#  'have i been a good wife': 0.23076923076923078,
#  'what do you figure it is': 0.23076923076923078,
#  'rational is not rational are you crazy': 0.23076923076923078,
#  'it almost lunchtime are you hungry': 0.23076923076923078,
#  'you are quite sure it secure': 0.23076923076923078,
#  'all right what is it now': 0.23076923076923078,
#  'are you waiting for a bus': 0.23076923076923078,
#  'this is be a game right': 0.23076923076923078,
#  'but you didnt see it right': 0.23076923076923078,
#  'is that what you think is that what you think i think': 0.23076923076923078,
#  'i give you a few idea': 0.23076923076923078,
#  'yes what is it you want': 0.23076923076923078,
#  'can i see you a minute': 0.23076923076923078,
#  'mr whale are you all right': 0.23076923076923078,
#  'is that why you did it': 0.23076923076923078,
#  'have you got it is it completed': 0.23076923076923078,
#  'give it back are you nut': 0.23076923076923078,
#  'i got worried are you ok': 0.23076923076923078,
#  'what is it you forget something': 0.23076923076923078,
#  'is that what you call it': 0.23076923076923078,
#  'men are you up for it': 0.23076923076923078,
#  'what are you doing you cant i': 0.23076923076923078,
#  'is it a boy or a girl': 0.23076923076923078,
#  'it mean you got a gun': 0.23076923076923078,
#  'were you mom you meet a guy': 0.23076923076923078,
#  'is it is this what you want': 0.23076923076923078,
#  'are you guy slut too huh huh': 0.23076923076923078,
#  'you know what that is right': 0.23076923076923078,
#  'is it a big party a big neighborhood party': 0.23076923076923078,
#  'are you sure you parked it there': 0.23076923076923078,
#  'not a big talker are you': 0.23076923076923078,
#  'what do you think it is': 0.23076923076923078,
#  'how bad is it for you': 0.23076923076923078,
#  'is it i dont see the': 0.23076923076923078,
#  'are you sure this is okay': 0.23076923076923078,
#  'havent you heard what i said': 0.23076923076923078,
#  'what are you gonna name it': 0.23076923076923078,
#  'i can hear you good can you hear me': 0.23076923076923078,
#  'i accept it what is suffering': 0.23076923076923078,
#  'you wha who are you is henry': 0.23076923076923078,
#  'is this who i think it is': 0.23076923076923078,
#  'i didnt see a warrant you see a warrant': 0.23076923076923078,
#  'what is that what are you doing': 0.23076923076923078,
#  'a letter may i see it': 0.23076923076923078,
#  'what are you guy gonna do': 0.23076923076923078,
#  'do you think is a fairy': 0.23076923076923078,
#  'do you think i did it': 0.23076923076923078,
#  'is he a fireman i like fireman': 0.23076923076923078,
#  'are you gonna start it up': 0.23076923076923078,
#  'you like it take a look': 0.23076923076923078,
#  'my arm is fine are you': 0.23076923076923078,
#  'do i look a funny a you do': 0.23076923076923078,
#  'i saidare you bout it bout it rowdy rowdy': 0.23076923076923078,
#  'are you calling the a murderer': 0.23076923076923078,
#  'you got it in a bar': 0.23076923076923078,
#  'is that all right with you': 0.23076923076923078,
#  'are you sure you even packed it': 0.23076923076923078,
#  'this is bryant are you alone': 0.23076923076923078,
#  'i figured you more a a socialist': 0.23076923076923078,
#  'are you watching a porno movie': 0.23076923076923078,
#  'you understand attorney right am i right': 0.23076923076923078,
#  'is that what i think it is': 0.23076923076923078,
#  'what is it a still life': 0.23076923076923078,
#  'i dont believe it do you': 0.23076923076923078,
#  'is it are the drug are they': 0.23076923076923078,
#  'i just heard who is he': 0.23076923076923078,
#  'oh i know a party right': 0.23076923076923078,
#  'i know you smoke weed right': 0.23076923076923078,
#  'what do you suppose it is': 0.23076923076923078,
#  'thank you what time is it': 0.23076923076923078,
#  'are you on a land line': 0.23076923076923078,
#  'pretty aint it you a plumber': 0.23076923076923078,
#  'see i wa right about you': 0.23076923076923078,
#  'you knew i wa seeing right': 0.23076923076923078,
#  'what if it not a guy': 0.23076923076923078,
#  'are you sure it isnt contagious': 0.23076923076923078,
#  'do you know what a is': 0.23076923076923078,
#  'you have a man near it': 0.23076923076923078,
#  'thats what i do do you do it': 0.23076923076923078,
#  'it really is you find anything': 0.23076923076923078,
#  'are you sure this is park': 0.23076923076923078,
#  'is it a king or a queen': 0.23076923076923078,
#  'christ i get in a good mood how hard is it just to decide to be in a good mood and then be in a good mood': 0.22727272727272727,
#  'i take it this is the bastard you told me about why the hell are you beating on him': 0.22727272727272727,
#  'what do i mean you think this is a toy you think it your own little goddamn coloring book': 0.22727272727272727,
#  'what is it you all of a sudden got this bug you had to go surfing this is a line right': 0.22727272727272727,
#  'but if i tell you it is a i just did were you listening to me isnt that enough': 0.22727272727272727,
#  'do you think i have not considered that i have a plan and you may rest assured that it is brilliant': 0.22727272727272727,
#  'what are you a mouse get out of the car and do it this is your chance': 0.22727272727272727,
#  'and you i take it are the who play his concerto on me the piano is princess fireandmusic': 0.22727272727272727,
#  'theresa gandhi you understand this is all a mistake im the good guy im the witness and im being punished': 0.22727272727272727,
#  'naturally you think my fiance is a bum now i guess ill have to give it back': 0.22727272727272727,
#  'so let kill the motherfucker i mean what are you guy like thats your new thing right': 0.22727272727272727,
#  'is it all right i made it out to cash you didnt tell me the name of the play': 0.22727272727272727,
#  'if you had a license i bet id have seen it by now how old are you fifteen': 0.22727272727272727,
#  'you dont know what a relief it is not to be me are you sure you want the job': 0.22727272727272727,
#  'i think thatll hold it hello shirley just helping someone tie up a present how are you': 0.22727272727272727,
#  'is paying for it and had a terrific row but insisted well can i fix you a drink': 0.22727272727272727,
#  'im lovin it you know how i know because im getting a boner my is hard no disrespect my sister': 0.22727272727272727,
#  'im sorry i am happy im very happy for you im glad you had a good time about time is he now': 0.22727272727272727,
#  'you want a toe i can get you a toe believe me there are way dude you dont know about it believe me': 0.22727272727272727,
#  'when ramesses destroyed it wa an accident you are a catastrophe why do i put up with you': 0.22727272727272727,
#  'all right truth i believe that one why is it so urgent you couldnt wait until morning': 0.22727272727272727,
#  'what are you talking about this is the new mac you a hacker': 0.2222222222222222,
#  'i dont know maybe i will say it how old are you anyway': 0.2222222222222222,
#  'i want to ask you a question do you thinktime travel is possible': 0.2222222222222222,
#  'i believe your next line is what are you trying to hide': 0.2222222222222222,
#  'i know ive seen it myself would you give that a try': 0.2222222222222222,
#  'what are you going to give me i hope i dont like it': 0.2222222222222222,
#  'can you eat it if you cant eat it i really dont care what it is': 0.2222222222222222,
#  'i wonder is it too late for to have a look around': 0.2222222222222222,
#  'i am delighted to see you both you have a good night rest': 0.2222222222222222,
#  'well i just have the baby and give it to you right': 0.2222222222222222,
#  'really nut i dont know you really thought it wa good tell me': 0.2222222222222222,
#  'hey it okay i like to pee so how are you doing': 0.2222222222222222,
#  'wait wait wait ha it occurred to you that i might bereaved a well': 0.2222222222222222,
#  'i see he made you cooperate and now are you a communist again': 0.2222222222222222,
#  'why is it every grave i open hold a new mystery inside': 0.2222222222222222,
#  'are you telling me youve never gotten it on with a girl': 0.2222222222222222,
#  'i mean what are you actually doing here what is the hidden agenda': 0.2222222222222222,
#  'i must say you look remarkably good you dont want a book then': 0.2222222222222222,
#  'you know each time i see you i hear that music what is it': 0.2222222222222222,
#  'no let the people enjoy him you see is a good godson': 0.2222222222222222,
#  'i dont get it who are you why have you been following me': 0.2222222222222222,
#  'you dont buy it okay so i still want mayfield is she': 0.2222222222222222,
#  'yeah but how come it worked i mean like what are you': 0.2222222222222222,
#  'what are you doing whats wrong i told you weve got a 430': 0.2222222222222222,
#  'baby i love you take it easy greasy how about a snort': 0.2222222222222222,
#  'i better go you sure youre all right been a pleasure sincerely': 0.2222222222222222,
#  'what doe it matter what i bel ieve what you worry about is what belief': 0.2222222222222222,
#  'nothing wrong i just want to get something straight you agree that there a good chance these two shooting are somehow related right': 0.2222222222222222,
#  'you got the gut tough guy gonna kill all is that it': 0.2222222222222222,
#  'but i dont think it what you really want to do is it': 0.2222222222222222,
#  'apparently not look it a storm here right now when are you coming back i dont know what to tell people any more': 0.2222222222222222,
#  'is it my imagination or are you just going through the motion': 0.2222222222222222,
#  'so youre a waitress right i meanfrom the uniform you were wearing': 0.2222222222222222,
#  'you vince you you are a crock a walking talking crock i mean what do you know': 0.2222222222222222,
#  'is it you if i said moose i look different fuck why shouldnt you': 0.2222222222222222,
#  'what is that a kind of chair i never heard of no ratan': 0.2222222222222222,
#  'is it i expected to go to the royal should i have a reservation': 0.2222222222222222,
#  'yeah yeah i know you told me that what else are you what are you a hypnotist': 0.2222222222222222,
#  'i dont know what it is but i wont use it is she entertaining you': 0.2222222222222222,
#  'funeral you guy really are dead what wa it like the funeral you cry': 0.2222222222222222,
#  'you get it i dont want to leave this is who i am': 0.2222222222222222,
#  'maybe it is why dont you take a little stroll and see': 0.2222222222222222,
#  'these people are paying you a lot do you think you could consider it': 0.2222222222222222,
#  'yes it is good what do you think is in these other drawer': 0.2222222222222222,
#  'first off i dont have a bos are you clear about that': 0.2222222222222222,
#  'just a guess you have it good with your wife you know sex': 0.2222222222222222,
#  'it ridiculous who am i to make a criticism to someone like you': 0.2222222222222222,
#  'that is simple isnt it i assume you can prove that if necessary': 0.2222222222222222,
#  'you are so good to me you also allow me to have a botanical garden': 0.2222222222222222,
#  'i know youre busy so ill get right to it you know her': 0.2222222222222222,
#  'the magnetometer is pegged sidescan is showing a big return but i dont see anything yet are you sure you got the depth right on this': 0.2222222222222222,
#  'and his love are like a retiarius do you know what a retiarius is': 0.2222222222222222,
#  'not a discharge edmunds you said before right so it be a message': 0.2222222222222222,
#  'return it to me indeed you may not i gave it to you a a present': 0.2222222222222222,
#  'no you guy happened you guy hear something creepy i dont think is dead': 0.2222222222222222,
#  'is there any possibility that it a hoax could you be mistaken': 0.2222222222222222,
#  'telling me off is it going a well a you hoped mr taylor': 0.2222222222222222,
#  'the war what are you crazy there are thing i miss about it': 0.2222222222222222,
#  'you heard of a hacker called acid burn you know who he is': 0.2222222222222222,
#  'no i wa just curious if what i heard about you is true': 0.2222222222222222,
#  'really you small town guy are good and have you located sidney father': 0.2222222222222222,
#  'lasso the stork you mean you what is it a boy or a girl': 0.2222222222222222,
#  'i used to do it when you were gone remember i used to do it a lot': 0.2222222222222222,
#  'good of course are you kidding ill tell you what buy me lunch my friend and ill tell you the best story you ever heard hows that and i guarantee every word of it is true': 0.21875,
#  'wait you two and i have a surprise for you that will settle this can you guess what it is': 0.21739130434782608,
#  'is the catholic who are you mister i ask because he doesnt see a whole lot of people': 0.21739130434782608,
#  'not resting well are you i know it that music you need your sleep is there anything else you want': 0.21739130434782608,
#  'is this deja vu or ha it really been a year not hitting me up for are you': 0.21739130434782608,
#  'fare war are murdering u had to lay off five guy i could do what is it money': 0.21739130434782608,
#  'been destroyed the threat is over are you all right the enterprise disappeared from our sensor for a moment': 0.21739130434782608,
#  'not like him is it to do a thing like that without telling you not losing your hold on him are you': 0.21739130434782608,
#  'no you shouldnt have stopped but you got away with it important thing is are you sure youre all right': 0.21739130434782608,
#  'is that why you drive this car i take it that you see kennedy assassination a a special kind of carcrash': 0.21739130434782608,
#  'is this a coup are you trying to tell me that i might be assassinated if i dont agree': 0.21739130434782608,
#  'who am i who are you you schmuck you cant even make a decent swastika give me the paint give it to me': 0.21739130434782608,
#  'is the war worth it is it worth a oneterm presidency because i think right now thats what were looking at': 0.21739130434782608,
#  'maybe i am a little ive got to leave for the office are you going to be all right': 0.21739130434782608,
#  'damn right it not like that because i wont let it be like that you want your slut the slut is yours': 0.21739130434782608,
#  'i think is a breakthrough denies he know or oswald is that right it prof he a liar keep on it bill': 0.21739130434782608,
#  'right i have you think i like living on fucking yucca we do a good job on this were in': 0.21739130434782608,
#  'i dont get it you get a scholarship to you get 35000 the first year and 50 last year where the hell is it': 0.21739130434782608,
#  'you assumed a brother coming in here can only afford fivehundred dollar a roll is that right are you a racist': 0.21739130434782608,
#  'you think it a little too bright': 0.21428571428571427,
#  'this is ray whats up are you': 0.21428571428571427,
#  'you doing a story on this guy': 0.21428571428571427,
#  'right friday night is night wherere you from': 0.21428571428571427,
#  'fell hey you fell is he all right': 0.21428571428571427,
#  'thats all right what are you drinking': 0.21428571428571427,
#  'is there a gun pointing at you': 0.21428571428571427,
#  'who are you what is your name': 0.21428571428571427,
#  'i know but youre broke are you': 0.21428571428571427,
#  'are you by nature a sadistic person': 0.21428571428571427,
#  'can i ask you a personal question': 0.21428571428571427,
#  'sound like a word what is it': 0.21428571428571427,
#  'you dont like this i take it': 0.21428571428571427,
#  'this is all a mistake you understand': 0.21428571428571427,
#  'are you sure youre totally into guy': 0.21428571428571427,
#  'would it stop you if i did': 0.21428571428571427,
#  'if it you what are you doing here': 0.21428571428571427,
#  'are you sure you wont have a drink': 0.21428571428571427,
#  'are you working on a new book': 0.21428571428571427,
#  'thats it thats all you give a about': 0.21428571428571427,
#  'are you crazy that cost a fortune': 0.21428571428571427,
#  'is that what you are angry about': 0.21428571428571427,
#  'why it is a wrestling match or': 0.21428571428571427,
#  'can you get it a little closer': 0.21428571428571427,
#  'i dont suppose it an airline is it': 0.21428571428571427,
#  'i said are you sure you seem unsure': 0.21428571428571427,
#  'i tell you i have a new girlfriend': 0.21428571428571427,
#  'you send them is that it max': 0.21428571428571427,
#  'what are you a klansman or something': 0.21428571428571427,
#  'are you suggesting i call him master': 0.21428571428571427,
#  'who the fuck is it to you': 0.21428571428571427,
#  'is that why you say it horrible': 0.21428571428571427,
#  'are you kidding i didnt do anything': 0.21428571428571427,
#  'which one are you and which one am i': 0.21428571428571427,
#  'please check is it full please could you check': 0.21428571428571427,
#  'hey brad are you still a virgin': 0.21428571428571427,
#  'can i see you for a second': 0.21428571428571427,
#  'do you think you are a real master': 0.21428571428571427,
#  'van orton what are you a czar': 0.21428571428571427,
#  'may i see you for a minute': 0.21428571428571427,
#  'can i tell you a story rick': 0.21428571428571427,
#  'my god you mean it wa good': 0.21428571428571427,
#  'can i have a word with you': 0.21428571428571427,
#  'i think i came didnt you feel it': 0.21428571428571427,
#  'any clue a to what it is': 0.21428571428571427,
#  'can i talk to you a second': 0.21428571428571427,
#  'are you the connection sound very good': 0.21428571428571427,
#  'are you sure about me i mean': 0.21428571428571427,
#  'you want a queen one right here': 0.21428571428571427,
#  'what is it a tribe an island': 0.21428571428571427,
#  'may i walk with you a way': 0.21428571428571427,
#  'what do you think is it me': 0.21428571428571427,
#  'this gorilla watching you is that right': 0.21428571428571427,
#  'would you like a drink right beside you': 0.21428571428571427,
#  'are you seeing anyone i mean seriously': 0.21428571428571427,
#  'how will i get it to you': 0.21428571428571427,
#  'is it a nice warm room sir': 0.21428571428571427,
#  'you asshole what are you mary is that you': 0.21428571428571427,
#  'they are or they arent which is it': 0.21428571428571427,
#  'ohh right would you like a soda': 0.21428571428571427,
#  'i wonder where is you dont suppose': 0.21428571428571427,
#  'you think this is all a joke': 0.21428571428571427,
#  'oh so you are a new man': 0.21428571428571427,
#  'is he here are you with dickie': 0.21428571428571427,
#  'data are you sure youre all right': 0.21428571428571427,
#  'i know light a match will you': 0.21428571428571427,
#  'you guy going to a costume party': 0.21428571428571427,
#  'do i what are you talking about': 0.21428571428571427,
#  'now if im the of and all these sand nigger are armed to the gill and you know it just a matter of time right am i right': 0.21428571428571427,
#  'barbaras a perfectly good name isnt it': 0.21428571428571427,
#  'look you dont know good all right': 0.21428571428571427,
#  'you think this is a fucking joke': 0.21428571428571427,
#  'is a dead man do you object': 0.21428571428571427,
#  'you got a machine on it yet': 0.21428571428571427,
#  'are you with her is she there': 0.21428571428571427,
#  'you mean did i want a date': 0.21428571428571427,
#  'i dont know are you in anthony': 0.21428571428571427,
#  'are you sure youll be all right': 0.21428571428571427,
#  'may i ask where are you bound': 0.21428571428571427,
#  'you get a chance to use it': 0.21428571428571427,
#  'can i tell you something can i tell you a secret': 0.21428571428571427,
#  'how do i know you are cop': 0.21428571428571427,
#  'hey can i buy you a beer': 0.21428571428571427,
#  'if it isnt a baby what is it': 0.21428571428571427,
#  'just a feeling you sense it too': 0.21428571428571427,
#  'what are you a fry or something': 0.21428571428571427,
#  'you call it a night after here': 0.21428571428571427,
#  'who do you think is behind it': 0.21428571428571427,
#  'can i ask you a favour major': 0.21428571428571427,
#  'what do you mean it a minimart': 0.21428571428571427,
#  'can i give you a hand beautiful': 0.21428571428571427,
#  'what are you talking about what is this': 0.21428571428571427,
#  'are you going in such a hurry': 0.21428571428571427,
#  'thats what i asked you aint it': 0.21428571428571427,
#  'is it okay if i drink this': 0.21428571428571427,
#  'can i talk to you a minute': 0.21428571428571427,
#  'here you are baron a drink a flip': 0.21428571428571427,
#  'who are you calling a pig rummy': 0.21428571428571427,
#  'could you tell a little about it': 0.21428571428571427,
#  'not too far are you a birdwatcher too': 0.21428571428571427,
#  'lombard this is not a name is it': 0.21428571428571427,
#  'you get it did i say that': 0.21428571428571427,
#  'not a private detective either are you': 0.21428571428571427,
#  'can you walk not broken is it': 0.21428571428571427,
#  'this is shermin are you mr haydn': 0.21428571428571427,
#  'i have to qualify is that it': 0.21428571428571427,
#  'thats it thats all i get a glare': 0.21428571428571427,
#  'there you are tedbaby everything all right': 0.21428571428571427,
#  'is it a slam dunk no but': 0.21428571428571427,
#  'a vague similarity it the same guy': 0.21428571428571427,
#  'it mean who side are you on': 0.21428571428571427,
#  'what kind of a car is it': 0.21428571428571427,
#  'well what do you think it is': 0.21428571428571427,
#  'what is it if it aint a curse': 0.21428571428571427,
#  'i know but ihow much is it': 0.21428571428571427,
#  'i dont know paper is it paper i dont remember': 0.21428571428571427,
#  'i said thisdo you want a drink': 0.21428571428571427,
#  'are you disappointed that i wont answer you': 0.21428571428571427,
#  'cant see a thing are you sure': 0.21428571428571427,
#  'cmere you got some good blow right': 0.21428571428571427,
#  'are we this is a weird neighborhood': 0.21428571428571427,
#  'do you know what year it is': 0.21428571428571427,
#  'and what are you like a wino': 0.21428571428571427,
#  'are you i been trying to reach you': 0.21428571428571427,
#  'hey are you okay you need a hand': 0.21428571428571427,
#  'you sold it i thought they stole it': 0.21428571428571427,
#  'i cant say i do what is it': 0.21428571428571427,
#  'i think ive found are you on': 0.21428571428571427,
#  'is it something youve heard about me': 0.21428571428571427,
#  'this is strange do you feel it': 0.21428571428571427,
#  'cant i just maim it a little': 0.21428571428571427,
#  'is she running a temperature what is it': 0.21428571428571427,
#  'charlie i said what time is it': 0.21428571428571427,
#  'not a dumb fuck are you del': 0.21428571428571427,
#  'is it a physical thing or a mental thing': 0.21428571428571427,
#  'may i ask you a personal question': 0.21428571428571427,
#  'is it like eichmann are we goofing': 0.21428571428571427,
#  'are you staying with a friend sir': 0.21428571428571427,
#  'pretty good cigar whered you get it': 0.21428571428571427,
#  'what do you see i see a butterfly': 0.21428571428571427,
#  'worry youve got it are you crazy': 0.21428571428571427,
#  'really i thought it wa pretty good': 0.21428571428571427,
#  'are you a joker huh tellin joke': 0.21428571428571427,
#  'you have a good time last night': 0.21428571428571427,
#  'oona do you suppose it a faerie': 0.21428571428571427,
#  'well then you didnt see it right': 0.21428571428571427,
#  'thats what you think is it jim': 0.21428571428571427,
#  'i didnt know you had a sister': 0.21428571428571427,
#  'thats a wig you wear isnt it': 0.21428571428571427,
#  'is there a song you dont know': 0.21428571428571427,
#  'wait a second what time is it': 0.21428571428571427,
#  'are you sure it cant hurt u': 0.21428571428571427,
#  'i have no idea are you ready': 0.21428571428571427,
#  'i say freddie what are you about': 0.21428571428571427,
#  'yeah i know this is it isnt it': 0.21428571428571427,
#  'can i ask how old you are': 0.21428571428571427,
#  'so what is it you do mister': 0.21428571428571427,
#  'i thought it wa that you spoke': 0.21428571428571427,
#  'i would mr doyle are you game': 0.21428571428571427,
#  'how did it go with you guy': 0.21428571428571427,
#  'i guess are you always so angry': 0.21428571428571427,
#  'when i die is it gonna hurt': 0.21428571428571427,
#  'what are you gonna do about it': 0.21428571428571427,
#  'i say will you have a cigarette': 0.21428571428571427,
#  'all you want is a phone number': 0.21428571428571427,
#  'are you and mom getting a divorce': 0.21428571428571427,
#  'is that what you call it real': 0.21428571428571427,
#  'are you sure is not all there': 0.21428571428571427,
#  'are you a close friend of haven': 0.21428571428571427,
#  'only if you were in it are you': 0.21428571428571427,
#  'a headline not a newspaper man are you': 0.21428571428571427,
#  'are you nut walking into a gun': 0.21428571428571427,
#  'wait a minute what are you saying': 0.21428571428571427,
#  'yeah i guess this is it huh': 0.21428571428571427,
#  'i know i suppose you heard about mr': 0.21428571428571427,
#  'you got a round figure on it': 0.21428571428571427,
#  'are you sure thats what i thought': 0.21428571428571427,
#  'i thought you might want a drink': 0.21428571428571427,
#  'what do you think i planned it': 0.21428571428571427,
#  'are you asking me on a date': 0.21428571428571427,
#  'are you telling me im a nonsmoker': 0.21428571428571427,
#  'are you cold would you like a blanket': 0.21428571428571427,
#  'i know what this is you in': 0.21428571428571427,
#  'you sure this is where it wa': 0.21428571428571427,
#  'is it okay if i record this': 0.21428571428571427,
#  'cant i just go with you guy': 0.21428571428571427,
#  'who is it he reminds you of': 0.21428571428571427,
#  'are you playing a trick on me': 0.21428571428571427,
#  'my it really you harrys friend right': 0.21428571428571427,
#  'it is happy birthday you get anything': 0.21428571428571427,
#  'do what show you a good time': 0.21428571428571427,
#  'are you going to be all right': 0.21428571428571427,
#  'are you so certain you are away from it': 0.21428571428571427,
#  'not going out right away are you': 0.21428571428571427,
#  'you want the tape there it is': 0.21428571428571427,
#  'you feel that is a simplistic retort': 0.21428571428571427,
#  'what is it that i cant figure': 0.21428571428571427,
#  'when when are you going to do it': 0.21428571428571427,
#  'give a good report and i walk': 0.21428571428571427,
#  'they have a right to know is a thief steal the truth i cant remember my baby i cant remember my baby it existed and i cant even remember do you understand that': 0.21428571428571427,
#  ...}

# %%
#get the first item in the dict
def get_the_next_conversation(conversations):
    keys_view = conversations.keys()
    keys_iterator = iter(keys_view)
    conversation = next(keys_iterator)
    return conversation

# %%
conversation = get_the_next_conversation(conversations)
conversation
# Out:
# 'is it a good a i hope it is'

# %% [markdown]
# ### The returned message

# %%
print('>>> '+msg_raw)
msg2 = list(messages[messages['msg_pre_processed'] == conversation]['msg_2'])[0]
print('<<< '+msg2)
# Out:
# >>> I heard you are a good guy. Is it right?
# <<< Better sir.

# %% [markdown]
# ## Calculate PageRank
# - create a bi-directional graph of messages using similarity bigger then a threshould

# %%
"""
Classe para criação de um nó (página) do grafo.
O cosntrutuor recebe recebe o nome do nó, a lista de nós de entrada e saída.
"""
class Node(object):
    def __init__(self, node_name: str, inlinks: list, outlinks: list):
        self.node_name = node_name
        self.inlinks = inlinks
        self.outlinks = outlinks

"""
Classe para criação do grafo de páginas.
O construtor inicializa um dicionário vazio de lista de adjacência. 
"""
class Graph(object):
    def __init__(self):
        self.adj_list = dict()

    #Adiciona um nó ao grafo com seus nós de entrada e sapida
    def add_node(self, node_name: str, inlinks: list, outlinks: list):
        node = Node(node_name = node_name, inlinks=inlinks, outlinks=outlinks)
        self.adj_list[node_name] = node

    #Imprime os dados do grafo criado
    def print_graph(self):
        for key in self.adj_list:
            print(f"{key}:")
            print(f"\tEntrada: {self.adj_list[key].inlinks}")
            print(f"\tSaída: {self.adj_list[key].outlinks}")

# %%
import numpy as np

"""
A classe PageRank possui métodos para computar o Page Rank de cada página dado um número de iterações.
"""
class PageRank(object):
    #Construtor da classe que recebe um objeto Graph, inicializa um dicionário vazio de scores
    def __init__(self, graph: Graph):
        self.graph = graph
        self.scores = dict()
        self.__initialize_scores()

    #Inicializa os scores do Page Rank com o valor inicial 1/n, onde n é o número de nós (páginas) do grafo
    def __initialize_scores(self):
        n = len(self.graph.adj_list)
        for key in self.graph.adj_list:
            self.scores[key] = 1/n

    #Calcula o Page Rank para cada página dado o número de iterações. Ainda não utiliza a convergence_rate no cálculos
    def compute(self, iterations: int = 10, convergence_rate: float = 0.01):
        new_scores = dict()
        for i in range(iterations):
            for  node in self.graph.adj_list:
                in_to_node = np.asarray([
                    self.scores[x] for x in self.graph.adj_list[node].inlinks
                ])
                out_to_node = self.graph.adj_list[node].inlinks
                amount_out_to_node = np.asarray([
                    len(self.graph.adj_list[x].outlinks) for x in out_to_node
                ])
                score = np.sum(in_to_node / amount_out_to_node)
                new_scores[node] = score
            #print(self.scores)
            self.scores = new_scores.copy()
        return self.scores

    def power_method(self, iterations: int = 10):
        #Gera a matrix de probabilidades de navegação a cada nó
        lenght = len(self.graph.adj_list)
        matrix = np.zeros((lenght, lenght))
        i = j = 0
        for node in self.graph.adj_list:
            for link in self.graph.adj_list[node].outlinks:
                for row in self.graph.adj_list:
                    if link == row:
                        matrix[i][j] = 1/len(self.graph.adj_list[node].outlinks)
                    i = i + 1
                i = 0
            j = j + 1
        print("Matriz de probabilidades ")
        print(matrix)
        #muliplica a matrix pelo score inicial
        print("Page Rank das iterações")
        scores_arr = np.asarray([
                    self.scores[key] for key in self.graph.adj_list
                ])
        itn = np.dot(matrix, scores_arr)
        print(itn)
        for i in range(iterations - 1):
            itn = np.dot(matrix, itn)
            print(itn)

# %%
def make_in_links(conversations, threshold=None):
    li = list()
    if threshold is None:
        for c in conversations.keys():
            li.append(c)
    else:
        for c in conversations.keys():
            if conversations[c] >= threshold:
                li.append(c)
    return li

# %%
def get_conversations(msg, res):
    return return_conversation_by_jaccard(msg, res, questions, answers)

# %%
def make_graph(qea, res, threshold=None):
    g = Graph()
    lenght = len(qea)
    i = 1
    
    for k in qea:
        conversations = get_conversations(k, res)
        if conversations is not None:        
            #in_links = {k: v for k, v in conversations.items() if v >= threshold and v != 1}
            in_links = make_in_links(conversations, threshold=threshold)
            in_links.remove(k)
            #if in_links:
            g.add_node(k, in_links, in_links)
                #print(g.print_graph())
        if (i % 100) == 0:
            print('Processed '+ str(i) +' of '+ str(lenght))    
        i += 1
    return g

# %%
def save_page_compute(qea, res, file_name, threshold=None, iterations=3):

    g = make_graph(qea=qea, res=res, threshold=threshold)

    p = PageRank(graph=g)
    pc = p.compute(iterations=iterations)
    pc = {k: v for k, v in sorted(pc.items(), key=lambda item: item[1], reverse=True)}

    f = open( file_name + '.txt', 'w' )
    f.write( repr(pc) )
    f.close()
    return pc

# %%
pc_q = save_page_compute(qea=questions, res=1, threshold=0.5, file_name='page_rank_questions')
# Out:
# Processed 100 of 76902
# Processed 200 of 76902
# Processed 300 of 76902
# Processed 400 of 76902
# Processed 500 of 76902
# Processed 600 of 76902
# Processed 700 of 76902
# Processed 800 of 76902
# Processed 70800 of 76902
# Processed 70900 of 76902
# Processed 71000 of 76902
# Processed 71100 of 76902
# Processed 71200 of 76902
# Processed 71300 of 76902
# Processed 71400 of 76902
# Processed 71500 of 76902
# Processed 71600 of 76902
# Processed 71700 of 76902
# Processed 71800 of 76902
# Processed 71900 of 76902
# Processed 72000 of 76902
# Processed 72100 of 76902
# Processed 72200 of 76902
# Processed 72300 of 76902
# Processed 72400 of 76902
# Processed 72500 of 76902
# Processed 72600 of 76902
# Processed 72700 of 76902
# Processed 72800 of 76902
# Processed 72900 of 76902
# Processed 73000 of 76902
# Processed 73100 of 76902
# Processed 73200 of 76902
# Processed 73300 of 76902
# Processed 73400 of 76902
# Processed 73500 of 76902
# Processed 73600 of 76902
# Processed 73700 of 76902
# Processed 73800 of 76902
# Processed 73900 of 76902
# Processed 74000 of 76902
# Processed 74100 of 76902
# Processed 74200 of 76902
# Processed 74300 of 76902
# Processed 74400 of 76902
# Processed 74500 of 76902
# Processed 74600 of 76902
# Processed 74700 of 76902
# Processed 74800 of 76902
# Processed 74900 of 76902
# Processed 75000 of 76902
# Processed 75100 of 76902
# Processed 75200 of 76902
# Processed 75300 of 76902
# Processed 75400 of 76902
# Processed 75500 of 76902
# Processed 75600 of 76902
# Processed 75700 of 76902
# Processed 75800 of 76902
# Processed 75900 of 76902
# Processed 76000 of 76902
# Processed 76100 of 76902
# Processed 76200 of 76902
# Processed 76300 of 76902
# Processed 76400 of 76902
# Processed 76500 of 76902
# Processed 76600 of 76902
# Processed 76700 of 76902
# Processed 76800 of 76902
# Processed 76900 of 76902

# %%
pc_a = save_page_compute(qea=answers, res=0, threshold=0.5, file_name='page_rank_answers')
# Out:
# Processed 100 of 175694
# Processed 200 of 175694
# Processed 300 of 175694
# Processed 400 of 175694
# Processed 500 of 175694
# Processed 600 of 175694
# Processed 700 of 175694
# Processed 800 of 175694
# Processed 900 of 175694
# Processed 1000 of 175694

# %% [raw]
# #checking page rank tends to 1
# s = 0
# for p in pc_a:
#     s += pc[p]
#
# s

# %% [markdown]
# ## Similary of Jaccard based on Page Rank

# %%
def return_conversation_by_jaccard_page_rank(msg, conversations, page_compute):
    """
    Return a dictionary of message and similarity sorted by highter similarity
    """
    #similarity = [jaccard_similarity(msg, str(m)) for m in questions]   
    similarity = {k: jaccard_similarity(msg, str(k)) for k, v in conversations.items()}
    
    result = dict()
    for k, v in similarity.items():        
        result[k] = page_compute[k] * v
    
    result = {k: v for k, v in sorted(result.items(), key=lambda item: item[1], reverse=True)}
    return next(iter(result))

# %%
conversation = return_conversation_by_jaccard_page_rank(msg, conversations, page_compute=pc_q)
conversation

# %%
print('Conversation: '+ conversation)
print('Page compute: '+ str(pc[conversation]))
print('Similarity: '+ str(conversations[conversation]))

# %%
print('Original: '+ msg)
print('Most similar: '+conversation)

print('>>> '+msg_raw)
msg2 = list(messages[messages['msg_pre_processed'] == conversation]['msg_2'])[0]
print('<<< '+msg2)

# %% [markdown]
# ## Return the result using the Cossine Similarity

# %%
bow = CountVectorizer()

# %%
def return_conversation_by_cossine(msg, res, questions, answers, bow):
    """
    Return a dictionary of message and similarity sorted by highter similarity
    """
    if res >= 0.5:
        msg_list = questions    
    else:
        msg_list = answers
       
    similarity = []
    for m in msg_list:
        new_msg_list = [msg, m]
        vector_bow = bow.fit_transform(new_msg_list)
        msg_bow = vector_bow.todense()[0]
        m_bow   = vector_bow.todense()[1]
        similarity.append(distance.cosine(msg_bow, m_bow))
    
    result = {} 
    for key in msg_list: 
        for value in similarity: 
            result[key] = value
            similarity.remove(value) 
            break 
    
    return {k: v for k, v in sorted(result.items(), key=lambda item: item[1], reverse=False)}

# %%
conversations = return_conversation_by_cossine(msg, res, questions, answers, bow)
conversations

# %%
conversation = get_the_next_conversation(conversations)
conversation

# %% [markdown]
# ### Return result

# %%
print('>>> '+msg_raw)
msg2 = list(messages[messages['msg_pre_processed'] == conversation]['msg_2'])[0]
print('<<< '+msg2)

# %% [markdown]
# ## Get result using Cossine Similarity with Embedding

# %%
def download_embedding(get_it):
    if get_it:
        # !gdown https://drive.google.com/uc?id=1zI8pGfbUHuU_0wY_FV4tD6w6ZCUJTQbh
    print('Download finished')

# %%
#The embedding is already downloaded
#Change to True to download
download_embedding(False)

# %%
# %%time
#get the embedding
newfilepath = "embedding_wiki_100d_pt.txt"
filepath = "ptwiki_20180420_100d.txt.bz2"
with open(newfilepath, 'wb') as new_file, bz2.BZ2File(filepath, 'rb') as file:
    for data in iter(lambda : file.read(100 * 1024), b''):
        new_file.write(data)

# %%
# %%time
word_vectors = gensim.models.KeyedVectors.load_word2vec_format(filepath, binary=False)

# %%
word_vectors

# %%
def calculate_embedding(phrase):
    """
    Return the mean of embeddings of a phrase
    """
    
    arr = np.array([word_vectors[word] for word in phrase if word in word_vectors.vocab])
    
    sum = np.zeros(len(arr[0]))
    for a in arr:
        sum = sum + a
        
    arr_mean = sum / len(arr) 
    
    return arr_mean

# %%
def return_conversation_by_cossine_embedding(msg, res, questions, answers, word_vectors):
    """
    Return a dictionary of message and similarity sorted by highter similarity
    """
    if res >= 0.5:
        msg_list = questions    
    else:
        msg_list = answers       
    
    msg = msg.split(' ')
    
    similarity = []
    for m in msg_list:        
        m = m.split(' ')
        
        try:
            msg_vector_embedding = calculate_embedding(msg)
            m_vector_embedding   = calculate_embedding(m)
        
            similarity.append(distance.cosine(msg_vector_embedding, m_vector_embedding))
        except:
            print("An exception occurred")
            print('> '+ ' '.join(m))
    
    result = {} 
    for key in msg_list: 
        for value in similarity: 
            result[key] = value
            similarity.remove(value) 
            break 
    
    return {k: v for k, v in sorted(result.items(), key=lambda item: item[1], reverse=False)}

# %%
# %%time
conversations = return_conversation_by_cossine_embedding(msg, res, questions, answers, word_vectors)
conversations

# %%
conversation = get_the_next_conversation(conversations)
conversation

# %% [markdown]
# ### Return result

# %%
print('>>> '+msg_raw)
msg2 = list(messages[messages['msg_pre_processed'] == conversation]['msg_2'])[0]
print('<<< '+msg2)
