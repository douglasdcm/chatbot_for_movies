# %% [markdown]
# ## A intenção do projeto é criar um chatbot baseado em reviews de filmes para que se possa fazer perguntas e manter uma conversa livre sobre este tema
#
# - link do banco de dados https://www.kaggle.com/Cornell-University/movie-dialog-corpus?select=movie_lines.tsv
# - referências
# >- https://shanebarker.com/blog/deep-learning-chatbot/
# > -https://towardsdatascience.com/how-to-create-a-chatbot-with-python-deep-learning-in-less-than-an-hour-56a063bdfc44

# %%
import string
import nltk
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import pandas as pd
import re
import numpy as np
import math
import random
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package wordnet to /home/douglas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Opening movie reviews

# %%
messages = pd.read_csv('./chatdata/movie_lines_normalized.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
messages.columns = ['msg_line', 'user_id', 'movie_id', 'msg']

# %%
messages.head(10)
# Out:
#   msg_line user_id movie_id                                                msg
# 0    L1045      u0       m0                                       They do not!
# 1    L1044      u2       m0                                        They do to!
# 2     L985      u0       m0                                         I hope so.
# 3     L984      u2       m0                                          She okay?
# 4     L925      u0       m0                                          Let's go.
# 5     L924      u2       m0                                                Wow
# 6     L872      u0       m0     Okay -- you're gonna need to learn how to lie.
# 7     L871      u2       m0                                                 No
# 8     L870      u0       m0  """I'm kidding. You know how sometimes you jus...
# 9     L869      u0       m0                   Like my fear of wearing pastels?

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304713 entries, 0 to 304712
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   msg_line  304713 non-null  object
#  1   user_id   304713 non-null  object
#  2   movie_id  304713 non-null  object
#  3   msg       304713 non-null  object
# dtypes: object(4)
# memory usage: 9.3+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id     msg
# count    304713  304713   304713  304713
# unique   304713    9035      659  265277
# top     L316222   u4525     m289   What?
# freq          1     537     1530    1679

# %% [markdown]
# ### Cleaning the msg_line of the conversations

# %%
#remove charactes
def remove_char(txt):
    return re.sub('[^0-9]','', txt)

# %%
#leaving just the number of the index, so L872 changes to 872
messages['msg_line_clean'] = [remove_char(msg) for msg in messages['msg_line']]

# %%
#change the column type to number
messages['msg_line_clean'] = pd.to_numeric(messages['msg_line_clean'])

# %%
messages = messages.sort_values(by=['msg_line_clean'])

# %%
#set the column as the index
messages = messages.set_index('msg_line_clean')

# %%
messages.head(10)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
#
#                                                               msg
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.

# %% [markdown]
# ### Removing entities

# %%
entities = pd.read_csv('./chatdata/entity_list.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
entities.columns = ['ent', 'type']

# %%
entities.head()
# Out:
#                        ent    type
# 0                    Kinda     ORG
# 1  The Dallas Times Herald     ORG
# 2             Queen Louisa  PERSON
# 3                      A.M     GPE
# 4               Cousin Hop  PERSON

# %%
entities['ent_len'] = [len(e) for e in entities['ent']]

# %%
s = entities['ent_len'].sort_values(ascending=False).index

# %%
entities = entities.reindex(s)

# %%
entities = entities.reset_index(drop=True)

# %%
entities.head()
# Out:
#                                                  ent         type  ent_len
# 0  """How can the Bolshevik cause gain respect am...  WORK_OF_ART      237
# 1  """The Premier wishes to inform the Government...  WORK_OF_ART      192
# 2  """ Come Tuesday twelve a.m. bingo these like-...  WORK_OF_ART      182
# 3  """The suggestion of the President regarding t...  WORK_OF_ART      155
# 4  """The Management of Boyd's takes pleasure in ...  WORK_OF_ART      146

# %%
data = messages['msg']

# %%
ent_list =  ['PERSON', 'ORG', 'NORP', 'FAC', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW', 'LANGUAGE']
#ent_list =  ['LANGUAGE']

ent = list()
for i in range(len(entities.index)):
    if entities['type'][i] in ent_list:
        ent.append(entities['ent'][i])

# %%
ent = list(set(ent))
print(len(ent))
print(ent)
# Out:
# 28514
# ['Oriental', 'Pavilion', 'The Fifth Element', 'The E-Ringers', 'Buzzy', 'Elton John', 'the L.A. Basin', 'Geiger', 'Hey Sid', 'Hopper Avenue Fair Lawn', 'Colombia', 'Colonists', 'Birthday Party', 'Henry Clerval', 'Japs', 'metropolis', 'Elizabeth Sherman', 'Motocross', 'Crazy Charlie', 'The Gaming Commission', 'Ready Uncle Lex', 'ommy', "Dave your've", 'Mecklen', 'Vito', 'the Fall River Debs', '""" How\'s your foot ?"', 'Monkeybone - Got', 'Mandrake the Magician', 'Carl Tillman', 'This Jade Fox', 'an Ode to Spring', "Shoot Vader's", 'Trainers', 'Sheriff of Taos County', 'Yorktown Virginia', 'The Consulting Detective', 'the Highliner Pinot', 'Charlie Chan', 'Frank Baker', 'Mine', 'Daniel Burdon', 'Crabbin', '"""Some Like It Hot."', '""" Bolts of lightning don\'t just """', 'Dealey', 'Left Quarantine', 'Faceman', 'Chinn', 'the Lieutenant Singh', 'CIIAC', 'Kiki', '"""Take a fifth step that we may serve the people"', 'the Sharon Stone', 'answerin', 'OBLIVION', 'ruffian', 'Napoleon Bonaparte', 'Flannery', '"""Oh Susanna"""', 'Screw Sting', 'Hello Bud', 'Kirk', 'Jesus Andy', 'Acula</u', 'Aged', 'Mamacita', 'Lucifer', 'Organa', 'Mike Junior Vaughn Brookie', 'Acapulco', 'Chloramphenicol', 'M.A.', 'coke', 'Threepio Human Cyborg', 'Green Hornet', 'Uncle Bobby', 'Troop', 'Creedence', "Peggy Sue's", 'Kay', 'Y. O. H.', 'Elizabeth Deane', 'Johnny U', 'hung', 'Watts', 'Clark Street', 'Outpost 1.0', 'Hewlitt Packard', 'Mister Dudley', 'Miss. G-6', 'the Daily Planet', 'Magicians', 'Judicial', 'Lon Chaney Jr.', 'Ungh', 'Russian', 'Heee Hee', "Bud White's", 'Riddler', 'Ethiopia', 'Allende', 'Elijah', 'Alden Lane', 'Fin Raziel', 'Royalton', 'The US Army', "And NO IT'S NOT DANGEROUS TO DO THAT", 'Regina', 'the Doc', 'Beany', 'District Court', 'Reed Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97', 'Tarantula Man', 'Jameson-- Bunch', 'Callahan', 'Handcuff', 'Fuck Diego', 'HELL', 'Goddamn Rutherford Auction House', 'Waal <', 'Pescedero', 'youĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97', 'Heddo Jeth-ica', 'Kanita', 'a Pierce Patchett', '-- C.C. Baxter', 'Irish', 'Kansas City', 'Herbert Greenleaf', 'Funky Town', 'Whatya', 'Pinot Grigio', 'Greece</u', 'Logue', 'Rosebaby Blossom', 'the Jersey Coast', 'Dade Community College', 'Simone Hawkins', 'Magic Johnson', 'Svengali', 'LaPlante', 'Mercury', 'Lhamo', 'KFT', '"""Remaining Men Together?"', 'the DeLuxe French Cleaners on Wabash Avenue', "C'mon", 'Yo Rock', 'OK Computer', 'Leftist Law', 'Florence Boulevard', 'Roseman Bridge', 'Spock', 'Maxies', "Valhere's", 'the Community Hospital', 'Call Morris', 'Frankfurt', 'Wayne Gretzky', 'The Man in Black', 'Oooooweee', 'Woodrue', 'social security', '"""Air... water... your """', 'Pyro', 'Laura', 'Northerner', "ya-- --an'", 'M.J Christ Helen', 'Frank Sinatra', 'Marm', 'Freeze', 'S.O.P', 'E.J.', 'Delighted Betty', 'Grozny', 'La Compania', 'Maysles', 'Grand Marnier', 'Barry Manilow', 'Franny', 'Tribeca', 'Fuckin-A.', 'Kringelein', 'Athens', 'Kane', 'Hector', 'Look Ted', 'Marshall Street', 'Skippy Tiger', 'Writin', 'Hidin', 'Plymouth', 'McKeltch', 'Superior', 'Rembrant', 'I. Either', 'Cheryl McGovern', 'Sheriff Buddy', 'Musclehead', 'Lee Wilkins', 'Wedge', 'THE FUCKING BOWLING TEAM', 'Uncle Phil', 'Abraham Slushee', 'reportin', 'Robert -', 'Goldberg', 'Marsellus Spivey', 'Tortuga', '"""The Number Four With a Smile."', 'Biocyte', 'Murray', 'Fenner', 'Mighty Mouse', 'Swell', 'J.T.', 'Bree Daniel', 'Aliens', 'Cuisinart', 'Wolf-slayer', 'Arrgh', 'Head Butler', 'Chocula Frankenberry', 'Renquist', "Cotter'll", 'Underwater Flying Objects', 'Chef', 'Swoon', 'The Mossy Thing', 'Otternschlag', 'Martin Luther King', 'Western Union', 'Sh Talby', 'Schooner', 'Bagman', 'the Journal of the American Medical Association', 'Henryk', 'Purser', 'Anais', 'L. B. Jefferies', 'Advocaat', 'St. Severin', 'Vic Ben Johnny', 'South', 'Route 9', 'Another Martini', 'Proudfoot', 'MacDuff', 'the Gorge of Eternal Peril', 'Lockheed', 'Streichhoelzer', 'Nara', 'the James Bro ...

# %%
dict = {}
for n in ent:
    dict[n] = len(n)

# %%
#sort dict by biggest values
dict = {k: v for k, v in sorted(dict.items(), key=lambda item: item[1], reverse=True)}

# %%
dict
# Out:
# {'"""How can the Bolshevik cause gain respect among the Moslems if your three representatives Buljanoff Iranoff and Kopalski get so drunk that they throw a carpet out of their hotel window and complain to the management that it didn\'t fly"': 237,
#  '"""The Premier wishes to inform the Government of the United States that it will be impossible for him to attend the meeting suggested by the President unless the meeting is held in Moscow."""': 192,
#  '""" Come Tuesday twelve a.m. bingo these like-minded deviates log on and start yakking it up: explicit sex crime gossip who did what to whom who wants to do what when why and how."""': 182,
#  '"""The suggestion of the President regarding the possibility of a meeting in Moscow would be unacceptable to Her Majesty\'s Government at the present time."': 155,
#  '"""The Management of Boyd\'s takes pleasure in requesting the company of Mr. Richard Starkey that\'s you in their recently refinished gaming rooms."': 146,
#  '"""Well Jim I says, it makes me sick to see a man struttin\' around and packin\' two pistols an\' a Henry rifle and cryin\' like a baby."': 133,
#  '"""The Purple Bread an intensely portrayed tale of love and envy set against the sweeping background of a Polish bakery."': 121,
#  "Fine if you don't want us stay with the scum in present management--dedicated to running you and Bluestar into the ground": 121,
#  "Yeah well that's a sore subject and therefore out of bounds to a young sprout of a hostage negotiator under my tutelage.": 120,
#  'The Truth of Suffering The Truth of the Cause of Suffering The Truth of the Cessation of Suffering the Truth of the Way': 119,
#  '""" It\'s so easy to get caught up in the whole ego cycle of this business and make it all about yourself."': 106,
#  "Facing the past is an important way in not making progress that's something I tell my men over and over --": 106,
#  '""" You were in a fight-- --they hadn\'t pulled me off that woman I would have jerked a knot in her."': 100,
#  '""" You gonna stand there in broad daylight and tell me you think I\'m the reason we\'re still here?"': 99,
#  '"""Old Fishbait he says, never lifted a thing in this world if there was a way he could roll it."': 97,
#  "So I run around and grab all the carbon paper from all the desks and take it to the men's room.": 95,
#  '"""The former executive has reason to bet on being sued for major cigarette manufacturers..."""': 95,
#  '""" Shit... Cobb Jones I want you to do something about that damn rattle in the air system..."': 94,
#  "For Mother's Day I used all my allowance that I'd been saving to take my mother to Kansas City": 94,
#  '"""The Kon-Tiki in motion was a little different from what it usually was in such conditions"': 93,
#  'Politics is for people who have a passion for changing life but lack a passion for living it': 92,
#  '"""The Fidelity Bank and Trust was robbed on Tuesday by a gang of twenty heavily armed men"': 91,
#  '""" You know with the makeup and everything1 I actually thought he was smart for a second."': 91,
#  '""" You want me to de-prioritize my current reports until you advise of a status upgrade?"': 90,
#  '"""The Event Horizon sensors show the same thing: Bio-readings of indeterminate origin"': 87,
#  '"""You and I are the only men with balls enough to walk through the park at midnight."': 86,
#  '""" --one of us all of us--I have no idea--brought whatever this thing is back here."': 85,
#  '""" At the end of the day I was approached by the Golden Pompeii Olive Oil company."': 84,
#  '"""Why Grubbel he says, he lives out of garbage cans because he won\'t take charity."': 84,
#  'Back in the Seventies I spent years putting away gangsters in a Colombian syndicate': 83,
#  'Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97then the bears came right into the bedroom and the little baby bear': 83,
#  '""" Well before you crawl off to die Jordan give me five minutes of good headwork."': 83,
#  "Charlie I'm from the old country and these American ways get me sometimes confused": 82,
#  '""" The Torah says not to light a fire on the Sabbath because it\'s work correct?"': 81,
#  '""" The ida originates at the right testicle and terminates at the left nostril."': 81,
#  '"I thought maybeĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97uhĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97""""""""""""""""believe you me"': 81,
#  '""" Maybe you\'d like to tell Mom and Dad why you stopped taking your medication."': 81,
#  '""" Because V\'ger is going to destroy all the carbon units on the third planet."': 80,
#  "Victor's landlord says an envelope of cash was in the office mailbox each month": 79,
#  'The world breaks everyone and afterwards many are strong in the broken places': 77,
#  '""" How fuckin\' retarded do you have to be to get shit-canned from that job?"': 77,
#  '""" the Sentient had taken control of the ship\'s guidance systems however-"""': 77,
#  '""" This Eleanor\'s been living at the International Towers for 3 years now."': 76,
#  "Well I'm the first one to admit that I don't know anything about bookkeeping": 76,
#  'Hell I could take you through it step by step explain why your story stinks': 75,
#  '""" The Clemens said to make him look like he just came from snowmobilin\'"': 74,
#  '""" But Di all this food reminds me of how much I want to teach our baby."': 74,
#  'Wholesome spiritually wealthy couple have found true love with each other': 73,
#  '"""Out of weariness I spoke to my own heart; to leave it all and to die."': 73,
#  '"""The way Zimmermann takes such good care of you and this drug-peddling"': 73,
#  '"""Money is a sort of sixth sense that gives meaning to all the others."': 72,
#  '"""That\'s right, Raoul, it wasn\'t your idea, none of this was your idea"': 72,
#  "'Cause I enforce security and get people to tell me what I need to know.": 72,
#  'Go ask his name--If he be married My grave is like to be my wedding bed': 71,
#  'This is Excelsior a Federation Starship traveling through Beta Quadrant': 71,
#  '""" The Sergeant discovered this relationship and wanted me expelled."': 70,
#  'Terrible for her but think about me young boy with that kind of power.': 70,
#  'He and Debbie stand outside the theater which is a multi-plex cinema.': 69,
#  '"""BERNIE LAPLANTE EXCUSE NUMBER FOUR THOUSAND ONE HUNDRED AND SIX."': 68,
#  '"""In the morning darlin\' in the morning we are G-O-N-E and you are"': 68,
#  '"""Look JohnĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97what we\'re handing them are platitudes."': 68,
#  'Burger Manifesto Part One The Dialectical Expression of Testosterone': 68,
#  '"""How can he give you monk\'s vows if he has not kept them himself?"': 68,
#  '""" Lecter\'s description was accurate he just lied about the name."': 67,
#  '""" That\'s the first time Marty ever brought a girl to this house."': 67,
#  "Well for Christ's sake everybody bugs everybody else; we know that": 66,
#  'Darling I drove Gaston to the market and look what I got from him!': 66,
#  '"Yeah they argued he was going to reveal the secret formula of """': 66,
#  '"""Narcissus would kill for a taste of Golden Pompeii Olive Oil?"': 65,
#  'SDECE Service de Documentation Exterieure et de Contre-Espionnage': 65,
#  '"""Hey I\'m the last guy to want to talk about school at the bar."': 65,
#  'Brown & Williamson Has a 500-Page Dossier Attacking Chief Critic': 64,
#  "Not until V'ger withdraws the devices orbiting the third planet": 63,
#  '"""Mister I met a man once when I was a kid it\'d always begin."': 63,
#  '"big boy""""""""""""""""Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97the Boss of the outfit"': 63,
#  '""" I-I\'m sorry - can someone else please run the Ouija board?"': 63,
#  '"""Look at the mill Frank -- look at the way it goes around..."': 63,
#  '""" King proved -- even an ape can win a prize with good press"': 63,
#  '"""In Xanadu did Kubla Khan a stately pleasure dome decree. ."': 62,
#  '"""Book of Love Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Chapter Four"': 62,
#  '""" Look I already told you I\'m not going to give you a ride."': 62,
#  '"""The Life and Loves of the Grand Duchess Swana of Russia"""': 61,
#  'Buljanoff she still has those old- fashioned Bolshevik ideas.': 61,
#  '""" Why in God\'s name wasn\'t this thing removed years ago??"': 60,
#  '"""Superintendent J. Mckechnie Vancouver Police Department."': 60,
#  '"""Superintendent J. McKechnie Vancouver Police Department."': 60,
#  '"""They retrofitted Ahab with some kind of rocket launcher."': 60,
#  '""" Love... Not hard to find you...just follow the Chaos..."': 60,
#  '""" THE VOICE...or maybe just JACK - EXCLAMATION POINT..."""': 60,
#  'Special Agent Sterling from the United States Secret Service': 60,
#  '""" Bunny, is that stuff I left in the garage still there?"': 59,
#  '"""Buljanoff Comrade for once in your life you\'re in Paris"': 59,
#  '"""You have a very good mind or I wouldn\'t have come back."': 59,
#  'the Grand World Championship Bicentennial Heavyweight Fight': 59,
#  'Computer Investigation and Infrastructure Assessment Center': 59,
#  'The Special Anti-Terrorist Detachment of the Border Patrol': 58,
#  'myĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97uhĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97wifeĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97if': 58,
#  '""" That\'s bullshit Got a letter from this Goodridge guy?"': 58,
#  '"""Roaring Twenties""""""""""""""""Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x85 or """': 58,
#  'Ä\x82Â\x84ÄšÄ\x84Ä\x82Â\x82Ă\x82Â\x95quelquĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92un rÄ\x82Â\x84Ă\x82Â\x82Ă\x84ĹĄĂ\x82Â\xa0': 58,
#  '"""Take a sixth step that we may follow our vows in life."': 58,
#  '"""Notice the Israelis: a fundamentally secular society."': 57,
#  "Does V'ger object to the presence of the two carbon units": 57,
#  'Early Midlife About-To-Marry Hanging Onto The-Bottom-Rung': 57,
#  'Ă\x84Â\x82Ă\x82Â\x84Ä\x82Â\x82Ă\x82Â\x99tre soupÄ\x82Â\x84Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â§onnÄ\x82Â\x84Ă\x82Â\x82Ă\x84ĹĄĂ\x82': 57,
#  'the Tribunal for Artists of the Denazification Commission': 57,
#  '"""It\'s not about a nice girl who meets a sensitive boy."': 57,
#  '""" In choosing you I feel that I serve my country well."': 57,
#  '"""Sforza an equestrian model of a never executed statue"': 57,
#  '- Professional Paranormal Investigations and Eliminations': 57,
#  '"La Picadura""""""""""""""""--""""""""""""""""the sting"': 56,
#  "the Waterford Merchant's Association of who I am Council": 56,
#  "'The Great Red Dragon and The Woman Clothed with the Sun": 56,
#  '""" You\'re a regular nuclear meltdown honey--slow down."': 56,
#  "Honey it's been hell up here down there and over yonder!": 56,
#  'No Dr. Hartdegen they are not just chickens and roosters': 56,
#  '"""Wait a minute--I think I can cut something else out."': 56,
#  'EdieĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 IĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 IĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 56,
#  'the Auditing Department of the Territorial Administrator': 56,
#  '"""Yes Jordan -- I\'ll wait for you no matter how long."': 55,
#  '""" All right- thee second embankment will go there.  "': 55,
#  '"""The Change Mr. Verger was... he made quite a study."': 55,
#  '""" Look... what I\'m doing is none of your business..."': 55,
#  '"""Springtime For Hitler signed, sealed and delivered."': 55,
#  '"""Later for that Walt let\'s get this: we need the """': 54,
#  'the British Government - all International Expeditions': 54,
#  '"""The Lord is remarkably tolerant of the charitable."': 54,
#  '"""Let\'s Get It On Marvin Gaye, from Let\'s Get It On."': 54,
#  '"""Berthier sees only what is in the open Murat said."': 54,
#  'The Bicentennial Heavyweight Championship of the World': 54,
#  'Lothar get up here fast and bring your First- Aid kit!': 54,
#  '""" And the Sheriff at the time was Big Charley Wade."': 54,
#  '""" Which Pa did an\' they were engaged within a week"': 53,
#  '""" We gonna hit \'em wid da BOMB DICKEY on dis\' one."': 53,
#  '""" But Walter we didn\'t make the fucking hand- off!"': 53,
#  "What'd the Messican mean a sick Horse's gonna get us?": 53,
#  '""" But Sheriff Wade he could shut you down anytime."': 53,
#  '"""Well Daddy\'s got his box at the stadium of course"': 53,
#  '"""How come the F.B.I. don\'t put anya this together?"': 53,
#  '"""How much you just ingested what a big man you are"': 53,
#  'The Blue Desert Tower of Ghosts Kingdom of the Blind': 52,
#  '"""The Century of the Detective by Jurgen Thorwald."': 52,
#  '""" The old crazy woman who lives off Old Gun Road."': 52,
#  'Junebug MacGuff Row 4 Third Seat From the Blackboard': 52,
#  '""" You said you were going to get her out of this."': 52,
#  '""" I\'m really beginning to hate that word of yours"': 52,
#  '"""My Bunny might have done something with her life"': 52,
#  '"""Wait a minute the fourteenth that\'s the same day"': 52,
#  'Tahiti Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96 Fiji Islands': 52,
#  '"""Water water everywhere but not a drop to drink."': 51,
#  "Alamo Road Alamo Street Alamo Square Alamo Buildin'": 51,
#  '"""Ay pilgrim lips that they must use in prayer."""': 51,
#  'French Club Drama Club Debate Club Girls Basketball': 51,
#  'A habituĂ\x84Â\x82Ă\x82Â\x84Ä\x82Â\x82Ă\x82Â\x8d of cemeteries his proudest': 51,
#  "ex-CIA John -- they're all Ivy League Establishment": 51,
#  'a Los Angeles Chamber of Commerce Business Achiever': 51,
#  '"""Take a fifth step that we may serve the people"': 50,
#  '"""Because Bobby is a loser you said so yourself."': 50,
#  '"""Mister Crowley what\'s inside of your head..."""': 50,
#  'the Allied Kommandatura Cultural Affairs Committee': 50,
#  'The Charnier Shipping Company of Marseilles France': 50,
#  'Dear you are a woman of super strength and beauty.': 50,
#  '""" Take a look at this file on Professor Morton."': 50,
#  'Lovett - Alexander P. Good morningĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 50,
#  '"""Love Affair With Irene Dunne And Charles Boyer"': 50,
#  'brokeĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97and hungryĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97and': 50,
#  'THE YAKIMA INDIAN RESERVATION WITH YOUR NAME ON IT': 50,
#  'the Environmental Protection Agency Third District': 50,
#  '"""The Little Girl who is she, what is she doing?"': 50,
#  "Today I'm offering you a lousy job at a lousy wage": 50,
#  'Tell them that everything is going to be just fine': 50,
#  "Rosa I can't believe you're doing all this for me": 49,
#  '""" And Switek resumes romancing Miss Ukraine..."': 49,
#  '"""Where the Fact is separated from the Fantasy."': 49,
#  '""" Boy what\'d I tell you about using that word?"': 49,
#  "But I'm not positive it's gonna happen tonight --": 49,
#  'Windsurfing Doctor Mensan IQ maverick Sagittarius': 49,
#  '"""Maybe now you appreciate the danger we\'re in."': 49,
#  'Alright this is some of the things they wrote me;': 49,
#  '""" The trick is to let them think it\'s true."""': 48,
#  'the Constitution and Declaration of Independence': 48,
#  '"""WHO CARES WHAT PSYCHIATRISTS WRITE ON WALLS?"': 48,
#  'the Mad Butcher the Demon Barber of Fleet Street': 48,
#  'Sure I like a woman with some meat on her bones.': 48,
#  'Vous Ă\x84Â\x82Ă\x82Â\x84Ä\x82Â\x82Ă\x82Â\x99tes FranÄ\x82Â\x84Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â§ais': 48,
#  '"""Vigo the Carpathian born 1505 died 1610 --"""': 48,
#  'the Cadwalader Chair in Statistical Paleontology': 48,
#  '"""The Machine there\'s a man I would work with."': 48,
#  '"""In the 18th century there was no such thing!"': 48,
#  "the Electric Psychedelic Pussycat Swinger's Club": 48,
#  '""" Thanks for teaching me an important lesson."': 48,
#  '"""People gonna walk into this place and say """': 48,
#  'the Journal of the American Medical Association': 47,
#  '"""How was I supposed to know they were women?"': 47,
#  '""" Pacific Northwest is a hotbed for serials."': 47,
#  'When I was a mere spit of a lad on Ferry Street': 47,
#  'Assistant Director Sales Aspen Snowmobile Tours': 47,
#  '"""Drove down the highway there was a big jam"': 46,
#  '""" The Emperor\'s going to fight in the arena"': 46,
#  '"""A History of the United States Volume I."""': 46,
#  'Miller Smith Cooper any of you in the airlock?': 46,
#  '"""The Night the Lights Went Out in Georgia"""': 46,
#  'Thirty-sixĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 sevĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 46,
#  '"""Existential Motifs in Russian Literature"""': 46,
#  'the United Nations High Commission on Refugees': 46,
#  'Otto Klemperer Arnold Schoenberg Max Reinhardt': 46,
#  '""" the Dodgers to lose or the summer to end."': 46,
#  'Oh the *other* prominent character in the play': 46,
#  '"""the old ball and chain that\'s when I left."': 46,
#  "Claire she's been a huge part of your life for": 46,
#  'The Legendary Black Beast of Aaaaarrrrrrggghhh': 46,
#  'the First Family against the Presidential Seal': 46,
#  '""" That\'s because they\'ve only seen it once."': 46,
#  '"""The Old Mill when I don\'t have an old mill"': 46,
#  'British Royal Organisation For Lasting Liquid': 45,
#  'the Muncie College of Business Administration': 45,
#  'Federal Bureau of Investigation Special Agent': 45,
#  'Mickey/Mallory-Woody Harrelson/Juliette Lewis': 45,
#  '""" NO FOUR THOUSAND ONE HUNDRED AND TWELVE."': 45,
#  '"""Love me love me love me... put me on t.v."': 45,
#  '"""All right Westley I\'ve never had a valet."': 45,
#  'P.K. Lassiter and Associates Investment House': 45,
#  'United States Coastguard Station North Island': 45,
#  'puncherĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 hooksĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 45,
#  '"""Like everything\'s on the tip of my tongue"': 45,
#  'the Center for Missing and Exploited Children': 45,
#  'lĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92achat trois ou quatre mille': 44,
#  'nnnnnnnaaaaaannnnnnnnncccccceeeeeee Mwaaaaaa': 44,
#  '"""through the <u>negligence</u> of others."': 44,
#  'La Jeunesse Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 44,
#  '"""The Prayer of Faith shall have the sick."': 44,
#  '""" How long have you been an investigator?"': 44,
#  '""" The Princess Louisa is too ill to move."': 44,
#  'Yes Cultural re-education Section Propaganda': 44,
#  '""" What the <u>hell</u> was I thinking of?"': 44,
#  'Hittites the Mesopotamians and the Sumerians': 44,
#  '""" Look a man can make an honest mistake!!"': 44,
#  '""" and the week before we had something..."': 44,
#  'Arctic Warrior Arctic Warrior Arctic Warrior': 44,
#  'no National Space Exploration Administration': 44,
#  'the U.S. Resource Center for Missing Persons': 44,
#  '"""What Alex is trying to say is that it """': 44,
#  'the DeLuxe French Cleaners on Wabash Avenue': 43,
#  'Think of it as a rite of passage to manhood': 43,
#  '""" You got about five minutes and change."': 43,
#  '"""A People\'s History of the United States"': 43,
#  'Surrender in the name of the King of France': 43,
#  '""" The Communists have never been closer."': 43,
#  "the Constitution Rock 'n' Roll and Baseball": 43,
#  "I'm waitin' for the 'leven o'clock crossing": 43,
#  'IV Victoria Edward VII George V Edward VIII': 43,
#  '"""Dine With Buljanof Iranoff and Kopalski"': 43,
#  'the Carter Theory of Criminal Investigation': 43,
#  'Skies a restaurant at the top of a building': 43,
#  '"""Look out for a guy with ten fingers...?"': 43,
#  '""" Pick that up and put it down properly."': 43,
#  '""" What\'s that strange name the newspaper"': 43,
#  'the B.I.A. -- Bureau of Indian Annihilation': 43,
#  '""" Oh fuck Toby\'s that little china girl."': 43,
#  'Rainbow with Egg Underneath and an Elephant': 43,
#  'Sebastian-Cabot- Buckingham-Palace-looking-': 43,
#  '""" I\'m just saying, the man is a problem."': 43,
#  'Naturalization Service Intergalactic Bureau': 43,
#  'Level 842CON G Division of Plastic Vendable': 43,
#  'Space Alien Revealed as Head of Time Warner': 43,
#  'The Demolitions Committee of Project Mayhem': 43,
#  '""" That\'s the iconography of rascism man!"': 43,
#  "'Happy Homes' for Harry and Emily Weiss of": 42,
#  'fingerĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 and Johnny Friendly': 42,
#  '"""The Rio Rancho this the blah blah blah"': 42,
#  'Plum Island Animal Disease Research Center': 42,
#  'THE DREADFUL SCORPITRON SHOULD BE CLOSE BY': 42,
#  '""" That\'s what I been telling everybody!"': 42,
#  'the American Federation of Variety Artists': 42,
#  '"""You need to make these your primary """': 42,
#  'Zuzu Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96 Zuzu': 42,
#  '""" You better not be fuckin\' teasin\' me."': 42,
#  'Dear Sleepless in Seattle: I live in Tulsa': 42,
#  'This is Gale Gayley for Channel Four News!': 42,
#  'May I live a thousand years and never hunt': 42,
#  '"""You wish you hadn\'t blown the whistle?"': 42,
#  'an Indian Reservation three thousand miles': 42,
#  '"""Now Nuke would I do a thing like that?"': 42,
#  "agoĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97you're": 42,
#  '"""For Excellence in the Pursuit of Truth"': 42,
#  '"""A perfect night for mystery and horror"': 42,
#  'Austin Powers International Man of Mystery': 42,
#  '"""A Foul-Rag-and-Bone Shop-of- the-Heart"': 42,
#  '""" What\'s the best fortune you ever got?"': 42,
#  '""" That\'s Paul\'s great weapon -- words."': 41,
#  'thisĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97with': 41,
#  '""" THE PRESIDENT HOLDING THE PHOTOGRAPH"': 41,
#  'Poker Face Radio Cookie Goldmouth Biscuit': 41,
#  '""" Look Mommy it doesn\'t even hurt him."': 41,
#  'Anesthesiology Massachusetts Commonwealth': 41,
#  'Johns Hopkins the University of Minnesota': 41,
#  'Mantan - The New Millennium Minstrel Show': 41,
#  'What am I supposed to tell your kids Jim!': 41,
#  '""" Maybe maybe... That just might work."': 41,
#  '""" No John you\'re too hard on yourself."': 41,
#  "Sooner or later you'll learn to trust me.": 41,
#  'Tippi-tippi-tim tippi-tim Tippi-tippi-tan': 41,
#  '"""He died well, that should please you."': 41,
#  '"""Goodness gracious great balls of fire"': 41,
#  '"Even this--""""""""""""""""Herb Shuttle"': 41,
#  'the Sickness and Accident Claims Division': 41,
#  '"Unsolved Most- Wacked-Out Home Videos"""': 41,
#  "EdieĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 it'sĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97": 41,
#  'Now what time does my plane leave Tuesday': 41,
#  'What if Tod... is just the first... of us': 41,
#  '""" Wake up young lady that\'s our train."': 41,
#  "the Federal Emergency Management Agency's": 41,
#  '""" That\'s what bothers me Mr. Garrison."': 41,
#  'The Black Panther Party for Self Defense': 40,
#  'the First American Financial Corporation': 40,
#  'the Boston University School of Medicine': 40,
#  '""" That\'s not what they\'re tellin\' me."': 40,
#  'the Allied Kommandatura Cultural Affairs': 40,
#  'Persons Who Will Profit From This Merger': 40,
#  'the University of California Los Angeles': 40,
#  'isĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97wellĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97we': 40,
#  'the University of Pennsylvania my P.H.D.': 40,
#  '"""The 100 Greatest Books Ever Written."': 40,
#  '""" Mack the Mouth at a loss for words."': 40,
#  'the kidsĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92 shoe department': 40,
#  "HE DIDN'T GET OUT OF THE COCKADOODIE CAR": 40,
#  'the Orchard Valley Correctional Facility': 40,
#  'Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x93Not LeonĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x94': 40,
#  "The Oliver Stone-George Bush Connection'": 40,
#  'the Northcountry Development Association': 40,
#  '"""Short Happy Life of Francis Macomber"': 40,
#  '""" That\'s the name of Jeff\'s magazine."': 40,
#  'the Accounting Office at Mission Control': 40,
#  '""" Sorry I can\'t take you seriously..."': 40,
#  '"""Hey Ma wadda we need this old house?"': 40,
#  'Fifteen years although I prefer the term': 40,
#  'Colt Browning Smith Thompson Kalashnikov': 40,
#  'Methodology and Practice Anesthesiology': 39,
#  '"""Peace on earth good will toward men"': 39,
#  "I'm gonna stick this right in your eye.": 39,
#  "Vigo the Carpathian in Leon Zundinger's": 39,
#  'Mortgage Department First National Bank': 39,
#  "Leader Of The Pack' 'Town Without Pity'": 39,
#  'the University of Pennsylvania Hospital': 39,
#  'Combat Operations Center Major Mandrake': 39,
#  '""" Rallying cry it\'s an insurrection."': 39,
#  'The Federal Emergency Management Agency': 39,
#  'Seems like a pretty open-minded guy huh': 39,
#  '"""And the last thing he said to me """': 39,
#  'the E.J. McClosky Manufacturing Company': 39,
#  '"""Where Did You Sleep Last Night sure"': 39,
#  'Hey I have something I just wrote right': 39,
#  '""" Life must be peachy on Planet Ted."': 39,
#  '"""You Can\'t Always Get What You Want."': 39,
#  'Commissar Razinin Board of Trade Moscow': 39,
#  'Come on Delly look at the country today': 39,
#  'Crash I get wet just thinking about you': 39,
#  '""" How about a COMINT classification?"': 39,
#  'The Network Executives Goofiest Moments': 39,
#  '"""You need a new real estate agent."""': 39,
#  '"""Old Mill""""""""""""""""...alright?"': 39,
#  '""" You know I can\'t believe I did it."': 39,
#  '""" You\'re telling me you\'re the A...?"': 39,
#  'Carter Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96': 39,
#  'General Garrison Confederate Third Army': 39,
#  '""" The Mission is happening tonight.."': 39,
#  'sheĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97she': 39,
#  'the Miracle Wonderland Carnival Company': 39,
#  'knowĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97butĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 39,
#  'the Federal Emergency Management Agency': 39,
#  'the Beach Boys Greatest Hits Volume Two': 39,
#  '"""The Lord Darrow Benefit screening"""': 39,
#  'Pass the sugar -- and I want a divorce': 38,
#  'the Senior Citizens Early-Bird Special': 38,
#  '"""The U.S. Attorney in Washington """': 38,
#  'Rumor: Frank Sinatra and Rita Hayworth': 38,
#  'Michael Kitz National Security Advisor': 38,
#  'Eureka Ammunition Company -- Gentlemen': 38,
#  'The Doctor and I will start it off and': 38,
#  '""" It\'s called... the Gritty Palace."': 38,
#  'Bringing every State to a Higher State': 38,
#  'the Brotherhood of the Cruciform Sword': 38,
#  'time royal succession regicide bribery': 38,
#  'Starfleet United Federation of Planets': 38,
#  '"""Clarence and Alabama Go to Cancoon"': 38,
#  'wasĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97butĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 38,
#  'The Roylance Guide to Secret Societies': 38,
#  'Burpelson Air Force Base HQ 843rd Wing': 38,
#  'Grigory Yefimovich Rasputin -- Grigory': 38,
#  '"""Come on Fran -- don\'t be like that"': 38,
#  'the United States Army Artillery Corps': 38,
#  '"""Finally Roberts decided something."': 38,
#  'The Heartbreak of Human Papillomavirus': 38,
#  'WHAT THEY LOSE ON EARTH BY BEING BLACK': 38,
#  'Golly I can see their eyes pop already': 38,
#  'the North American Broadcasting System': 38,
#  '"""How\'d we ever get such in a ru-utt"': 38,
#  'the Brown & Williamson Tobacco Company': 38,
#  'the Seventh National Bank of Tarrytown': 38,
#  "The Vampire's Tomb The Ghoul Goes West": 38,
#  '""" You will find your answers there."': 38,
#  'Danbury Federal Correctional Institute': 38,
#  '""" What\'s the *medical* explanation?"': 38,
#  "Quantico out of MIT -- you're a techie": 38,
#  '""" It\'s Gary you\'re talking about."""': 38,
#  '"""Funny..... - it suddenly hit me..."': 38,
#  '""" Bolts of lightning don\'t just """': 37,
#  'Shakespeare Charles Dickens Moby Dick': 37,
#  "Listen I'm sorry but I'm running late": 37,
#  'the County Family Services Department': 37,
#  'Press Relations for the Flight Office': 37,
#  'the International Maritime Convention': 37,
#  '""" That\'s a great title for a song!"': 37,
#  '""" First prize is a trip to Moscow!"': 37,
#  'Excuse me Vendela have you seen Diane': 37,
#  'the Constitution of the United States': 37,
#  'the Worldwide Jewish Media Conspiracy': 37,
#  'ArtArtArtArtMooneyMooneyMooney Mooney': 37,
#  '""" Oh Mommy you\'re embarrassing me."': 37,
#  '"""Maybe you can\'t even describe it."': 37,
#  'protĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x82gĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x82': 37,
#  'Selective Operations Unit Agent Levoi': 37,
#  'the Pleasantville Chamber of Commerce': 37,
#  'Federal Bureau of Investigation Tenth': 37,
#  '""" Our money situation is not good."': 37,
#  '"""Driving the Demons From the Mind."': 37,
#  'the University of Maryland Fall Mixer': 37,
#  'The Cuer-vo Gold the fi-ine Columbian': 37,
#  'Monsieur DelbenĂ\x84Â\x82Ă\x82Â\x84Ä\x82Â\x82Ă\x82Â\x8d. Mine': 37,
#  'the Los Angeles International Airport': 37,
#  'Written Directed and Starring Ed Wood': 37,
#  'Accident and Compensation Association': 37,
#  '"""Mister can you spare us a copper?"': 37,
#  'the Board of Centro Mondo Commerciale': 37,
#  "And NO IT'S NOT DANGEROUS TO DO THAT": 36,
#  'youĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 36,
#  '""" You\'ll be sitting on the right."': 36,
#  '""" This guy LaPlante won an award?"': 36,
#  '""" in spelling... six in behavior."': 36,
#  '""" This guy\'s kinda dorky lookin\'."': 36,
#  "Brad I know you don't love me now --": 36,
#  'the Boston Lying-in South End Branch': 36,
#  'SID Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 36,
#  'the Battle of Little Big Horn Custer': 36,
#  'COINTELPRO Selective Operations Unit': 36,
#  'the Bolsheviks of their filthy money': 36,
#  'Massachusetts Supreme Judicial Court': 36,
#  'the BLACK BEAST of Aaaaarrrrrrggghhh': 36,
#  '"""Guess we\'re goin\' over to the """': 36,
#  'Mess with the Best Die Like the Rest': 36,
#  '""" Hard up as you are at your age?"': 36,
#  '""" Everybody says he was so brave."': 36,
#  'the Pemberton Condensed Steam Engine': 36,
#  'Pierre Steak-bur-ger Fren-n-ch Fries': 36,
#  '"""The Voiiiiices made him do it."""': 36,
#  'The Schopenhauer of the 20th century': 36,
#  'the International Fletch Corporation': 36,
#  'Belle give the Sheriff a cup of rum.': 36,
#  '""" Righteousness for his namesake."': 36,
#  'Jetson Los Angeles Police Department': 36,
#  'QuĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92est-ce que tu veux': 36,
#  "Title's the first thing's got to go.": 36,
#  'the Criminal District Court Building': 36,
#  'Hope youĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92re ready Sid': 36,
#  'Section Fourteen for Section Fifteen': 36,
#  'the Un-American Activities Committee': 36,
#  '"""What\'s so fuckin\' good about it?"': 36,
#  'Harold the Patron Saint of Taxidermy': 36,
#  "She Doesn't Want to Bare Her Breasts": 36,
#  'Royal Australian Regiment Task Force': 36,
#  'De MoraesĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92s residence': 36,
#  '""" Ossining Correctional Facility."': 36,
#  'the Empire State Building -- Perfect': 36,
#  '""" You gonna git me back tomorrow?"': 36,
#  'The Board of Parrish Communications': 35,
#  'the Junior Chamber of Commerce Brad': 35,
#  'The Federal Bureau of Investigation': 35,
#  'The W.C. Fields Fan Club Newsletter': 35,
#  'On top of the Empire State Building': 35,
#  'the First National Bank of Toontown': 35,
#  'the Sheboygan Conservatory of Music': 35,
#  '"""How are you really doing Panes?"': 35,
#  'C.R.S. Consumer Recreation Services': 35,
#  'the Philadelphia Symphony Orchestra': 35,
#  '"""The Philosophy of Time Travel"""': 35,
#  'Oz - Oz - Oz-Oz - Oz - Oz - Oz - Oz': 35,
#  '"""Bread Instead of Bullets Club"""': 35,
#  "The Space Shuttle's Seismic Secret'": 35,
#  'The Little Sisters of the Moonlight': 35,
#  '""" An historical moment Gentlemen"': 35,
#  'Kane - My Declaration of Principles': 35,
#  'noĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97IĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97': 35,
#  'the Little Lebowski Urban Achievers': 35,
#  'Dear Penthouse I never thought this': 35,
#  "Mister Spock's Starfleet commission": 35,
#  'Blaine & Edwards Publishing Company': 35,
#  'Applied Mathematics and Engineering': 35,
#  'Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x91ArtĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92': 35,
#  '""" But the House did him first."""': 35,
#  'the San Francisco Police Department': 35,
#  'Ä\x82Â\x84ÄšÄ\x84Ä\x82Â\x82Ă\x82Â\x95 la tÄ\x82Â\x84Ă\x82Â\x82Ă\x84ĹĄĂ\x82': 35,
#  "fine I'm not going to fuck with you": 35,
#  'the International House of Pancakes': 35,
#  'Mullen and Company Public Relations': 35,
#  '"""What\'s so great about New York?"': 35,
#  '""" Ohh... Page three of the Post."': 35,
#  'the Board of the Zoological Society': 35,
#  '""" How are you tonight Mr. Falco?"': 35,
#  'Archangel de Jesus Montoya- Londono': 35,
#  '579B Block l9 Northwestern Section': 34,
#  'The Diedre Mayfair Research Clinic': 34,
#  '"""How\'s the investigation going?"': 34,
#  'the Bowen-Hamilton Textile Company': 34,
#  'The Supreme Sovereign of Sexuality': 34,
#  'Copacabana School of Dramatic Arts': 34,
#  'the Apollo Cinema on Sansom Street': 34,
#  'the Guinness Book of World Records': 34,
#  'the Organization for the Organized': 34,
#  'Special Correspondent at the Front': 34,
#  "Agent Low's theory of Suspect Zero": 34,
#  'the Boston Strangler Alber deSalvo': 34,
#  '""" Marty... Like dykes and dogs."': 34,
#  'the Book-of-All- Knowledgefullness': 34,
#  'TheyĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92re German Jews': 34,
#  'Buljanoff and Iranoff and Kopalski': 34,
#  'the Federation Starship Enterprise': 34,
#  'A VIOLENT RAINSTORM BUCKING WILDLY': 34,
#  'the Philosophical Research Society': 34,
#  '""" Boy the nuts are out tonight."': 34,
#  'Cinderella Man Grows Hair On Chest': 34,
#  'Wilhelm FurtwÄ\x82Â\x84Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â¤ngler': 34,
#  "ThĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97that's all right": 34,
#  '""" Toby... who the fuck is Toby?"': 34,
#  'Panther International Headquarters': 34,
#  '"""How about the Hell Merchants"""': 34,
#  'Carlos Marcello Santos Trafficante': 34,
#  '"""Bread Instead of Bullets Club?"': 34,
#  'The Northern Chronic Care Facility': 34,
#  "'Wings of a Dove' having the nerve": 34,
#  'Eddie Moses Communications Attache': 34,
#  'better than you Monsieur Delacroix': 34,
#  'Ä\x82Â\x84Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x89ysÄ\x82Â\x84Ă\x82Â\x82Ă\x84ĹĄĂ\x82Â\xa0': 34,
#  'Zombie Sluts From Beyond the Grave': 34,
#  'The Thing From Another Tax-Bracket': 34,
#  'the Free Diving World Championship': 34,
#  '""" Tell me about Beynon\'s ranch."': 34,
#  '""" How many weeks are you honey/"': 34,
#  "Can I ask you somethin' lieutenant": 34,
#  "Jerome County Sheriff's Department": 34,
#  "the Small Businessmen's Assocation": 34,
#  'the Federal Bureau of Intimidation': 34,
#  "World's Champion of Women's Rights": 34,
#  '"""Hey Delmore where\'s your Daddy"': 34,
#  '"You\'re a...""""""""""""""""guest"': 34,
#  "The Crime of the Century' Remember": 34,
#  'Wild Goose Flying in the Night Sky': 34,
#  '""" Look I don\'t want a -- Jerry."': 34,
#  'Contemporary Crisis in Western Man': 34,
#  '"""The Number Four With a Smile."': 33,
#  'The Multi-Jurisdiction Task Force': 33,
#  'The House Armed Service Committee': 33,
#  'the Miami Vice Action Spectacular': 33,
#  'butĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Wait a minute': 33,
#  "a 'Bus and Truck' company to come": 33,
#  'Weds the Boy of a Thousand Deaths': 33,
#  'Tell The girl to take care of it.': 33,
#  'the Metropolitan Transfer Company': 33,
#  'the Pleasantville Code of Conduct': 33,
#  'The National Psoriasis Foundation': 33,
#  '"""Vase with twelve Sunflowers"""': 33,
#  'Goldmouth Poker Face Cookie Radio': 33,
#  '"""Maybe we\'re ragged and funny."': 33,
#  "the O'Higgins of Castle O'Higgins": 33,
#  "PDT'S. Personal-Data Transmitters": 33,
#  'The City National on San Vincente': 33,
#  'the Resurrection Protective Force': 33,
#  'the Black Panther-Police Shootout': 33,
#  'the Riker Institute for the Blind': 33,
#  "Improvised Antipersonnel Devices'": 33,
#  '""" Well ... How can I put this."': 33,
#  'Benthic Explorer Benthic Explorer': 33,
#  'the Los Angeles Police Department': 33,
#  '""" You weren\'t so bad yourself."': 33,
#  '"""The Planet Of Galactic Peace?"': 33,
#  'Henry Portrait of a Serial Killer': 33,
#  'the Southern Heavyweight Champion': 33,
#  'the Confederate States of America': 33,
#  '""" You thinkin\' of goin\' there?"': 33,
#  '"""The Creator has not answered."': 33,
#  '"""Death at the Double X Ranch"""': 33,
#  'the Bear Creek Indian Reservation': 33,
#  'the Sheriff the Convenience Store': 33,
#  '"""Life is but a walking shadow."': 33,
#  'the Lina Wertmuller Film Festival': 33,
#  "the Department of Motor Vehicle's": 33,
#  'The Patriot Home the Chronic Care': 33,
#  'Perry Como Luciano Pavarotti Sole': 33,
#  '""" He\'s certainly good-natured."': 33,
#  'Cinderella Man Woos Mystery Girl!': 33,
#  '"""That\'s when one half of Paris"': 33,
#  '"""Live now because life is dust"': 33,
#  'My JesusĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x85 Consuelo': 33,
#  'the Western Hemisphere Conference': 33,
#  'the Stanislavski Catering Company': 33,
#  'the Berlin Philharmonic Orchestra': 33,
#  '""" Seventy-one per cent said """': 33,
#  'Mister Affirmative-Action Peacnik': 33,
#  'the Federal Bureau of Instigation': 33,
#  'the Nuclear Regulatory Commission': 33,
#  'Margaret Ann Muldovan - Newspaper': 33,
#  'The Mayor and Chamber of Commerce': 33,
#  'the Palace of the Legion of Honor': 33,
#  '"""That\'s from your movie right?"': 33,
#  'this rue de ThĂ\x84Â\x82Ă\x82Â\x84Ä\x82Â\x82Ă\x82Â\x8dbes': 33,
#  'the Democratic National Committee': 33,
#  "Lousy thank you I'm falling apart": 33,
#  'Neil I know this seems impossible': 33,
#  'DeSalvo Bianchi & Buono Berkowitz': 33,
#  '""" That\'s what they were up to!"': 33,
#  '""" How were we -- were we cool?"': 33,
#  '"""The Canada Thing was a shuck."': 33,
#  'Stonewall Jackson Jefferson Davis': 33,
#  'Goddamn Rutherford Auction House': 32,
#  'the Graf Zeppelin - and the next': 32,
#  '"""Secret Clauses of the Treaty"': 32,
#  "What's the FBI really doing here": 32,
#  'Okay. Dance Music For Old People': 32,
#  'the Mission Communication Center': 32,
#  'Borschevsky Russian Intelligence': 32,
#  '"""Pontius Pilate Athletic Club"': 32,
#  'Wish I could have known you more': 32,
#  "the Women's Western Golf Classic": 32,
#  'a Senate Investigating Committee': 32,
#  '"""Is Shari Good Enough for Ed?"': 32,
#  'Laguna Jamming Custom Surfboards': 32,
#  'the Traditional Harvest Offering': 32,
#  'the Office of Naval Intelligence': 32,
#  'University for an MBA in Finance': 32,
#  'the Security Exchange Commission': 32,
#  'the National Intelligence Agency': 32,
#  'the Starfleet corps of engineers': 32,
#  'the Congressional Medal of Honor': 32,
#  'Janine Janine JanineJanineJanine': 32,
#  'The Food and Drug Administration': 32,
#  'the Canadian Medical Association': 32,
#  'the Institute for Mental Therapy': 32,
#  '"""The Number Four With a Smile"': 32,
#  'KingĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97King Westley': 32,
#  'The Writings of Saint Thomas Aqu': 32,
#  'The Caveman Against the Cavalier': 32,
#  'the Western Manhattan Warehouses': 32,
#  '"""You rat you are the murderer"': 32,
#  'the Whittier Community Playhouse': 32,
#  '"""The Relighting of the Tree"""': 32,
#  'Washington Crossing the Delaware': 32,
#  'the Universe Space or Space-Time': 32,
#  'the North Shore Clothing Company': 32,
#  'Joseph Mengele Franklin Pangborn': 32,
#  '"Write write--""""""""""""""""I"': 32,
#  'I Just Called To Say I Loved You': 32,
#  '"""Beth the message said Harry."': 32,
#  '""" You\'ve seen only one movie?"': 32,
#  '"""Happy Birthday Somebody Else"': 32,
#  'the Huntington Memorial Hospital': 32,
#  'the Department of Motor Vehicles': 32,
#  'the Nuclear Regulatory Commition': 32,
#  '""" Is Sunshine your real name?"': 32,
#  '"""Please Eddie do this for me."': 32,
#  'the Seminole Negro Indian Scouts': 32,
#  "Now I'm shopping for Aqua Salmon": 32,
#  '"""The Whole Thing\'s Theatre..."': 32,
#  '"""Life is crushing in on me."""': 32,
#  'this Theater of Mass Destruction': 32,
#  'longerĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Why Cyril': 32,
#  '"""The sentence that started """': 32,
#  'Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96Ă\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x96': 32,
#  'Washington Bartholomew Hogwallop': 32,
#  'the kidsĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92 recital': 32,
#  'the National Criminal Sperm Bank': 32,
#  'the International Same Name Club': 32,
#  'Ladies and Gentlemen of the Jury': 32,
#  'the United Federation of Planets': 32,
#  'I am the Law and I am the Danish': 32,
#  'And Death Shall Have No Dominion': 32,
#  '""" A Complaint Follow-Up form."': 32,
#  'The Office of Naval Intelligence': 32,
#  'I Want to make things up to you.': 32,
#  '""" She\'s the prettiest y\'know."': 32,
#  'the Department of Transportation': 32,
#  'thatĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Unconscious': 32,
#  'the United States Secret Service': 32,
#  'the Ministry of Public Security': 31,
#  'preÄ\x82Â\x84Ă\x82Â\x82Ă\x84ĹĄĂ\x82Â\x82sold Alabama': 31,
#  'Robbery Detail Inspector Dayton': 31,
#  'Glades Correctional Institution': 31,
#  '""" You want to be rich right?"': 31,
#  'the Central Intelligence Agency': 31,
#  'article 184 of Interstellar Law': 31,
#  '"""Alright Cage you\'ve got me."': 31,
#  'The Graveyard to Indian Country': 31,
#  "You're gonna die tonight faggot": 31,
#  'the Call Building San Francisco': 31,
#  'the Brown & Williamson Building': 31,
#  '"""The Chinese Professionals"""': 31,
#  'the Loveless Steam Engine Works': 31,
#  '""" That\'s what I call justice"': 31,
#  'Commissar on the Board of Trade': 31,
#  'Harvard School of Medicine 1939': 31,
#  "Sheriff Hartman's Bombing Squad": 31,
#  'Humphrey Bogart Harley Davidson': 31,
#  'Little Lebowski Urban Achievers': 31,
#  "World's Fair at Flushing Meadow": 31,
#  'Madame Josephine de Beauharnais': 31,
#  'The Department of Public Health': 31,
#  'Casewell Insurance Underwriters': 31,
#  'David -- Especially Tiger Woods': 31,
#  'the Whig Party of Cross Corners': 31,
#  "Nah 'cause I had my comic books": 31,
#  'Ladysmith at Nukden Port Arthur': 31,
#  'I was gonna pin it to your wall': 31,
#  'Precise equipmentĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82': 31,
#  "Sue Ann Rogers Betty Sizemore's": 31,
#  "Uncle Terrence you're... AHHH!!": 31,
#  '""" ON BREAN, WHO IS DOODLING."': 31,
#  'Federal Bureau of Investigation': 31,
#  'Constitution and Bill of Rights': 31,
#  'The Host of the Old South Hotel': 31,
#  'I thought you had Play Practice': 31,
#  '""" The Jimmy Stewart picture?"': 31,
#  '"""Your Grampa is going to die"': 31,
#  'the National Geographic Society': 31,
#  '"""Declaration of Independence"': 31,
#  'International Satellite Systems': 31,
#  'the Stratosphere Hotel & Casino': 31,
#  'the Universitatus Committeeatum': 31,
#  'Linen Supply Business or Cement': 31,
#  '"""That\'s what he\'s here for"""': 31,
#  'Sandefur and Brown & Williamson': 31,
#  'Melissa Margaret Marr Celebrity': 31,
#  'Blow Job Queen of the Tri-State': 31,
#  '"""Return of the Streetfighter"': 31,
#  '""" Oh Frank I\'m not anti-male"': 31,
#  'the Vancouver Police Department': 31,
#  'The Las Vegas Police Department': 31,
#  'cheap-- Yup a Benthic Petroleum': 31,
#  'The Lone Ranger Sarah Bernhardt': 31,
#  '"""The Lone Rider of Santa Fe?"': 31,
#  '""" It\'s A C zero zero five."""': 31,
#  '"""Goddamn right that\'s right."': 31,
#  'Raymond Levoi Criminal Division': 31,
#  'the Chinese National Conference': 31,
#  'First Federal Bank of Manhattan': 31,
#  'ASK ME A QUESTION ABOUT MY LIFE': 31,
#  'Romeo isĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x85Italian': 31,
#  "Studs because that's what's on.": 31,
#  '"""Coming Home in a Body Bag"""': 31,
#  '"""Customs Agents get blown up"': 31,
#  'the Archdiocese Eddie Concannon': 31,
#  "the 'Pappy O'Daniel Flour Hour'": 31,
#  'Sports Phone like every hour on': 31,
#  'the Warriors of All Red Nations': 31,
#  'I Just Called To Say I Love You': 31,
#  'the Northern Fucking Hemisphere': 31,
#  'What the fuck am I doing here?': 30,
#  'tashabararassssssuuuuusaaaaaaa': 30,
#  'Yeah for the last time I hope.': 30,
#  'U.S. ARMY RESEARCH LABORATORY/': 30,
#  'the Union-Leeds - the Exchange': 30,
#  'Brits Arabs Hungarians Germans': 30,
#  'The Freedom of Information Act': 30,
#  'the Department of the Interior': 30,
#  'Mohammed Ali Paula Abdul Rahim': 30,
#  '""" Scared of Oswald are you?"': 30,
#  'Mike Ditka Sensitivity Seminar': 30,
#  '"""Look I really love you and"': 30,
#  'the University in the Old Town': 30,
#  '"""Leonardo\'s Greatest Hits"""': 30,
#  '""" You read Harry\'s new one?"': 30,
#  "Johnnie-Come-Latelies braggin'": 30,
#  'the Kiersey Temperament Sorter': 30,
#  'the Knights of the Round Table': 30,
#  '"""You said: that you have """': 30,
#  'the State House Courtroom Nine': 30,
#  '"""The grand productive days."': 30,
#  'The World Council of Ministers': 30,
#  'St. Catherine Laboure Hospital': 30,
#  'The National Flower of Albania': 30,
#  'choisi moi-mĂ\x84Â\x82Ă\x82Â\x84Ä\x82Â\x82Ă\x82Â\x99me': 30,
#  'the Door Number Three Syndrome': 30,
#  'The New York Pneumatic Railway': 30,
#  "'The Psychiatrist and the Law'": 30,
#  'The Flower That Drank The Moon': 30,
#  'the Friends of Democratic Cuba': 30,
#  'this Neighborly Life Insurance': 30,
#  'the Royal Geographical Society': 30,
#  '"""This guy was a bad monkey."': 30,
#  'those Little Dirty Comic Books': 30,
#  'Radio Announcer a Sportswriter': 30,
#  'Gateway Lab St. Louis Missouri': 30,
#  'The Center for Disease Control': 30,
#  'Cowan-- Sir before you boot me': 30,
#  'Bennington Harrisville Acworth': 30,
#  'Riverhead Veterans Psychiatric': 30,
#  'the Center For Disease Control': 30,
#  'Page eightyĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97six': 30,
#  'the Environmental Control Room': 30,
#  'G.G. Market one-eight-four-two': 30,
#  'avez recommandÄ\x82Â\x84Ă\x82Â\x82Ă\x84ĹĄĂ\x82Â\xa0': 30,
#  'Bob Barrenger Claire Wellesley': 30,
#  'Mount Pyramid the Grand Canals': 30,
#  'Thunder Road Bruce Springsteen': 30,
#  "Leon's in a bad mood don't get": 30,
#  'the Minnesota Modeling Academy': 30,
#  "the United States Government's": 30,
#  'Joe listenĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Get': 30,
#  'A Childhood behind Golden Bars': 30,
#  '"""That\'s why they call it """': 30,
#  'the Chicago Symphony Orchestra': 30,
#  '"""How to Plant Perennials."""': 30,
#  "M.J They're not talking to me.": 30,
#  '"""No ballplayer ever said """': 30,
#  'the River Shore Birdie Steptoe': 30,
#  'Dew yew hayuv ah-dentifikyshun': 30,
#  'Easthampton Hospital for Women': 30,
#  "America's Funniest Home Videos": 30,
#  '"""Victor Laszlo apprehended."': 30,
#  '"Home Cooking"""""""""""""""""': 30,
#  'the Army Nursing Corps Captain': 30,
#  'Administration Ensign Blondell': 30,
#  'the Shaughnessy Heights Course': 30,
#  'the dukeĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x85Orsino': 30,
#  'Jasper Lamar Crabb 25000 acres': 30,
#  '""" You\'re a thinking person."': 30,
#  'Hoffa - Trafficante - Marcello': 30,
#  'Directing <u>is</u> my day job': 30,
#  'the Chocamunga Cracker Killers': 30,
#  'American Journal of Psychology': 30,
#  'Jean Baptiste Poquelin Moliere': 30,
#  'Delinquent Property Tax Notice': 30,
#  'Mademoiselle Michelle Beaufort': 30,
#  'the Foreign Policy Association': 30,
#  'The Great Jerk-Off Book Caper': 29,
#  '"""Look I\'m sorry about this"': 29,
#  '""" It\'s me or Wallace Jack."': 29,
#  'Fine Arts University of Tokyo': 29,
#  'the Bureau of Missing Persons': 29,
#  'the Master of the Bogan Force': 29,
#  'Mimi Jorgensen Morelli Tanner': 29,
#  'Central Collective Storehouse': 29,
#  'the Car Thief Retirement Home': 29,
#  "the National Puppet Company's": 29,
#  "Inaugural Speech press corp's": 29,
#  '"""Old Macdonald... had --"""': 29,
#  'Razinin Board of Trade Moscow': 29,
#  'The Paper Street Soap Company': 29,
#  'the American Bowling Congress': 29,
#  'Barclay Hotel on River Street': 29,
#  "Dead Man's Curve Jan and Dean": 29,
#  'the Oakland Police Department': 29,
#  'The Marriage Guidance Council': 29,
#  'the Constitutional Convention': 29,
#  '"""Blazing Guns of the West."': 29,
#  'melodramaticĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x85 ': 29,
#  'BÄ\x82Â\x84ÄšÄ\x84Ä\x82Â\x82Ă\x82Â\x95ader-Meinhof': 29,
#  'the Blonde Legal Defense Fund': 29,
#  'Modern Homicide Investigation': 29,
#  'Graverobbers From Outer Space': 29,
#  'Timmy Tommy Joey Robby Johnny': 29,
#  'the Japanese Community Center': 29,
#  'the National Cancer Institute': 29,
#  '""" You put it all on paper."': 29,
#  'Consumer Recrreation Services': 29,
#  'delle disdicevoli circostanze': 29,
#  'Win-an-Emmy Social Conscience': 29,
#  'the Manchester Cotton Company': 29,
#  'the Ludovico Medical Facility': 29,
#  '""" I\'m going to the Chinks."': 29,
#  'the French Polynesian Pacific': 29,
#  'Monsieur Mesdames Bon appetit': 29,
#  'a Declaration of Independence': 29,
#  'Enemy Armada Off Jersey Coast': 29,
#  '""" Nice guys but I\'m cheap."': 29,
#  'McLean versus Urban Transport': 29,
#  'the National Security Council': 29,
#  '"""Am I supposed to do that?"': 29,
#  '"""Accident and Compensation"': 29,
#  'Lucy In The Sky With Diamonds': 29,
#  'Harry Harry Harry Harry Harry': 29,
#  'Locke Vattel Voltaire Diderot': 29,
#  'friendsĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Maybe': 29,
#  'the Chicago Police Department': 29,
#  "'Reform the Reds With a Rope'": 29,
#  'the Museum of Natural History': 29,
#  '""" No the Mediocre Mantini."': 29,
#  'Brindisi versus Electric Boat': 29,
#  '""" That\'s twenty feet high."': 29,
#  '"""You did this to yourself."': 29,
#  'the Christine Jorgensen Story': 29,
#  'The Museum of Natural History': 29,
#  'THE GROUP WATCHING TELEVISION': 29,
#  'a John DoeĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97and': 29,
#  'Cyberdyne Systems Corporation': 29,
#  'Slow-Moving Dipping Mechanism': 29,
#  'the Seventeen Point Agreement': 29,
#  'Herbert Richard Greenleaf 1st': 29,
#  'Federal Communications Office': 29,
#  '"""Nickel Nick\'s Slot Arcade"': 29,
#  'the Sex Pistols on Kings Road': 29,
#  'James F. Grantz John G. Check': 29,
#  '"""""""""""""""""Gee Wichita"': 29,
#  'The Elite Special Forces Unit': 29,
#  'Mrs De MoraesĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x92': 29,
#  'the Fenelon-Barnes Slave Knot': 29,
#  'Military Intelligence Command': 29,
#  'The Hound of the Baskervilles': 29,
#  'THE GIRDERS Stonefaced MELTON': 29,
#  '""" Okay. I wasn\'t finished."': 29,
#  'Row Row Row Row Row Your Boat': 29,
#  'Benjamin Franklin High School': 29,
#  'Come to Me My Melancholy Baby': 29,
#  'Mustang Shelby Mustang GT-500': 29,
#  'The Mounties Guard The Border': 29,
#  'Leonard Nero Security Express': 29,
#  'Mount Lavinia Hospital Ceylon': 29,
#  '"""You start tomorrow night."': 29,
#  'the State Certification Board': 29,
#  "the O'Higgins of Redmondstown": 29,
#  'the ABC Telemarketing Company': 29,
#  "Please...Please don't stop me": 29,
#  '"""The Old Man and the Sea"""': 29,
#  'Harvard Bellevue John Hopkins': 29,
#  '"""How do I kill this bunny?"': 29,
#  'of the Master Control Program': 29,
#  'Maureen Prescott Billy Loomis': 29,
#  '""" And the Statie\'s like """': 29,
#  '""" Quite a night Inspector."': 29,
#  'DicksonĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Helen': 29,
#  'Port Royal not Isla de Muerta': 29,
#  'the Famous Curb Service Whore': 29,
#  'The Dobbins Kirk Line Halifax': 29,
#  'the Child Protective Services': 29,
#  'witnesses for the prosecution': 29,
#  'Alan Seagrave Donald Cosgrove': 29,
#  '""" Were the mid-terms hard?"': 29,
#  'the Hood and Arthur Pendragon': 29,
#  'Royal Hospital for Incurables': 29,
#  'StewĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Goodbye': 28,
#  'Der ami macht mich noch ganz': 28,
#  'the Nazi Ministry of Culture': 28,
#  'hikingĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97 Hitch': 28,
#  'the National Baseball League': 28,
#  'The Project for the Children': 28,
#  'Alert Starfleet Headquarters': 28,
#  'the Department of Sanitation': 28,
#  'slimedogs selling angel dust': 28,
#  'Charlie Nicholas David Niven': 28,
#  'Sehen sie da gleich da unter': 28,
#  'Potential Brown & Williamson': 28,
#  '"Jack""""""""""""""""--that"': 28,
#  'the Holy Mother the Clarence': 28,
#  'the International Convention': 28,
#  'gloveĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97flopped': 28,
#  "I thought I'd find you here.": 28,
#  'Red G-Grange Red Str-Strange': 28,
#  'the Douglas Exhibition Shaft': 28,
#  '"""The Harold Ryan Fan Club"': 28,
#  '"""He\'s making himself a """': 28,
#  'The Tranquilizer Tranquility': 28,
#  '"""Blood Sweat and Canvas"""': 28,
#  'Shirley Petals of South Bend': 28,
#  'the Medical Records Division': 28,
#  'Billy Palestinian Guerrillas': 28,
#  'the Pleasantville Town Hall:': 28,
#  'From Transexual Transylvania': 28,
#  'the American Bar Association': 28,
#  'Icthyo Sapiens April 14 1865': 28,
#  'miserableĂ\x84Â\x82Ă\x82Â\x82Ä\x82Â\x82Ă\x82Â\x97and': 28,
#  'The United States Government': 28,
#  '"""Modern American Poetry"""': 28,
#  'Appropriation Liaison Office': 28,
#  'The Criminal Courts Building': 28,
#  '"""The Angel of Flight 104!"': 28,
#  '"""They\'re all the same. """': 28,
#  'the Massachusetts Delegation': 28,
#  'The Behavioral Sciences Unit': 28,
#  'Joseph Emperor Joseph Statue': 28,
#  'these Revolutionary Brothers': 28,
#  'the Wicked Witch of the West': 28,
#  'the County of the Land of Oz': 28,
#  'the Charlestown State Prison': 28,
#  'the Royal Zoological Society': 28,
#  'the Old Lakeville Road Group': 28,
#  'the Road Research Laboratory': 28,
#  '""" You\'re a wonderful man."': 28,
#  'the National Security Agency': 28,
#  'the Wicked Witch of the East': 28,
#  'Disappearing-Reappearing Ink': 28,
#  'Austen Platt Jaret & Donovan': 28,
#  'the White House Advance Team': 28,
#  'a Global Positioning Tracker': 28,
#  ...}

# %%
def remove_entity(corpus):
    corpus = corpus.split(' ')
    corpus = [c for c in corpus if c not in list(dict.keys())]
    return ' '.join(corpus)

# %% [raw]
# %%time
# messages['msg_pre_processed'] = [remove_entity(m) for m in list(data)]

# %%
#chepoint
messages.to_csv('./chatdata/movie_lines_pre_processed.tsv', index=False, sep='\t', header=True)

# %% [markdown]
# ### Opening conversation sequence

# %%
#read the file with the conversation sequence
conv_seq = pd.read_csv('./chatdata/movie_conversations.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
conv_seq.columns = ['user1_id', 'user2_id', 'movie_id', 'sequence']

# %%
conv_seq.head(10)
# Out:
#   user1_id user2_id movie_id                              sequence
# 0       u0       u2       m0         ['L194' 'L195' 'L196' 'L197']
# 1       u0       u2       m0                       ['L198' 'L199']
# 2       u0       u2       m0         ['L200' 'L201' 'L202' 'L203']
# 3       u0       u2       m0                ['L204' 'L205' 'L206']
# 4       u0       u2       m0                       ['L207' 'L208']
# 5       u0       u2       m0  ['L271' 'L272' 'L273' 'L274' 'L275']
# 6       u0       u2       m0                       ['L276' 'L277']
# 7       u0       u2       m0                       ['L280' 'L281']
# 8       u0       u2       m0                       ['L363' 'L364']
# 9       u0       u2       m0                       ['L365' 'L366']

# %%
conv_seq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83097 entries, 0 to 83096
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user1_id  83097 non-null  object
#  1   user2_id  83097 non-null  object
#  2   movie_id  83097 non-null  object
#  3   sequence  83097 non-null  object
# dtypes: object(4)
# memory usage: 2.5+ MB

# %%
conv_seq.describe()
# Out:
#        user1_id user2_id movie_id               sequence
# count     83097    83097    83097                  83097
# unique     5420     5608      617                  83097
# top       u4331    u1475     m289  ['L657815' 'L657816']
# freq        193      187      338                      1

# %% [markdown]
# ### Build conversation sequence

# %%
def split_conversation(txt):
    txt_alt = txt.split(' ')
    return txt_alt

# %%
def seq_to_list(seq):
    seq_list = [remove_char(s) for s in seq]
    return seq_list

# %%
#initializing the msg_2 column
messages['msg_2'] = '-'

# %%
def link_conversations(seq_list, df, filter1, filter2):
    i = 0
    while i in range(len(seq_list)):
        if i+1 < len(seq_list):
            next_msg = df.loc[int(seq_list[i+1]), filter1]
            df.at[int(seq_list[i]), filter2] = next_msg
        i+=1

# %%
#link each message with its answer
for conv in conv_seq['sequence']:
    #split each sequence by space
    seq = split_conversation(conv)

    #remove the char L from the sequences
    txt_alt = [remove_char(s) for s in seq]

    #use the conversation sequence to build the target answer for each message
    link_conversations(txt_alt, messages, 'msg', 'msg_2')

# %%
messages.head(30)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
# 78                  L78      u7       m0
# 87                  L87      u2       m0
# 88                  L88      u7       m0
# 89                  L89      u2       m0
# 90                  L90      u7       m0
# 91                  L91      u2       m0
# 92                  L92      u7       m0
# 103                L103      u8       m0
# 104                L104      u5       m0
# 105                L105      u8       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 89                                                    Who is she?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 91                                                       Why not?
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...
#
#                                                             msg_2
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                                              -
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                                              -
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                                              -
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                                              -
# 77              Yeah but these guys have never seen a horse. T...
# 78                                                              -
# 87                                  You burn you pine you perish?
# 88                                                    Who is she?
# 89              Bianca Stratford. Sophomore. Don't even think ...
# 90                                                       Why not?
# 91              I could start with your haircut but it doesn't...
# 92                                                              -
# 103              Expressing my opinion is not a terrorist action.
# 104             Well yes compared to your other choices of exp...
# 105             I still maintain that he kicked himself in the...

# %% [markdown]
# ## Pre processing the msg

# %%
data = messages['msg']

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
lemmatizer = WordNetLemmatizer()
def pre_processing_text(corpus):
    #remove html tags
    corpus = re.sub(r'<.*?>', '', str(corpus))
    
    #remove non-alphanumeric characters
    corpus = re.sub(r'[^a-z A-Z 0-9 \s]', '', str(corpus))
    
    #remove duplicated spaces
    corpus = re.sub(r' +', ' ', str(corpus))
    
    #capitalization
    corpus = corpus.lower()
    
    #tokenization
    corpus = re.findall(r"\w+(?:'\w+)?|[^\w\s]", corpus)
    
    #lammatization
    corpus = [lemmatizer.lemmatize(c, get_wordnet_pos(c)) for c in corpus]
    
    #remove punctuation
    corpus = [t for t in corpus if t not in string.punctuation]
    
    #remove stopwords
    #it makes the model worst
    stopwords_ = stopwords.words("english")
    corpus = [t for t in corpus if t not in stopwords_]
    
    corpus = ' '.join(corpus)

    return corpus

# %%
# %%time
data_pre_processed = [pre_processing_text(str(m)) for m in data]
data_pre_processed
# Out:
# CPU times: user 8min 59s, sys: 3min 42s, total: 12min 42s
# Wall time: 12min 45s
# ['change hair',
#  '',
#  'might wanna think',
#  'miss',
#  'say expose group freshman girl',
#  'bratwurst eat lunch',
#  'teeth zipper',
#  'new guy',
#  'tell',
#  'cmon im suppose give tour',
#  'dakota',
#  'north actually howd',
#  'kid people actually live',
#  'yeah couple outnumber cow though',
#  'many people old school',
#  'thirtytwo',
#  'get',
#  'many people go',
#  'couple thousand evil',
#  'im use',
#  'yeah guy never see horse jack clint eastwood',
#  'girl',
#  'burn pine perish',
#  '',
#  'bianca stratford sophomore dont even think',
#  '',
#  'could start haircut doesnt matter shes allow date old sister thats impossibility',
#  'katarina stratford youve terrorize blaise',
#  'express opinion terrorist action',
#  'well yes compare choice expression year today event quite mild way bobby rictors gonad retrieval operation go quite well case youre interested',
#  'still maintain kick ball merely spectator',
#  'point kat people perceive somewhat',
#  'tempestuous',
#  'believe heinous bitch term use often',
#  '',
#  'patrick verona random skid',
#  'thats pat verona one go year heard porn movie',
#  'im sure completely incapable anything interest',
#  'always look',
#  'block e',
#  'mandella eat starve slow way die',
#  'little',
#  'whats',
#  'attempt slit',
#  'realize men fine institution severely lack kill william shakespeare beyond scope normal teenage obsession youre venture far past daytime talk show fodder enter world need expensive therapy',
#  'imagine thing hed say sex',
#  'girl like always like guy like',
#  'theyre breed mother like guy like grandmother gene pool rarely dilute',
#  'always shiteating grin',
#  'joey dorsey permashitgrin wish could say moron number twelve class model mostly regional stuff rumor big tube sock ad come',
#  'know french',
#  'sure mom canada',
#  'guess sign tutor',
#  'mean id get chance talk',
#  'could consecrate friend',
#  'vintage look kat havent reading sassy',
#  'yeah notice part feature big kmart spread elbow tough break',
#  'theyre run rest next month',
#  'people school incredibly foul',
#  'could always go im sure william friend',
#  'yeah minor encounter shrew',
#  'thats biancas sister',
#  'mewl rampalian wretch',
#  'microwave',
#  'make anyone cry today',
#  'whereve',
#  'nowhere hi daddy',
#  'whats synonym throb',
#  'sarah lawrence side country',
#  'know',
#  'thought decide go school u 0',
#  'decide',
#  'dont get upset daddy boy think might ask',
#  'youre date sister start date end discussion',
#  'never start date',
#  'neither ill get sleep night',
#  'fair shes mutant daddy',
#  'someone whose diary devote favorite groom tip',
#  'enough',
#  'doesnt want date',
#  'exactly point',
#  'jesus man even grab sandwich woman start dilate',
#  'tumescent',
#  'youre help',
#  'make quick roxanne korrine andrew barrett incredibly horrendous public break quad',
#  'well thought wed start pronunciation thats okay',
#  'hack gag spit part please',
#  'okay bout try french cuisine saturday night',
#  'youre ask thats cute whats name',
#  'forget',
#  'fault didnt proper introduction',
#  'cameron',
#  'thing cameron im mercy particularly hideous breed loser sister cant date',
#  'seem like could get date easy enough',
#  '',
#  'unsolved mystery use really popular start high school like get sick something',
#  'thats shame',
#  'gosh could find kat boyfriend',
#  'let see',
#  'teach french get know dazzle charm fall love',
#  'unlikely even still cant go whats point',
#  '',
#  'wanna go',
#  'make think hell',
#  'seem like thrives danger',
#  'kid criminal heard lit state trooper fire get alcatraz',
#  'always let felon sit honor biology',
#  'im serious man whack sell liver black market could buy new speaker',
#  'forget reputation think weve get plan',
#  'actually say shed go',
#  'thats say',
#  'know go bianca youd set youd outrank everyone strictly alist side',
#  'thought hat people',
#  'hey ive gotta client get wall street',
#  'hey',
#  'lose',
#  'nope come chat',
#  'dont chat',
#  'well actually thought id run idea know see youre interested',
#  '',
#  'cant go sister insane head case one go right',
#  'conversation purpose',
#  'need recruit guy wholl go someone job',
#  'get involve',
#  'like choice besides let enemy think orchestrate battle youre position power let pretend call shot busy set plan time woo bianca',
#  'huge rag fit sarah lawrence insists go maledominated puke frat boy number one golf team school say',
#  'william would never go state school',
#  'william didnt even go high school',
#  'thats never proven',
#  'neither heterosexuality',
#  'appreciate effort toward speedy death im consume mind',
#  'matter',
#  'bianca would school want precious dont forget tiara',
#  'dont understand patrick havent anything asinine week feel well',
#  'touch flu',
#  'im loss talk year absence',
#  'dont discus drive need hemorrhoid',
#  'whats discus',
#  'werent abuse arent stupid far tell youre slightly psychotic youre fuckup',
#  'well know prestige job title benefit package pretty good',
#  'cesc tete head',
#  'right see youre ready quiz',
#  'dont want know say though want know useful thing like good store much champagne cost stuff like chat never life point head someone',
#  'thats nice one',
#  'forget french',
#  'little find wench date plan progress',
#  'well someone think might',
#  '',
#  '',
#  'yeah',
#  'think',
#  'two leg nice rack',
#  'yeah whatever want go',
#  'sure sparky ill get right',
#  'say',
#  'need money take girl',
#  'youd go cake',
#  'get verona pick tab honor',
#  'youre gonna pay take girl',
#  'cant date sister one get boyfriend thats catch doesnt want boyfriend',
#  'much',
#  'cant take girl like twenty buck',
#  'fine thirty',
#  'take leave isnt negotiation',
#  'fifty youve get man',
#  'mean woman ya doin',
#  'sweat like pig actually',
#  'way get guy attention',
#  'mission life',
#  'pick friday',
#  'oh right friday',
#  'night take place youve never back',
#  'like 7eleven burnside even know name screwboy',
#  'know lot',
#  'potential smack crap dont get way',
#  'least start wear bra',
#  'hate dont',
#  'dont really think warrant strong emotion',
#  'say youll spend dollar night track',
#  'would',
#  'come pony flat beer money eye hand',
#  'cover vomit',
#  'seventhirty',
#  'follow',
#  'laundromat saw car thought id say hi',
#  'hi',
#  'youre big talker',
#  'depends topic fender dont really whip verbal frenzy',
#  'hey mind',
#  '',
#  'insurance cover pm',
#  'tell seizure',
#  'sarah lawrence punish',
#  'thought punish',
#  'cant agree',
#  'youre make decision',
#  'parent thats right',
#  'want doesnt matter',
#  'youre eighteen dont know want wont know youre fortyfive dont',
#  'want go east coast school want trust make choice want',
#  'shell fifty expect result',
#  'im',
#  'watch bitch trash car doesnt count date',
#  'get control act craze public keep image',
#  'upped price',
#  '',
#  'hundred buck date',
#  'forget',
#  'forget sister',
#  'get something mind',
#  'count help cause thug obviously fail arent ever go date',
#  'word gentleman',
#  'youre sweet',
#  'get hair look like',
#  'ebers deep conditioner every two day never ever use blowdryer without diffuser attachment',
#  'say',
#  '',
#  'whatever hell youre standin waitin say',
#  'plan',
#  'situation man cameron major jones bianca stratford',
#  'chick three tit',
#  'think speak correctly say camerons love pure purer say joey dorseys',
#  'dorsey plow whoever want im cash',
#  'thats help kat',
#  'dorsey get girl',
#  'patrick pat youre look big picture joeys pawn set whole thing cameron get girl',
#  'two gonna help tame wild beast',
#  'guy',
#  'mean strictly non prisonmovie type way',
#  'yeah well see',
#  'golden opportunity patrick ask katarina party',
#  'case well need make schoolwide blow',
#  'bogey get bent',
#  'kid hell piss joy ultimate kiss',
#  '',
#  'expensive',
#  'exactly go bogey lowenbraus thing saturday',
#  'hopefully',
#  'sure',
#  'really really really wanna go cant unless sister go',
#  'im workin doesnt seem goin',
#  'shes',
#  'lesbian found picture jared leto one drawer im pretty sure shes harbor samesex tendency',
#  'thats kind guy like pretty one',
#  'know ive ever heard say shed dip date guy smoke',
#  'whatve get',
#  'ive retrieve certain piece information miss katarina stratford think youll find helpful',
#  '',
#  'good enough',
#  'number one hate smoker',
#  'lung cancer issue',
#  'favorite uncle',
#  'dead fortyone',
#  'tell im nonsmoker',
#  '',
#  'pretty',
#  'okay wasnt sure',
#  'okay like thai food feminist prose angry stinky girl music indierock persuasion',
#  'give im suppose buy noodle book sit around listen chick cant play instrument',
#  'ever club skunk',
#  'yeah',
#  'gigglepuss play tomorrow night',
#  'dont make man',
#  'assail ear one night',
#  'favorite band',
#  'prefer think simply alternative law allows',
#  'im likin guy well',
#  'oh god mean youre become normal',
#  'mean gigglepuss play club skunk go',
#  'oh thought might date dont know im bother ask go bogey lowensteins party saturday night',
#  'think',
#  'think youre freak think torture think suck',
#  'think thisll work',
#  'fear',
#  'always pleasure brucie',
#  'didnt pegged gigglepuss fan arent little preteen bellybutton ring',
#  'fan fan see couple minor come',
#  'never',
#  'padua girl one tall decent body one kinda short undersexed',
#  'sent em',
#  'hey great show huh',
#  'unknown',
#  'excuse',
#  'thats want isnt',
#  'mind youre sort ruin',
#  'know guy bikini kill raincoat theyre right',
#  'know raincoat',
#  'dont',
#  'whatd say',
#  'care',
#  'told part already',
#  'hell ive go whole thing head',
#  'hear youre helpin verona',
#  'uh yeah old friend',
#  'verona',
#  'take bathe together kid',
#  'well fuck im heavily invest',
#  'hey high good right',
#  'youre completely demented',
#  'see next week',
#  'daddy',
#  'wherere go',
#  'must know attempt go small study group friend',
#  'otherwise know orgy',
#  'party daddy knew youd forbid go since gloria steinem isnt go',
#  'daddy people expect',
#  'kat go youre go',
#  'youre ruin life wont normal cant normal',
#  'whats normal',
#  'bogey lowensteins party normal youre busy listen bitch need prozac know',
#  'cant forget one night youre completely wretched',
#  'least im clout fen suck hedgepig',
#  'like im suppose know even mean',
#  'shakespeare maybe youve heard',
#  'yeah freak friend mandellas boyfriend guess since im allow go ob dead guy',
#  'oh god start',
#  'party daddy',
#  'wear belly go',
#  'daddy',
#  'minute',
#  'completely unbalanced',
#  'go',
#  'promise wont talk boy unless sister present',
#  '',
#  'shell scare away',
#  'ya goin',
#  'away',
#  'sister',
#  'leave sister alone',
#  'would',
#  'whats',
#  'im get trash man isnt youre suppose party',
#  'say wanna',
#  'funny youre one',
#  'go',
#  '',
#  'joey',
#  'hi',
#  'look like thing work tonight huh',
#  'know chastity',
#  'believe share art instructor',
#  'great',
#  'would mind get drink cameron',
#  'extremely unfortunate maneuver',
#  'hell kind guy pick girl carry away youre talk',
#  'buttholus extremus hey youre make progress',
#  '',
#  'yeah ive get sears catalog thing go tube sock gig thats gonna huge im ad queen harry next week',
#  'queen harry',
#  'gay cruise line ill like wear uniform stuff',
#  'neat',
#  'agent say ive get good shot prada guy next year',
#  'practically propose found dermatologist mean dr bonchowski great exactly relevant party conversation',
#  'oily dry',
#  'combination dont know thought hed different gentleman',
#  'bianca dont think highlight date joey dorsey go include dooropening coatholding',
#  'sometimes wonder guy suppose want go one actually want go know',
#  'know id give private line go guy like joey',
#  'bianca need talk need tell',
#  'really dont think need social advice right',
#  'time',
#  'deal deal',
#  'howd',
#  '',
#  'get act like human',
#  'okay',
#  'im fine im',
#  'youre okay',
#  'need lie awhile',
#  'uh uh lie youll go sleep',
#  'know let sleep',
#  'concussion dog go sleep concussion woke vegetable could tell difference',
#  'cameron im little busy',
#  'whole thing',
#  'talk',
#  'shes partial joey',
#  'cameron like girl',
#  'sure',
#  'go get',
#  'patronize',
#  'leave use big word youre shitfaced',
#  '',
#  'told',
#  'dont care die',
#  'sure',
#  '',
#  'id start take girl like',
#  'like could find one',
#  'see need affection ive get blind hatred',
#  'let sit',
#  'whyd let get',
#  '',
#  'dorsey',
#  'hate',
#  'know itd pretty big deal get mainline tequila dont seem like type',
#  'hey man think cool dont think laid back like everyone else',
#  'thought',
#  'know say',
#  'kat wake',
#  '',
#  'dont get act like youre good go totally apeshit get',
#  'youre welcome',
#  'home twenty minute',
#  'dont home til two',
#  'fun tonight',
#  'ton',
#  'im control',
#  'gigglepuss know like saw',
#  'go last year',
#  'busy',
#  'jail',
#  'maybe',
#  'werent',
#  'whyd ask',
#  'whyd lie',
#  '',
#  '',
#  '',
#  'start band',
#  'father wouldnt approve',
#  'dont strike type would ask permission',
#  'oh think know',
#  'im gettin',
#  'dad pain',
#  'want someone im',
#  '',
#  'bianca',
#  'offense youre sister without know everyone like',
#  'look back party always seem occupy',
#  '',
#  'never want go',
#  'well',
#  'thats say',
#  '',
#  'always selfish',
#  'go party thought officially oppose suburban social activity',
#  'didnt choice',
#  'didnt choice wheres kat',
#  'bianca favor backfire',
#  'didnt',
#  'get drunk puked get reject big fun',
#  'get cozy sting',
#  'ive get sweetpayin job im lose',
#  'whatd',
#  'know decide nail drunk remember',
#  'hey tire breathing',
#  'hi',
#  'cool picture fan',
#  'yeah guess',
#  'think',
#  'oh yeah',
#  'macbeth right',
#  'right',
#  'kat fan',
#  'yeah',
#  'hate fire thousand sun thats direct quote',
#  'need time cool ill give day',
#  'makin headway',
#  'kiss',
#  '',
#  'dont know dorsey limothe flower another hundred tux',
#  'enough barbie n ken shit know',
#  'even imagine hell would go bastion commercial excess',
#  'well guess since dont date',
#  'listen sound like betty piss archie take veronica',
#  'okay okay wont go like dress anyway',
#  'look wrong perspective make statement',
#  'oh good something new different u',
#  'hey sweet cheek',
#  'hi joey',
#  'youre concentrate awfully hard consider gym class',
#  'listen want talk prom',
#  'know deal go kat doesnt go',
#  'excuse see feminine mystique lose copy',
#  '',
#  'heard poetry reading',
#  '',
#  'pleasant',
#  'wholesome',
#  'unwelcome',
#  'unwelcome guess someone still panty twist',
#  'dont one minute think effect whatsoever panty',
#  'effect',
#  'upchuck reflex nothing',
#  'right shes still piss',
#  'sweet love renew thy force',
#  'man dont say shit like people hear',
#  'humiliate woman sacrifice altar dignity even score',
#  'best case scenario youre back payroll awhile',
#  'whats bad',
#  'get girl',
#  'left sprung dickhead cruise',
#  'look sunshine',
#  'guess never told im afraid height',
#  'cmon bad',
#  'try lookin angle',
#  'put right foot',
#  'forget im stayin',
#  'want climb show get',
#  'maybe',
#  'partridge family',
#  'figure something ridiculous win respect piss',
#  'good call',
#  'howd get chapin look way',
#  'dazzle wit',
#  'soft side knew',
#  'yeah well dont let get',
#  'whats excuse',
#  'act way',
#  'yes',
#  'dont like people expect expect time get disappointed change',
#  'disappoint start youre cover',
#  'something like',
#  'screw',
#  '',
#  'never disappointed',
#  '',
#  '',
#  'state trooper',
#  'fallacy',
#  'duck',
#  'hearsay',
#  'know porn career lie',
#  'tell something true',
#  'hate pea',
#  'something real something one else know',
#  'youre sweet sexy completely hot',
#  '',
#  'one else know',
#  'youre amazingly selfassured anyone ever told',
#  'go prom',
#  'request command',
#  'know mean',
#  '',
#  '',
#  'wont go',
#  '',
#  'dont want stupid tradition',
#  'create little drama start new rumor',
#  'motive',
#  'tell',
#  'need therapy anyone ever told',
#  'answer question patrick',
#  'nothing nothing pleasure company',
#  'guillermo say go lighter youre gonna look like extra 90210',
#  '',
#  'listen crap',
#  'crap',
#  'endless blonde babble im like boring',
#  'thank god hear one story coiffure',
#  'figure youd get good stuff eventually',
#  'good stuff',
#  'real',
#  'like fear wear pastel',
#  'im kid know sometimes become persona dont know quit',
#  '',
#  'okay youre gonna need learn lie',
#  'would rather ravish pirate british rear admiral',
#  'pirate question',
#  'daddy want discus prom tomorrow night',
#  'prom kat date',
#  '',
#  'hot rod joey right want bend rule',
#  'hot rod whatever',
#  'youre go unless sister go end story',
#  'fine see im prisoner house im daughter im possession',
#  'theyll dance theyll kiss theyll come home let go',
#  'kiss think happens kiss isnt keep elbow placenta day',
#  'listen know hate sit home im susie high school',
#  'like care',
#  'care im firm believer something reason someone else',
#  'wish luxury im sophomore get ask prom cant go',
#  'joey never told go',
#  '',
#  '9th month',
#  '',
#  'like total babe',
#  'hate joey',
#  'back different story',
#  '',
#  'say everyone',
#  '',
#  'afterwards told didnt want anymore wasnt ready get piss broke',
#  '',
#  'swore id never anything everyone else havent since except bogey party stun gastrointestinal display',
#  'didnt tell',
#  'want let make mind',
#  'didnt really thought could make decision wouldve let go instead help daddy hold hostage',
#  'thats',
#  'im stupid enough repeat mistake',
#  'guess thought protect',
#  'god youre like keep lock away dark cant experience anything',
#  'experience good bianca cant always trust people want',
#  'guess ill never know',
#  'wanna watch weve get crap crap crap crap',
#  'dr ruth',
#  'im miss something',
#  'date daddy captain oppression like men know',
#  'wow',
#  'let go',
#  'great time honey',
#  '',
#  'happen',
#  'daughter go prom',
#  'anything say',
#  'absolutely',
#  'thought',
#  'howd get tux last minute',
#  'scurvy date get convict whered get dress',
#  'something know',
#  'oh huh',
#  'look im sorry question motif wrong',
#  'see',
#  '',
#  'william ask meet',
#  'oh honey tell havent progress fullon hallucination',
#  'think sophomore prom',
#  '',
#  'grandmother',
#  '',
#  'thats last year shed never live alone grandfather die stayed wasnt jail dont know marilyn manson ive never slept spice girl spent year sit next grandma couch watch wheel fortune end story',
#  'completely adorable',
#  'get bad still freshman yearbook',
#  'wait',
#  'paid take one person truly hate knew setup',
#  'wasnt like',
#  'really like payment bonus sleep',
#  'didnt care money',
#  'look beautiful last night know',
#  '',
#  'okay',
#  'hope',
#  'sister',
#  'yeah left bikers big one full sperm',
#  'funny',
#  'dont understand allure dehydrate food something hip',
#  'daddy',
#  'tell dance fun',
#  'part',
#  'part',
#  'part bianca beat hell guy',
#  'bianca',
#  'whats matter upset rubbed',
#  'impressed',
#  'know father dont like admit daughter capable run life mean weve become spectator bianca still let play inning youve bleacher year go sarah lawrence wont even able watch game',
#  'go',
#  'oh christ dont tell youve change mind already sent em check',
#  'let go',
#  'set',
#  'want',
#  'completely damage send therapy forever',
#  'want',
#  'suppose feel well like right time think',
#  'smack',
#  'woman complete fruitloop',
#  '',
#  'fender strat bought',
#  'thought could use start band',
#  'besides extra cash asshole paid take really great girl',
#  'right',
#  'yeah fuck fell',
#  'veggie burger burnt object grill',
#  'like torture',
#  'oh bianca get freshman yearbook',
#  'even dare',
#  '',
#  '',
#  'patrick',
#  'perm',
#  'man knew treasurer sanchez',
#  'yes majesty',
#  'diego bright boy pleasure teach serious brother raise together colon even brother different mother',
#  'father think best teacher would chosen',
#  'god thats week',
#  'thats say',
#  'manage',
#  'difficulty promise total fool',
#  'wish sail west',
#  'open new route asia moment two way reach',
#  'certain ocean say infinite',
#  'ignorance believe indie 750 league west canary island',
#  'certain',
#  'calculation toscanelli marin de tyr esdras',
#  'esdras jew',
#  'christ',
#  'two minute already youre dead man dont let passion overwhelm colon',
#  'ill try remember marchena',
#  'father marchena',
#  'passion something one cannot control',
#  'get carry away contradict',
#  'ive contradict life eternity',
#  'god know meaning word son',
#  'could go year',
#  'know',
#  'havent give much life',
#  'well thats true child man wont marry always leave',
#  'go argue',
#  'id love argue sometimes youre never',
#  'perhaps never meant live woman',
#  'find hard believe',
#  'say asia found sail west',
#  'yes eminence voyage take six seven week',
#  'unfortunately colon precisely opinion differ familiar work aristotle erathostene ptolemeus',
#  'eminence',
#  'cannot ignore accord calculation circumference earth approximately 22000 league make ocean uncrossable',
#  'senor colon experienced captain understand concern crew willing conscience loss men would rely upon judgment',
#  'excellency right',
#  'eminence one way settle matter make journey ready risk life prove possible',
#  'life others',
#  'agree follow yes',
#  'trade excellency accord marco polo kingdom china one richest world even mean building roofed gold',
#  'interest gold',
#  'portuguese already discover blackskinned people find population bring word god',
#  'god intend proximity asia believe would wait show world',
#  'choose carpenter son reveal world',
#  'dont realize word could consider heretical',
#  'blind faith consider heresy',
#  'asia found west prove',
#  'ifgodwillsit',
#  'state reason interested man proposition eminence',
#  'judgment',
#  'naturally would really deplore loss potential opportunity spain dispute point geography',
#  'mercenary already try convince king portugal absurd notion',
#  'indeed world full mercenary state often make use benefit concern welfare prosperity spain',
#  'mustnt give way despair must wait',
#  'wait ive wait seven year already much longer want wait',
#  'god intend go go',
#  'damn god',
#  'colon',
#  'damn set theory base never leave safety study go find world tell something listen',
#  'lie',
#  'colon dont',
#  'meet man',
#  'immediately',
#  'even listen since council say santangel tell man honor sincerity sanchez fool',
#  'woman say would take granada moor',
#  'ocean uncrossable',
#  'say granada today',
#  'impregnable',
#  'cannot ignore verdict council',
#  'surely anything want',
#  'may speak freely',
#  'show inclination speak otherwise',
#  'know see see someone doesnt accept world afraid see woman think',
#  'woman',
#  'old senor colon',
#  'thirty seven majesty',
#  '',
#  '',
#  'wait long fought hard expect take risk take profit servant',
#  'remind senor colon position bargain',
#  'im bargaining',
#  'ambitious',
#  'never ambitious excellency ambition virtue among noble fault rest u',
#  'wont accept proposal well simply find someone',
#  'right sanchez demand could never grant',
#  'never majesty although',
#  'monk',
#  'yes would pity wouldnt call back',
#  'say yes',
#  'thank god',
#  'im ask swear anything',
#  'dont want wait',
#  'thats something cant decide',
#  'want go',
#  'therell time',
#  'promise swear st christopher',
#  'swear holy saint heaven',
#  'yes yes',
#  'nomine patris et filius et spiritus sancti',
#  'forgive father sin',
#  'listen son',
#  'father betrayed family betrayed men betrayed',
#  'say',
#  'lie journey longer say',
#  'long',
#  'sure could twice distance',
#  'may god forgive must tell must tell men',
#  'tell wont follow know right father trust',
#  'son son certitude sometimes frighten christopher must speak dont',
#  'bound oath father',
#  'believe',
#  'give absolution',
#  'due west captain mendez may god u',
#  'god u admiral',
#  'well men sir wonder know position weve lose sight land day ago',
#  'think mendez',
#  'well surely know quadrant ive never see use night',
#  'come',
#  'read',
#  'twenty eight',
#  'never see heat like even la mina',
#  'water go putrid barrel',
#  'youll drinking piss glory spain admiral colon bastard',
#  'listen chicken',
#  'ah leave alone harm',
#  'face like dont want look hear',
#  'devil child',
#  'well go crazy',
#  'see land',
#  'left three week ago alonso cant near',
#  'cant far say also dont like smell sea around smell like cunt bad sign',
#  'lie cheat way past 750 league',
#  'six day ago yes',
#  'must mad',
#  'keep hope men alive',
#  'verge mutiny colon',
#  'think dont know',
#  'lose',
#  'land know',
#  'dont know anything listen colon ship right im tell turn back',
#  'half water go rest nearly putrid know',
#  'jesus maria never listen',
#  'never talk u remember',
#  'bloody',
#  'pinzon pinzon go forward think',
#  'tell',
#  'youre right let men decide',
#  'say cuba',
#  'tribe island',
#  'island far',
#  'come speak first',
#  'tell chief thank',
#  'chief know',
#  'tell country beautiful tell leave men build fort',
#  'chief say many',
#  'thousand',
#  '',
#  'bring word god',
#  'chief say god',
#  'also bring medicine',
#  'chief say',
#  'medicine tell admire people',
#  'wont easy get rid prophet sanchez',
#  'contrary eminence seem man prepare cross',
#  'say indian vice god dont see kind pleasure would make sin',
#  'indian word moxica',
#  'thought',
#  'come go naked day god create',
#  'dont see sin nakedness live accord nature never end summer island cover tree fill blossom fruit',
#  'forgive colon gold',
#  'defend admirably',
#  'commoner',
#  'understand soon appoint governor island',
#  'forgive bobadilla position already take',
#  'may ask',
#  'bartolome giacomo colon',
#  'lack notary contact administration',
#  'bobadilla already judge dear cristobal',
#  'good also need judge except thief',
#  'seem special talent make friend',
#  'many already',
#  'rise high short time dangerous occupation little hypocrisy go long way',
#  'beatrix want ask something',
#  'dont usually ask',
#  'arrange queen take fernando diego service',
#  'lose cousin friend wash blood',
#  'want keep head shoulder youll say',
#  'want war fine thousand outnumber u ten kill tribe',
#  'dont need know',
#  'come stay build start crusade forest enough danger sweep u away day brave swallow grief name die accomplish come',
#  'work people want peace ask chief understands',
#  'understands',
#  'ask help',
#  'cant raise wheel without',
#  'horse doesnt work',
#  'moxica work',
#  'hear colon horse',
#  'every ship return cargo sick die gold new world prof expensive majesty',
#  'werent expect immediate profit must faith must give time time',
#  'one act brutality create chaos tribe fight join force u criminal savagery',
#  'savagery monkey understand',
#  'youll held detention deprive privilege possession return spain judged anything say',
#  'regret',
#  'find utapan look',
#  'god',
#  'utapan wont speak use know speak',
#  'never learn speak language',
#  'bad order execution five member nobility',
#  'true brother buyl',
#  'suggest sanchez',
#  'must replace',
#  'would think task',
#  'alonso de bobadilla',
#  'yes remember',
#  'letter appointment',
#  'appointment',
#  'viceroy west indie',
#  'congratulation free search mainland',
#  'far',
#  'seaman heard week sea hope disappointed',
#  'could mainland found exactly say would',
#  'afraid bad news',
#  'explore mainland',
#  'time',
#  'without brother return santo domingo colony may explore continent',
#  'thank',
#  'one thing id like understand want go back',
#  'majesty men content read thing must see eye cannot',
#  'know tolerate impertinence',
#  '',
#  'afraid',
#  'call guard',
#  'call',
#  'afraid nothing dreamer',
#  'look window',
#  'see',
#  'roof tower palace spire',
#  'create people like',
#  'god youre beautiful cant believe man ever take away',
#  'try didnt let',
#  'take everything',
#  'everything think care im free man rich dont make man rich make busier',
#  'feel fernando',
#  'bad',
#  'whats',
#  'draw isthmus say isthmus',
#  'cant',
#  'father',
#  'must passage ocean',
#  'see',
#  'tragedy waste life',
#  'waste let tell something arojaz name mine ever remember',
#  'suppose old men',
#  'youll always old father',
#  'disagree',
#  'knew would',
#  'new world create new people',
#  'oh new man',
#  'dont know impression didnt change much still cant accept world',
#  'cant stay u little',
#  'busy inside',
#  'tell',
#  'cant keep eye would like catch moment didnt spend',
#  'listen',
#  'listen father cant help hearing',
#  'say',
#  'asks come visit left address',
#  'never one except aboard ship',
#  'want tell everything remember father begin everything',
#  'really god wouldnt know start yet',
#  'tell first thing come mind',
#  'say thing say dont open mouth',
#  'okay',
#  'dont fool around',
#  'okay',
#  'hear say',
#  'want document trip america',
#  'next could see document please',
#  'yes sir',
#  'intend purpose visit united state',
#  'two week holiday',
#  'much money carry',
#  'fivehundred dollar',
#  'show sir camera fis area',
#  'travel together',
#  'yes',
#  'please join u come forward',
#  'problem',
#  'youre travel together want talk together hi take look document related',
#  'yeshes friend',
#  'okay youre czech national youre russian national know one another',
#  'prague',
#  'long planning stay',
#  'two week',
#  'id like speak okay',
#  'doesnt speak english',
#  'speak english',
#  'answer question planning stay two week youre',
#  'new york',
#  'yes new york planning stay new york',
#  'cheap hotel',
#  'come',
#  'im movie',
#  'moviesto movie see movie',
#  'yes boy see movie school call wonderful life direct frank capra ever since want come america land free home brave land anyone anything long white',
#  'excuse',
#  'waitin hit warrant get emergency service heavy weapon standin ready go say lemme get cigar outta car go get cigar boom sudden turn around kid shotgun let one go right standin coulda coulda head blown stupid kid get panicky take safety hadnt go back cigar bad habit wouldve head blown',
#  'jesus christ',
#  'coffee gotta slow',
#  'vodka tonic',
#  'maybe could put shot martell',
#  'freaky ill tell stupid kid',
#  'whats kid gonna say sorry meanwhile im anymore like last week morgue guy chopped spleen liver heart pan six hour ago guy walkin dog buyin quart milk know kid robbed 3 shit shot cant tell piece beef human im thinkin thats sooner later thats',
#  'sooner later thats everybody',
#  'chopped chopped like mean get left coupla article medal two plaque coupla year one remembers anymore',
#  'think youre get little moody eddie',
#  'im moody',
#  'isnt little moody',
#  'course moody think love',
#  'love',
#  'old kid',
#  'kid let seesusans 15 aundreas 9 dont tell youre think kid old never mind let tell every stupid cliche hear kid change life make well person make whole true kid friend talk kid want vomit get right leon',
#  'yeah',
#  'paulie youve get kid right',
#  'okay work vodka factory understand kind work',
#  'butcher',
#  'youre butcher use pig intestine',
#  'stuff sausage',
#  'bone',
#  ...]

# %%
messages['msg_pre_processed'] = data_pre_processed

# %% [markdown]
# ### Checking for duplicated messages in msg

# %%
data = messages['msg_pre_processed']

# %%
dict = {}
for n in data:
    if n in dict:
        dict[n] = dict[n] + 1
    else:
        dict[n] = 1

# %%
#sort dict by biggest values
dict = {k: v for k, v in sorted(dict.items(), key=lambda item: item[1], reverse=True)}

# %%
dict
# Out:
# {'': 12843,
#  'yes': 2121,
#  'yeah': 1552,
#  'know': 876,
#  'go': 692,
#  'okay': 653,
#  'right': 629,
#  'dont know': 629,
#  'sure': 554,
#  'oh': 535,
#  'say': 514,
#  'get': 508,
#  'whats': 467,
#  'mean': 462,
#  'well': 441,
#  'come': 411,
#  'think': 406,
#  'want': 393,
#  'thank': 379,
#  'talk': 351,
#  'really': 347,
#  'dont': 325,
#  'like': 319,
#  'hello': 315,
#  'unknown': 310,
#  'thanks': 305,
#  'happen': 291,
#  'yes sir': 289,
#  'course': 277,
#  'see': 276,
#  'good': 263,
#  'nothing': 263,
#  'tell': 256,
#  'huh': 253,
#  'hi': 252,
#  'fuck': 249,
#  'im sorry': 247,
#  'sir': 241,
#  'cant': 237,
#  'hell': 220,
#  'look': 214,
#  'thats right': 202,
#  'uhhuh': 195,
#  'love': 191,
#  'hey': 187,
#  'im': 177,
#  'whats wrong': 173,
#  'thats': 165,
#  'fine': 162,
#  'one': 162,
#  'way': 156,
#  'sorry': 156,
#  'time': 151,
#  'shit': 147,
#  'excuse': 145,
#  'shut': 145,
#  'guess': 140,
#  'oh god': 139,
#  'please': 138,
#  'dont think': 136,
#  'didnt': 135,
#  'stop': 135,
#  'maybe': 130,
#  'oh yeah': 127,
#  'told': 119,
#  'wait': 117,
#  'ok': 116,
#  'help': 115,
#  'work': 112,
#  'dont understand': 110,
#  'much': 109,
#  'jesus': 109,
#  'whats matter': 109,
#  'would': 108,
#  'let go': 108,
#  'long': 108,
#  'believe': 107,
#  'alright': 107,
#  'great': 106,
#  'kill': 103,
#  'dad': 98,
#  'dont believe': 98,
#  'youre': 97,
#  'call': 95,
#  'take': 95,
#  'whats go': 94,
#  'ask': 87,
#  'bad': 86,
#  'could': 86,
#  'leave': 85,
#  'never': 82,
#  'name': 82,
#  'yet': 82,
#  'wont': 81,
#  'understand': 81,
#  'exactly': 81,
#  'forget': 79,
#  'im sure': 79,
#  'whats name': 78,
#  'kid': 78,
#  'dead': 77,
#  'find': 76,
#  'thought': 75,
#  'problem': 75,
#  'hear': 75,
#  'give': 75,
#  'money': 74,
#  'ready': 72,
#  'father': 69,
#  'try': 68,
#  'friend': 68,
#  'mother': 68,
#  'lie': 67,
#  'man': 67,
#  'nice': 67,
#  'promise': 66,
#  'absolutely': 65,
#  'true': 65,
#  'heard': 65,
#  'uh huh': 63,
#  'whatd say': 62,
#  'listen': 62,
#  'miss': 60,
#  'hold': 60,
#  'anything': 60,
#  'nope': 59,
#  'need': 58,
#  'suppose': 57,
#  'idea': 57,
#  'im fine': 57,
#  'go ahead': 56,
#  'oh yes': 56,
#  'make': 56,
#  'mom': 56,
#  'certainly': 55,
#  'bullshit': 55,
#  'uh': 55,
#  'remember': 55,
#  'let': 55,
#  'stay': 54,
#  'goodbye': 54,
#  'ill': 54,
#  'else': 54,
#  'beautiful': 54,
#  'guy': 53,
#  'god': 53,
#  'old': 53,
#  'yep': 53,
#  'job': 52,
#  'tonight': 52,
#  'jack': 52,
#  'show': 52,
#  'good night': 52,
#  'thing': 51,
#  'late': 51,
#  'wow': 50,
#  'two': 50,
#  'many': 50,
#  'yes maam': 50,
#  'oh shit': 49,
#  'bet': 49,
#  'wife': 49,
#  'watch': 49,
#  'u': 49,
#  'beg pardon': 49,
#  'whats happen': 49,
#  'neither': 49,
#  'dont want': 48,
#  'always': 48,
#  'youre kid': 47,
#  'home': 47,
#  'okay okay': 47,
#  'whats problem': 46,
#  'live': 46,
#  'dont worry': 45,
#  'bye': 45,
#  'minute': 44,
#  'sit': 44,
#  'im go': 44,
#  'crazy': 44,
#  'people': 44,
#  'know know': 44,
#  'good morning': 44,
#  'trust': 44,
#  'cool': 44,
#  'afraid': 43,
#  'saw': 43,
#  'everything': 43,
#  'die': 43,
#  'ah': 43,
#  'mine': 43,
#  'back': 43,
#  'hope': 42,
#  'yeah know': 42,
#  'place': 42,
#  'dont like': 42,
#  'isnt': 42,
#  'yah': 42,
#  'follow': 41,
#  'check': 41,
#  'figure': 41,
#  'hows': 41,
#  'deal': 40,
#  'something': 40,
#  'look like': 40,
#  'car': 40,
#  'girl': 39,
#  'didnt tell': 39,
#  'gonna': 39,
#  'move': 39,
#  'feel': 39,
#  'wouldnt': 39,
#  'wait minute': 39,
#  'mm': 39,
#  'thats say': 38,
#  'care': 38,
#  'yes yes': 38,
#  'dream': 38,
#  'wasnt': 38,
#  'open': 38,
#  'hell go': 38,
#  'night': 38,
#  'yeah sure': 38,
#  'damn': 38,
#  'oh jesus': 38,
#  'hurt': 37,
#  'wrong': 37,
#  'honey': 37,
#  'lose': 36,
#  'found': 36,
#  'leave alone': 36,
#  'need help': 36,
#  'mmm': 36,
#  'probably': 36,
#  'shoot': 36,
#  'yup': 36,
#  'goodnight': 36,
#  'dont say': 36,
#  'serious': 36,
#  'something like': 35,
#  'start': 35,
#  'dont get': 35,
#  'thats true': 35,
#  'finish': 35,
#  'child': 35,
#  'come back': 35,
#  'let see': 34,
#  'daddy': 34,
#  'jesus christ': 34,
#  'hmm': 34,
#  'want talk': 34,
#  'youre sure': 34,
#  'close': 34,
#  'play': 34,
#  'want know': 34,
#  'john': 34,
#  'scar': 34,
#  'little': 33,
#  'enough': 33,
#  'answer': 33,
#  'room': 33,
#  'agree': 33,
#  'want see': 33,
#  'keep': 33,
#  'set': 32,
#  'want go': 32,
#  'yes know': 32,
#  'youre right': 32,
#  'didnt know': 32,
#  'dont remember': 32,
#  'whatever': 32,
#  'careful': 32,
#  'dont know youre talk': 32,
#  'morning': 32,
#  'shes': 31,
#  'hate': 31,
#  'real': 31,
#  'married': 31,
#  'yeah right': 31,
#  'pardon': 31,
#  'george': 31,
#  'knew': 31,
#  'doesnt matter': 31,
#  'holy shit': 31,
#  'thank sir': 31,
#  'son': 31,
#  'bastard': 31,
#  'funny': 30,
#  'woman': 30,
#  'doctor': 30,
#  'possible': 30,
#  'drink': 30,
#  'pleasure': 30,
#  'couldnt': 30,
#  'boy': 30,
#  'im hungry': 30,
#  'im afraid': 30,
#  'tomorrow': 30,
#  'whatre': 30,
#  'day': 30,
#  'still': 30,
#  'word': 30,
#  'aye sir': 30,
#  'hurry': 29,
#  'baby': 29,
#  'whats suppose mean': 29,
#  'dont care': 29,
#  'might': 29,
#  'accident': 29,
#  'shhh': 29,
#  'harry': 29,
#  'good luck': 28,
#  'question': 28,
#  'lock': 28,
#  'put': 28,
#  'david': 28,
#  'hm': 28,
#  'choice': 28,
#  'turn': 28,
#  'nick': 28,
#  'mind': 28,
#  'yeah guess': 27,
#  'far': 27,
#  'thats good': 27,
#  'frank': 27,
#  'roger': 27,
#  'captain': 27,
#  'cold': 27,
#  'never heard': 27,
#  'later': 27,
#  'whats point': 27,
#  'brother': 27,
#  'know mean': 26,
#  'use': 26,
#  'wish': 26,
#  'take care': 26,
#  'alive': 26,
#  'husband': 26,
#  'youre go': 26,
#  'left': 26,
#  'michael': 26,
#  'didnt say': 26,
#  'truth': 26,
#  'go away': 26,
#  'surprise': 26,
#  'house': 26,
#  'whatd': 25,
#  'run': 25,
#  'must': 25,
#  'pay': 25,
#  'head': 25,
#  'fault': 25,
#  'arent': 25,
#  'dont want talk': 25,
#  'howd know': 25,
#  'aye': 25,
#  'kiss': 24,
#  'hit': 24,
#  'cop': 24,
#  'youre crazy': 24,
#  'sort': 24,
#  'gun': 24,
#  'today': 24,
#  'wheres': 24,
#  'meaning': 24,
#  'wonder': 24,
#  'fun': 24,
#  'id like': 24,
#  'well see': 24,
#  'oh right': 24,
#  'stand': 24,
#  'dunno': 24,
#  'quiet': 24,
#  'change': 24,
#  'hmmm': 24,
#  'dance': 24,
#  'youre late': 24,
#  'read': 23,
#  'nah': 23,
#  'im okay': 23,
#  'ill take': 23,
#  'get away': 23,
#  'hell talk': 23,
#  'three': 23,
#  'first': 23,
#  'different': 23,
#  'sometimes': 23,
#  'walk': 23,
#  'cmon': 23,
#  'dog': 23,
#  'write': 23,
#  'ben': 23,
#  'thats bad': 23,
#  'claire': 23,
#  'thank god': 22,
#  'trouble': 22,
#  'ill go': 22,
#  'soon': 22,
#  'business': 22,
#  'theyre': 22,
#  'get back': 22,
#  'whered get': 22,
#  'charlie': 22,
#  'swear': 22,
#  'sign': 22,
#  'oh really': 22,
#  'go home': 22,
#  'objection': 22,
#  'hang': 22,
#  'jake': 22,
#  'wonderful': 21,
#  'perfect': 21,
#  'let get': 21,
#  'book': 21,
#  'anything else': 21,
#  'easy': 21,
#  'thank much': 21,
#  'safe': 21,
#  'youre lie': 21,
#  'aint': 21,
#  'need talk': 21,
#  'important': 21,
#  'point': 21,
#  'something wrong': 21,
#  'thats okay': 21,
#  'relax': 21,
#  'goin': 21,
#  'youre welcome': 20,
#  'im serious': 20,
#  'son bitch': 20,
#  'dont mind': 20,
#  'beat': 20,
#  'none': 20,
#  'fire': 20,
#  'look good': 20,
#  'ive see': 20,
#  'gotta go': 20,
#  'havent': 20,
#  'interest': 20,
#  'im scar': 20,
#  'already': 20,
#  'handle': 20,
#  'met': 20,
#  'happens': 20,
#  'year': 20,
#  'murder': 20,
#  'nobody': 20,
#  'bob': 20,
#  'drive': 20,
#  'chance': 19,
#  'coffee': 19,
#  'im listen': 19,
#  'quite': 19,
#  'shot': 19,
#  'bother': 19,
#  'want come': 19,
#  'thats enough': 19,
#  'four': 19,
#  'ill see': 19,
#  'win': 19,
#  'dont ask': 19,
#  'lovely': 19,
#  'smile': 19,
#  'doesnt': 19,
#  'yeah yeah': 19,
#  'yeah well': 19,
#  'water': 19,
#  'ever': 19,
#  'impossible': 19,
#  'whered go': 19,
#  'fuck go': 19,
#  'get money': 19,
#  'fight': 19,
#  'doin': 19,
#  'bitch': 19,
#  'others': 19,
#  'jimmy': 19,
#  'joe': 19,
#  'part': 18,
#  'boyfriend': 18,
#  'wha': 18,
#  'excellent': 18,
#  'tom': 18,
#  'bring': 18,
#  'go back': 18,
#  'reason': 18,
#  'sleep': 18,
#  'meet': 18,
#  'cant tell': 18,
#  'war': 18,
#  'cant go': 18,
#  'hows go': 18,
#  'calm': 18,
#  'depends': 18,
#  'perhaps': 18,
#  'alone': 18,
#  'nervous': 18,
#  'dont know mean': 18,
#  'ill right': 18,
#  'break': 18,
#  'doubt': 18,
#  'big': 18,
#  'well go': 18,
#  'youre wrong': 18,
#  'peter': 18,
#  'tire': 18,
#  'end': 18,
#  'congratulation': 18,
#  'walter': 18,
#  'whats like': 18,
#  'xxxxxx': 18,
#  'kind': 18,
#  'mmhm': 18,
#  'life': 18,
#  'plan': 17,
#  'christ': 17,
#  'good idea': 17,
#  'cut': 17,
#  'im come': 17,
#  'luck': 17,
#  'shes dead': 17,
#  'eh': 17,
#  'mary': 17,
#  'hospital': 17,
#  'im try': 17,
#  'suit': 17,
#  'bill': 17,
#  'hungry': 17,
#  'whats funny': 17,
#  'im glad': 17,
#  'order': 17,
#  'never mind': 17,
#  'alex': 17,
#  'mmmm': 17,
#  'shouldnt': 17,
#  'terrific': 17,
#  'oh hi': 17,
#  'forgive': 17,
#  'phone': 17,
#  'family': 17,
#  'maam': 17,
#  'really think': 17,
#  'key': 17,
#  'dont see': 17,
#  'thats great': 17,
#  'oh come': 17,
#  'howd get': 17,
#  'wouldnt know': 17,
#  'im right': 17,
#  'expect': 17,
#  'charge': 17,
#  'pretty': 16,
#  'screw': 16,
#  'yes course': 16,
#  'save': 16,
#  'eddie': 16,
#  'feel well': 16,
#  'whats get': 16,
#  'mommy': 16,
#  'letter': 16,
#  'jim': 16,
#  'think go': 16,
#  'best': 16,
#  'thats nice': 16,
#  'cant believe': 16,
#  'know well': 16,
#  'speak': 16,
#  'eat': 16,
#  'well dont': 16,
#  'game': 16,
#  'whoa': 16,
#  'right right': 16,
#  'definitely': 16,
#  'knock': 16,
#  'dont tell': 16,
#  'im work': 16,
#  'case': 16,
#  'around': 16,
#  'even': 16,
#  'girlfriend': 16,
#  'almost': 16,
#  'sweet': 16,
#  'sound good': 16,
#  'oh okay': 16,
#  'benjamin': 16,
#  'clean': 15,
#  'last night': 15,
#  'would know': 15,
#  'explain': 15,
#  'thats ridiculous': 15,
#  'cant say': 15,
#  'bed': 15,
#  'whats mean': 15,
#  'doesnt make sense': 15,
#  'yeah okay': 15,
#  'dont go': 15,
#  'report': 15,
#  'know name': 15,
#  'go go': 15,
#  'indeed': 15,
#  'majesty': 15,
#  'hand': 15,
#  'see later': 15,
#  'dude': 15,
#  'drunk': 15,
#  'well know': 15,
#  'andy': 15,
#  'uhuh': 15,
#  'im ready': 15,
#  'five': 15,
#  'oh please': 15,
#  'less': 15,
#  'id love': 15,
#  'ray': 15,
#  'fuck talk': 15,
#  'ouch': 15,
#  'get car': 15,
#  'correct': 15,
#  'yessir': 15,
#  'jeffrey': 15,
#  'whats say': 15,
#  'know go': 15,
#  'well think': 15,
#  'ill call': 15,
#  'police': 15,
#  'um': 15,
#  'ow': 15,
#  'ed': 15,
#  'dont touch': 15,
#  'decide': 14,
#  'matter': 14,
#  'new york': 14,
#  'ill right back': 14,
#  'im tell': 14,
#  'didnt mean': 14,
#  'max': 14,
#  'may': 14,
#  'enjoy': 14,
#  'alice': 14,
#  'get get': 14,
#  'drop': 14,
#  'stupid': 14,
#  'obviously': 14,
#  'would like': 14,
#  'mistake': 14,
#  'take look': 14,
#  'begin': 14,
#  'stay away': 14,
#  'fix': 14,
#  'clear': 14,
#  'ill get': 14,
#  'much time': 14,
#  'fact': 14,
#  'sing': 14,
#  'thats funny': 14,
#  'pull': 14,
#  'apartment': 14,
#  'brought': 14,
#  'color': 14,
#  'cute': 14,
#  'asleep': 14,
#  'go hell': 14,
#  'dave': 14,
#  'meant': 14,
#  'death': 14,
#  'quit': 14,
#  'didnt say anything': 14,
#  'none business': 14,
#  'anyway': 14,
#  'thats fine': 14,
#  'good see': 14,
#  'mama': 14,
#  'partner': 14,
#  'want stay': 14,
#  'whatre talk': 14,
#  'ha': 14,
#  'come come': 14,
#  'fast': 14,
#  'please dont': 14,
#  'whats difference': 14,
#  'bobby': 14,
#  'stuff': 14,
#  'johnny': 14,
#  'mike': 14,
#  'hear say': 13,
#  'asshole': 13,
#  'hell happen': 13,
#  'oh sure': 13,
#  'hot': 13,
#  'amen': 13,
#  'notice': 13,
#  'daughter': 13,
#  'dont know say': 13,
#  'like hell': 13,
#  'oh know': 13,
#  'sent': 13,
#  'oh see': 13,
#  'hiding': 13,
#  'lead': 13,
#  'im go home': 13,
#  'wait second': 13,
#  'fuckin': 13,
#  'six': 13,
#  'youve': 13,
#  'somebody': 13,
#  'star': 13,
#  'im leave': 13,
#  'difference make': 13,
#  'shut fuck': 13,
#  'yes thank': 13,
#  'everybody': 13,
#  'ask question': 13,
#  'oh im sorry': 13,
#  'mhm': 13,
#  'long time': 13,
#  'say something': 13,
#  'want kill': 13,
#  'dont trust': 13,
#  'want tell': 13,
#  'prove': 13,
#  'week': 13,
#  'know want': 13,
#  'interested': 13,
#  'dont know anything': 13,
#  'want say': 13,
#  'picture': 13,
#  'dont want know': 13,
#  'dinner': 13,
#  'make think': 13,
#  'pas': 13,
#  'amaze': 13,
#  'mad': 13,
#  'cant leave': 13,
#  'sam': 13,
#  'well dont know': 13,
#  'hi mom': 13,
#  'get right': 13,
#  'norman': 13,
#  'know happen': 12,
#  'dont need': 12,
#  'dont know dont know': 12,
#  'tell u': 12,
#  'im say': 12,
#  'black': 12,
#  'pop': 12,
#  'smoke': 12,
#  'marty': 12,
#  'yeah thats right': 12,
#  'youll': 12,
#  'ted': 12,
#  'dont want go': 12,
#  'oh oh': 12,
#  'oh man': 12,
#  'appreciate': 12,
#  'yeah get': 12,
#  'never say': 12,
#  'think know': 12,
#  'dont bother': 12,
#  'oh thank': 12,
#  'howd go': 12,
#  'al': 12,
#  'nice meet': 12,
#  'anymore': 12,
#  'oh great': 12,
#  'movie': 12,
#  'save life': 12,
#  'look beautiful': 12,
#  'idiot': 12,
#  'hair': 12,
#  'party': 12,
#  'naturally': 12,
#  'yeah thanks': 12,
#  'yeah like': 12,
#  'yeah maybe': 12,
#  'youre hurt': 12,
#  'ask something': 12,
#  'take time': 12,
#  'power': 12,
#  'bout': 12,
#  'side': 12,
#  'dont call': 12,
#  'uhoh': 12,
#  'make say': 12,
#  'darling': 12,
#  'someone': 12,
#  'open door': 12,
#  'hi dad': 12,
#  'dorothy': 12,
#  'everything okay': 12,
#  'sex': 12,
#  'anything wrong': 12,
#  'long time ago': 12,
#  'think get': 12,
#  'dont follow': 12,
#  'mr president': 12,
#  'weird': 12,
#  'marry': 12,
#  'anyone': 12,
#  'oh christ': 12,
#  'school': 12,
#  'touch': 12,
#  'spock': 12,
#  'screen': 12,
#  'joey': 11,
#  'go get': 11,
#  'know say': 11,
#  'get job': 11,
#  'yes think': 11,
#  'come home': 11,
#  'continued': 11,
#  'talkin': 11,
#  'class': 11,
#  'im ask': 11,
#  'body': 11,
#  'let talk': 11,
#  'whats plan': 11,
#  'insane': 11,
#  'blood': 11,
#  'sick': 11,
#  'dont ridiculous': 11,
#  'er': 11,
#  'think youre': 11,
#  'well come': 11,
#  'wait wait': 11,
#  'elaine': 11,
#  'every day': 11,
#  'ill try': 11,
#  'nonsense': 11,
#  'young': 11,
#  'bathroom': 11,
#  'second': 11,
#  'whatll': 11,
#  'yesterday': 11,
#  'fair enough': 11,
#  'youre serious': 11,
#  'count': 11,
#  'slow': 11,
#  'music': 11,
#  'yo': 11,
#  'free': 11,
#  'upset': 11,
#  'early': 11,
#  'didnt anything': 11,
#  'cigarette': 11,
#  'didnt see': 11,
#  'feel good': 11,
#  'oh good': 11,
#  'worried': 11,
#  'paul': 11,
#  'come get': 11,
#  'dont move': 11,
#  'know im': 11,
#  'take long': 11,
#  'thats point': 11,
#  'youll see': 11,
#  'shhhh': 11,
#  'lawyer': 11,
#  'call police': 11,
#  'take easy': 11,
#  'ten': 11,
#  'fine fine': 11,
#  'paper': 11,
#  'think youre go': 11,
#  'could say': 11,
#  'want one': 11,
#  'doc': 11,
#  'mile': 11,
#  'since': 11,
#  'susan': 11,
#  'mess': 11,
#  'ellie': 11,
#  'im look': 11,
#  'bingo': 11,
#  'know feel': 11,
#  'lieutenant': 11,
#  'beth': 11,
#  'speak english': 10,
#  'ill come': 10,
#  'robert': 10,
#  'give back': 10,
#  'im tire': 10,
#  'dont choice': 10,
#  'dont come': 10,
#  'youre joking': 10,
#  'cash': 10,
#  'howd find': 10,
#  'look great': 10,
#  'nothing nothing': 10,
#  'want go home': 10,
#  'whered come': 10,
#  'moment': 10,
#  'larry': 10,
#  'shall': 10,
#  'wake': 10,
#  'warn': 10,
#  'let try': 10,
#  'buy': 10,
#  'ill say': 10,
#  'incredible': 10,
#  'didnt get': 10,
#  'naw': 10,
#  'cant help': 10,
#  'german': 10,
#  'nightmare': 10,
#  'patient': 10,
#  'charm': 10,
#  'twenty': 10,
#  'recognize': 10,
#  'oh sorry': 10,
#  'first time': 10,
#  'im good': 10,
#  'rise': 10,
#  'dyou mean': 10,
#  'cant come': 10,
#  'didnt like': 10,
#  'men': 10,
#  'guest': 10,
#  'ya': 10,
#  'sure thing': 10,
#  'try kill': 10,
#  'sound': 10,
#  'seriously': 10,
#  'matter fact': 10,
#  'thats way': 10,
#  'pray': 10,
#  'ill tell': 10,
#  'im busy': 10,
#  'positive': 10,
#  'mmmmm': 10,
#  'big one': 10,
#  'dont want hear': 10,
#  'dangerous': 10,
#  'bag': 10,
#  'didnt kill': 10,
#  'liar': 10,
#  'tell truth': 10,
#  'kay': 10,
#  'love much': 10,
#  'protect': 10,
#  'unbelievable': 10,
#  'thats im': 10,
#  'fuck fuck': 10,
#  'want money': 10,
#  'dont look': 10,
#  'need money': 10,
#  'nothin': 10,
#  'imagine': 10,
#  'anna': 10,
#  'lucky': 10,
#  'suggest': 10,
#  'get way': 10,
#  'thats impossible': 10,
#  'clothes': 10,
#  'yes would': 10,
#  'know get': 10,
#  'chicken': 10,
#  'goddamn': 10,
#  'cant take': 10,
#  'agent': 10,
#  'tunnel': 10,
#  'history': 10,
#  'understood': 10,
#  'dont time': 10,
#  'ill wait': 10,
#  'cant stay': 10,
#  'give key': 10,
#  'lord': 10,
#  'ill bet': 10,
#  'fascinate': 10,
#  'swim': 10,
#  'ahh': 10,
#  'buddy': 10,
#  'epps': 10,
#  'steve': 10,
#  'youre good': 10,
#  'fear': 9,
#  'wherere go': 9,
#  'sister': 9,
#  'ill think': 9,
#  'thats thought': 9,
#  'sell': 9,
#  'much pay': 9,
#  'ive get go': 9,
#  'copy': 9,
#  'fish': 9,
#  'yes go': 9,
#  'get married': 9,
#  'particularly': 9,
#  'agnes': 9,
#  'someone else': 9,
#  'thats lie': 9,
#  'cant remember': 9,
#  'send': 9,
#  'thats girl': 9,
#  'well take': 9,
#  'expect believe': 9,
#  'goodbye darling': 9,
#  'oh god oh god': 9,
#  'pain': 9,
#  'go work': 9,
#  ...}

# %%
#example of duplcated msg
messages[messages['msg_pre_processed'] == 'yes']
# Out:
# Empty DataFrame
# Columns: [msg_line, user_id, movie_id, msg, msg_2, msg_pre_processed]
# Index: []

# %%
#get the repeated messages
d_list = list()
for k in dict:
    if dict[k] > 1:
        d_list.append(k)

# %%
d_list
# Out:
# ['',
#  'yes',
#  'yeah',
#  'know',
#  'go',
#  'okay',
#  'right',
#  'dont know',
#  'sure',
#  'oh',
#  'say',
#  'get',
#  'whats',
#  'mean',
#  'well',
#  'come',
#  'think',
#  'want',
#  'thank',
#  'talk',
#  'really',
#  'dont',
#  'like',
#  'hello',
#  'unknown',
#  'thanks',
#  'happen',
#  'yes sir',
#  'course',
#  'see',
#  'good',
#  'nothing',
#  'tell',
#  'huh',
#  'hi',
#  'fuck',
#  'im sorry',
#  'sir',
#  'cant',
#  'hell',
#  'look',
#  'thats right',
#  'uhhuh',
#  'love',
#  'hey',
#  'im',
#  'whats wrong',
#  'thats',
#  'fine',
#  'one',
#  'way',
#  'sorry',
#  'time',
#  'shit',
#  'excuse',
#  'shut',
#  'guess',
#  'oh god',
#  'please',
#  'dont think',
#  'didnt',
#  'stop',
#  'maybe',
#  'oh yeah',
#  'told',
#  'wait',
#  'ok',
#  'help',
#  'work',
#  'dont understand',
#  'much',
#  'jesus',
#  'whats matter',
#  'would',
#  'let go',
#  'long',
#  'believe',
#  'alright',
#  'great',
#  'kill',
#  'dad',
#  'dont believe',
#  'youre',
#  'call',
#  'take',
#  'whats go',
#  'ask',
#  'bad',
#  'could',
#  'leave',
#  'never',
#  'name',
#  'yet',
#  'wont',
#  'understand',
#  'exactly',
#  'forget',
#  'im sure',
#  'whats name',
#  'kid',
#  'dead',
#  'find',
#  'thought',
#  'problem',
#  'hear',
#  'give',
#  'money',
#  'ready',
#  'father',
#  'try',
#  'friend',
#  'mother',
#  'lie',
#  'man',
#  'nice',
#  'promise',
#  'absolutely',
#  'true',
#  'heard',
#  'uh huh',
#  'whatd say',
#  'listen',
#  'miss',
#  'hold',
#  'anything',
#  'nope',
#  'need',
#  'suppose',
#  'idea',
#  'im fine',
#  'go ahead',
#  'oh yes',
#  'make',
#  'mom',
#  'certainly',
#  'bullshit',
#  'uh',
#  'remember',
#  'let',
#  'stay',
#  'goodbye',
#  'ill',
#  'else',
#  'beautiful',
#  'guy',
#  'god',
#  'old',
#  'yep',
#  'job',
#  'tonight',
#  'jack',
#  'show',
#  'good night',
#  'thing',
#  'late',
#  'wow',
#  'two',
#  'many',
#  'yes maam',
#  'oh shit',
#  'bet',
#  'wife',
#  'watch',
#  'u',
#  'beg pardon',
#  'whats happen',
#  'neither',
#  'dont want',
#  'always',
#  'youre kid',
#  'home',
#  'okay okay',
#  'whats problem',
#  'live',
#  'dont worry',
#  'bye',
#  'minute',
#  'sit',
#  'im go',
#  'crazy',
#  'people',
#  'know know',
#  'good morning',
#  'trust',
#  'cool',
#  'afraid',
#  'saw',
#  'everything',
#  'die',
#  'ah',
#  'mine',
#  'back',
#  'hope',
#  'yeah know',
#  'place',
#  'dont like',
#  'isnt',
#  'yah',
#  'follow',
#  'check',
#  'figure',
#  'hows',
#  'deal',
#  'something',
#  'look like',
#  'car',
#  'girl',
#  'didnt tell',
#  'gonna',
#  'move',
#  'feel',
#  'wouldnt',
#  'wait minute',
#  'mm',
#  'thats say',
#  'care',
#  'yes yes',
#  'dream',
#  'wasnt',
#  'open',
#  'hell go',
#  'night',
#  'yeah sure',
#  'damn',
#  'oh jesus',
#  'hurt',
#  'wrong',
#  'honey',
#  'lose',
#  'found',
#  'leave alone',
#  'need help',
#  'mmm',
#  'probably',
#  'shoot',
#  'yup',
#  'goodnight',
#  'dont say',
#  'serious',
#  'something like',
#  'start',
#  'dont get',
#  'thats true',
#  'finish',
#  'child',
#  'come back',
#  'let see',
#  'daddy',
#  'jesus christ',
#  'hmm',
#  'want talk',
#  'youre sure',
#  'close',
#  'play',
#  'want know',
#  'john',
#  'scar',
#  'little',
#  'enough',
#  'answer',
#  'room',
#  'agree',
#  'want see',
#  'keep',
#  'set',
#  'want go',
#  'yes know',
#  'youre right',
#  'didnt know',
#  'dont remember',
#  'whatever',
#  'careful',
#  'dont know youre talk',
#  'morning',
#  'shes',
#  'hate',
#  'real',
#  'married',
#  'yeah right',
#  'pardon',
#  'george',
#  'knew',
#  'doesnt matter',
#  'holy shit',
#  'thank sir',
#  'son',
#  'bastard',
#  'funny',
#  'woman',
#  'doctor',
#  'possible',
#  'drink',
#  'pleasure',
#  'couldnt',
#  'boy',
#  'im hungry',
#  'im afraid',
#  'tomorrow',
#  'whatre',
#  'day',
#  'still',
#  'word',
#  'aye sir',
#  'hurry',
#  'baby',
#  'whats suppose mean',
#  'dont care',
#  'might',
#  'accident',
#  'shhh',
#  'harry',
#  'good luck',
#  'question',
#  'lock',
#  'put',
#  'david',
#  'hm',
#  'choice',
#  'turn',
#  'nick',
#  'mind',
#  'yeah guess',
#  'far',
#  'thats good',
#  'frank',
#  'roger',
#  'captain',
#  'cold',
#  'never heard',
#  'later',
#  'whats point',
#  'brother',
#  'know mean',
#  'use',
#  'wish',
#  'take care',
#  'alive',
#  'husband',
#  'youre go',
#  'left',
#  'michael',
#  'didnt say',
#  'truth',
#  'go away',
#  'surprise',
#  'house',
#  'whatd',
#  'run',
#  'must',
#  'pay',
#  'head',
#  'fault',
#  'arent',
#  'dont want talk',
#  'howd know',
#  'aye',
#  'kiss',
#  'hit',
#  'cop',
#  'youre crazy',
#  'sort',
#  'gun',
#  'today',
#  'wheres',
#  'meaning',
#  'wonder',
#  'fun',
#  'id like',
#  'well see',
#  'oh right',
#  'stand',
#  'dunno',
#  'quiet',
#  'change',
#  'hmmm',
#  'dance',
#  'youre late',
#  'read',
#  'nah',
#  'im okay',
#  'ill take',
#  'get away',
#  'hell talk',
#  'three',
#  'first',
#  'different',
#  'sometimes',
#  'walk',
#  'cmon',
#  'dog',
#  'write',
#  'ben',
#  'thats bad',
#  'claire',
#  'thank god',
#  'trouble',
#  'ill go',
#  'soon',
#  'business',
#  'theyre',
#  'get back',
#  'whered get',
#  'charlie',
#  'swear',
#  'sign',
#  'oh really',
#  'go home',
#  'objection',
#  'hang',
#  'jake',
#  'wonderful',
#  'perfect',
#  'let get',
#  'book',
#  'anything else',
#  'easy',
#  'thank much',
#  'safe',
#  'youre lie',
#  'aint',
#  'need talk',
#  'important',
#  'point',
#  'something wrong',
#  'thats okay',
#  'relax',
#  'goin',
#  'youre welcome',
#  'im serious',
#  'son bitch',
#  'dont mind',
#  'beat',
#  'none',
#  'fire',
#  'look good',
#  'ive see',
#  'gotta go',
#  'havent',
#  'interest',
#  'im scar',
#  'already',
#  'handle',
#  'met',
#  'happens',
#  'year',
#  'murder',
#  'nobody',
#  'bob',
#  'drive',
#  'chance',
#  'coffee',
#  'im listen',
#  'quite',
#  'shot',
#  'bother',
#  'want come',
#  'thats enough',
#  'four',
#  'ill see',
#  'win',
#  'dont ask',
#  'lovely',
#  'smile',
#  'doesnt',
#  'yeah yeah',
#  'yeah well',
#  'water',
#  'ever',
#  'impossible',
#  'whered go',
#  'fuck go',
#  'get money',
#  'fight',
#  'doin',
#  'bitch',
#  'others',
#  'jimmy',
#  'joe',
#  'part',
#  'boyfriend',
#  'wha',
#  'excellent',
#  'tom',
#  'bring',
#  'go back',
#  'reason',
#  'sleep',
#  'meet',
#  'cant tell',
#  'war',
#  'cant go',
#  'hows go',
#  'calm',
#  'depends',
#  'perhaps',
#  'alone',
#  'nervous',
#  'dont know mean',
#  'ill right',
#  'break',
#  'doubt',
#  'big',
#  'well go',
#  'youre wrong',
#  'peter',
#  'tire',
#  'end',
#  'congratulation',
#  'walter',
#  'whats like',
#  'xxxxxx',
#  'kind',
#  'mmhm',
#  'life',
#  'plan',
#  'christ',
#  'good idea',
#  'cut',
#  'im come',
#  'luck',
#  'shes dead',
#  'eh',
#  'mary',
#  'hospital',
#  'im try',
#  'suit',
#  'bill',
#  'hungry',
#  'whats funny',
#  'im glad',
#  'order',
#  'never mind',
#  'alex',
#  'mmmm',
#  'shouldnt',
#  'terrific',
#  'oh hi',
#  'forgive',
#  'phone',
#  'family',
#  'maam',
#  'really think',
#  'key',
#  'dont see',
#  'thats great',
#  'oh come',
#  'howd get',
#  'wouldnt know',
#  'im right',
#  'expect',
#  'charge',
#  'pretty',
#  'screw',
#  'yes course',
#  'save',
#  'eddie',
#  'feel well',
#  'whats get',
#  'mommy',
#  'letter',
#  'jim',
#  'think go',
#  'best',
#  'thats nice',
#  'cant believe',
#  'know well',
#  'speak',
#  'eat',
#  'well dont',
#  'game',
#  'whoa',
#  'right right',
#  'definitely',
#  'knock',
#  'dont tell',
#  'im work',
#  'case',
#  'around',
#  'even',
#  'girlfriend',
#  'almost',
#  'sweet',
#  'sound good',
#  'oh okay',
#  'benjamin',
#  'clean',
#  'last night',
#  'would know',
#  'explain',
#  'thats ridiculous',
#  'cant say',
#  'bed',
#  'whats mean',
#  'doesnt make sense',
#  'yeah okay',
#  'dont go',
#  'report',
#  'know name',
#  'go go',
#  'indeed',
#  'majesty',
#  'hand',
#  'see later',
#  'dude',
#  'drunk',
#  'well know',
#  'andy',
#  'uhuh',
#  'im ready',
#  'five',
#  'oh please',
#  'less',
#  'id love',
#  'ray',
#  'fuck talk',
#  'ouch',
#  'get car',
#  'correct',
#  'yessir',
#  'jeffrey',
#  'whats say',
#  'know go',
#  'well think',
#  'ill call',
#  'police',
#  'um',
#  'ow',
#  'ed',
#  'dont touch',
#  'decide',
#  'matter',
#  'new york',
#  'ill right back',
#  'im tell',
#  'didnt mean',
#  'max',
#  'may',
#  'enjoy',
#  'alice',
#  'get get',
#  'drop',
#  'stupid',
#  'obviously',
#  'would like',
#  'mistake',
#  'take look',
#  'begin',
#  'stay away',
#  'fix',
#  'clear',
#  'ill get',
#  'much time',
#  'fact',
#  'sing',
#  'thats funny',
#  'pull',
#  'apartment',
#  'brought',
#  'color',
#  'cute',
#  'asleep',
#  'go hell',
#  'dave',
#  'meant',
#  'death',
#  'quit',
#  'didnt say anything',
#  'none business',
#  'anyway',
#  'thats fine',
#  'good see',
#  'mama',
#  'partner',
#  'want stay',
#  'whatre talk',
#  'ha',
#  'come come',
#  'fast',
#  'please dont',
#  'whats difference',
#  'bobby',
#  'stuff',
#  'johnny',
#  'mike',
#  'hear say',
#  'asshole',
#  'hell happen',
#  'oh sure',
#  'hot',
#  'amen',
#  'notice',
#  'daughter',
#  'dont know say',
#  'like hell',
#  'oh know',
#  'sent',
#  'oh see',
#  'hiding',
#  'lead',
#  'im go home',
#  'wait second',
#  'fuckin',
#  'six',
#  'youve',
#  'somebody',
#  'star',
#  'im leave',
#  'difference make',
#  'shut fuck',
#  'yes thank',
#  'everybody',
#  'ask question',
#  'oh im sorry',
#  'mhm',
#  'long time',
#  'say something',
#  'want kill',
#  'dont trust',
#  'want tell',
#  'prove',
#  'week',
#  'know want',
#  'interested',
#  'dont know anything',
#  'want say',
#  'picture',
#  'dont want know',
#  'dinner',
#  'make think',
#  'pas',
#  'amaze',
#  'mad',
#  'cant leave',
#  'sam',
#  'well dont know',
#  'hi mom',
#  'get right',
#  'norman',
#  'know happen',
#  'dont need',
#  'dont know dont know',
#  'tell u',
#  'im say',
#  'black',
#  'pop',
#  'smoke',
#  'marty',
#  'yeah thats right',
#  'youll',
#  'ted',
#  'dont want go',
#  'oh oh',
#  'oh man',
#  'appreciate',
#  'yeah get',
#  'never say',
#  'think know',
#  'dont bother',
#  'oh thank',
#  'howd go',
#  'al',
#  'nice meet',
#  'anymore',
#  'oh great',
#  'movie',
#  'save life',
#  'look beautiful',
#  'idiot',
#  'hair',
#  'party',
#  'naturally',
#  'yeah thanks',
#  'yeah like',
#  'yeah maybe',
#  'youre hurt',
#  'ask something',
#  'take time',
#  'power',
#  'bout',
#  'side',
#  'dont call',
#  'uhoh',
#  'make say',
#  'darling',
#  'someone',
#  'open door',
#  'hi dad',
#  'dorothy',
#  'everything okay',
#  'sex',
#  'anything wrong',
#  'long time ago',
#  'think get',
#  'dont follow',
#  'mr president',
#  'weird',
#  'marry',
#  'anyone',
#  'oh christ',
#  'school',
#  'touch',
#  'spock',
#  'screen',
#  'joey',
#  'go get',
#  'know say',
#  'get job',
#  'yes think',
#  'come home',
#  'continued',
#  'talkin',
#  'class',
#  'im ask',
#  'body',
#  'let talk',
#  'whats plan',
#  'insane',
#  'blood',
#  'sick',
#  'dont ridiculous',
#  'er',
#  'think youre',
#  'well come',
#  'wait wait',
#  'elaine',
#  'every day',
#  'ill try',
#  'nonsense',
#  'young',
#  'bathroom',
#  'second',
#  'whatll',
#  'yesterday',
#  'fair enough',
#  'youre serious',
#  'count',
#  'slow',
#  'music',
#  'yo',
#  'free',
#  'upset',
#  'early',
#  'didnt anything',
#  'cigarette',
#  'didnt see',
#  'feel good',
#  'oh good',
#  'worried',
#  'paul',
#  'come get',
#  'dont move',
#  'know im',
#  'take long',
#  'thats point',
#  'youll see',
#  'shhhh',
#  'lawyer',
#  'call police',
#  'take easy',
#  'ten',
#  'fine fine',
#  'paper',
#  'think youre go',
#  'could say',
#  'want one',
#  'doc',
#  'mile',
#  'since',
#  'susan',
#  'mess',
#  'ellie',
#  'im look',
#  'bingo',
#  'know feel',
#  'lieutenant',
#  'beth',
#  'speak english',
#  'ill come',
#  'robert',
#  'give back',
#  'im tire',
#  'dont choice',
#  'dont come',
#  'youre joking',
#  'cash',
#  'howd find',
#  'look great',
#  'nothing nothing',
#  'want go home',
#  'whered come',
#  'moment',
#  'larry',
#  'shall',
#  'wake',
#  'warn',
#  'let try',
#  'buy',
#  'ill say',
#  'incredible',
#  'didnt get',
#  'naw',
#  'cant help',
#  'german',
#  'nightmare',
#  'patient',
#  'charm',
#  'twenty',
#  'recognize',
#  'oh sorry',
#  'first time',
#  'im good',
#  'rise',
#  'dyou mean',
#  'cant come',
#  'didnt like',
#  'men',
#  'guest',
#  'ya',
#  'sure thing',
#  'try kill',
#  'sound',
#  'seriously',
#  'matter fact',
#  'thats way',
#  'pray',
#  'ill tell',
#  'im busy',
#  'positive',
#  'mmmmm',
#  'big one',
#  'dont want hear',
#  'dangerous',
#  'bag',
#  'didnt kill',
#  'liar',
#  'tell truth',
#  'kay',
#  'love much',
#  'protect',
#  'unbelievable',
#  'thats im',
#  'fuck fuck',
#  'want money',
#  'dont look',
#  'need money',
#  'nothin',
#  'imagine',
#  'anna',
#  'lucky',
#  'suggest',
#  'get way',
#  'thats impossible',
#  'clothes',
#  'yes would',
#  'know get',
#  'chicken',
#  'goddamn',
#  'cant take',
#  'agent',
#  'tunnel',
#  'history',
#  'understood',
#  'dont time',
#  'ill wait',
#  'cant stay',
#  'give key',
#  'lord',
#  'ill bet',
#  'fascinate',
#  'swim',
#  'ahh',
#  'buddy',
#  'epps',
#  'steve',
#  'youre good',
#  'fear',
#  'wherere go',
#  'sister',
#  'ill think',
#  'thats thought',
#  'sell',
#  'much pay',
#  'ive get go',
#  'copy',
#  'fish',
#  'yes go',
#  'get married',
#  'particularly',
#  'agnes',
#  'someone else',
#  'thats lie',
#  'cant remember',
#  'send',
#  'thats girl',
#  'well take',
#  'expect believe',
#  'goodbye darling',
#  'oh god oh god',
#  'pain',
#  'go work',
#  ...]

# %%
messages = messages.drop_duplicates(subset=['msg_pre_processed'])

# %%
#example of duplcated msg
messages[messages['msg_pre_processed'] == 'yes']
# Out:
#                msg_line user_id movie_id  msg  \
# msg_line_clean
# 817                L817      u9       m0  Yes
#
#                                                             msg_2  \
# msg_line_clean
# 817             I don't like to do what people expect. Then th...
#
#                msg_pre_processed  target
# msg_line_clean
# 817                          yes       0

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229108 entries, 49 to 666576
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   msg_line           229108 non-null  object
#  1   user_id            229108 non-null  object
#  2   movie_id           229108 non-null  object
#  3   msg                229108 non-null  object
#  4   msg_2              229108 non-null  object
#  5   msg_pre_processed  229108 non-null  object
# dtypes: object(6)
# memory usage: 12.2+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id                                msg   msg_2  \
# count    229108  229108   229108                             229108  229108
# unique   229108    8980      617                             229108  145702
# top     L316222   u3681     m289  If anything ever happens to me...       -
# freq          1     415     1126                                  1   64196
#
#                                         msg_pre_processed
# count                                              229108
# unique                                             229108
# top     onei take care grow tough neighbourhood ive ha...
# freq                                                    1

# %% [markdown]
# ## Removing empty messages

# %%
messages[messages['msg_pre_processed'] == '']
# Out:
# Empty DataFrame
# Columns: [msg_line, user_id, movie_id, msg, msg_2, msg_pre_processed, target]
# Index: []

# %%
messages = messages.drop(messages[messages['msg_pre_processed'] == ''].index)

# %% [markdown]
# ### Removing nan msg origined by '' messages

# %%
#return generic answer
def generic_answer(txt):
  asw_list = ['talk more about it',
              'can you explain it better?',
              'I need to think more about it',
              'maybe...'
              ]
  if txt == '-' or txt == '':
    return random.choice(asw_list)
  return txt

# %%
messages[messages['msg_pre_processed'].isna()]

# %%
#filling the nan messages with a string- not necessary
messages = messages.fillna(generic_answer('-'))

# %% [markdown]
# ### Removing apostrophes (need for embedding and page rank  dictionary)

# %%
messages['msg_pre_processed'] = [ word.replace("\'","") for word in messages['msg_pre_processed'] ]

# %% [markdown]
# ### Filling '-' or '' messages with a generic one

# %%
#seting a generic answer to the messages without answer
messages['msg_2'] = [generic_answer(msg) for msg in messages['msg_2']]

# %%
messages.head(30)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
# 78                  L78      u7       m0
# 87                  L87      u2       m0
# 88                  L88      u7       m0
# 90                  L90      u7       m0
# 92                  L92      u7       m0
# 103                L103      u8       m0
# 104                L104      u5       m0
# 105                L105      u8       m0
# 106                L106      u5       m0
# 107                L107      u8       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
# 78              Yeah but these guys have never seen a horse. T...
# 87                                              That girl -- I --
# 88                                  You burn you pine you perish?
# 90              Bianca Stratford. Sophomore. Don't even think ...
# 92              I could start with your haircut but it doesn't...
# 103             Katarina Stratford. My my. You've been terrori...
# 104              Expressing my opinion is not a terrorist action.
# 105             Well yes compared to your other choices of exp...
# 106             I still maintain that he kicked himself in the...
# 107             The point is Kat -- people perceive you as som...
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                    change hair
# 50                                     can you explain it better?
# 51                                              might wanna think
# 59                                                           miss
# 60                                 say expose group freshman girl
# 61                                            bratwurst eat lunch
# 62                                                   teeth zipper
# 63                                                        new guy
# 64                                                           tell
# 65                                      cmon im suppose give tour
# 66                                                         dakota
# 67                                            north actually howd
# 68                                       kid people actually live
# 69                               yeah couple outnumber cow though
# 70                                         many people old school
# 71                                                      thirtytwo
# 72                                                            get
# 73                                                 many people go
# 74                                           couple thousand evil
# 77                                                         im use
# 78                   yeah guy never see horse jack clint eastwood
# 87                                                           girl
# 88                                               burn pine perish
# 90                     bianca stratford sophomore dont even think
# 92              could start haircut doesnt matter shes allow d...
# 103                     katarina stratford youve terrorize blaise
# 104                              express opinion terrorist action
# 105             well yes compare choice expression year today ...
# 106                     still maintain kick ball merely spectator
# 107                            point kat people perceive somewhat
#
#                                                 msg_pre_processed  target
# msg_line_clean
# 49                                                    change hair       1
# 50                                             talk more about it       0
# 51                                              might wanna think       0
# 59                                                           miss       0
# 60                                 say expose group freshman girl       0
# 61                                            bratwurst eat lunch       0
# 62                                                   teeth zipper       1
# 63                                                        new guy       1
# 64                                                           tell       0
# 65                                      cmon im suppose give tour       0
# 66                                                         dakota       1
# 67                                            north actually howd       1
# 68                                       kid people actually live       1
# 69                               yeah couple outnumber cow though       0
# 70                                         many people old school       1
# 71                                                      thirtytwo       0
# 72                                                            get       0
# 73                                                 many people go       1
# 74                                           couple thousand evil       0
# 77                                                         im use       0
# 78                   yeah guy never see horse jack clint eastwood       0
# 87                                                           girl       0
# 88                                               burn pine perish       1
# 90                     bianca stratford sophomore dont even think       0
# 92              could start haircut doesnt matter shes allow d...       0
# 103                     katarina stratford youve terrorize blaise       0
# 104                              express opinion terrorist action       0
# 105             well yes compare choice expression year today ...       0
# 106                     still maintain kick ball merely spectator       0
# 107                            point kat people perceive somewhat       0

# %% [markdown]
# ### Tagging the msg with classes

# %%
def define_target(corpus):
    
    if '?' in corpus:
        return 1
    else:
        return 0

# %%
data = messages['msg']

# %%
messages['target'] = [define_target(m) for m in data]

# %%
messages['target'] = messages['target'].astype(int)

# %%
messages.head(20)
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# 61                  L61      u9       m0
# 62                  L62      u8       m0
# 63                  L63      u7       m0
# 64                  L64      u2       m0
# 65                  L65      u7       m0
# 66                  L66      u7       m0
# 67                  L67      u2       m0
# 68                  L68      u7       m0
# 69                  L69      u2       m0
# 70                  L70      u7       m0
# 71                  L71      u2       m0
# 72                  L72      u7       m0
# 73                  L73      u2       m0
# 74                  L74      u7       m0
# 77                  L77      u2       m0
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# 61                        It was a bratwurst. I was eating lunch.
# 62                                 With the teeth of your zipper?
# 63                                               You the new guy?
# 64                                             So they tell me...
# 65                      C'mon. I'm supposed to give you the tour.
# 66                                   So -- which Dakota you from?
# 67                                    North actually. How'd you ?
# 68                     I was kidding. People actually live there?
# 69              Yeah. A couple. We're outnumbered by the cows ...
# 70                       How many people were in your old school?
# 71                                                    Thirty-two.
# 72                                                       Get out!
# 73                                       How many people go here?
# 74                             Couple thousand. Most of them evil
# 77                                              That I'm used to.
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                     can you explain it better?
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# 61                                 With the teeth of your zipper?
# 62                                     can you explain it better?
# 63                                             So they tell me...
# 64                      C'mon. I'm supposed to give you the tour.
# 65                                             talk more about it
# 66                                    North actually. How'd you ?
# 67                     I was kidding. People actually live there?
# 68              Yeah. A couple. We're outnumbered by the cows ...
# 69                       How many people were in your old school?
# 70                                                    Thirty-two.
# 71                                                       Get out!
# 72                                       How many people go here?
# 73                             Couple thousand. Most of them evil
# 74                                             talk more about it
# 77              Yeah but these guys have never seen a horse. T...
#
#                                msg_pre_processed  target
# msg_line_clean
# 49                                   change hair       1
# 50                                                     0
# 51                             might wanna think       0
# 59                                          miss       0
# 60                say expose group freshman girl       0
# 61                           bratwurst eat lunch       0
# 62                                  teeth zipper       1
# 63                                       new guy       1
# 64                                          tell       0
# 65                     cmon im suppose give tour       0
# 66                                        dakota       1
# 67                           north actually howd       1
# 68                      kid people actually live       1
# 69              yeah couple outnumber cow though       0
# 70                        many people old school       1
# 71                                     thirtytwo       0
# 72                                           get       0
# 73                                many people go       1
# 74                          couple thousand evil       0
# 77                                        im use       0

# %% [markdown]
# ### Save data

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229108 entries, 49 to 666576
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   msg_line           229108 non-null  object
#  1   user_id            229108 non-null  object
#  2   movie_id           229108 non-null  object
#  3   msg                229108 non-null  object
#  4   msg_2              229108 non-null  object
#  5   msg_pre_processed  229108 non-null  object
#  6   target             229108 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 14.0+ MB

# %%
messages
# Out:
#                msg_line user_id movie_id  \
# msg_line_clean
# 49                  L49      u0       m0
# 50                  L50      u3       m0
# 51                  L51      u0       m0
# 59                  L59      u9       m0
# 60                  L60      u8       m0
# ...                 ...     ...      ...
# 666522          L666522   u9034     m616
# 666546          L666546   u9027     m616
# 666547          L666547   u9029     m616
# 666575          L666575   u9028     m616
# 666576          L666576   u9031     m616
#
#                                                               msg  \
# msg_line_clean
# 49                                      Did you change your hair?
# 50                                                            No.
# 51                                 You might wanna think about it
# 59                                                  I missed you.
# 60              It says here you exposed yourself to a group o...
# ...                                                           ...
# 666522          So far only their scouts. But we have had repo...
# 666546          Splendid site Crealock splendil I want to esta...
# 666547                                              Certainly Sin
# 666575          Choose your targets men. That's right Watch th...
# 666576          Keep steady. You're the best shots of the Twen...
#
#                                                             msg_2  \
# msg_line_clean
# 49                                                            No.
# 50                                 You might wanna think about it
# 51                                     can you explain it better?
# 59              It says here you exposed yourself to a group o...
# 60                        It was a bratwurst. I was eating lunch.
# ...                                                           ...
# 666522                                         talk more about it
# 666546                                              Certainly Sin
# 666547                                         talk more about it
# 666575          Keep steady. You're the best shots of the Twen...
# 666576                                 can you explain it better?
#
#                                                 msg_pre_processed  target
# msg_line_clean
# 49                                                    change hair       1
# 50                                                                      0
# 51                                              might wanna think       0
# 59                                                           miss       0
# 60                                 say expose group freshman girl       0
# ...                                                           ...     ...
# 666522                  far scout report small impi farther north       0
# 666546          splendid site crealock splendil want establish...       0
# 666547                                              certainly sin       0
# 666575              choose target men thats right watch marker 55       0
# 666576          keep steady youre best shot twentyfourth bunch...       0
#
# [229108 rows x 7 columns]

# %%
messages.to_csv('./chatdata/movie_lines_pre_processed.tsv', index=False, sep='\t', header=True)

# %%
messages[0:3000].to_csv('./chatdata/movie_lines_pre_processed_for_test.tsv', index=False, sep='\t', header=True)
