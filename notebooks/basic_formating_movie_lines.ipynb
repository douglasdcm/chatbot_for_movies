# %% [markdown]
# ## A intenção do projeto é criar um chatbot baseado em reviews de filmes para que se possa fazer perguntas e manter uma conversa livre
#
# - link do banco de dados https://www.kaggle.com/Cornell-University/movie-dialog-corpus?select=movie_lines.tsv
# - referências
# >- https://shanebarker.com/blog/deep-learning-chatbot/
# > -https://towardsdatascience.com/how-to-create-a-chatbot-with-python-deep-learning-in-less-than-an-hour-56a063bdfc44

# %%
import pandas as pd
import re
import numpy as np

# %%
#setting parameters for data visualization
np.set_printoptions(threshold=None, precision=2)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('precision', 2)

# %% [markdown]
# ### Opening movie reviews

# %%
messages = pd.read_csv('./chatdata/movie_lines.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
messages.columns = ['msg_line', 'user_id', 'movie_id', 'user_name', 'msg']

# %%
messages.head(10)
# Out:
#   msg_line user_id movie_id user_name  \
# 0    L1045      u0       m0    BIANCA
# 1    L1044      u2       m0   CAMERON
# 2     L985      u0       m0    BIANCA
# 3     L984      u2       m0   CAMERON
# 4     L925      u0       m0    BIANCA
# 5     L924      u2       m0   CAMERON
# 6     L872      u0       m0    BIANCA
# 7     L871      u2       m0   CAMERON
# 8    "L870      u0       m0    BIANCA
# 9     L869      u0       m0    BIANCA
#
#                                                  msg
# 0                                       They do not!
# 1                                        They do to!
# 2                                         I hope so.
# 3                                          She okay?
# 4                                          Let's go.
# 5                                                Wow
# 6     Okay -- you're gonna need to learn how to lie.
# 7                                                 No
# 8  I'm kidding.  You know how sometimes you just ...
# 9                   Like my fear of wearing pastels?

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304713 entries, 0 to 304712
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   msg_line   304713 non-null  object
#  1   user_id    304713 non-null  object
#  2   movie_id   304713 non-null  object
#  3   user_name  304670 non-null  object
#  4   msg        303815 non-null  object
# dtypes: object(5)
# memory usage: 11.6+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id user_name     msg
# count    304713  304713   304713    304670  303815
# unique   304713    9035      659      5929  265093
# top     L362967   u4525     m289      JACK   What?
# freq          1     537     1530      3032    1679

# %% [markdown]
# ## Pre-processing data

# %% [markdown]
# ### msg_line

# %%
messages['msg_line'].size
# Out:
# 304713

# %%
#removing " (quotes)
messages['msg_line'] = [line.replace('\"','') for line in messages['msg_line']]

# %% [markdown]
# ### user_id

# %%
#nothing to do

# %% [markdown]
# ### user_name

# %%
data = messages['user_name']

# %%
#There are some user_name concatenaed with messages. For these, the value will be copied to msg column
incorrect_user_names = set([n for n in data if not(str(n).isupper())])
incorrect_user_names
# Out:
# {"A.T.L I'm not sure.  We have no launch protocol; the entry of the passenger is supposed to initiate activation.",
#  "A.T.L There is no abort procedure -- we don't know how we turned the damn thing on let alone how to turn it off.",
#  "A.T.L There's no plug to pull.",
#  'A.T.L We have benzel activation repeat we have benzel activation.  Control to Arroway you okay in there?  Repeat Control to Arroway come back.',
#  "A.T.L We've lost contact.",
#  "BUSTER You're* a doctor Homer--you don't smell like ether.",
#  'C.O ""We\'ll all have lunch.""  Good idea. Oh and let\'s be sure to invite this sociologist too -- just in case we want to have a FUCKING BRIDGE GAME AFTERWARDS!"',
#  "C.O -- nothing I can do about it unless you're suggesting I infringe on their civil liberties -- which I'd happily do if you'll just trim a little fat off the Constitution.",
#  "C.O All right lieutenant give me a name and specifics I'll have the X.O. file an action first thing in the morning.  A name?",
#  "C.O And if you just happen to wash out I won't have to contend with you bitchin' to some hairy-chested female Senator?  And please note I did not identify any one in particular.",
#  'C.O Are you rated to repair a Marauder power suit Rico ?',
#  'C.O Basically -- he asked me if I could unring a bell.',
#  "C.O Because I was civil now you're complaining.",
#  'C.O Did you just barge in here and curse at your base commander?  If so I regard that as a bonafide brain- fart and I resent it when people fart inside my home.',
#  'C.O Did you just have a brain-fart?',
#  "C.O Didn't take long.",
#  'C.O Do you freely admit to the charges made against you ?',
#  "C.O Don't worry about it.  If it's off your collar and out of your eyes that's all I'm going to ask.",
#  'C.O I don\'t know of any delicate way to say this lieutenant so I won\'t try.  Claims have been made that you have engaged in fraternization -- of the same-sex variety.  Specifically that you were...  ""... seen leaving the apartment of another female officer at such a time and in such a manner as to suggest conduct unbecoming."""',
#  "C.O I don't see how O'Neil.  Dismissed.",
#  "C.O I find this as distasteful as you lieutenant.  But if it's on my desk it's on my shoulders.  There's going to be an inquiry -- it will not be quick and it will definitely not be pretty.  You should prepare yourself.",
#  "C.O I'm not out to change your sex lieutenant.  You'll have separate beds separate heads.  If you have specific medical needs inform the infirmary.  If a classmate or superior acts in an harassing or otherwise unbecoming manner please inform me immediately so I can deal with it immediately.  Questions?",
#  "C.O I'm not sure what --",
#  "C.O If you were like everyone else lieutenant I suspect we wouldn't be making statements about not making statements would we?  Take your leave.",
#  'C.O No sir WHAT?',
#  "C.O Of course but there's more --",
#  'C.O Oh really.',
#  "C.O Permission to evaporate O'Neil.",
#  'C.O Rico did you give the recruit permission to remove his helmet ?',
#  'C.O Senator they stand out on the public highway with telephoto lenses --',
#  "C.O So.  We're still coming to terms with the exact protocol for this -- for integrating the Spec-Recon training.  It may not always be smooth but we're trying to make it as painless as possible for you.",
#  "C.O Sorry son. I can't do it. You signed the 1240/A. It would be illegal.",
#  'C.O Standing right here in my office.',
#  'C.O Straight up?',
#  'C.O Then good night.',
#  "C.O Then that's all I have to say. Dismissed.",
#  'C.O Then why did you order your man to remove his helmet during a live fire exercise ?',
#  'C.O Uh V.I.P. security arrangements generally take some time Senator.',
#  "C.O Well if you had to go over my head lieutenant that's the way to do it.  Christ nothin' like a 0-200 call from the Commander and Chief to get the bowels movin'.",
#  "C.O Well.  'Least now we're talking the same language.  So one standard.  Is that what you're after?",
#  "C.O What I resent lieutenant is some politician using my base as a test tube for her grand social experiment.  What I resent is the sensitivity training that is now mandatory for my men... the day-care center I have to build where an officer's lounge used to be... and the OB/GYN I have to keep on staff just so someone can keep track of your personal pap smears.  But most of all lieutenant I resent your perfume however subtle it may be competing with the aroma of my fine three-dollar-and-fifty- nine cent cigar which I will happily put out this very instant if the phallic nature of it happens to offend your goddamn fragile sensibilities.  DOES IT?",
#  'C.O Would you care for a beverage?  Tea?',
#  'C.O Yes of course.  Please have a seat lieutenant...',
#  "C.O You makin' friends with the press lieutenant?",
#  "C.O You'll get everything you want O'Neil.  Let's see if you want what you're gonna get.",
#  'C.O Your prerogative Senator.',
#  "CARETAKER You* find out I can't.",
#  "CASY Some*body got to take the blame. They just *got* to hang it on somebody you know.  An' I ain't doin' nothin' but set around.",
#  "CASY Used* to be. Not no more. I lost the call.  But boy I sure *used* to have it! I'd get an irrigation ditch so squirmin' full of repented sinners I pretty near *drowned* half of 'em!  But not no more. I lost the sperit.",
#  "CREIGHTON Screw* you--Jesus! Take it to a lawyer! No I insist! This is *dry* cleaning this is not some fly-by- night thing here! I must say I've been an entrepreneur for thirteen years and I've never--",
#  'D. B . . . Er this John Doe idea is yours huh?',
#  "D. B Ah you bet your life you didn't! You look in your papers ladies and gentlemen and you'll find Miss Mitchell's signed confession that she was the one that wrote it!",
#  'D. B All right but present it to him as a great cause for the common man.',
#  "D. B And Miss MitchellÂ\x97I think from now on you'd better work directly with me.",
#  "D. B And what about the suicide note? You didn't write that either!",
#  "D. B Devoted entirely to the interests of all the John Does all over the country. Which practically means ninety per cent of the voters. He will also announce the third party's candidate for the presidency. A man whom he personally recommends. A great humanitarian; the best friend the John Does have.",
#  "D. B Did you write itÂ\x97or didn't you?",
#  "D. B Do it and I'll give you a hundred dollars a week.",
#  'D. B Go ahead open it open it.',
#  'D. B Go down to the office and arrange for some radio time.',
#  "D. B Hello. Whenever there's a pretty woman around erÂ\x97  This is my nephew Ted Sheldon Miss Mitchell.",
#  'D. B Hello?',
#  'D. B How much money do you get?',
#  'D. B Huh? Get what?',
#  "D. B I think maybe you'd better. And ConnellÂ\x97I'd like to have the John Doe contract all the receipts for the money we have advanced him and the letter Miss Mitchell wrote for which I gave her a thousand dollars.",
#  'D. B I want it as soon as possible.',
#  'D. B Is there anything wrong?',
#  "D. B It's not a lie! Nickels and dimes! To stuff into their own pockets! You can read all about it in the newspapers there!",
#  'D. B Let go of me!  This man had no intention of jumping off of the top of a building! He was paid to say so!  Do you deny that?',
#  "D. B Money?  Well I'm glad to hear somebody admit it. Do you suppose you could write a radio speech that would put that fellow over?",
#  "D. B No no noÂ\x97that's your seat.",
#  "D. B Now hold on a minute young man! Hold on! That's rather big talk! I started the John Doe clubs with my money and I'll decide whether or not they're being properly used!",
#  "D. B That's only the beginning. You play your cards right and you'll never have to worry about money again. Oh I knew it.",
#  "D. B There! You see? He admits it! You're a fake John Doe! And for what you've done to all these good peopleÂ\x97they ought to run you out of the countryÂ\x97and I hope they do it!",
#  "D. B There's nobody holding you here Mr. Doe.  It's only natural that peopleÂ\x97",
#  'D. B Thirty dollars? Well er what are you after? I mean what do you want? A journalistic career?',
#  'D. B Tomorrow night before a crowd of fifteen thousand people and talking over a nation-wide radio hook-up John Doe will announce the formation of a third party.',
#  "D. B Well don't say anything at all. Just sit down.",
#  'D. B Well?',
#  "D. B Were you paid for itÂ\x97or weren't you?",
#  'D. B Why certainly. With your ability to influence people it might grow into a glorious movement.',
#  'D. B WhyÂ\x97uhÂ\x97',
#  'D. B Yes. The John Doe Party.',
#  'D.T So what?',
#  "D.T We're by Ozone...",
#  'D.T What do you need?',
#  'D.T What do you think?',
#  'D.T Yeah?',
#  'D.T You mean shut your ass down!',
#  "DAVIS Used* to be your land. B'longs to the comp'ny now.",
#  'DESK SGT Just missed Deleon.  Hayes is up in the squad.',
#  "DESK SGT No I think he's up in interrogation.",
#  "DESK SGT That's Deleon and Hayes' collar.",
#  'DESK SGT Yeah.',
#  "DIZ I'm* just waiting for a street car--",
#  "DORIS That means I don't run Nirdlinger's!*",
#  'ED I* was with her.',
#  'FIRST A.D ""Suspicions of arson these fires believed set by a disturbed Teenager were in fact the inspiration for the formation of..."""',
#  'FIRST A.D A witness to what...?',
#  'FIRST A.D Could you tell me where a fellow goes to get a drink in this town?',
#  'FIRST A.D Have you got the new pages on the Old Mill?  Hey, Bob.',
#  'FIRST A.D He should be put in jail.',
#  "FIRST A.D I can't find the writer.",
#  "FIRST A.D I don't know what she's bitching about she's flashed her tits in the last five movies...she'd bare her breasts to do a <u>voice</u> over.",
#  'FIRST A.D I have to talk to you.  My wife...',
#  "FIRST A.D I'm looking for the writer.",
#  "FIRST A.D I'm trying honey...I'm...look is your Ma when is your <u>Mom</u> coming?  Oh.  What did the <u>midwife</u>...?",
#  "FIRST A.D I'm very sorry I...",
#  'FIRST A.D It burnt down.',
#  'FIRST A.D Mmmm.  You have children?',
#  "FIRST A.D My <u>wife's having a baby</u>...",
#  'FIRST A.D My wife is going to have a baby and...',
#  'FIRST A.D My wife just went into labor...',
#  "FIRST A.D My wife's going to have a baby.",
#  'FIRST A.D Sure.',
#  "FIRST A.D That's right.",
#  'FIRST A.D The writer.',
#  "FIRST A.D They think it's your First Wife...",
#  "FIRST A.D Town's out of lilacs.",
#  "FIRST A.D We can't shoot in the Old Mill.",
#  'FIRST A.D You bet he did.',
#  'FIRST A.D You mean <u>with White</u>...?',
#  'FIRST A.D You mean you need a witness in addition to White...?',
#  'FIRST A.D You should.',
#  'FUZZY Liver* killed him?',
#  "GRAMPA Ain't* a-goin'... ain't a-goin'...",
#  'H.L Dammit Sam the people are concerned about crime--',
#  "H.L Historic occasion isn't it?",
#  "H.L Jorge and his Chamber of Commerce boys got to keep things hummin'--",
#  "H.L That kind of talk doesn't help Sam.",
#  "H.L That's a matter of interpretation--",
#  'H.L When we backed you--',
#  "H.L Which is why we need to talk to you about the new jail--just so we're all on the same page.",
#  "HANS  Well have a look at what our friends outside are doing and I'll be right up.",
#  "HOMER Go* anywhere? Of course not! That would be *doing* something wouldn't it? We wouldn't want to *do* something. Let's just sit here all night!",
#  'HOMER What* will be okay?',
#  'J.D ""I die knowing no one knew the real me."""',
#  'J.D ""To me though suicide is the natural answer to the myriad of problems life has given me."""',
#  'J.D ""You say tomayto I say tomahto. Let\'s call the whole thing off...Hold it!"',
#  'J.D A well-timed lightning bolt through her window and Monday morning all the other heathers shit everybody would be cast fucking adrift.',
#  'J.D Adolescence is a period of life fraught with anxiety and confusion.',
#  "J.D Alright!  She did good!  Didn't she?",
#  'J.D And your worst enemy.',
#  'J.D Aw God.',
#  'J.D Catch a movie? Miniature Golf?',
#  'J.D Chick-en.',
#  'J.D Did to.',
#  'J.D Did you get married real young?',
#  'J.D Did you miss him completely?',
#  'J.D Do you take German?',
#  "J.D Don't move! I'll get him back!",
#  "J.D Don't worry. I'll ask you to do me a favor. You'll get the negatives and everything back then.",
#  'J.D Dreadful etiquette. I apologize.',
#  "J.D Everybody's life's got static. Is your life perfect?",
#  "J.D Exquisite but I don't think ununderstanding is a word.",
#  "J.D Football season's over Veronica. Kurt and Ram had nothing to offer the school but date-rapes and A.I.D.S. jokes.",
#  'J.D Fuck.  Fuck.  Fuck.  Fuckes.  Snot... Fuckee.  You want to use that?',
#  "J.D Get crucial. We won't be using blanks this time.",
#  'J.D Good plan.',
#  'J.D Heather Chandler is more popular than ever now.',
#  'J.D Heather Chandler is one bitch that deserves to die.',
#  "J.D How do you know I took it?  How do you know they didn't just give it to me?",
#  'J.D How do you think Mr. Kelly would react to a son with a limp wrist with a pulse?',
#  "J.D Human nature.  I'm majoring in behavioral science.",
#  'J.D I am the great and powerful Oz...',
#  "J.D I could be up for that. I've already started underlining <u>meaningful</u> passages in Heather's copy of Catcher in the Rye if you know what I mean. So are we on?",
#  "J.D I don't get it! You were wrong! I was right! Strength damnit! Come back!",
#  "J.D I don't know.  Nowhere.  What are you doin'?",
#  "J.D I don't really like your friends either.",
#  "J.D I guess I don't know what the hell I'm talking about.",
#  'J.D I knew that loose was too noose! I mean noose too loose! Goddamn you!',
#  "J.D I may be the outlaw but you're the one stealin' my heart.",
#  'J.D I saw the croquet set-up in the back. Up for a match?',
#  "J.D I think you can. In Catcher in the Rye Holden says his ideal job'd be making sure some kids don't fall off a cliff. He doesn't realize if you pay too much attention to the kids you'll back off the cliff yourself.",
#  'J.D I was just making it more special.',
#  "J.D I'm a Pine-Sol man myself.",
#  "J.D I'm a robber.",
#  "J.D I'm just a little freaked all right?  You got what you wanted you know.",
#  "J.D I'm just some guy.  A guy whose parole officer is probably having a shit fit right about now.",
#  "J.D I've always believed if done right armed robbery doesn't have to be a totally unpleasant experience.",
#  "J.D I've been moved around all my life; Dallas Baton Rouge Vegas Sherwood Ohio there's always a 7-11. Any town any time I can pop a Ham and Cheese in the microwave and feast on a Big Wheel. Keeps me sane.",
#  "J.D If you'll excuse me......",
#  'J.D Incredible similarity.',
#  "J.D It doesn't work on small animals!",
#  "J.D Jason why don't you ask your little friend to stay for dinner.",
#  "J.D Just a humble perk from my Dad's Construction company or should I say Deconstruction company?",
#  "J.D Just push the red button twice. That's what stops it. If that's what you want babe?",
#  "J.D Just saying it's not hard to end a life.",
#  'J.D Look at that. Eskimo. One word. I love it. I usually go for whole sentences myself but hey this is perfecto. Eskimo. So mysterious...',
#  'J.D Man Veronica pull the plug on that shit. I say we go with Big Blue.',
#  "J.D Maybe it's time for a vacation.",
#  'J.D Move away from me.',
#  'J.D Mute!',
#  'J.D My father seems to enjoy tearing things down more than putting things up. Seen the commerical? ""Bringing every State to a Higher State."""',
#  'J.D Nag nag nag nag. nag.',
#  "J.D Naw honey that would be burglary. I never got arrested for burglary. Burglary's for chicken shits.  If you're gonna rob someone ya just have to go right on up to 'em and do it.  Just take the money.  That's robbery.  That's a whole 'nother deal.",
#  'J.D Nice. The last time I saw my Mom she was waving out the window of a library in Texas. Right <u>Dad</u>?',
#  'J.D No.',
#  "J.D Nope.  I've never robbed a bank.",
#  'J.D Now that you mention it they might have been a little bit jumpy.',
#  'J.D Of course.',
#  "J.D Oh I just had the <u>nicest</u> chat with Ms. Dumptruck. Got along famously! It's scary how everyone's got a story to tell....Would you care to see the canoeing shots?",
#  "J.D Oh.  I... where's Louise?",
#  "J.D Okay we'll use this. She won't be able to tell what she's drinking.",
#  "J.D Our love is God. Let's get a Slurpee.",
#  "J.D Our relationship's moving fast I know but I have real real respect for you.",
#  'J.D Our sins? What sins? If you put a Nazi in a concentration camp does that make you a Nazi?',
#  'J.D Perrier water!',
#  "J.D Phase my ass! You'll be <u>back</u>! I'm storming Normandy beaches and you're running in place with Pauline Fonda's airhead peacenik exercise program. Have to stay tough! You'll be back.",
#  'J.D Probably just row on out to the middle of a lake. Bring along my sax some tequila and some Bach.',
#  "J.D Remember he's left-handed.",
#  'J.D See the condoms in the grass over there. We killed tonight Veronica. We murdered our baby.',
#  "J.D She wants to ignore the high school experience. Our way's better. We scare people into not being assholes.",
#  "J.D So how come you don't have any kids?",
#  "J.D Some teenybopper rag says Big Fun wants to play a Prom. It could be Westerburg's if we can get everyone's John Hancock.",
#  'J.D Something tells me you picked up the wrong cup.',
#  "J.D Strength. Westerburg doesn't need mushy togetherness it needs a leader. Heather Chandler was that leader but...",
#  'J.D That only proves my point more. The word is a badge for her failures at school.',
#  'J.D That sounds nice.',
#  'J.D That was my first game of Strip Croquet you know. I thank you.',
#  "J.D That's lonely for you I guess.  I always think of motel rooms as lonely.",
#  "J.D That's the stupidest question I've ever heard.",
#  "J.D The extreme always makes an impression but you're right it was severe. Did you say a Cherry or Coke Slurpee?",
#  "J.D Thelma?  It's me.",
#  "J.D Then let's just concoct ourselves a little hangover cure that'll induce her to spew red white and blue.",
#  'J.D There are no stupid questions.',
#  "J.D These are Ich Luge bullets. My grandfather snared a shitload of them in W.W. Two. They're like tranquilizers only they break the surface of the skin enough to cause blood but not any real harm.",
#  'J.D They used them on themselves to make it look like they were dead. Really quite a brilliant device but too flamboyant to seriously produce.',
#  "J.D This is Ohio. If you don't have a brewsky in your hand after dark you might as well be wearing a dress.",
#  "J.D This is the last thing she'll ever write. She'll want to cash in on as many fifty-cent words as poss.",
#  "J.D Uh well hey let's take a look at the homosexual artifacts I dug up. Now prepare to be a little disappointed.",
#  "J.D Uh-uh.  I'm a little freaked right now about seeing my father though.",
#  'J.D Umm yes.  She was driving.',
#  "J.D We did a murder. In Ohio that's a crime. But if this was like a suicide thing.....",
#  "J.D We've got a Playgirl a candy dish a Joan Crawford post card and lipstick.",
#  "J.D Well I guess I'd better...",
#  "J.D Well I robbed a gas station once and I robbed a couple of liquor stores and some convenience stores. And that's it.",
#  "J.D Well I was just down on my luck and it seemed like somethin' I was good at so I...",
#  "J.D Well first you pick your place see then I'd just sit back and watch it for awhile.  Ya gotta wait for just the right moment which is something you know instinctively that can't be taught.  Then I'd waltz on in...",
#  "J.D Well if you don't mind me sayin' so he sounds like a real asshole.",
#  "J.D Well not anymore Thelma except for bustin' parole I haven't done one wrong thing.",
#  "J.D Wha-at? Come on there's another T.V. in the kitchen. You know you used to have a sense of humor.",
#  'J.D What are we going to tell the cops? ""Fuck it if she can\'t take a joke Sarge."""',
#  "J.D What in the hell do you think I'm doing? Taking out her tonsils?",
#  'J.D What is this shit?',
#  'J.D What?',
#  "J.D Who's the nut?",
#  'J.D Yeah great.',
#  'J.D You believed it because you wanted to believe it. Your true feelings were too gross and icky for you to face.',
#  "J.D You didn't say Simon Says.",
#  "J.D You don't get it do you? Society nods its head at any horror the American teenager can think to bring upon itself. We don't need gloves and does anyone really care about exact handwriting?",
#  'J.D You going to pull a Big Gulp with that?',
#  'J.D You kids are making too much damn noise.',
#  'J.D You know it. Oh man I almost forgot. The one perfecto thing I picked up...',
#  'J.D You might say we had a meeting of the minds yes.',
#  'J.D You really fucked me up Veronica.',
#  "J.D You want to wipe the slate clean as much as I do. Okay so maybe I am killing everyone in the school because nobody loves me. You have a purpose though! Remember? Let's face it the only place different social types can genuinely get along with each other is in heaven.",
#  "J.D You're a little angle you are.",
#  "J.D You're not listening. People are going to look at the ashes of Westerburg and say there's a school that self-destructed not because society didn't care but because that school <u>was</u> society. Is that deep or what? I'll let you put it in your diary babe. Free of charge.",
#  "J.D You've got power Veronica. Power I didn't think you had. The slate is clean.",
#  'J.D Yup.  Thanks for the ride.  You all take care.',
#  "J.P Condolences. How you fixed for cabbage this mornin'?",
#  'J.P Raise a hand to me and... .',
#  "J.P You'd be off the pier for good.",
#  "J.P You'll work.",
#  "J.R I saw you fight Bob Satterfield in '46 Jake. In Chicago. You were great.",
#  "J.R Where's your wife Jake?",
#  "J.R You were great Jake. Just like old times. Good thing Sugar Ray wasn't here tonight. Oh Jake this is State's Attorney Bronson and his wife.",
#  'J.T Half the gunslingers that drift into town turn up on our police force.',
#  "J.T His son is worse than he was. He's smoother so you don't always hear him coming but he'll do anything to keep his range free.",
#  'J.T The problem is Emmett you killed the wrong McKendrick.',
#  "JACK SR Don't be stubborn. The pay won't be grand but it's regular. That's what you need isn't it? I know you don't like taking my advice...",
#  "JACK SR Don't let yourself down.",
#  "JACK SR For Christ's sake Jacko don't look a gift horse in the mouth. Have you written that name down? Reynolds at the Golden Lion. ",
#  'JACK SR Found a job?',
#  "JACK SR Great. I've just started a new company. Solid financing. It's good.  I love you Jacko you know that",
#  "JACK SR I've set this up for you. Call the Golden Lion and ask for Mr Reynolds he's the Manager. I don't know him personally but I've spoken to his boss. Don't say no Jacko. Give yourself a break.",
#  "JACK SR Well I've got something for you. In London I mean. I've been chatting to some friends. Do you know the Golden Lion casino? It's in Bayswater I believe... They're looking for a dealer a croupier.",
#  "JEFFERSON Gentlemen*! Gentlemen are supposed to believe in something decent. Instead of twisting facts and making a joke of everything--why don't you tell the people the *truth* for a change?",
#  'JEFFERSON This* is.',
#  "JEFFERSON Who*! Miss--! Is that--? Why didn't you--? Holy smoke;  H-hello... Yes Miss Paine... How-- how are you Miss Paine...? What?... Escort *you* Gee--I mean--*sure*-- *yes*! I'd be--. Reception for a *princess*! Gosh!... Thanks Miss Paine. Yes. I--I'll be there! Goodbye Miss Paine.  Did you hear that?--Escort Susan Paine--reception for a princess! Imagine her calling me--asking *me*-- !",
#  'KANE SR If I want to I can go to court. A father has a right to -',
#  'KANE SR Sorry Mr. Thatcher!  What the kid needs is a good thrashing!',
#  "KANE SR That's the train with all the lights.",
#  "KANE SR Well let's hope it's all for the best.",
#  'KANE SR Yes.',
#  "KANE SR You people seem to forget that I'm the boy's father.",
#  "KANE SR You're going to live with Mr. Thatcher from now on Charlie!  You're going to be rich.  Your Ma figures - that is er - she and I have decided that this isn't the place for you to grow up in. You'll probably be the richest man in America someday and you ought to -",
#  'KORSHUNOV                      Please tell me your name.',
#  "L.C First he's gonna shit. And then he's gonna kill us.",
#  'L.C He is.',
#  "L.C Hey slow down. This is my brother's car.",
#  'L.C I like sex.',
#  "L.C My brother is going to kill us. He's gonna kill you and then he's gonna kill me. He's gonna kill us.",
#  'L.C My brother is gonna shit.',
#  "L.C My brother's car!",
#  'L.C Seen the new Playboy?',
#  "L.C Suzanne Somers' tits.",
#  "L.C That's him! He did it!",
#  "L.C They're fuckin' with us.",
#  "L.C This ain't no cop.",
#  'L.C We just missed the turnoff to the party.',
#  "L.C You can't fix this car Spicoli.",
#  "L.T I don't under--",
#  "L.T I'm sorry Mr. Dean. But Larry's in St. Lukes now so I'm a little--I'm not myself. The Union bosses say unless we take Bellmoth's offer it'll only get worse.",
#  "L.T Last night Larry Spinks he works the Steel Press he goes to a bar with his wife Rosalie to have a glass of chianti 'cause it's his birthday and these two guys these Guido mother-fuckers they jump him when he goes to the bathroom.",
#  'L.T Mr. Dean--',
#  "L.T Well that's why I'm here Mr. Dean. 'Cause you're a labor lawyer.",
#  'L.T Why would the Union--',
#  'LARCH Alcohol* killed him--he drank himself to death.',
#  "LARCH No*! I don't want to know him! He's doing *missionary* work--in *India*! I wrote him *weeks* ago but he's either too holy or too busy to answer. Maybe he got killed in the war!",
#  'LEONARD     *  Thank you.       *',
#  "LEONARD  Depends on if he's here in town. Or if he's moved on. See I've got all this -  ",
#  "LEONARD  I'm not too good on the phone. I need to     * look people in the eye when I talk to   * them.       *",
#  "LEONARD  John G. was clever. He took the dead man's gun and replaced it with the sap that he'd hit me with. He left my gun and left the getaway car. He gave the police a complete package. They found a sap with my blood on it in the dead man's hand and they only found my gun. They didn't need to look for anyone else. I was the only guy who disagreed with the facts and I had brain damage.    *",
#  "LEONARD  So I'll take a picture get a tattoo.   *       * The world doesn't disappear when you    * close your eyes does it? My actions    * still have meaning even if I can't     * remember them. My wife deserves     * vengeance and it doesn't make any  * difference whether I know about it.     *",
#  "M.J <u>He</u> won't.",
#  'M.J <u>You</u> called <u>us</u> Doctor Hudson.',
#  'M.J A man?  I thought he was a boy.  This last Christmas was the happiest Christmas I had in the last ten years... you know why?  It was the first Christmas in six years I was not in love.  Son of a bitch <u>married men</u>!  Who cares about marriage the bed just gets crowded and noisy?!',
#  'M.J Am I in charge of this thing?  Or not.',
#  'M.J Answer it.',
#  "M.J Anybody in this department ever worked a serial killer case?  She's the expert.  I need help.",
#  "M.J Because I think I'm wrong.",
#  "M.J Because I'm all you've got.",
#  "M.J Because it's your job that's all.",
#  'M.J Because of your phone calls.',
#  "M.J Bunch of Swedish women.  You're too young.",
#  "M.J Bundy.  That's the last one in your speech...",
#  "M.J But it's a different m.o.",
#  'M.J Can you make a copy we can show on our computers?',
#  "M.J Christ Helen.  The first time we're ahead of the son of a bitch! I can't leave you like this -- and there's no time.  Knock yourself out.",
#  'M.J Clint is putting a guard on you. But if you swear to leave the computer on Winona will assign him to the hall outside.',
#  'M.J Cut the crap.  You got a sheet the length of my arm...',
#  'M.J Detective Niccoletti?',
#  "M.J Do you have any evidence to report ma'am?  Do you know any of the victims...",
#  "M.J Doesn't work that way.  You had your chance now fuck yourself...",
#  "M.J Don't put yourself down like that. I <u>never</u> used you.  I worked my way up like a marine grunt!",
#  "M.J Don't swear at me because we got problems.  I'm just giving you the news.  I went to a Catholic school; I'll tell you what they teach.  On the knuckles they teach.",
#  "M.J Don't try to lie Ruben.  You don't have the face for it.  I need you to help interrogate the burglar in Hudson's place...",
#  'M.J For months... last October.',
#  'M.J Get Mercer to run the medical dental legal bills laundry and dry cleaning receipts extermin- ators mailmen grocery and drugstore deliveries handymen plumbers...',
#  'M.J Get the pictures and casts of footprints.',
#  'M.J Give him <u>that</u>pompous son of a bitch.',
#  'M.J Give me Ruben back...',
#  "M.J God you're cute when you're mad.",
#  'M.J Good.',
#  'M.J Halloran.',
#  "M.J He comes in the window we maybe grab him.  Where's the on-switch?",
#  'M.J He said to send you his regards and to tell you that the Bureau holds you in the highest esteem.',
#  "M.J He'll get caught.  If he has a plan that'll be what trips him up...",
#  "M.J He's just mad he let me keep the espresso machine.  We heard from Doctor Hudson?",
#  "M.J Helen -- let go.  You've got to let go.",
#  "M.J Helen -- the killer directly contacted you.  His interest in you is <u>intense</u>.  I'm worried about you. I don't want to lose you.  I know this stirs up every monster under the bed but this is the only direct contact we have with him. The only chance we have to trap him.  So you can turn Internet back on or I do and we put somebody here on a 24 hour shift and you can kick scream and hyperventilate.",
#  'M.J Helen Hudson...',
#  'M.J Helen hang up let Ruben get on with his work...',
#  'M.J Helen.  I saw him die.  I saw him burning on the basement stairs he never reached the top.',
#  'M.J Helen... excuse me we...',
#  "M.J Hello Ruben...  So that's that...",
#  'M.J Honest to God Ruben!',
#  "M.J How come you're so up on Dr. Hudson?",
#  'M.J How did you know they were stockings?',
#  'M.J How do you know that?',
#  'M.J How many do you need to sleep. Really sheep?',
#  "M.J I did not; the Mouth -- that's what we call Susan Schiffer -- got it on her own.",
#  "M.J I don't look at pictures.  I look at the <u>real thing</u>.  I don't feel infected.",
#  'M.J I gotta have Ruben and a...',
#  "M.J I just came from her... here's what you haven't seen.",
#  'M.J I just got here myself Susan.',
#  'M.J I just got here.  Talk to you later...',
#  'M.J I just thought it was so -- unprofessional.  Of you both!',
#  "M.J I know Windex for God's sake I clean my own windows...",
#  'M.J I put my ass on the line giving you that.',
#  "M.J I think you are.  I really admire everything you've done; it would be an honor to work with you and we need all the help we can get especially yours.",
#  "M.J I want a guard on you.  I'm worried about leaving you alone.",
#  "M.J I want to tell you it's a great honor to meet you and talk to you.",
#  "M.J I'll talk to Conrad myself.  I'll be in the jail when you wind this up...",
#  "M.J I'm checking out anybody who lives like DeSalvo.  Records of arrests for rape especially by a man wearing green.  Checking out psychiatric hospitals for his personality profile.  Cross check- ing names from arrests for sexual offenses public fondling.  If they've got a German wife.  We can keep cops working on this kind of junk for years and this guy's going to hit again soon.",
#  "M.J I'm giving you Clint outside.",
#  "M.J I'm going to put a guard on your door.",
#  "M.J I'm gonna drop charges on the break-and-enter at Hudson's...",
#  "M.J I'm over here?  What's your name Officer?",
#  "M.J I'm sorry it had to come to your attention.  I am dealing with it.",
#  "M.J I'm working on it!  It's what I do.  Quinn...Halloran.  I'll wait.  Where's Andy can we get some coffee in here?",
#  "M.J I've got to go.  I've <u>got</u> to go.",
#  "M.J If this is a first step in kicking me off the case just tell me to my face sir don't waste time being diplomatic.",
#  'M.J If this is just the dump site where did he do the job?  Where did he pick her up?',
#  'M.J Injected Windex!  Why would he switch to a new m.o.?',
#  "M.J Inspector Halloran Homicide.  I'm in charge here.",
#  'M.J Inspector Halloran.  Homicide. You were supposed to contact a Peter Kurten?',
#  "M.J Investigators Halloran and Goetz.  I apologize for Goetz he's a firehouse dog.",
#  "M.J It's also the major piece of evidence and it makes you a key part of his plan.  You can't run away from it anymore.  Look at the order he's doing them... He did three as the Boston Strangler just to tell us a copycat serial killer was at work.  Then he did one like the Hillside Strang- ler.  And then one as Son of Sam. To lead us on -- to where and what end?  And he's doing more than that -- he's imitating each killer's method as closely as he can -- in details.  Injecting Windex.  Using .44.  Playing Abba.",
#  "M.J It's not the same guy.  It should be a self-solver.  No bow around the neck left and body outdoors completely different.  The others were housewives secretaries he talked his way inside killed them in their own living room or bed- or bathroom.  This one didn't have a husband or a boyfriend no family temp waitress 3 arrests for misdemeanor dope offenses DUI asphyxiation probably from a plastic bag over her head.  Sexually assaulted.  The others weren't molested that way.  We're waiting for the sperm tests...",
#  'M.J Just horseshit luck.',
#  "M.J Let's get out of here...",
#  'M.J Look at her legs.',
#  "M.J Look at the sign.  'Hell'?  In the Festival of Love?  You make any sense in that?",
#  "M.J Look.  There's the order:  you wrote it:  DeSalvo Bianchi & Buono Berkowitz and Dahmer.  It's going to be Dahmer next.  Which means he'll kill a man.",
#  "M.J Maybe it's something you did in this life Nikko...",
#  'M.J My promise.',
#  'M.J My third grade teacher at the convent shot better than that.',
#  "M.J No ma'am.  This is no joke.  And neither is tying up telephone lines to police with crank calls while people in trouble are trying to get through for help.",
#  'M.J Nobody knows you have anything to do with this case; nothing has been on TV or the news... Why would he want to get in <u>your</u> computer?',
#  'M.J Nothing.',
#  'M.J Now listen up Ruben.  You never never never mess with somebody <u>inside</u> the case!',
#  'M.J Oh I know.',
#  'M.J Oh maaaaan?!',
#  "M.J Oh shut up and don't be so damn self righteous.",
#  'M.J Okay.',
#  'M.J Or the F.B.I.?',
#  'M.J Order Chinese for us and meet me the library?  Anything but beef.',
#  'M.J Over here.',
#  "M.J Quinn decided we should form a task force -- they're all one case now. He wants all the senior detectives on it...  She wasn't killed here.",
#  'M.J Quinn will be here any minute.  What are you going to say?',
#  'M.J Right.',
#  'M.J Ring the gong he goes.  Poor impulse control.',
#  'M.J Ruben my God I ought to put you on report.',
#  "M.J Ruben's dead.   So stupid a cop thing a crazy kid and a buncha dumb mistakes... I'm sorry... because you and he...",
#  "M.J Ruben's gone to look... It's banged up but it looks like a .44.  It's Son of Sam.  Is it Son of Sam?",
#  'M.J She takes tranquilizers her doctor prescribes.',
#  'M.J She was killed somewhere else and dumped outdoors in an empty lot. Where it says ""no dumping.""  Her legs pulled apart in a kind of sexual pose.   It\'s all different but it seems so -- the same. Artificial and <u>posed</u>... Something\'s wrong with it."',
#  "M.J She's in no shape to give her statement tonight...",
#  "M.J Shut up -- I'm talking.  You got felony breaking and entering burglary felonious...",
#  'M.J Sir Doctor Hudson and I see a pattern develop...',
#  'M.J Snotty neurotic bitch...',
#  'M.J So far nothing they test for comes up positive.',
#  'M.J So.  Do we tell the media and hope for somebody to come forward with information?',
#  "M.J Someone broke into her place last night.  It wasn't connected to our case but it shook her up pretty bad so I haven't...",
#  "M.J Sugar and cream for Goetz; I take mine black.  You're absolutely correct.  The politicians don't want panic headlines spoiling the Festival of Love.",
#  "M.J Sure.  She likes <u>you</u> Rube.  She likes the way you move.  She sure as hell isn't in love with me.",
#  'M.J Tell her about <u>what</u>?',
#  "M.J Tell her we're sorry we bothered her.",
#  'M.J Tell it to your shrink.',
#  "M.J That was Bundy.  He killed forty of them identical long hair parted in the middle alike as Barbie dolls.  ...this is hopeless.  Let's try to get time for a police spokesman to appear on college radio and TV hookups and broadcast a warning?",
#  "M.J That's always your privilege sir.",
#  "M.J That's amazing.  A whole new book thought up in a minute.  Very good.  All I know how t do is get up take a shower and go to work. Hope if he does another I'll nail the son of bitch and they'll spell my name right in the newspaper. Where is Andy going?",
#  "M.J That's an opinion not evidence...",
#  "M.J That's exactly... I could have taken that same picture this morning.",
#  "M.J That's not consistent... You said they never changed their style they're robots...",
#  "M.J The prowler in Hudson's apartment turns out to have a meeting with a suspect...",
#  'M.J The same as the firs two. Definitely a serial.',
#  "M.J The woman's unstable.  You could wind up with a harassment charge. <u>Anything</u>.  You're like some horny little teenager.",
#  'M.J They get fan letters...',
#  'M.J They\'re not talking to me.  Saks looks right through me.  I ask him for some bodies for the phones -- he\'s so encouraging: ""you make that <u>your</u> little job.""  Condescending bastard.  Helen on your lists to call is San Quentin.  Daryll Lee Cullum?"',
#  "M.J This has been the worst 48 hours of my life.  I'm going home.  I'm going to try to get drunk.",
#  'M.J We could use a little help.',
#  "M.J We'll get the paramedics...",
#  "M.J We'll show that to...",
#  "M.J We're going to review all the evidence carefully before making any statement...",
#  "M.J We've got another one.",
#  "M.J Well it's a hell of an apartment you got here.  I'm living one step away from the projects myself but I get to go to work every day wading in blood and guts.  I guess the books you wrote about these sons of bitches paid off pretty good.",
#  'M.J Well thanks.',
#  'M.J Well you outranked <u>me</u> Nikko.',
#  'M.J What Friday?',
#  'M.J What about her arms?',
#  "M.J What clues?  I'm going to work Helen Hudson.",
#  'M.J What does it matter?  This guy you checked your course records who signed up?',
#  "M.J What does this mean?  Now we got the FBI my team is expendable? I'm working my ass off is anybody listening?  Why Ruben anyway?  He and Nikko don't even get on together...",
#  "M.J What's that siren?",
#  "M.J Whatever it is I'm gonna find out and sooner is a hell of lot better than later.",
#  "M.J Where's the john?  Let me clean up this mess and get back to work.",
#  'M.J Who came in after you?',
#  'M.J Who turned off the Internet computer...',
#  'M.J Who?',
#  'M.J Why imitate a dead serial killer?',
#  'M.J Why would he send this to Helen Hudson...',
#  'M.J Work with me.',
#  'M.J Would you want to work with us on this?',
#  "M.J Yeah everything's different.",
#  'M.J Yessir.',
#  'M.J Yessir.  I have reflected on that sir.  Which explains my gushing deference to you sir.',
#  'M.J You already made the delivery?',
#  "M.J You can't go out lecturing?  Tough shit.  Women are dying.  Where can I lay this stuff out?",
#  "M.J You damn well better start working on that impulse control.  A woman who is implicated in this case? Someone who's practically a piece of <u>evidence</u>?",
#  "M.J You don't listen very good.  This break in -- I can call it a felony -- three strikes and you got about sixteen strikes already and you're in jail for the rest of your life no parole.  Or I could see it gets forgotten.",
#  "M.J You got that right Nikko it's none of your business.",
#  'M.J You messed with the evidence.',
#  'M.J You messed with the scene.',
#  'M.J You talked to me.  Do you remember?',
#  "M.J You touch anything Mike?  Pick up anything?  Use the doorknob?  I don't want to find your prints on anything later and you tell me you forgot to tell me.",
#  "M.J You want mine too?  You take his you take mine.  I'm the one fucked it up...",
#  "M.J You were going to make a delivery to Peter Kurten for Daryll Lee Cullum.  I want Kurten's phone number.",
#  "M.J You're afraid of him.",
#  "M.J You're damn right I do.",
#  "M.J You're good enough you'll never have to kill anyone.  I joined the cops to save lives not waste them.",
#  "M.J You're in terrible trouble Nikko.",
#  'MCGANN You* tell Jim Taylor.',
#  'MUDDY What* view?',
#  'MUDDY You* taught her I suppose...',
#  'R.L A naked woman chained in ya house?',
#  "R.L Ain't gonna be moved?",
#  'R.L And now these three remain: faith hope and love. But the greatest of these is love.  Who gives this girl in marriage?',
#  'R.L Are you outta ya GODDAMN MIND?',
#  'R.L Bojo called. Said you got to see your brother at the long end of a broken bottle.',
#  "R.L Goin' dove huntin'?",
#  "R.L Gotta get that chain off her Laz. Somethin' like this gets out you could land in a heap of trouble.",
#  "R.L He knows where ya at. Just answer the door if he come knockin'.",
#  'R.L Heard about this morning.',
#  "R.L I gotta ask you. Why do you think Laz is keepin' you chained like this?",
#  'R.L I just know how you get. Good to know them butterflies still in ya gut.',
#  'R.L I think you did alright by God under the circumstances.  Your people are here for you Laz. This is your home. No shame in showing your face.',
#  "R.L I'm gonna tell you somethin' and it's just gonna be between you and me.  I think folks carry on about heaven too much. Like it's some all-you-can- eat buffet up in the clouds. And folks just gonna do as they're told so they can eat what they want behind some pearly gates. I can go to Shoney's for that.",
#  "R.L Laz I know about that girl.  Good number of this town's sinners got my ear you know.  Oh Laz. She's had a mess of crabs and them STD's. What'chu thinking?",
#  "R.L Mm. MM. Now these eggs got some kick to it. What'chu got in this?",
#  'R.L One thing at a time Laz.',
#  'R.L Or what?',
#  'R.L Pass them potatoes Lincoln.',
#  'R.L Rae look at Ronnie. And tell him how you feel.',
#  "R.L So he got it into his head that the only thing gonna keep you from endin' up bleedin' on the side of the road again without a stitch of clothing on is...  You think he's crazy for thinkin' that?",
#  "R.L Somethin' wrong with ya phone? Been callin' the last few days.",
#  "R.L That kind of talk is between us. Don't you go in there with that shit on your tongue.",
#  "R.L That's right.",
#  'R.L Then what?',
#  'R.L This all looks wonderful.',
#  'R.L Was that Lincoln James I seen run off?',
#  "R.L What's on your mind?",
#  "R.L What's that chain around her for?",
#  'R.L What? I called Bojo like you say. Called up the fellas in the band...',
#  "R.L Why's his britches round his knees?",
#  'R.L Yeah you know you home old man. You just walked through the door.',
#  "R.L You ain't gonna make a fuss are you?  Nothing a man can do when a woman make up her mind.",
#  'R.L You believe He wants this? A woman chained to ya radiator?',
#  'R.L You could put it that way.',
#  'R.L You get a call from Rose?',
#  'R.L You mean with you and that woman chained to ya radiator?',
#  'R.L You say she was beat on. You call the sheriff on that?',
#  "R.L You sayin' that gun's for me if I don't?",
#  'RECEPTIONIST ...Mr. Athol will be with you as soon as possible. Will you be able to wait?',
#  "RECEPTIONIST I'm sorry. We're running behind. So many applicants...so few jobs... If you'll just have a seat.",
#  'RECEPTIONIST Is there anything else?',
#  "RECEPTIONIST Water fountain's through that door down the hall.",
#  "REDBEARD It would have been a beautiful bridge John. I never noticed before occupied with other business I suppose...  ...never really pay much attention to that kind of thing but I've had the time today nothing else on and this... it's graceful and the placement couldn't be prettier... and... ",
#  "ROSE ROSE Happy*! What are you thinkin'? How am I supposed to take care of a baby! I can't have a baby.",
#  "SAUNDERS All right*, then. After all, what's it to me? So they *drop* him out of a balloon. All I care is--I don't want to be around. See? Squeamish. See? That's what I am. No, sir. I don't have to take it. Won't be a party to no murder. I'm gonna quit. I'm through.",
#  "SAUNDERS Me! Me*! I *still* don't see why I should--! If you love him so much why don't you go to him yourself and-- ? Or better still--get up in that Senate and *fight* for him!",
#  'SAUNDERS No*!',
#  "SHEPHERD                      CBS said they'll give us four minutes.  They thought the Russian was a nice touch.",
#  "SHEPHERD                      We could always put you in a duck blind with a twelve gauge.  The second amendment types'll love that.",
#  "T.J Bad fuckin' news.  Even the families dropped him when they found they had a fruitcake on their hands.  But he knows where a lot of bodies are buried.  It'd cap it for Garber if he could bring him in.",
#  "T.J Be happy.  He's good at this.",
#  'T.J Computer device?',
#  'T.J Device.',
#  "T.J Do it or look for another profession.  That's a choice I guess.",
#  'T.J Fuck factor ten.',
#  'T.J Fuckin A I think I got two partial prints here!',
#  'T.J Glass what is it?',
#  'T.J Got it! Ace Match Company Flint Michigan.',
#  "T.J He's married he don't even know what a lesbian is.",
#  'T.J Helluva fuck factor.',
#  "T.J Hey I'm next.",
#  'T.J Hey Mike out of the bag into the bureau huh... How do you like it so far?',
#  'T.J IRA - instant retirement account.',
#  "T.J In this crowd? It's gonna be Marlboros Camels and maybe a few Kools.",
#  'T.J Jesus...',
#  'T.J Lane oil...',
#  "T.J Let's face it we all knew it would happen sooner or later. The guy who can build a mousetrap that's better than we are ...",
#  'T.J Make an appointment.',
#  'T.J My first undercover assignment. I gotta look good right?',
#  "T.J No we're terrorists stay back or we'll blow.",
#  'T.J Pooch can you move it?',
#  'T.J Quiet!',
#  'T.J Scorch marks... looks like they used silly putty.',
#  "T.J So what're we looking for?",
#  "T.J Tell me I'm dreamin'.",
#  "T.J That feeling won't last long.",
#  "T.J That guy's wife must be pretty pissed off to play a trick like that.",
#  "T.J That's one more time than any of the rest of us have seen it.",
#  'T.J Vice cop on a homicide?',
#  'T.J Vice... Jesus.',
#  "T.J Wasn't your fault.",
#  "T.J We've created a monster.",
#  "T.J We've lost brothers too we know what that's like.",
#  'T.J What do ay say?',
#  "T.J Yeah he's helping us work up a profile on this thing.",
#  'T.J Yeah!  Seniority gets the day shift.',
#  'TAYLOR But you never asked me*!',
#  'TAYLOR Henry Hill?* That crackpot? That long-haired--! Why you should have killed that so fast--!',
#  "TAYLOR I* know what I'm doing! I'll say what I *want*!",
#  "TAYLOR You won't?*",
#  "TAYLOR Your* political future! I bought it for you and made you a present. And I can grab it back so fast it'll make your head spin. You got a nerve to stand there and worry about just *your future* when we're in this spot!  The man is--*Miller*.",
#  'U.S.M.P His name?',
#  'U.S.M.P Okay.',
#  'U.S.M.P Passport please.',
#  "U.S.M.P What's the purpose of your visit here?",
#  'U.S.M.P Where are you staying?',
#  "WALLY And* over the Himalayas. That's called flying over the hump.",
#  "WALLY Homer* liked it!  Didn't you?",
#  nan}

# %%
#copy incorrec_user_name to msg column
for i in range(len(data)):
    if data[i] in incorrect_user_names:
        messages['msg'][i] = data[i]

# %%
#checking if the data is copied
messages[messages['user_name'] == 'C.O Because I was civil now you\'re complaining.']
# Out:
#       msg_line user_id movie_id  \
# 31938  L241782   u1008      m66
#
#                                              user_name  \
# 31938  C.O Because I was civil now you're complaining.
#
#                                                    msg
# 31938  C.O Because I was civil now you're complaining.

# %%
#the user name will not be used in this database as there is the user id
messages = messages.drop(columns=['user_name'])

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id     msg
# count    304713  304713   304713  304405
# unique   304713    9035      659  265679
# top     L362967   u4525     m289   What?
# freq          1     537     1530    1679

# %%
#saving data to file because msg column depends on it
messages.to_csv('./chatdata/movie_lines_normalized.tsv', index=False, sep='\t', header=False)

# %% [markdown]
# ### msg

# %%
messages = pd.read_csv('./chatdata/movie_lines_normalized.tsv', header = None, delimiter="\t", quoting=3, encoding='ISO-8859-2')

# %%
messages.columns = ['msg_line', 'user_id', 'movie_id', 'msg']

# %%
messages.head(10)
# Out:
#   msg_line user_id movie_id                                                msg
# 0    L1045      u0       m0                                       They do not!
# 1    L1044      u2       m0                                        They do to!
# 2     L985      u0       m0                                         I hope so.
# 3     L984      u2       m0                                          She okay?
# 4     L925      u0       m0                                          Let's go.
# 5     L924      u2       m0                                                Wow
# 6     L872      u0       m0     Okay -- you're gonna need to learn how to lie.
# 7     L871      u2       m0                                                 No
# 8     L870      u0       m0  "I'm kidding.  You know how sometimes you just...
# 9     L869      u0       m0                   Like my fear of wearing pastels?

# %%
data = messages['msg']

# %%
#remove the name of the users

# %%
#replace nan msg with UNKNOWN
messages = messages.fillna('UNKNOWN')
data = messages['msg']

# %%
#replace '' messages
messages['msg'] = [re.sub(r' +', ' ', m) for m in data]
messages = messages.replace(' ', 'NO ANSWER')

# %%
messages[messages['msg'] == 'nan']
# Out:
# Empty DataFrame
# Columns: [msg_line, user_id, movie_id, msg]
# Index: []

# %%
messages[messages['msg'].isna()]
# Out:
# Empty DataFrame
# Columns: [msg_line, user_id, movie_id, msg]
# Index: []

# %%
#check non-english words

# %% [markdown]
# ## Save to file

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304713 entries, 0 to 304712
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   msg_line  304713 non-null  object
#  1   user_id   304713 non-null  object
#  2   movie_id  304713 non-null  object
#  3   msg       304713 non-null  object
# dtypes: object(4)
# memory usage: 9.3+ MB

# %%
messages.describe()
# Out:
#        msg_line user_id movie_id     msg
# count    304713  304713   304713  304713
# unique   304713    9035      659  265277
# top     L362967   u4525     m289   What?
# freq          1     537     1530    1679

# %%
messages.to_csv('./chatdata/movie_lines_normalized.tsv', index=False, sep='\t', header=False)
